# %% [markdown]
# ## learning-AI : deep learning application (61357002)
# ### PT : MNIST GAN
#
# **MNIST 데이터셋을 이용하여 GAN 실습**
#
# <br>
#
# - **임규연 (lky473736)**
# - 2024.10.30.에 문서 작성
# - **Reference**
#     - https://github.com/shinyflight/Simple-GAN-TensorFlow-2.0/blob/master/GAN.py
#     - https://ddongwon.tistory.com/124
#     - https://colab.research.google.com/drive/12CqGv89Z14jXR5RHLFI9XAEXQ4YhlK5R?source=post_page-----a073a5425ef2--------------------------------#scrollTo=a891995d-3de8-45a7-b88c-4a24a65a4547
#
#
# ## <span id='dl'><mark>DL</mark></span>
#
# MNIST dataset을 이용하여 적대적 생성 신경망인 **GAN : Generative Adversarial Networks을 실습**해본다. GAN은 두 개의 신경망, 즉 **생성기(Generator)와 판별기(Discriminator)로 구성**되어 있다. 생성기는 랜덤 노이즈(z)를 입력으로 받아 가짜 이미지를 생성하는 역할을 하며, 그 목표는 판별기를 속일 수 있는 진짜 같은 이미지를 만들어내는 것이다. 반면, 판별기는 진짜 이미지와 생성기가 만든 가짜 이미지를 입력받아 이들이 진짜인지 가짜인지 구별하는 역할을 하며, 진짜와 가짜 이미지를 정확히 분류하는 것이 목표이다.

# %%
import pandas as pd
from sklearn.model_selection import StratifiedShuffleSplit
from scipy.stats import skew
import os
import csv
import matplotlib.pyplot as plt
import seaborn as sns
import tensorflow as tf
from tensorflow import keras
import numpy as np
import scipy
from tqdm import tqdm
# Out:
# 2024-10-30 15:14:40.646130: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.

# %%
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import layers

# cnn model vary kernel size
from numpy import mean
from numpy import std
from numpy import dstack
from pandas import read_csv
from matplotlib import pyplot
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense
from tensorflow.keras.layers import Flatten
from tensorflow.keras.layers import Dropout
from keras.utils import to_categorical

import tensorflow.keras
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Dropout, Flatten, Reshape, LSTM, Conv1D, MaxPooling1D
from tensorflow.keras.layers import TimeDistributed, Conv1D, MaxPooling1D

# %%
import tensorflow as tf
from tensorflow.keras.layers import Dense, LeakyReLU, Reshape, Flatten
from tensorflow.keras.datasets import mnist
import numpy as np
import matplotlib.pyplot as plt

# %%
import numpy as np
import matplotlib.pyplot as plt
from keras.datasets import mnist
from keras.models import Sequential
from keras.layers import Dense, Reshape, Flatten, Dropout
from keras.layers import BatchNormalization
from keras.optimizers import Adam

# %% [markdown]
# -----

# %% [markdown]
# ### GAN
#
# <img src="https://media.licdn.com/dms/image/D5612AQHkJCQXbWOMaQ/article-cover_image-shrink_600_2000/0/1682400466378?e=2147483647&v=beta&t=x7lcQ2xx6gWaS0HPnftVbspyA8fTQXivsEf5_q9gAig" width="500px">
#
# GAN의 작동 순서는 Generator가 랜덤 노이즈를 입력받아 가짜 이미지를 생성하고, 이를 Discriminator에 전달하여 진짜와 가짜를 구분하는 방식으로 동작한다. Discriminator는 실제 이미지와 생성된 가짜 이미지를 입력받아 이진 분류를 수행하며, 이 과정에서 두 네트워크가 서로 경쟁하며 발전하는 구조이다.
#
# Generator는 기본적으로 Decoder 구조와 유사한 형태를 가지는데, 저차원의 랜덤 노이즈를 입력받아 Dense layer를 통해 특징을 확장하고 upsampling 과정을 거쳐 고차원의 이미지를 생성한다. 이 과정에서 tf.keras.layers의 Dense, Conv2DTranspose, BatchNormalization, LeakyReLU가 주로 사용되며, 마지막 출력층에는 Tanh 활성화 함수를 적용한다.
#
# Discriminator는 Encoder 구조와 유사하게 구성되며, 고차원의 이미지를 입력받아 Conv2D layer를 통해 특징을 추출하고 점차 차원을 축소하여 최종적으로 이진 분류를 수행한다. tf.keras.layers의 Conv2D, BatchNormalization, LeakyReLU, Dropout이 주로 사용되며, 마지막 층에는 Dense layer와 Sigmoid 활성화 함수를 통해 진짜/가짜 확률을 출력한다. 이러한 구조는 기본적인 Autoencoder에서 Encoder 부분과 유사한 형태를 보이지만, 목적함수와 학습 방식에서 차이가 있다.
#
# 여기서는 **Dense layer (full connected layer)만을 이용하여 구성한다. 추후 CGAN, DCGAN을 다른 노트북 파일에서 작업한다.**

# %%
# 데이터셋 로드
(X_train, _), (_, _) = mnist.load_data()
X_train = X_train / 255.0  # 정규화
X_train = np.expand_dims(X_train, axis=-1)  # 차원 추가
# X_train의 형태: (60000, 28, 28, 1)

# %%
# 하이퍼파라미터
latent_dim = 100  # 잠재 공간 차원
epochs = 1000
batch_size = 128

# %%
# 생성자 모델
def build_generator():
    model = Sequential()
    model.add(Dense(256, input_dim=latent_dim))
    model.add(BatchNormalization())
    model.add(Dense(512))
    model.add(BatchNormalization())
    model.add(Dense(1024))
    model.add(BatchNormalization())
    model.add(Dense(28 * 28, activation='tanh'))
    model.add(Reshape((28, 28, 1)))
    return model

# %%
# 판별자 모델
def build_discriminator():
    model = Sequential()
    model.add(Flatten(input_shape=(28, 28, 1)))
    model.add(Dense(512))
    model.add(Dropout(0.3))
    model.add(Dense(256))
    model.add(Dropout(0.3))
    model.add(Dense(1, activation='sigmoid'))
    return model

# %%
generator = build_generator()
discriminator = build_discriminator()

discriminator.compile(loss='binary_crossentropy', optimizer=Adam(), metrics=['accuracy'])
# Out:
# /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/keras/src/layers/core/dense.py:87: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/keras/src/layers/reshaping/flatten.py:37: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)

# %%
# GAN 모델 설정
discriminator.trainable = False
gan_input = Sequential()
gan_input.add(generator)
gan_input.add(discriminator)
gan_input.compile(loss='binary_crossentropy', optimizer=Adam())

# %%
# 이미지 저장 및 실시간 표시 함수
def save_and_show_generated_images(epoch):
    noise = np.random.normal(0, 1, size=[10, latent_dim])
    generated_images = generator.predict(noise)
    generated_images = generated_images.reshape(10, 28, 28)

    # 이미지를 저장
    plt.figure(figsize=(10, 1))
    for i in range(10):
        plt.subplot(1, 10, i + 1)
        plt.imshow(generated_images[i], interpolation='nearest', cmap='gray')
        plt.axis('off')

    # 현재 에폭 표시
    plt.suptitle(f'Epoch: {epoch + 1}', fontsize=16)
    plt.savefig(f'gan_generated_epoch_{epoch}.png')
    plt.close()

    # 실시간으로 이미지 보여주기
    plt.figure(figsize=(10, 1))
    for i in range(10):
        plt.subplot(1, 10, i + 1)
        plt.imshow(generated_images[i], interpolation='nearest', cmap='gray')
        plt.axis('off')

    # 현재 에폭 표시
    plt.suptitle(f'Epoch: {epoch + 1}', fontsize=16)
    plt.show()
    plt.pause(0.001)  # 잠깐 대기하여 이미지 업데이트
    print(f'Epoch: {epoch + 1}/{epochs}, D Loss: {d_loss[0]}, G Loss: {g_loss}')

# %%
# GAN 학습 루프
for epoch in range(epochs):
    # 진짜 이미지와 가짜 이미지 생성
    idx = np.random.randint(0, X_train.shape[0], batch_size)
    real_images = X_train[idx]

    noise = np.random.normal(0, 1, size=[batch_size, latent_dim])
    generated_images = generator.predict(noise)

    # 가짜 이미지의 형태를 맞추기
    generated_images = np.expand_dims(generated_images, axis=-1)  # 형태: (batch_size, 28, 28, 1)

    # 판별자 학습
    real_labels = np.ones((batch_size, 1))
    fake_labels = np.zeros((batch_size, 1))

    d_loss_real = discriminator.train_on_batch(real_images, real_labels)
    d_loss_fake = discriminator.train_on_batch(generated_images, fake_labels)
    d_loss = 0.5 * np.add(d_loss_real, d_loss_fake)

    # 생성자 학습
    noise = np.random.normal(0, 1, size=[batch_size, latent_dim])
    g_loss = gan_input.train_on_batch(noise, real_labels)

    # 50 에폭마다 이미지 저장 및 실시간 표시
    if epoch % 50 == 0:
        save_and_show_generated_images(epoch)
    
    # 현재 에폭과 손실 출력
    print(f'Epoch: {epoch + 1}/{epochs}, D Loss: {d_loss[0]}, G Loss: {g_loss}')
# Out:
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/keras/src/backend/tensorflow/trainer.py:75: UserWarning: The model does not have any trainable weights.
#   warnings.warn("The model does not have any trainable weights.")
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 73ms/step
# Epoch: 1/1000, D Loss: 0.7627930641174316, G Loss: [array(0.8054795, dtype=float32), array(0.8054795, dtype=float32), array(0.484375, dtype=float32)]
# Epoch: 1/1000, D Loss: 0.7627930641174316, G Loss: [array(0.8054795, dtype=float32), array(0.8054795, dtype=float32), array(0.484375, dtype=float32)]
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# WARNING:tensorflow:5 out of the last 5 calls to <function TensorFlowTrainer.make_train_function.<locals>.one_step_on_iterator at 0x130425620> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has reduce_retracing=True option that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# WARNING:tensorflow:6 out of the last 6 calls to <function TensorFlowTrainer.make_train_function.<locals>.one_step_on_iterator at 0x130518360> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has reduce_retracing=True option that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# Epoch: 2/1000, D Loss: 0.7949626445770264, G Loss: [array(0.81456244, dtype=float32), array(0.81456244, dtype=float32), array(0.5097656, dtype=float32)]
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# Epoch: 3/1000, D Loss: 0.8194802403450012, G Loss: [array(0.8390713, dtype=float32), array(0.8390713, dtype=float32), array(0.5026042, dtype=float32)]
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# Epoch: 4/1000, D Loss: 0.8324862718582153, G Loss: [array(0.8461931, dtype=float32), array(0.8461931, dtype=float32), array(0.49804688, dtype=float32)]
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# Epoch: 5/1000, D Loss: 0.8407070636749268, G Loss: [array(0.8574438, dtype=float32), array(0.8574438, dtype=float32), array(0.49765626, dtype=float32)]
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# Epoch: 6/1000, D Loss: 0.8535122871398926, G Loss: [array(0.8654442, dtype=float32), array(0.8654442, dtype=float32), array(0.50130206, dtype=float32)]
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# Epoch: 7/1000, D Loss: 0.8687865734100342, G Loss: [array(0.8851419, dtype=float32), array(0.8851419, dtype=float32), array(0.49609375, dtype=float32)]
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# Epoch: 8/1000, D Loss: 0.8798097372055054, G Loss: [array(0.88699126, dtype=float32), array(0.88699126, dtype=float32), array(0.4951172, dtype=float32)]
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# Epoch: 9/1000, D Loss: 0.8822647333145142, G Loss: [array(0.88791776, dtype=float32), array(0.88791776, dtype=float32), array(0.4969618, dtype=float32)]
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# Epoch: 10/1000, D Loss: 0.8894286155700684, G Loss: [array(0.8974515, dtype=float32), array(0.8974515, dtype=float32), array(0.48867187, dtype=float32)]
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# Epoch: 11/1000, D Loss: 0.8989661335945129, G Loss: [array(0.90557903, dtype=float32), array(0.90557903, dtype=float32), array(0.47975853, dtype=float32)]
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# Epoch: 12/1000, D Loss: 0.9045990109443665, G Loss: [array(0.91202146, dtype=float32), array(0.91202146, dtype=float32), array(0.47851562, dtype=float32)]
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# Epoch: 13/1000, D Loss: 0.912200927734375, G Loss: [array(0.91858953, dtype=float32), array(0.91858953, dtype=float32), array(0.4750601, dtype=float32)]
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# Epoch: 14/1000, D Loss: 0.9175324440002441, G Loss: [array(0.9236078, dtype=float32), array(0.9236078, dtype=float32), array(0.47405133, dtype=float32)]
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# Epoch: 15/1000, D Loss: 0.9202265739440918, G Loss: [array(0.92451155, dtype=float32), array(0.92451155, dtype=float32), array(0.47369793, dtype=float32)]
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# Epoch: 16/1000, D Loss: 0.9241262674331665, G Loss: [array(0.9297458, dtype=float32), array(0.9297458, dtype=float32), array(0.47265625, dtype=float32)]
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# Epoch: 17/1000, D Loss: 0.9300786852836609, G Loss: [array(0.93656063, dtype=float32), array(0.93656063, dtype=float32), array(0.4698989, dtype=float32)]
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# Epoch: 18/1000, D Loss: 0.9362090826034546, G Loss: [array(0.94290364, dtype=float32), array(0.94290364, dtype=float32), array(0.46896702, dtype=float32)]
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# Epoch: 19/1000, D Loss: 0.9415181875228882, G Loss: [array(0.9452751, dtype=float32), array(0.9452751, dtype=float32), array(0.46731085, dtype=float32)]
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# Epoch: 20/1000, D Loss: 0.9441626071929932, G Loss: [array(0.9491612, dtype=float32), array(0.9491612, dtype=float32), array(0.4671875, dtype=float32)]
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# Epoch: 21/1000, D Loss: 0.9469425082206726, G Loss: [array(0.9507039, dtype=float32), array(0.9507039, dtype=float32), array(0.46707588, dtype=float32)]
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# Epoch: 22/1000, D Loss: 0.9526501297950745, G Loss: [array(0.95846784, dtype=float32), array(0.95846784, dtype=float32), array(0.4659091, dtype=float32)]
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# Epoch: 23/1000, D Loss: 0.9580094218254089, G Loss: [array(0.96267235, dtype=float32), array(0.96267235, dtype=float32), array(0.46450406, dtype=float32)]
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# Epoch: 24/1000, D Loss: 0.9650348424911499, G Loss: [array(0.9725707, dtype=float32), array(0.9725707, dtype=float32), array(0.4620768, dtype=float32)]
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# Epoch: 25/1000, D Loss: 0.9725062847137451, G Loss: [array(0.9785398, dtype=float32), array(0.9785398, dtype=float32), array(0.46171874, dtype=float32)]
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# Epoch: 26/1000, D Loss: 0.9806597232818604, G Loss: [array(0.9871744, dtype=float32), array(0.9871744, dtype=float32), array(0.4586839, dtype=float32)]
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# Epoch: 27/1000, D Loss: 0.9878177046775818, G Loss: [array(0.9933785, dtype=float32), array(0.9933785, dtype=float32), array(0.458478, dtype=float32)]
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# Epoch: 28/1000, D Loss: 0.9944301247596741, G Loss: [array(0.9998742, dtype=float32), array(0.9998742, dtype=float32), array(0.45563617, dtype=float32)]
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# Epoch: 29/1000, D Loss: 1.0009896755218506, G Loss: [array(1.0075761, dtype=float32), array(1.0075761, dtype=float32), array(0.45554957, dtype=float32)]
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# Epoch: 30/1000, D Loss: 1.0075230598449707, G Loss: [array(1.0135633, dtype=float32), array(1.0135633, dtype=float32), array(0.45416668, dtype=float32)]
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# Epoch: 31/1000, D Loss: 1.0150551795959473, G Loss: [array(1.019738, dtype=float32), array(1.019738, dtype=float32), array(0.45123488, dtype=float32)]
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# Epoch: 32/1000, D Loss: 1.0215086936950684, G Loss: [array(1.0289955, dtype=float32), array(1.0289955, dtype=float32), array(0.44970703, dtype=float32)]
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# Epoch: 33/1000, D Loss: 1.0312174558639526, G Loss: [array(1.0373504, dtype=float32), array(1.0373504, dtype=float32), array(0.4466146, dtype=float32)]
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# Epoch: 34/1000, D Loss: 1.0383305549621582, G Loss: [array(1.0443912, dtype=float32), array(1.0443912, dtype=float32), array(0.4453125, dtype=float32)]
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# Epoch: 35/1000, D Loss: 1.0448951721191406, G Loss: [array(1.0507486, dtype=float32), array(1.0507486, dtype=float32), array(0.4453125, dtype=float32)]
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# Epoch: 36/1000, D Loss: 1.052024483680725, G Loss: [array(1.0583358, dtype=float32), array(1.0583358, dtype=float32), array(0.4440104, dtype=float32)]
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# Epoch: 37/1000, D Loss: 1.0604912042617798, G Loss: [array(1.0670551, dtype=float32), array(1.0670551, dtype=float32), array(0.4416174, dtype=float32)]
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# Epoch: 38/1000, D Loss: 1.0728857517242432, G Loss: [array(1.0820233, dtype=float32), array(1.0820233, dtype=float32), array(0.4376028, dtype=float32)]
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# Epoch: 39/1000, D Loss: 1.0846035480499268, G Loss: [array(1.0914786, dtype=float32), array(1.0914786, dtype=float32), array(0.43479568, dtype=float32)]
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# Epoch: 40/1000, D Loss: 1.0938875675201416, G Loss: [array(1.1012409, dtype=float32), array(1.1012409, dtype=float32), array(0.43271485, dtype=float32)]
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# Epoch: 41/1000, D Loss: 1.104623794555664, G Loss: [array(1.1130186, dtype=float32), array(1.1130186, dtype=float32), array(0.43064025, dtype=float32)]
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# Epoch: 42/1000, D Loss: 1.116187334060669, G Loss: [array(1.1234773, dtype=float32), array(1.1234773, dtype=float32), array(0.4278274, dtype=float32)]
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# Epoch: 43/1000, D Loss: 1.1274290084838867, G Loss: [array(1.1358737, dtype=float32), array(1.1358737, dtype=float32), array(0.4255087, dtype=float32)]
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# Epoch: 44/1000, D Loss: 1.1381169557571411, G Loss: [array(1.1453571, dtype=float32), array(1.1453571, dtype=float32), array(0.4239169, dtype=float32)]
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# Epoch: 45/1000, D Loss: 1.1493988037109375, G Loss: [array(1.1578602, dtype=float32), array(1.1578602, dtype=float32), array(0.42152777, dtype=float32)]
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# Epoch: 46/1000, D Loss: 1.16215181350708, G Loss: [array(1.1712697, dtype=float32), array(1.1712697, dtype=float32), array(0.41873303, dtype=float32)]
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# Epoch: 47/1000, D Loss: 1.175358772277832, G Loss: [array(1.1842027, dtype=float32), array(1.1842027, dtype=float32), array(0.41663897, dtype=float32)]
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# Epoch: 48/1000, D Loss: 1.18778657913208, G Loss: [array(1.1964158, dtype=float32), array(1.1964158, dtype=float32), array(0.41389975, dtype=float32)]
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# Epoch: 49/1000, D Loss: 1.200547456741333, G Loss: [array(1.2096099, dtype=float32), array(1.2096099, dtype=float32), array(0.41151148, dtype=float32)]
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# Epoch: 50/1000, D Loss: 1.2152822017669678, G Loss: [array(1.2259891, dtype=float32), array(1.2259891, dtype=float32), array(0.4086719, dtype=float32)]
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# Epoch: 51/1000, D Loss: 1.228785753250122, G Loss: [array(1.2370833, dtype=float32), array(1.2370833, dtype=float32), array(0.40732232, dtype=float32)]
# Epoch: 51/1000, D Loss: 1.228785753250122, G Loss: [array(1.2370833, dtype=float32), array(1.2370833, dtype=float32), array(0.40732232, dtype=float32)]
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# Epoch: 52/1000, D Loss: 1.2424782514572144, G Loss: [array(1.2528751, dtype=float32), array(1.2528751, dtype=float32), array(0.40489784, dtype=float32)]
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# Epoch: 53/1000, D Loss: 1.2573440074920654, G Loss: [array(1.2669832, dtype=float32), array(1.2669832, dtype=float32), array(0.4030071, dtype=float32)]
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# Epoch: 54/1000, D Loss: 1.2726129293441772, G Loss: [array(1.2826688, dtype=float32), array(1.2826688, dtype=float32), array(0.4007523, dtype=float32)]
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# Epoch: 55/1000, D Loss: 1.2871580123901367, G Loss: [array(1.296588, dtype=float32), array(1.296588, dtype=float32), array(0.3990767, dtype=float32)]
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# Epoch: 56/1000, D Loss: 1.3018758296966553, G Loss: [array(1.3119615, dtype=float32), array(1.3119615, dtype=float32), array(0.39711216, dtype=float32)]
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# Epoch: 57/1000, D Loss: 1.3180776834487915, G Loss: [array(1.3287416, dtype=float32), array(1.3287416, dtype=float32), array(0.39487392, dtype=float32)]
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# Epoch: 58/1000, D Loss: 1.3335304260253906, G Loss: [array(1.3435464, dtype=float32), array(1.3435464, dtype=float32), array(0.39271283, dtype=float32)]
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# Epoch: 59/1000, D Loss: 1.3473594188690186, G Loss: [array(1.3564054, dtype=float32), array(1.3564054, dtype=float32), array(0.39135328, dtype=float32)]
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# Epoch: 60/1000, D Loss: 1.3629395961761475, G Loss: [array(1.3752563, dtype=float32), array(1.3752563, dtype=float32), array(0.39016926, dtype=float32)]
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# Epoch: 61/1000, D Loss: 1.3816015720367432, G Loss: [array(1.3932878, dtype=float32), array(1.3932878, dtype=float32), array(0.38863987, dtype=float32)]
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# Epoch: 62/1000, D Loss: 1.3998557329177856, G Loss: [array(1.4114426, dtype=float32), array(1.4114426, dtype=float32), array(0.38627774, dtype=float32)]
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# Epoch: 63/1000, D Loss: 1.4172091484069824, G Loss: [array(1.4285583, dtype=float32), array(1.4285583, dtype=float32), array(0.38485864, dtype=float32)]
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# Epoch: 64/1000, D Loss: 1.434731364250183, G Loss: [array(1.4463763, dtype=float32), array(1.4463763, dtype=float32), array(0.38305664, dtype=float32)]
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# Epoch: 65/1000, D Loss: 1.4533228874206543, G Loss: [array(1.4660308, dtype=float32), array(1.4660308, dtype=float32), array(0.3815505, dtype=float32)]
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# Epoch: 66/1000, D Loss: 1.4732334613800049, G Loss: [array(1.4858782, dtype=float32), array(1.4858782, dtype=float32), array(0.37961647, dtype=float32)]
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# Epoch: 67/1000, D Loss: 1.4927366971969604, G Loss: [array(1.5052094, dtype=float32), array(1.5052094, dtype=float32), array(0.37826493, dtype=float32)]
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# Epoch: 68/1000, D Loss: 1.5109955072402954, G Loss: [array(1.5225918, dtype=float32), array(1.5225918, dtype=float32), array(0.37701058, dtype=float32)]
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# Epoch: 69/1000, D Loss: 1.5300917625427246, G Loss: [array(1.5434966, dtype=float32), array(1.5434966, dtype=float32), array(0.3754529, dtype=float32)]
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# Epoch: 70/1000, D Loss: 1.5491909980773926, G Loss: [array(1.5613436, dtype=float32), array(1.5613436, dtype=float32), array(0.3748326, dtype=float32)]
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# Epoch: 71/1000, D Loss: 1.5681602954864502, G Loss: [array(1.5805721, dtype=float32), array(1.5805721, dtype=float32), array(0.37296435, dtype=float32)]
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# Epoch: 72/1000, D Loss: 1.587203025817871, G Loss: [array(1.5995679, dtype=float32), array(1.5995679, dtype=float32), array(0.3715278, dtype=float32)]
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# Epoch: 73/1000, D Loss: 1.6062767505645752, G Loss: [array(1.6188704, dtype=float32), array(1.6188704, dtype=float32), array(0.37007704, dtype=float32)]
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# Epoch: 74/1000, D Loss: 1.626389980316162, G Loss: [array(1.6402767, dtype=float32), array(1.6402767, dtype=float32), array(0.3691934, dtype=float32)]
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# Epoch: 75/1000, D Loss: 1.646965742111206, G Loss: [array(1.6597651, dtype=float32), array(1.6597651, dtype=float32), array(0.36760417, dtype=float32)]
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# Epoch: 76/1000, D Loss: 1.667708396911621, G Loss: [array(1.6817918, dtype=float32), array(1.6817918, dtype=float32), array(0.36610815, dtype=float32)]
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# Epoch: 77/1000, D Loss: 1.6881940364837646, G Loss: [array(1.700855, dtype=float32), array(1.700855, dtype=float32), array(0.36495537, dtype=float32)]
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# Epoch: 78/1000, D Loss: 1.7077159881591797, G Loss: [array(1.7211599, dtype=float32), array(1.7211599, dtype=float32), array(0.36408255, dtype=float32)]
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# Epoch: 79/1000, D Loss: 1.7278313636779785, G Loss: [array(1.7411561, dtype=float32), array(1.7411561, dtype=float32), array(0.36298457, dtype=float32)]
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# Epoch: 80/1000, D Loss: 1.7478249073028564, G Loss: [array(1.7610395, dtype=float32), array(1.7610395, dtype=float32), array(0.36186522, dtype=float32)]
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# Epoch: 81/1000, D Loss: 1.767909049987793, G Loss: [array(1.7813131, dtype=float32), array(1.7813131, dtype=float32), array(0.36101466, dtype=float32)]
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# Epoch: 82/1000, D Loss: 1.78810715675354, G Loss: [array(1.8014702, dtype=float32), array(1.8014702, dtype=float32), array(0.359899, dtype=float32)]
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# Epoch: 83/1000, D Loss: 1.8084111213684082, G Loss: [array(1.8216895, dtype=float32), array(1.8216895, dtype=float32), array(0.3584808, dtype=float32)]
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# Epoch: 84/1000, D Loss: 1.8280131816864014, G Loss: [array(1.8412094, dtype=float32), array(1.8412094, dtype=float32), array(0.35770088, dtype=float32)]
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# Epoch: 85/1000, D Loss: 1.8480761051177979, G Loss: [array(1.8614328, dtype=float32), array(1.8614328, dtype=float32), array(0.35652575, dtype=float32)]
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# Epoch: 86/1000, D Loss: 1.8677071332931519, G Loss: [array(1.8807827, dtype=float32), array(1.8807827, dtype=float32), array(0.35542333, dtype=float32)]
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# Epoch: 87/1000, D Loss: 1.886838674545288, G Loss: [array(1.8996571, dtype=float32), array(1.8996571, dtype=float32), array(0.35452586, dtype=float32)]
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# Epoch: 88/1000, D Loss: 1.9063948392868042, G Loss: [array(1.9201392, dtype=float32), array(1.9201392, dtype=float32), array(0.35391513, dtype=float32)]
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# Epoch: 89/1000, D Loss: 1.9264459609985352, G Loss: [array(1.9395303, dtype=float32), array(1.9395303, dtype=float32), array(0.35283533, dtype=float32)]
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# Epoch: 90/1000, D Loss: 1.9447991847991943, G Loss: [array(1.9570835, dtype=float32), array(1.9570835, dtype=float32), array(0.35238716, dtype=float32)]
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# Epoch: 91/1000, D Loss: 1.9635169506072998, G Loss: [array(1.977186, dtype=float32), array(1.977186, dtype=float32), array(0.35194883, dtype=float32)]
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# Epoch: 92/1000, D Loss: 1.9826416969299316, G Loss: [array(1.9949176, dtype=float32), array(1.9949176, dtype=float32), array(0.35096806, dtype=float32)]
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# Epoch: 93/1000, D Loss: 2.0021657943725586, G Loss: [array(2.0162873, dtype=float32), array(2.0162873, dtype=float32), array(0.3500504, dtype=float32)]
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# Epoch: 94/1000, D Loss: 2.024477958679199, G Loss: [array(2.0395956, dtype=float32), array(2.0395956, dtype=float32), array(0.34898603, dtype=float32)]
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# Epoch: 95/1000, D Loss: 2.0448689460754395, G Loss: [array(2.0569706, dtype=float32), array(2.0569706, dtype=float32), array(0.34814966, dtype=float32)]
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# Epoch: 96/1000, D Loss: 2.0627286434173584, G Loss: [array(2.075559, dtype=float32), array(2.075559, dtype=float32), array(0.34724936, dtype=float32)]
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step
# Epoch: 97/1000, D Loss: 2.0810980796813965, G Loss: [array(2.0940018, dtype=float32), array(2.0940018, dtype=float32), array(0.3468911, dtype=float32)]
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# Epoch: 98/1000, D Loss: 2.099348545074463, G Loss: [array(2.111934, dtype=float32), array(2.111934, dtype=float32), array(0.3463409, dtype=float32)]
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step
# Epoch: 99/1000, D Loss: 2.117978096008301, G Loss: [array(2.1311274, dtype=float32), array(2.1311274, dtype=float32), array(0.3457623, dtype=float32)]
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# Epoch: 100/1000, D Loss: 2.136151075363159, G Loss: [array(2.1481626, dtype=float32), array(2.1481626, dtype=float32), array(0.34511718, dtype=float32)]
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# Epoch: 101/1000, D Loss: 2.1538796424865723, G Loss: [array(2.166897, dtype=float32), array(2.166897, dtype=float32), array(0.34463954, dtype=float32)]
# Epoch: 101/1000, D Loss: 2.1538796424865723, G Loss: [array(2.166897, dtype=float32), array(2.166897, dtype=float32), array(0.34463954, dtype=float32)]
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# Epoch: 102/1000, D Loss: 2.172532320022583, G Loss: [array(2.1854155, dtype=float32), array(2.1854155, dtype=float32), array(0.34401807, dtype=float32)]
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step
# Epoch: 103/1000, D Loss: 2.190770149230957, G Loss: [array(2.2034676, dtype=float32), array(2.2034676, dtype=float32), array(0.34356037, dtype=float32)]
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# Epoch: 104/1000, D Loss: 2.208871364593506, G Loss: [array(2.2215247, dtype=float32), array(2.2215247, dtype=float32), array(0.3429988, dtype=float32)]
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# Epoch: 105/1000, D Loss: 2.227858543395996, G Loss: [array(2.2414463, dtype=float32), array(2.2414463, dtype=float32), array(0.34248513, dtype=float32)]
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# Epoch: 106/1000, D Loss: 2.2468104362487793, G Loss: [array(2.2595878, dtype=float32), array(2.2595878, dtype=float32), array(0.34201798, dtype=float32)]
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# Epoch: 107/1000, D Loss: 2.2655582427978516, G Loss: [array(2.2786489, dtype=float32), array(2.2786489, dtype=float32), array(0.34141356, dtype=float32)]
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# Epoch: 108/1000, D Loss: 2.283350944519043, G Loss: [array(2.2953866, dtype=float32), array(2.2953866, dtype=float32), array(0.34100115, dtype=float32)]
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# Epoch: 109/1000, D Loss: 2.300034999847412, G Loss: [array(2.311836, dtype=float32), array(2.311836, dtype=float32), array(0.34030962, dtype=float32)]
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# Epoch: 110/1000, D Loss: 2.3163905143737793, G Loss: [array(2.3286035, dtype=float32), array(2.3286035, dtype=float32), array(0.3400568, dtype=float32)]
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# Epoch: 111/1000, D Loss: 2.3342556953430176, G Loss: [array(2.347012, dtype=float32), array(2.347012, dtype=float32), array(0.3392807, dtype=float32)]
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# Epoch: 112/1000, D Loss: 2.352372646331787, G Loss: [array(2.3646474, dtype=float32), array(2.3646474, dtype=float32), array(0.33848354, dtype=float32)]
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# Epoch: 113/1000, D Loss: 2.369596481323242, G Loss: [array(2.3816938, dtype=float32), array(2.3816938, dtype=float32), array(0.33776963, dtype=float32)]
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# Epoch: 114/1000, D Loss: 2.3862545490264893, G Loss: [array(2.398128, dtype=float32), array(2.398128, dtype=float32), array(0.33737665, dtype=float32)]
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# Epoch: 115/1000, D Loss: 2.40255069732666, G Loss: [array(2.4144197, dtype=float32), array(2.4144197, dtype=float32), array(0.33699048, dtype=float32)]
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# Epoch: 116/1000, D Loss: 2.4183530807495117, G Loss: [array(2.429872, dtype=float32), array(2.429872, dtype=float32), array(0.33677936, dtype=float32)]
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# Epoch: 117/1000, D Loss: 2.4346678256988525, G Loss: [array(2.4468267, dtype=float32), array(2.4468267, dtype=float32), array(0.3362046, dtype=float32)]
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# Epoch: 118/1000, D Loss: 2.4509775638580322, G Loss: [array(2.4623554, dtype=float32), array(2.4623554, dtype=float32), array(0.33554026, dtype=float32)]
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# Epoch: 119/1000, D Loss: 2.466750383377075, G Loss: [array(2.4783797, dtype=float32), array(2.4783797, dtype=float32), array(0.33469012, dtype=float32)]
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# Epoch: 120/1000, D Loss: 2.482701301574707, G Loss: [array(2.4943805, dtype=float32), array(2.4943805, dtype=float32), array(0.334375, dtype=float32)]
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# Epoch: 121/1000, D Loss: 2.4983279705047607, G Loss: [array(2.5096993, dtype=float32), array(2.5096993, dtype=float32), array(0.33377454, dtype=float32)]
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# Epoch: 122/1000, D Loss: 2.5143229961395264, G Loss: [array(2.526391, dtype=float32), array(2.526391, dtype=float32), array(0.33356813, dtype=float32)]
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# Epoch: 123/1000, D Loss: 2.5307834148406982, G Loss: [array(2.5425408, dtype=float32), array(2.5425408, dtype=float32), array(0.3330475, dtype=float32)]
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# Epoch: 124/1000, D Loss: 2.546391487121582, G Loss: [array(2.5572786, dtype=float32), array(2.5572786, dtype=float32), array(0.33218876, dtype=float32)]
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# Epoch: 125/1000, D Loss: 2.561551332473755, G Loss: [array(2.5730698, dtype=float32), array(2.5730698, dtype=float32), array(0.3315625, dtype=float32)]
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# Epoch: 126/1000, D Loss: 2.5757498741149902, G Loss: [array(2.58589, dtype=float32), array(2.58589, dtype=float32), array(0.3311942, dtype=float32)]
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# Epoch: 127/1000, D Loss: 2.5890753269195557, G Loss: [array(2.5997295, dtype=float32), array(2.5997295, dtype=float32), array(0.33089322, dtype=float32)]
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# Epoch: 128/1000, D Loss: 2.6035287380218506, G Loss: [array(2.6146512, dtype=float32), array(2.6146512, dtype=float32), array(0.33035278, dtype=float32)]
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# Epoch: 129/1000, D Loss: 2.6181271076202393, G Loss: [array(2.6290817, dtype=float32), array(2.6290817, dtype=float32), array(0.3299116, dtype=float32)]
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# Epoch: 130/1000, D Loss: 2.632593870162964, G Loss: [array(2.6434748, dtype=float32), array(2.6434748, dtype=float32), array(0.32947716, dtype=float32)]
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step
# Epoch: 131/1000, D Loss: 2.6472294330596924, G Loss: [array(2.6582897, dtype=float32), array(2.6582897, dtype=float32), array(0.32913885, dtype=float32)]
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# Epoch: 132/1000, D Loss: 2.6616203784942627, G Loss: [array(2.6723402, dtype=float32), array(2.6723402, dtype=float32), array(0.32871684, dtype=float32)]
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# Epoch: 133/1000, D Loss: 2.6750876903533936, G Loss: [array(2.68526, dtype=float32), array(2.68526, dtype=float32), array(0.32838935, dtype=float32)]
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# Epoch: 134/1000, D Loss: 2.68803334236145, G Loss: [array(2.6983502, dtype=float32), array(2.6983502, dtype=float32), array(0.3279501, dtype=float32)]
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step
# Epoch: 135/1000, D Loss: 2.7016851902008057, G Loss: [array(2.7122672, dtype=float32), array(2.7122672, dtype=float32), array(0.32751736, dtype=float32)]
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# Epoch: 136/1000, D Loss: 2.7152578830718994, G Loss: [array(2.725675, dtype=float32), array(2.725675, dtype=float32), array(0.32714844, dtype=float32)]
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# Epoch: 137/1000, D Loss: 2.7282915115356445, G Loss: [array(2.7383692, dtype=float32), array(2.7383692, dtype=float32), array(0.3267849, dtype=float32)]
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step
# Epoch: 138/1000, D Loss: 2.7400262355804443, G Loss: [array(2.7490354, dtype=float32), array(2.7490354, dtype=float32), array(0.3263983, dtype=float32)]
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# Epoch: 139/1000, D Loss: 2.7517099380493164, G Loss: [array(2.7618847, dtype=float32), array(2.7618847, dtype=float32), array(0.32607353, dtype=float32)]
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# Epoch: 140/1000, D Loss: 2.764610528945923, G Loss: [array(2.7745018, dtype=float32), array(2.7745018, dtype=float32), array(0.32527903, dtype=float32)]
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# Epoch: 141/1000, D Loss: 2.777594566345215, G Loss: [array(2.787843, dtype=float32), array(2.787843, dtype=float32), array(0.32471743, dtype=float32)]
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# Epoch: 142/1000, D Loss: 2.790435791015625, G Loss: [array(2.8003693, dtype=float32), array(2.8003693, dtype=float32), array(0.3244113, dtype=float32)]
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# Epoch: 143/1000, D Loss: 2.802762269973755, G Loss: [array(2.8123121, dtype=float32), array(2.8123121, dtype=float32), array(0.32369974, dtype=float32)]
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# Epoch: 144/1000, D Loss: 2.8145129680633545, G Loss: [array(2.8241942, dtype=float32), array(2.8241942, dtype=float32), array(0.32359484, dtype=float32)]
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# Epoch: 145/1000, D Loss: 2.8269481658935547, G Loss: [array(2.8370082, dtype=float32), array(2.8370082, dtype=float32), array(0.32319504, dtype=float32)]
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# Epoch: 146/1000, D Loss: 2.8392417430877686, G Loss: [array(2.8486543, dtype=float32), array(2.8486543, dtype=float32), array(0.32277396, dtype=float32)]
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# Epoch: 147/1000, D Loss: 2.851168155670166, G Loss: [array(2.8609765, dtype=float32), array(2.8609765, dtype=float32), array(0.32251808, dtype=float32)]
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# Epoch: 148/1000, D Loss: 2.863313674926758, G Loss: [array(2.8727827, dtype=float32), array(2.8727827, dtype=float32), array(0.32205448, dtype=float32)]
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# Epoch: 149/1000, D Loss: 2.8748955726623535, G Loss: [array(2.884255, dtype=float32), array(2.884255, dtype=float32), array(0.32180685, dtype=float32)]
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# Epoch: 150/1000, D Loss: 2.8869528770446777, G Loss: [array(2.8968666, dtype=float32), array(2.8968666, dtype=float32), array(0.32158855, dtype=float32)]
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# Epoch: 151/1000, D Loss: 2.899374485015869, G Loss: [array(2.909085, dtype=float32), array(2.909085, dtype=float32), array(0.3211662, dtype=float32)]
# Epoch: 151/1000, D Loss: 2.899374485015869, G Loss: [array(2.909085, dtype=float32), array(2.909085, dtype=float32), array(0.3211662, dtype=float32)]
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# Epoch: 152/1000, D Loss: 2.911344528198242, G Loss: [array(2.9209692, dtype=float32), array(2.9209692, dtype=float32), array(0.3210064, dtype=float32)]
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# Epoch: 153/1000, D Loss: 2.922761917114258, G Loss: [array(2.9318576, dtype=float32), array(2.9318576, dtype=float32), array(0.32087418, dtype=float32)]
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# Epoch: 154/1000, D Loss: 2.9338531494140625, G Loss: [array(2.94304, dtype=float32), array(2.94304, dtype=float32), array(0.32056615, dtype=float32)]
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# Epoch: 155/1000, D Loss: 2.9447412490844727, G Loss: [array(2.9536195, dtype=float32), array(2.9536195, dtype=float32), array(0.32041332, dtype=float32)]
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# Epoch: 156/1000, D Loss: 2.9553236961364746, G Loss: [array(2.964204, dtype=float32), array(2.964204, dtype=float32), array(0.32016227, dtype=float32)]
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# Epoch: 157/1000, D Loss: 2.9663379192352295, G Loss: [array(2.9756558, dtype=float32), array(2.9756558, dtype=float32), array(0.3199144, dtype=float32)]
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# Epoch: 158/1000, D Loss: 2.9775853157043457, G Loss: [array(2.986668, dtype=float32), array(2.986668, dtype=float32), array(0.319645, dtype=float32)]
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# Epoch: 159/1000, D Loss: 2.988245964050293, G Loss: [array(2.9970918, dtype=float32), array(2.9970918, dtype=float32), array(0.31950176, dtype=float32)]
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# Epoch: 160/1000, D Loss: 2.9987120628356934, G Loss: [array(3.0074692, dtype=float32), array(3.0074692, dtype=float32), array(0.31926268, dtype=float32)]
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# Epoch: 161/1000, D Loss: 3.0091099739074707, G Loss: [array(3.0179188, dtype=float32), array(3.0179188, dtype=float32), array(0.3190751, dtype=float32)]
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# Epoch: 162/1000, D Loss: 3.019896984100342, G Loss: [array(3.0290773, dtype=float32), array(3.0290773, dtype=float32), array(0.3190104, dtype=float32)]
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# Epoch: 163/1000, D Loss: 3.030472755432129, G Loss: [array(3.0390508, dtype=float32), array(3.0390508, dtype=float32), array(0.31892255, dtype=float32)]
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# Epoch: 164/1000, D Loss: 3.041390895843506, G Loss: [array(3.0508482, dtype=float32), array(3.0508482, dtype=float32), array(0.31866902, dtype=float32)]
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# Epoch: 165/1000, D Loss: 3.052560567855835, G Loss: [array(3.0613651, dtype=float32), array(3.0613651, dtype=float32), array(0.31834754, dtype=float32)]
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# Epoch: 166/1000, D Loss: 3.062964916229248, G Loss: [array(3.0716562, dtype=float32), array(3.0716562, dtype=float32), array(0.31810054, dtype=float32)]
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# Epoch: 167/1000, D Loss: 3.073118209838867, G Loss: [array(3.0816562, dtype=float32), array(3.0816562, dtype=float32), array(0.31787986, dtype=float32)]
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# Epoch: 168/1000, D Loss: 3.083045244216919, G Loss: [array(3.0914195, dtype=float32), array(3.0914195, dtype=float32), array(0.31756884, dtype=float32)]
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# Epoch: 169/1000, D Loss: 3.0930423736572266, G Loss: [array(3.1018157, dtype=float32), array(3.1018157, dtype=float32), array(0.31740016, dtype=float32)]
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# Epoch: 170/1000, D Loss: 3.102972984313965, G Loss: [array(3.1109426, dtype=float32), array(3.1109426, dtype=float32), array(0.3169807, dtype=float32)]
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# Epoch: 171/1000, D Loss: 3.11203670501709, G Loss: [array(3.120253, dtype=float32), array(3.120253, dtype=float32), array(0.3169088, dtype=float32)]
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# Epoch: 172/1000, D Loss: 3.1212544441223145, G Loss: [array(3.1292686, dtype=float32), array(3.1292686, dtype=float32), array(0.3167242, dtype=float32)]
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# Epoch: 173/1000, D Loss: 3.130596876144409, G Loss: [array(3.1389434, dtype=float32), array(3.1389434, dtype=float32), array(0.3165643, dtype=float32)]
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# Epoch: 174/1000, D Loss: 3.1402511596679688, G Loss: [array(3.1485791, dtype=float32), array(3.1485791, dtype=float32), array(0.3163838, dtype=float32)]
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# Epoch: 175/1000, D Loss: 3.1499526500701904, G Loss: [array(3.1583066, dtype=float32), array(3.1583066, dtype=float32), array(0.31627232, dtype=float32)]
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# Epoch: 176/1000, D Loss: 3.15895414352417, G Loss: [array(3.1666987, dtype=float32), array(3.1666987, dtype=float32), array(0.3161843, dtype=float32)]
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# Epoch: 177/1000, D Loss: 3.1676998138427734, G Loss: [array(3.1757274, dtype=float32), array(3.1757274, dtype=float32), array(0.31618556, dtype=float32)]
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# Epoch: 178/1000, D Loss: 3.176687717437744, G Loss: [array(3.1846175, dtype=float32), array(3.1846175, dtype=float32), array(0.31603318, dtype=float32)]
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# Epoch: 179/1000, D Loss: 3.1854522228240967, G Loss: [array(3.193222, dtype=float32), array(3.193222, dtype=float32), array(0.31590432, dtype=float32)]
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# Epoch: 180/1000, D Loss: 3.193881034851074, G Loss: [array(3.2014866, dtype=float32), array(3.2014866, dtype=float32), array(0.3157118, dtype=float32)]
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# Epoch: 181/1000, D Loss: 3.2029037475585938, G Loss: [array(3.2112784, dtype=float32), array(3.2112784, dtype=float32), array(0.315543, dtype=float32)]
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# Epoch: 182/1000, D Loss: 3.212259292602539, G Loss: [array(3.2201192, dtype=float32), array(3.2201192, dtype=float32), array(0.3153331, dtype=float32)]
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# Epoch: 183/1000, D Loss: 3.221121072769165, G Loss: [array(3.2288976, dtype=float32), array(3.2288976, dtype=float32), array(0.3149334, dtype=float32)]
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# Epoch: 184/1000, D Loss: 3.2295098304748535, G Loss: [array(3.23684, dtype=float32), array(3.23684, dtype=float32), array(0.3146442, dtype=float32)]
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# Epoch: 185/1000, D Loss: 3.2375411987304688, G Loss: [array(3.2451155, dtype=float32), array(3.2451155, dtype=float32), array(0.31456926, dtype=float32)]
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# Epoch: 186/1000, D Loss: 3.2457568645477295, G Loss: [array(3.2531762, dtype=float32), array(3.2531762, dtype=float32), array(0.3143691, dtype=float32)]
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# Epoch: 187/1000, D Loss: 3.2535152435302734, G Loss: [array(3.2607527, dtype=float32), array(3.2607527, dtype=float32), array(0.31427556, dtype=float32)]
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# Epoch: 188/1000, D Loss: 3.2616119384765625, G Loss: [array(3.2693062, dtype=float32), array(3.2693062, dtype=float32), array(0.31397524, dtype=float32)]
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# Epoch: 189/1000, D Loss: 3.2698445320129395, G Loss: [array(3.2769883, dtype=float32), array(3.2769883, dtype=float32), array(0.31351274, dtype=float32)]
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# Epoch: 190/1000, D Loss: 3.278054714202881, G Loss: [array(3.2858453, dtype=float32), array(3.2858453, dtype=float32), array(0.31332237, dtype=float32)]
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# Epoch: 191/1000, D Loss: 3.2869114875793457, G Loss: [array(3.2947047, dtype=float32), array(3.2947047, dtype=float32), array(0.3130931, dtype=float32)]
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# Epoch: 192/1000, D Loss: 3.29540753364563, G Loss: [array(3.3028853, dtype=float32), array(3.3028853, dtype=float32), array(0.3129476, dtype=float32)]
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# Epoch: 193/1000, D Loss: 3.3038101196289062, G Loss: [array(3.3116012, dtype=float32), array(3.3116012, dtype=float32), array(0.31284407, dtype=float32)]
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# Epoch: 194/1000, D Loss: 3.3124570846557617, G Loss: [array(3.3199434, dtype=float32), array(3.3199434, dtype=float32), array(0.31264094, dtype=float32)]
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# Epoch: 195/1000, D Loss: 3.3206286430358887, G Loss: [array(3.328048, dtype=float32), array(3.328048, dtype=float32), array(0.31256008, dtype=float32)]
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# Epoch: 196/1000, D Loss: 3.3294665813446045, G Loss: [array(3.337503, dtype=float32), array(3.337503, dtype=float32), array(0.31234056, dtype=float32)]
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# Epoch: 197/1000, D Loss: 3.3382725715637207, G Loss: [array(3.3458793, dtype=float32), array(3.3458793, dtype=float32), array(0.31234136, dtype=float32)]
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# Epoch: 198/1000, D Loss: 3.346296787261963, G Loss: [array(3.3535054, dtype=float32), array(3.3535054, dtype=float32), array(0.31224352, dtype=float32)]
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# Epoch: 199/1000, D Loss: 3.3544163703918457, G Loss: [array(3.3620348, dtype=float32), array(3.3620348, dtype=float32), array(0.31212705, dtype=float32)]
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# Epoch: 200/1000, D Loss: 3.362595558166504, G Loss: [array(3.3698432, dtype=float32), array(3.3698432, dtype=float32), array(0.31185547, dtype=float32)]
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# Epoch: 201/1000, D Loss: 3.3702569007873535, G Loss: [array(3.37734, dtype=float32), array(3.37734, dtype=float32), array(0.31168377, dtype=float32)]
# Epoch: 201/1000, D Loss: 3.3702569007873535, G Loss: [array(3.37734, dtype=float32), array(3.37734, dtype=float32), array(0.31168377, dtype=float32)]
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# Epoch: 202/1000, D Loss: 3.378106117248535, G Loss: [array(3.3855324, dtype=float32), array(3.3855324, dtype=float32), array(0.31157178, dtype=float32)]
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# Epoch: 203/1000, D Loss: 3.3858938217163086, G Loss: [array(3.3929236, dtype=float32), array(3.3929236, dtype=float32), array(0.3114609, dtype=float32)]
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# Epoch: 204/1000, D Loss: 3.392897605895996, G Loss: [array(3.3994327, dtype=float32), array(3.3994327, dtype=float32), array(0.31146598, dtype=float32)]
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# Epoch: 205/1000, D Loss: 3.4001963138580322, G Loss: [array(3.4075737, dtype=float32), array(3.4075737, dtype=float32), array(0.31137577, dtype=float32)]
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# Epoch: 206/1000, D Loss: 3.407776355743408, G Loss: [array(3.4144788, dtype=float32), array(3.4144788, dtype=float32), array(0.3111916, dtype=float32)]
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# Epoch: 207/1000, D Loss: 3.41500186920166, G Loss: [array(3.4220023, dtype=float32), array(3.4220023, dtype=float32), array(0.31093374, dtype=float32)]
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# Epoch: 208/1000, D Loss: 3.422513008117676, G Loss: [array(3.4294393, dtype=float32), array(3.4294393, dtype=float32), array(0.31075346, dtype=float32)]
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# Epoch: 209/1000, D Loss: 3.429708480834961, G Loss: [array(3.4364817, dtype=float32), array(3.4364817, dtype=float32), array(0.3105936, dtype=float32)]
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# Epoch: 210/1000, D Loss: 3.4368934631347656, G Loss: [array(3.4438977, dtype=float32), array(3.4438977, dtype=float32), array(0.31052828, dtype=float32)]
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# Epoch: 211/1000, D Loss: 3.4445149898529053, G Loss: [array(3.451569, dtype=float32), array(3.451569, dtype=float32), array(0.31044504, dtype=float32)]
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# Epoch: 212/1000, D Loss: 3.45192551612854, G Loss: [array(3.458703, dtype=float32), array(3.458703, dtype=float32), array(0.3102705, dtype=float32)]
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# Epoch: 213/1000, D Loss: 3.458857774734497, G Loss: [array(3.465481, dtype=float32), array(3.465481, dtype=float32), array(0.3101526, dtype=float32)]
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# Epoch: 214/1000, D Loss: 3.465333938598633, G Loss: [array(3.4716432, dtype=float32), array(3.4716432, dtype=float32), array(0.30996275, dtype=float32)]
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# Epoch: 215/1000, D Loss: 3.472139835357666, G Loss: [array(3.478952, dtype=float32), array(3.478952, dtype=float32), array(0.30970204, dtype=float32)]
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# Epoch: 216/1000, D Loss: 3.479113817214966, G Loss: [array(3.4857275, dtype=float32), array(3.4857275, dtype=float32), array(0.30962455, dtype=float32)]
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# Epoch: 217/1000, D Loss: 3.4859304428100586, G Loss: [array(3.4925413, dtype=float32), array(3.4925413, dtype=float32), array(0.3094578, dtype=float32)]
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# Epoch: 218/1000, D Loss: 3.492767333984375, G Loss: [array(3.499275, dtype=float32), array(3.499275, dtype=float32), array(0.30916715, dtype=float32)]
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# Epoch: 219/1000, D Loss: 3.499469757080078, G Loss: [array(3.5059695, dtype=float32), array(3.5059695, dtype=float32), array(0.30902183, dtype=float32)]
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# Epoch: 220/1000, D Loss: 3.5063276290893555, G Loss: [array(3.5131273, dtype=float32), array(3.5131273, dtype=float32), array(0.3089666, dtype=float32)]
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# Epoch: 221/1000, D Loss: 3.5132126808166504, G Loss: [array(3.5196393, dtype=float32), array(3.5196393, dtype=float32), array(0.3087175, dtype=float32)]
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# Epoch: 222/1000, D Loss: 3.519928455352783, G Loss: [array(3.5265417, dtype=float32), array(3.5265417, dtype=float32), array(0.30854097, dtype=float32)]
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# Epoch: 223/1000, D Loss: 3.526648998260498, G Loss: [array(3.5331132, dtype=float32), array(3.5331132, dtype=float32), array(0.30847114, dtype=float32)]
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# Epoch: 224/1000, D Loss: 3.5332064628601074, G Loss: [array(3.539655, dtype=float32), array(3.539655, dtype=float32), array(0.30838448, dtype=float32)]
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# Epoch: 225/1000, D Loss: 3.540083885192871, G Loss: [array(3.546846, dtype=float32), array(3.546846, dtype=float32), array(0.30814236, dtype=float32)]
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# Epoch: 226/1000, D Loss: 3.546660900115967, G Loss: [array(3.55272, dtype=float32), array(3.55272, dtype=float32), array(0.30804065, dtype=float32)]
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step
# Epoch: 227/1000, D Loss: 3.552915573120117, G Loss: [array(3.5591972, dtype=float32), array(3.5591972, dtype=float32), array(0.30773336, dtype=float32)]
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# Epoch: 228/1000, D Loss: 3.559386968612671, G Loss: [array(3.5657823, dtype=float32), array(3.5657823, dtype=float32), array(0.3075829, dtype=float32)]
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# Epoch: 229/1000, D Loss: 3.565715789794922, G Loss: [array(3.5719736, dtype=float32), array(3.5719736, dtype=float32), array(0.30758733, dtype=float32)]
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# Epoch: 230/1000, D Loss: 3.5723934173583984, G Loss: [array(3.5790567, dtype=float32), array(3.5790567, dtype=float32), array(0.3074049, dtype=float32)]
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# Epoch: 231/1000, D Loss: 3.578878402709961, G Loss: [array(3.5849283, dtype=float32), array(3.5849283, dtype=float32), array(0.30732548, dtype=float32)]
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# Epoch: 232/1000, D Loss: 3.585073471069336, G Loss: [array(3.5913534, dtype=float32), array(3.5913534, dtype=float32), array(0.3071289, dtype=float32)]
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# Epoch: 233/1000, D Loss: 3.5913991928100586, G Loss: [array(3.5977094, dtype=float32), array(3.5977094, dtype=float32), array(0.30705136, dtype=float32)]
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# Epoch: 234/1000, D Loss: 3.5974745750427246, G Loss: [array(3.6034594, dtype=float32), array(3.6034594, dtype=float32), array(0.30707467, dtype=float32)]
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# Epoch: 235/1000, D Loss: 3.602874279022217, G Loss: [array(3.60834, dtype=float32), array(3.60834, dtype=float32), array(0.30693153, dtype=float32)]
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# Epoch: 236/1000, D Loss: 3.608523368835449, G Loss: [array(3.6148584, dtype=float32), array(3.6148584, dtype=float32), array(0.30677304, dtype=float32)]
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# Epoch: 237/1000, D Loss: 3.615255832672119, G Loss: [array(3.6217182, dtype=float32), array(3.6217182, dtype=float32), array(0.30656645, dtype=float32)]
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# Epoch: 238/1000, D Loss: 3.621824264526367, G Loss: [array(3.6280546, dtype=float32), array(3.6280546, dtype=float32), array(0.3064929, dtype=float32)]
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# ...
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# Epoch: 918/1000, D Loss: 5.090665817260742, G Loss: [array(5.0923443, dtype=float32), array(5.0923443, dtype=float32), array(0.284552, dtype=float32)]
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# Epoch: 919/1000, D Loss: 5.0916337966918945, G Loss: [array(5.0933094, dtype=float32), array(5.0933094, dtype=float32), array(0.28453568, dtype=float32)]
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# Epoch: 920/1000, D Loss: 5.092679977416992, G Loss: [array(5.094432, dtype=float32), array(5.094432, dtype=float32), array(0.2845236, dtype=float32)]
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# Epoch: 921/1000, D Loss: 5.093791484832764, G Loss: [array(5.095564, dtype=float32), array(5.095564, dtype=float32), array(0.28454974, dtype=float32)]
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# Epoch: 922/1000, D Loss: 5.09482479095459, G Loss: [array(5.0964828, dtype=float32), array(5.0964828, dtype=float32), array(0.2845716, dtype=float32)]
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# Epoch: 923/1000, D Loss: 5.095821380615234, G Loss: [array(5.0975533, dtype=float32), array(5.0975533, dtype=float32), array(0.28459337, dtype=float32)]
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# Epoch: 924/1000, D Loss: 5.0968499183654785, G Loss: [array(5.0985117, dtype=float32), array(5.0985117, dtype=float32), array(0.28457284, dtype=float32)]
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# Epoch: 925/1000, D Loss: 5.097750186920166, G Loss: [array(5.0993843, dtype=float32), array(5.0993843, dtype=float32), array(0.2845946, dtype=float32)]
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# Epoch: 926/1000, D Loss: 5.098738670349121, G Loss: [array(5.1004558, dtype=float32), array(5.1004558, dtype=float32), array(0.284591, dtype=float32)]
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# Epoch: 927/1000, D Loss: 5.099808692932129, G Loss: [array(5.1014986, dtype=float32), array(5.1014986, dtype=float32), array(0.28454104, dtype=float32)]
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# Epoch: 928/1000, D Loss: 5.100736618041992, G Loss: [array(5.1023555, dtype=float32), array(5.1023555, dtype=float32), array(0.2845375, dtype=float32)]
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# Epoch: 929/1000, D Loss: 5.101571559906006, G Loss: [array(5.103134, dtype=float32), array(5.103134, dtype=float32), array(0.2845003, dtype=float32)]
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# Epoch: 930/1000, D Loss: 5.102430820465088, G Loss: [array(5.104091, dtype=float32), array(5.104091, dtype=float32), array(0.28450942, dtype=float32)]
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# Epoch: 931/1000, D Loss: 5.1034955978393555, G Loss: [array(5.1052313, dtype=float32), array(5.1052313, dtype=float32), array(0.28445557, dtype=float32)]
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# Epoch: 932/1000, D Loss: 5.1045379638671875, G Loss: [array(5.1061554, dtype=float32), array(5.1061554, dtype=float32), array(0.2844102, dtype=float32)]
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# Epoch: 933/1000, D Loss: 5.105457305908203, G Loss: [array(5.107112, dtype=float32), array(5.107112, dtype=float32), array(0.28439426, dtype=float32)]
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# Epoch: 934/1000, D Loss: 5.106389999389648, G Loss: [array(5.108047, dtype=float32), array(5.108047, dtype=float32), array(0.28439927, dtype=float32)]
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# Epoch: 935/1000, D Loss: 5.107454299926758, G Loss: [array(5.10919, dtype=float32), array(5.10919, dtype=float32), array(0.28438336, dtype=float32)]
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# Epoch: 936/1000, D Loss: 5.108607292175293, G Loss: [array(5.1103554, dtype=float32), array(5.1103554, dtype=float32), array(0.28436333, dtype=float32)]
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# Epoch: 937/1000, D Loss: 5.109640598297119, G Loss: [array(5.1112833, dtype=float32), array(5.1112833, dtype=float32), array(0.28439334, dtype=float32)]
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# Epoch: 938/1000, D Loss: 5.110590934753418, G Loss: [array(5.112241, dtype=float32), array(5.112241, dtype=float32), array(0.2844025, dtype=float32)]
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# Epoch: 939/1000, D Loss: 5.111575126647949, G Loss: [array(5.1132474, dtype=float32), array(5.1132474, dtype=float32), array(0.28439498, dtype=float32)]
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# Epoch: 940/1000, D Loss: 5.112511157989502, G Loss: [array(5.1141367, dtype=float32), array(5.1141367, dtype=float32), array(0.28439993, dtype=float32)]
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# Epoch: 941/1000, D Loss: 5.113506317138672, G Loss: [array(5.115226, dtype=float32), array(5.115226, dtype=float32), array(0.2843966, dtype=float32)]
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# Epoch: 942/1000, D Loss: 5.114557266235352, G Loss: [array(5.1162324, dtype=float32), array(5.1162324, dtype=float32), array(0.284414, dtype=float32)]
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# Epoch: 943/1000, D Loss: 5.115506172180176, G Loss: [array(5.11709, dtype=float32), array(5.11709, dtype=float32), array(0.28437334, dtype=float32)]
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# Epoch: 944/1000, D Loss: 5.116375923156738, G Loss: [array(5.118019, dtype=float32), array(5.118019, dtype=float32), array(0.2844114, dtype=float32)]
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# Epoch: 945/1000, D Loss: 5.1172895431518555, G Loss: [array(5.1189194, dtype=float32), array(5.1189194, dtype=float32), array(0.2844246, dtype=float32)]
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# Epoch: 946/1000, D Loss: 5.118215084075928, G Loss: [array(5.1198525, dtype=float32), array(5.1198525, dtype=float32), array(0.28443778, dtype=float32)]
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# Epoch: 947/1000, D Loss: 5.119167327880859, G Loss: [array(5.1208134, dtype=float32), array(5.1208134, dtype=float32), array(0.28444263, dtype=float32)]
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# Epoch: 948/1000, D Loss: 5.12011194229126, G Loss: [array(5.121744, dtype=float32), array(5.121744, dtype=float32), array(0.28445578, dtype=float32)]
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# Epoch: 949/1000, D Loss: 5.121046543121338, G Loss: [array(5.1226826, dtype=float32), array(5.1226826, dtype=float32), array(0.28447297, dtype=float32)]
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# Epoch: 950/1000, D Loss: 5.121982574462891, G Loss: [array(5.123616, dtype=float32), array(5.123616, dtype=float32), array(0.28448603, dtype=float32)]
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# Epoch: 951/1000, D Loss: 5.122891426086426, G Loss: [array(5.1244993, dtype=float32), array(5.1244993, dtype=float32), array(0.2844703, dtype=float32)]
# Epoch: 951/1000, D Loss: 5.122891426086426, G Loss: [array(5.1244993, dtype=float32), array(5.1244993, dtype=float32), array(0.2844703, dtype=float32)]
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# Epoch: 952/1000, D Loss: 5.123778343200684, G Loss: [array(5.125384, dtype=float32), array(5.125384, dtype=float32), array(0.28446692, dtype=float32)]
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# Epoch: 953/1000, D Loss: 5.124642848968506, G Loss: [array(5.1262183, dtype=float32), array(5.1262183, dtype=float32), array(0.28443485, dtype=float32)]
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# Epoch: 954/1000, D Loss: 5.125547409057617, G Loss: [array(5.127165, dtype=float32), array(5.127165, dtype=float32), array(0.28437418, dtype=float32)]
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# Epoch: 955/1000, D Loss: 5.12648868560791, G Loss: [array(5.1281404, dtype=float32), array(5.1281404, dtype=float32), array(0.28441182, dtype=float32)]
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# Epoch: 956/1000, D Loss: 5.127492904663086, G Loss: [array(5.1291704, dtype=float32), array(5.1291704, dtype=float32), array(0.284433, dtype=float32)]
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# Epoch: 957/1000, D Loss: 5.1285176277160645, G Loss: [array(5.1301656, dtype=float32), array(5.1301656, dtype=float32), array(0.28442153, dtype=float32)]
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# Epoch: 958/1000, D Loss: 5.129438400268555, G Loss: [array(5.130999, dtype=float32), array(5.130999, dtype=float32), array(0.28440192, dtype=float32)]
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# Epoch: 959/1000, D Loss: 5.130376815795898, G Loss: [array(5.13207, dtype=float32), array(5.13207, dtype=float32), array(0.284419, dtype=float32)]
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# Epoch: 960/1000, D Loss: 5.13144588470459, G Loss: [array(5.1331143, dtype=float32), array(5.1331143, dtype=float32), array(0.28441975, dtype=float32)]
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# Epoch: 961/1000, D Loss: 5.132341384887695, G Loss: [array(5.1338735, dtype=float32), array(5.1338735, dtype=float32), array(0.28438395, dtype=float32)]
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# Epoch: 962/1000, D Loss: 5.133119583129883, G Loss: [array(5.1346483, dtype=float32), array(5.1346483, dtype=float32), array(0.28435633, dtype=float32)]
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# Epoch: 963/1000, D Loss: 5.133978843688965, G Loss: [array(5.1355896, dtype=float32), array(5.1355896, dtype=float32), array(0.28433686, dtype=float32)]
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# Epoch: 964/1000, D Loss: 5.1350507736206055, G Loss: [array(5.1367903, dtype=float32), array(5.1367903, dtype=float32), array(0.2842972, dtype=float32)]
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# Epoch: 965/1000, D Loss: 5.136041641235352, G Loss: [array(5.137569, dtype=float32), array(5.137569, dtype=float32), array(0.28429404, dtype=float32)]
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# Epoch: 966/1000, D Loss: 5.136749267578125, G Loss: [array(5.138217, dtype=float32), array(5.138217, dtype=float32), array(0.28426662, dtype=float32)]
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# Epoch: 967/1000, D Loss: 5.137526035308838, G Loss: [array(5.139115, dtype=float32), array(5.139115, dtype=float32), array(0.2842514, dtype=float32)]
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# Epoch: 968/1000, D Loss: 5.138452053070068, G Loss: [array(5.14005, dtype=float32), array(5.14005, dtype=float32), array(0.2842362, dtype=float32)]
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# Epoch: 969/1000, D Loss: 5.139330863952637, G Loss: [array(5.1409054, dtype=float32), array(5.1409054, dtype=float32), array(0.28424117, dtype=float32)]
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# Epoch: 970/1000, D Loss: 5.140303611755371, G Loss: [array(5.141965, dtype=float32), array(5.141965, dtype=float32), array(0.28422198, dtype=float32)]
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# Epoch: 971/1000, D Loss: 5.141303062438965, G Loss: [array(5.142903, dtype=float32), array(5.142903, dtype=float32), array(0.2841988, dtype=float32)]
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# Epoch: 972/1000, D Loss: 5.142162322998047, G Loss: [array(5.1437125, dtype=float32), array(5.1437125, dtype=float32), array(0.28421986, dtype=float32)]
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# Epoch: 973/1000, D Loss: 5.143139839172363, G Loss: [array(5.1448383, dtype=float32), array(5.1448383, dtype=float32), array(0.2842088, dtype=float32)]
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# Epoch: 974/1000, D Loss: 5.144157886505127, G Loss: [array(5.145765, dtype=float32), array(5.145765, dtype=float32), array(0.28424186, dtype=float32)]
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# Epoch: 975/1000, D Loss: 5.14506721496582, G Loss: [array(5.1466455, dtype=float32), array(5.1466455, dtype=float32), array(0.28420672, dtype=float32)]
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# Epoch: 976/1000, D Loss: 5.145847797393799, G Loss: [array(5.1473417, dtype=float32), array(5.1473417, dtype=float32), array(0.2842237, dtype=float32)]
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# Epoch: 977/1000, D Loss: 5.146641731262207, G Loss: [array(5.148234, dtype=float32), array(5.148234, dtype=float32), array(0.28425667, dtype=float32)]
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# Epoch: 978/1000, D Loss: 5.14755916595459, G Loss: [array(5.1491356, dtype=float32), array(5.1491356, dtype=float32), array(0.2842376, dtype=float32)]
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# Epoch: 979/1000, D Loss: 5.148549556732178, G Loss: [array(5.1502156, dtype=float32), array(5.1502156, dtype=float32), array(0.28424254, dtype=float32)]
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# Epoch: 980/1000, D Loss: 5.149572849273682, G Loss: [array(5.1511583, dtype=float32), array(5.1511583, dtype=float32), array(0.2842036, dtype=float32)]
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# Epoch: 981/1000, D Loss: 5.150433540344238, G Loss: [array(5.1519547, dtype=float32), array(5.1519547, dtype=float32), array(0.28419262, dtype=float32)]
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# Epoch: 982/1000, D Loss: 5.15130615234375, G Loss: [array(5.152874, dtype=float32), array(5.152874, dtype=float32), array(0.28414586, dtype=float32)]
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step
# Epoch: 983/1000, D Loss: 5.152215957641602, G Loss: [array(5.153809, dtype=float32), array(5.153809, dtype=float32), array(0.28413498, dtype=float32)]
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# Epoch: 984/1000, D Loss: 5.153057098388672, G Loss: [array(5.154557, dtype=float32), array(5.154557, dtype=float32), array(0.28411222, dtype=float32)]
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# Epoch: 985/1000, D Loss: 5.153947830200195, G Loss: [array(5.155567, dtype=float32), array(5.155567, dtype=float32), array(0.2840498, dtype=float32)]
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# Epoch: 986/1000, D Loss: 5.154885768890381, G Loss: [array(5.1564603, dtype=float32), array(5.1564603, dtype=float32), array(0.2840232, dtype=float32)]
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# Epoch: 987/1000, D Loss: 5.15592098236084, G Loss: [array(5.1575966, dtype=float32), array(5.1575966, dtype=float32), array(0.2839729, dtype=float32)]
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# Epoch: 988/1000, D Loss: 5.157001495361328, G Loss: [array(5.1586227, dtype=float32), array(5.1586227, dtype=float32), array(0.28394642, dtype=float32)]
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# Epoch: 989/1000, D Loss: 5.157930850982666, G Loss: [array(5.159487, dtype=float32), array(5.159487, dtype=float32), array(0.28393975, dtype=float32)]
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# Epoch: 990/1000, D Loss: 5.158830642700195, G Loss: [array(5.160439, dtype=float32), array(5.160439, dtype=float32), array(0.28394097, dtype=float32)]
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# Epoch: 991/1000, D Loss: 5.159776210784912, G Loss: [array(5.161339, dtype=float32), array(5.161339, dtype=float32), array(0.28393826, dtype=float32)]
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# Epoch: 992/1000, D Loss: 5.160680294036865, G Loss: [array(5.162263, dtype=float32), array(5.162263, dtype=float32), array(0.28395525, dtype=float32)]
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# Epoch: 993/1000, D Loss: 5.161566734313965, G Loss: [array(5.163104, dtype=float32), array(5.163104, dtype=float32), array(0.28396037, dtype=float32)]
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# Epoch: 994/1000, D Loss: 5.162384033203125, G Loss: [array(5.163912, dtype=float32), array(5.163912, dtype=float32), array(0.2839773, dtype=float32)]
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# Epoch: 995/1000, D Loss: 5.163210868835449, G Loss: [array(5.16476, dtype=float32), array(5.16476, dtype=float32), array(0.2839785, dtype=float32)]
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# Epoch: 996/1000, D Loss: 5.164153099060059, G Loss: [array(5.165799, dtype=float32), array(5.165799, dtype=float32), array(0.2839836, dtype=float32)]
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# Epoch: 997/1000, D Loss: 5.165207862854004, G Loss: [array(5.166852, dtype=float32), array(5.166852, dtype=float32), array(0.283973, dtype=float32)]
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# Epoch: 998/1000, D Loss: 5.166176795959473, G Loss: [array(5.1677375, dtype=float32), array(5.1677375, dtype=float32), array(0.2839742, dtype=float32)]
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step
# Epoch: 999/1000, D Loss: 5.167058944702148, G Loss: [array(5.168618, dtype=float32), array(5.168618, dtype=float32), array(0.28399494, dtype=float32)]
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# Epoch: 1000/1000, D Loss: 5.16795539855957, G Loss: [array(5.169506, dtype=float32), array(5.169506, dtype=float32), array(0.2839375, dtype=float32)]
