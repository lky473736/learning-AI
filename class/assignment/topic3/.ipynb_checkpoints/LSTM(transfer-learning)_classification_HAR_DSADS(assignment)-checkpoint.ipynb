# %% [markdown]
# ## learning-AI : deep learning application (61357002)
# ### assignment :  HAR DSADS classification using LSTM with transfer learning (DL)
#
# **HAR DSADS 데이터를 순환 데이터로 만들어 LSTM 방식의 classification, 전이 학습을 사용**
#
# <br>
#
# - **임규연 (lky473736)**
# - 2024.09.24. ~ 2024.09.25.에 문서 작성
# - **dataset** : ```../data/DSA_features.csv```
# - **Reference**
#     - Generalizable Low-Resource Activity Recognition with Diverse and Discriminative Representation Learning (Xin Qin... / https://arxiv.org/abs/2306.04641)
#     - https://www.tensorflow.org/tutorials/images/transfer_learning?hl=ko
#     - https://velog.io/@xuio/Transfer-Learning%EA%B3%BC-Fine-Tuning
#     - https://ratsgo.github.io/nlpbook/docs/introduction/transfer/
#     - https://www.lgcns.com/blog/cns-tech/ai-data/11934/

# %% [markdown]
# -----
#
# ## <span id='dl'><mark>DL</mark></span>
#
# deep learning으로 HAR DSADS를 classification할 수 있는 예제인 ```Pre-trained_model.ipynb```(https://github.com/MyungKyuYi/AI-class/blob/main/Pre-trained_model.ipynb) 을 수정 및 내용을 추가한다. 이때, transfer learning을 도입하여 학습을 진행한다. 목차는 아래와 같다.
#
# - **개요 : 전이학습에 대한 이해 및 classification strategy 세우기**
# - **1. 간단한 탐색적 데이터 분석 및 데이터 전처리 수행, 순환 데이터로 구성**
# - **2. RA model 구축 및 저장**
# - **3. LA model 구축 및 저장**
# - **4. transfer learning - LA model을 base로 둔 RA 기준의 remodeling**
# - **5. transfer learning - RA model을 base로 둔 LA 기준의 remodeling**

# %%
import pandas as pd
from sklearn.model_selection import StratifiedShuffleSplit
from scipy.stats import skew
import os
import csv
import matplotlib.pyplot as plt
import seaborn as sns
import tensorflow as tf
from tensorflow import keras
import numpy as np
import scipy
from tqdm import tqdm

# %%
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import layers

# cnn model vary kernel size
from numpy import mean
from numpy import std
from numpy import dstack
from pandas import read_csv
from matplotlib import pyplot
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense
from tensorflow.keras.layers import Flatten
from tensorflow.keras.layers import Dropout
from keras.utils import to_categorical

import tensorflow.keras
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Dropout, Flatten, Reshape, LSTM, Conv1D, MaxPooling1D
from tensorflow.keras.layers import TimeDistributed, Conv1D, MaxPooling1D

# %% [markdown]
# -----
#
#
# ### 개요 : 전이학습에 대한 이해 및 classification strategy 세우기
#
# <img src="./a_lot_of_mice.png" width="500px">
#
# 전이학습을 이해하기 위한 간단한 예시를 들자면, 내가 **만약 다람쥐와 땃쥐 사진을 구분하는 2D-CNN classification model을 만든다고 가정하자.** 기존처럼 feature extraction을 위해 convolution layer 배치하고, pooling 상황에 맞게 두고, overfitting을 막기 위해 dropout이나 l2 규제 layer에 씌우는 등의 메소드를 사용하여 modeling할 것이다. 그때 (갑자기) Google에서 다람쥐뿐만이 아닌, 각종 쥐 사진을 분류 가능한 classification 모델을 배포한다고 한다! **Google의 선진 기술을 체험해보고 싶은 개발자 개미들은 당연히 모델을 개조하여 자신만의 모델을 구성하고 싶어할 것이다. (물론 기업 입장에서는 더욱) 이때 필요한 기술이 전이학습이다.**
#
# <img src="https://blog.kakaocdn.net/dn/cAmFFd/btq4EdHvIvZ/cxHcykXW4KaSLkjC1duDok/img.png" width="500px">
#
# **전이학습은 현재 해결해야 할 주제와 비슷한 주제를 이미 해결한 기존 모델을 이용 및 개조하여 더욱 성능 좋은 모델을 만드는 과정**이라고 볼 수 있다. 이전 예시에서, 나는 다람쥐와 땃쥐를 구분하는 모델을 구축하고 싶었다. 이때 Google은 각종 쥐를 분류하는 모델을 만들었고, 내가 당면한 문제와 Google이 제시한 문제는 매우 비슷하다. 따라서 나는 Google의 쥐 분류 모델을 base로 삼아서 modeling하면 되지 않겠는가? 위 figure에서 나와있듯이, A는 이미 모델링이 완료된 것이며, B를 해결하기 위해 A를 구성하는 모델을 일부 재사용하는 것이다.
#
# 전이학습의 핵심은 **이미 학습된 모델의 가중치를 재사용하여 새로운 문제를 해결하는 데 필요한 시간과 자원을 절감**하는 것이다. 특히 **feature extraction** 부분은 기본적으로 이미지에서 유용한 특징들을 찾아내는 과정인데, 이를 새로 구축하는 것보다는 **이미 잘 훈련된 모델의 하위 계층**을 그대로 가져와 사용하는 것이 매우 효율적이라는 것이다. 예를 들어, Google의 쥐 분류 모델에서 **convolutional layer와 pooling layer**는 다양한 쥐 이미지로부터 중요한 시각적 특징들을 잘 추출할 수 있게 이미 학습된 상태이다. 따라서 우리는 이러한 하위 계층들을 그대로 두고, **마지막 분류 계층 (Dense layer로 구성되었을 것이다.)** 만 우리의 문제에 맞게 조정하는 방식으로 새로운 모델을 빠르고 효과적으로 구축할 수 있다.
#
# 이러한 방식은 특히 **데이터가 부족할 때** 효과적이다. 만약 우리가 다람쥐와 땃쥐 이미지를 충분히 확보하지 못한 상태에서 모델을 처음부터 끝까지 학습시키려 한다면, 충분히 일반화된 모델을 만들기 어려울 수 있다. 하지만 전이학습을 활용하면 **이미 대규모 데이터셋에서 학습된 모델의 지식을 활용할 수 있기 때문에 상대적으로 적은 데이터로도 좋은 성능을 얻을 수 있다.**
#
# 본 문서에서는 이러한 전이학습을 예제로 구현한 ```./reference/Pre-trained_model.ipynb```를 가동시켜보고, 기존 문서에서 내용을 수정 및 보완, 추가하여 본다.
#
#
# ------
#
# ### 1. 간단한 탐색적 데이터 분석 및 데이터 전처리 수행, 순환 데이터로 구성
# - 데이터 시각화 및 필요한 정보를 얻어낸다.
# - 결측치 제거, outlier 제거 등의 데이터 전처리를 수행한다.
# - 순환 데이터로 구성하기 위하여 split_sequence를 빈도 기준으로 한다.

# %%
# 파일 읽기

df = pd.read_csv("../../data/DSA_features.csv")
df
# Out:
#       T_xacc_mean  T_xacc_max  T_xacc_min  T_xacc_var  T_xacc_std  \
# 0        7.975714      8.1605      7.6823    0.014395    0.119981
# 1        7.978250      8.1763      7.8472    0.007551    0.086896
# 2        7.970894      8.0860      7.8470    0.003092    0.055603
# 3        7.938412      8.1083      7.6901    0.003763    0.061343
# 4        7.908930      8.1305      7.8322    0.001741    0.041731
# ...           ...         ...         ...         ...         ...
# 9115     8.280854     34.1980     -2.9038   28.080803    5.299132
# 9116     9.591118     51.6970     -3.4129   35.722025    5.976791
# 9117     9.599113     27.9300     -1.0765   48.850886    6.989341
# 9118     9.692482     72.7820     -2.6734   59.378336    7.705734
# 9119     9.380641     45.0090     -3.5938   40.459334    6.360765
#
#       T_xacc_skew  T_yacc_mean  T_yacc_max  T_yacc_min  T_yacc_var  ...  \
# 0       -0.023319     1.083150      1.1832     0.99744    0.002208  ...
# 1        0.552416     1.140865      1.2129     1.05810    0.000784  ...
# 2        0.100538     1.140962      1.2128     1.07960    0.000508  ...
# 3       -0.231914     1.165260      1.3170     1.07870    0.002173  ...
# 4        2.042285     1.187504      1.2574     1.09450    0.000662  ...
# ...           ...          ...         ...         ...         ...  ...
# 9115     1.350075    -1.491537     11.2240   -11.65100   14.670334  ...
# 9116     2.981144     0.086304      6.9951   -11.76400    5.329897  ...
# 9117     0.449237    -0.728367      3.7801    -8.36910    5.683022  ...
# 9118     4.491114    -0.582724      6.1216    -8.85710    4.162963  ...
# 9119     1.688626    -0.266325      5.8603    -6.91970    4.017098  ...
#
#       LL_ymag_std  LL_ymag_skew  LL_zmag_mean  LL_zmag_max  LL_zmag_min  \
# 0        0.000792      0.177075     -0.057119    -0.054963    -0.059241
# 1        0.000860     -0.286918     -0.057268    -0.054945    -0.059589
# 2        0.000762     -0.134430     -0.057068    -0.054711    -0.059065
# 3        0.000735      0.021485     -0.056422    -0.053670    -0.058310
# 4        0.000824     -0.148229     -0.055801    -0.053313    -0.057815
# ...           ...           ...           ...          ...          ...
# 9115     0.200829     -0.040701      0.297666     0.708480    -0.117430
# 9116     0.148745     -0.266377      0.224716     0.554670    -0.250950
# 9117     0.310748     -0.009505     -0.237786     0.088854    -0.477260
# 9118     0.156493      0.050624      0.533023     0.677800     0.055941
# 9119     0.229154     -0.342228      0.491919     0.707920     0.251280
#
#        LL_zmag_var  LL_zmag_std  LL_zmag_skew    activity  people
# 0     6.778722e-07     0.000823      0.036729     sitting      p1
# 1     7.032302e-07     0.000839      0.347471     sitting      p1
# 2     6.268222e-07     0.000792      0.045579     sitting      p1
# 3     8.011245e-07     0.000895      0.240690     sitting      p1
# 4     6.853423e-07     0.000828      0.258429     sitting      p1
# ...            ...          ...           ...         ...     ...
# 9115  4.135451e-02     0.203358     -0.310022  basketBall      p8
# 9116  3.355704e-02     0.183186     -0.736410  basketBall      p8
# 9117  2.026107e-02     0.142341      0.668438  basketBall      p8
# 9118  1.356379e-02     0.116464     -1.482489  basketBall      p8
# 9119  9.358254e-03     0.096738     -0.223302  basketBall      p8
#
# [9120 rows x 272 columns]

# %%
# data info, describe

df.info()
df.describe()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9120 entries, 0 to 9119
# Columns: 272 entries, T_xacc_mean to people
# dtypes: float64(270), object(2)
# memory usage: 18.9+ MB
#        T_xacc_mean   T_xacc_max   T_xacc_min   T_xacc_var   T_xacc_std  \
# count  9120.000000  9120.000000  9120.000000  9120.000000  9120.000000
# mean      7.765766    14.625536     3.602974    17.807013     2.454290
# std       3.758022    11.823448     5.622855    45.188787     3.432895
# min     -11.575660    -4.758700   -99.715000     0.000135     0.011633
# 25%       8.374161     9.523200     0.000000     0.036855     0.191977
# 50%       9.186328    12.549500     5.757900     2.241468     1.497153
# 75%       9.515573    15.843250     7.649075     6.680571     2.584680
# max      10.713139    93.694000     9.749000   392.898630    19.821671
#
#        T_xacc_skew  T_yacc_mean   T_yacc_max   T_yacc_min   T_yacc_var  ...  \
# count  9120.000000  9120.000000  9120.000000  9120.000000  9120.000000  ...
# mean      0.305587    -0.811036     1.801847    -3.704204     2.049747  ...
# std       0.768360     2.201692     4.177165     3.982579     3.908675  ...
# min      -7.826631    -9.782885    -9.703600   -49.941000     0.000141  ...
# 25%      -0.161535    -1.134192     0.172375    -4.837875     0.012121  ...
# 50%       0.275042    -0.375678     1.571750    -2.470150     0.737663  ...
# 75%       0.845410     0.127612     3.005450    -1.279725     1.900426  ...
# max       9.070164     7.051530    41.013000     2.656400    54.332000  ...
#
#        LL_ymag_min   LL_ymag_var  LL_ymag_std  LL_ymag_skew  LL_zmag_mean  \
# count  9120.000000  9.120000e+03  9120.000000   9120.000000   9120.000000
# mean      0.111347  1.818862e-02     0.105897     -0.055440      0.064504
# std       0.362373  2.382393e-02     0.083518      0.526959      0.346660
# min      -0.901760  3.044156e-07     0.000552     -3.693948     -0.912397
# 25%      -0.111835  5.683172e-04     0.023839     -0.343123     -0.156271
# 50%       0.184470  1.078612e-02     0.103856     -0.075786      0.086285
# 75%       0.315962  2.740661e-02     0.165549      0.177076      0.295415
# max       0.969020  3.041940e-01     0.551538      5.035185      1.020691
#
#        LL_zmag_max  LL_zmag_min   LL_zmag_var  LL_zmag_std  LL_zmag_skew
# count  9120.000000  9120.000000  9.120000e+03  9120.000000   9120.000000
# mean      0.169687    -0.052866  7.624694e-03     0.059342     -0.089861
# std       0.360190     0.359712  1.903445e-02     0.064059      0.619636
# min      -0.910830    -1.126000  2.960874e-07     0.000544     -5.111532
# 25%      -0.035821    -0.326125  2.227543e-04     0.014925     -0.402781
# 50%       0.210825    -0.040447  1.813539e-03     0.042586     -0.092036
# 75%       0.422270     0.206933  6.927870e-03     0.083234      0.228493
# max       1.042600     0.999440  2.790198e-01     0.528223      3.560828
#
# [8 rows x 270 columns]

# %%
# 결측치 처리

print (df.isnull().sum())
df = df.dropna()
print ()
print (df.isnull().sum())
# Out:
# T_xacc_mean     0
# T_xacc_max      0
# T_xacc_min      0
# T_xacc_var      0
# T_xacc_std      0
#                ..
# LL_zmag_var     0
# LL_zmag_std     0
# LL_zmag_skew    0
# activity        0
# people          0
# Length: 272, dtype: int64
#
# T_xacc_mean     0
# T_xacc_max      0
# T_xacc_min      0
# T_xacc_var      0
# T_xacc_std      0
#                ..
# LL_zmag_var     0
# LL_zmag_std     0
# LL_zmag_skew    0
# activity        0
# people          0
# Length: 272, dtype: int64

# %%
# attribute가 무엇으로 구성되어 있는지 확인

print (df.columns)

'''
    attribute가 무려 271개나 있다. (activity 제외 / activity가 여기서 target값이 되겠다)
'''
# Out:
# Index(['T_xacc_mean', 'T_xacc_max', 'T_xacc_min', 'T_xacc_var', 'T_xacc_std',
#        'T_xacc_skew', 'T_yacc_mean', 'T_yacc_max', 'T_yacc_min', 'T_yacc_var',
#        ...
#        'LL_ymag_std', 'LL_ymag_skew', 'LL_zmag_mean', 'LL_zmag_max',
#        'LL_zmag_min', 'LL_zmag_var', 'LL_zmag_std', 'LL_zmag_skew', 'activity',
#        'people'],
#       dtype='object', length=272)
# '\n    attribute가 무려 271개나 있다. (activity 제외 / activity가 여기서 target값이 되겠다)\n'

# %%
# target값인 df['activity']의 각 클래스별 갯수 확인 

df['activity'].value_counts()
# Out:
# activity
# sitting                    480
# walkingTreadmillIncline    480
# jumping                    480
# rowing                     480
# cyclingVertical            480
# cyclingHorizontal          480
# crossTrainer               480
# stepper                    480
# runningTreadmill           480
# walkingTreadmillFlat       480
# standing                   480
# walkingLot                 480
# movingInElevator           480
# standingInElevatorStill    480
# decendingStairs            480
# ascendingStairs            480
# lyingRigh                  480
# lyingBack                  480
# basketBall                 480
# Name: count, dtype: int64

# %%
# countplot

import pandas as pd
import matplotlib.pyplot as plt

# 레이블별 갯수 확인
label_counts = df['activity'].value_counts()

# 바 그래프 그리기
label_counts.plot(kind='bar')

# 그래프 제목 및 라벨 설정
plt.title('Label Count')
plt.xlabel('Labels')
plt.ylabel('Count')

'''
    모든 class가 480개로 빈도수가 동일하기 때문에 클래스 편향이 일어나지 않을 것이다.
'''
# Out:
# '\n    모든 class가 480개로 빈도수가 동일하기 때문에 클래스 편향이 일어나지 않을 것이다.\n'

# %%
# filter 기능을 통하여 RA_와 LA_로 시작하는 이름의 attribute를 통하여 split

df_RA = df.filter(regex='RA_') 
df_LA = df.filter(regex='LA_') 

'''
    여기서 RA는 Right Arm, LA는 Left Arm을 의미하며,
    각각을 구분한 이유는, RA에 특화되어 있는 모델과 LA에 특화되어 있는 모델을 각각 만들어 전이학습하기 위해서이다.
'''
# Out:
# '\n    여기서 RA는 Right Arm, LA는 Left Arm을 의미하며,\n    각각을 구분한 이유는, RA에 특화되어 있는 모델과 LA에 특화되어 있는 모델을 각각 만들어 전이학습하기 위해서이다.\n'

# %%
# 첫번째 열에 target 추가

# df_RA.insert(3, 'activity', df['activity'])
df_RA.insert(0, 'activity', df['activity'])

# df_LA.insert(3, 'activity', df['activity'])
df_LA.insert(0, 'activity', df['activity'])

print (df_RA.head(2))
print ()
print (df_LA.head(2))

'''
    가장 첫번째 열에 activity가 추가되었다
'''
# Out:
#   activity  RA_xacc_mean  RA_xacc_max  RA_xacc_min  RA_xacc_var  RA_xacc_std  \
# 0  sitting      0.679134      0.75930      0.58542     0.001546     0.039324
# 1  sitting      0.644964      0.73158      0.53064     0.001333     0.036508
#
#    RA_xacc_skew  RA_yacc_mean  RA_yacc_max  RA_yacc_min  ...  RA_ymag_min  \
# 0     -0.415694      5.713088       5.8483       5.5956  ...     -0.57428
# 1      0.410625      5.795154       5.9546       5.6687  ...     -0.57398
#
#    RA_ymag_var  RA_ymag_std  RA_ymag_skew  RA_zmag_mean  RA_zmag_max  \
# 0     0.000012     0.003401      -0.05219     -0.211136     -0.18401
# 1     0.000005     0.002216       0.22274     -0.206431     -0.18054
#
#    RA_zmag_min  RA_zmag_var  RA_zmag_std  RA_zmag_skew
# 0     -0.24523     0.000044     0.006638     -1.153902
# 1     -0.23624     0.000032     0.005660      0.458427
#
# [2 rows x 55 columns]
#
#   activity  LA_xacc_mean  LA_xacc_max  LA_xacc_min  LA_xacc_var  LA_xacc_std  \
# 0  sitting      3.403317       3.4875       3.2682     0.001583     0.039790
# 1  sitting      3.427302       3.6630       3.3168     0.004305     0.065614
#
#    LA_xacc_skew  LA_yacc_mean  LA_yacc_max  LA_yacc_min  ...  LA_ymag_min  \
# 0     -0.744647     -8.375713      -8.2927      -8.4821  ...      0.33748
# 1      1.000107     -8.397591      -8.3118      -8.5017  ...      0.33000
#
#    LA_ymag_var  LA_ymag_std  LA_ymag_skew  LA_zmag_mean  LA_zmag_max  \
# 0     0.000003     0.001810     -0.215069      0.072273     0.076374
# 1     0.000017     0.004159     -0.611251      0.074557     0.085184
#
#    LA_zmag_min  LA_zmag_var  LA_zmag_std  LA_zmag_skew
# 0     0.067940     0.000004     0.001910     -0.166015
# 1     0.068169     0.000022     0.004643      0.717286
#
# [2 rows x 55 columns]
# '\n    가장 첫번째 열에 activity가 추가되었다\n'

# %%
print ("LA\n", df_LA['activity'].value_counts())
print ()
print ("RA\n",df_RA['activity'].value_counts())

'''
    activity에 각 활동명이 class로 되어 있어서, 이를 integer로 변경해야 하겠다.
    0-based class (int)로 구성하기 위해 label encoding을 진행한다
'''
# Out:
# LA
#  activity
# sitting                    480
# walkingTreadmillIncline    480
# jumping                    480
# rowing                     480
# cyclingVertical            480
# cyclingHorizontal          480
# crossTrainer               480
# stepper                    480
# runningTreadmill           480
# walkingTreadmillFlat       480
# standing                   480
# walkingLot                 480
# movingInElevator           480
# standingInElevatorStill    480
# decendingStairs            480
# ascendingStairs            480
# lyingRigh                  480
# lyingBack                  480
# basketBall                 480
# Name: count, dtype: int64
#
# RA
#  activity
# sitting                    480
# walkingTreadmillIncline    480
# jumping                    480
# rowing                     480
# cyclingVertical            480
# cyclingHorizontal          480
# crossTrainer               480
# stepper                    480
# runningTreadmill           480
# walkingTreadmillFlat       480
# standing                   480
# walkingLot                 480
# movingInElevator           480
# standingInElevatorStill    480
# decendingStairs            480
# ascendingStairs            480
# lyingRigh                  480
# lyingBack                  480
# basketBall                 480
# Name: count, dtype: int64
# '\n    activity에 각 활동명이 class로 되어 있어서, 이를 integer로 변경해야 하겠다.\n    0-based class (int)로 구성하기 위해 label encoding을 진행한다\n'

# %%
# target 값이 현재 문자열로 이루어져 있기 때문에 label encoding을 통하여 0-based로 된 class로 remapping

from sklearn.preprocessing import LabelEncoder

label_encoder = LabelEncoder()
df_RA['activity'] = label_encoder.fit_transform(df_RA['activity'])

label_encoder = LabelEncoder()
df_LA['activity'] = label_encoder.fit_transform(df_LA['activity'])
# Out:
# /var/folders/_z/gryfr07n59jgb3wrd062h1ym0000gn/T/ipykernel_58062/124429059.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_RA['activity'] = label_encoder.fit_transform(df_RA['activity'])
# /var/folders/_z/gryfr07n59jgb3wrd062h1ym0000gn/T/ipykernel_58062/124429059.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_LA['activity'] = label_encoder.fit_transform(df_LA['activity'])

# %%
# label encoding된 결과 확인

print ("LA\n", df_LA['activity'].value_counts())
print ()
print ("RA\n", df_RA['activity'].value_counts())
# Out:
# LA
#  activity
# 12    480
# 18    480
# 6     480
# 10    480
# 4     480
# 3     480
# 2     480
# 15    480
# 11    480
# 17    480
# 13    480
# 16    480
# 9     480
# 14    480
# 5     480
# 0     480
# 8     480
# 7     480
# 1     480
# Name: count, dtype: int64
#
# RA
#  activity
# 12    480
# 18    480
# 6     480
# 10    480
# 4     480
# 3     480
# 2     480
# 15    480
# 11    480
# 17    480
# 13    480
# 16    480
# 9     480
# 14    480
# 5     480
# 0     480
# 8     480
# 7     480
# 1     480
# Name: count, dtype: int64

# %%
# input, target split

# RA의 target을 activity로 설정함
df_RA_Y = df_RA['activity'] 
df_RA_X = df_RA.drop ('activity', axis=1)
print  (df_RA_X.head(10))

# LA의 target을 activity로 설정함
df_LA_Y = df_LA['activity']
df_LA_X=df_LA.drop('activity',axis=1)
print (df_LA_X.head(10))
# Out:
#    RA_xacc_mean  RA_xacc_max  RA_xacc_min  RA_xacc_var  RA_xacc_std  \
# 0      0.679134      0.75930      0.58542     0.001546     0.039324
# 1      0.644964      0.73158      0.53064     0.001333     0.036508
# 2      0.608212      0.67737      0.53546     0.000637     0.025244
# 3      0.591138      0.71177      0.51524     0.001349     0.036731
# 4      0.558168      0.67190      0.50535     0.000626     0.025020
# 5      0.559089      0.62268      0.51006     0.000567     0.023811
# 6      0.540004      0.59306      0.49022     0.000286     0.016898
# 7      0.537077      0.59728      0.48991     0.000448     0.021171
# 8      0.538192      0.61939      0.47966     0.001079     0.032846
# 9      0.485706      0.53814      0.44280     0.000314     0.017713
#
#    RA_xacc_skew  RA_yacc_mean  RA_yacc_max  RA_yacc_min  RA_yacc_var  ...  \
# 0     -0.415694      5.713088       5.8483       5.5956     0.003779  ...
# 1      0.410625      5.795154       5.9546       5.6687     0.001132  ...
# 2      0.153302      5.833086       5.8918       5.7656     0.000488  ...
# 3      0.525019      5.863846       5.9645       5.7556     0.001423  ...
# 4      1.076782      5.884745       5.9401       5.8384     0.000471  ...
# 5      0.690420      5.901690       5.9498       5.8553     0.000291  ...
# 6      0.129868      5.915167       5.9546       5.8625     0.000284  ...
# 7      0.224971      5.931283       5.9837       5.8842     0.000369  ...
# 8      0.331206      5.943086       6.0031       5.8575     0.000840  ...
# 9      0.363395      5.985106       6.0321       5.9423     0.000345  ...
#
#    RA_ymag_min  RA_ymag_var  RA_ymag_std  RA_ymag_skew  RA_zmag_mean  \
# 0     -0.57428     0.000012     0.003401     -0.052190     -0.211136
# 1     -0.57398     0.000005     0.002216      0.222740     -0.206431
# 2     -0.57563     0.000004     0.001954     -0.221765     -0.205648
# 3     -0.57858     0.000007     0.002688      0.075011     -0.203739
# 4     -0.57996     0.000005     0.002278     -0.219440     -0.203684
# 5     -0.57880     0.000004     0.001953      1.102780     -0.201944
# 6     -0.58279     0.000005     0.002170     -0.650696     -0.202174
# 7     -0.58316     0.000006     0.002489      0.649105     -0.200392
# 8     -0.58469     0.000008     0.002815     -0.112814     -0.199643
# 9     -0.58590     0.000006     0.002544      0.353879     -0.198586
#
#    RA_zmag_max  RA_zmag_min  RA_zmag_var  RA_zmag_std  RA_zmag_skew
# 0     -0.18401     -0.24523     0.000044     0.006638     -1.153902
# 1     -0.18054     -0.23624     0.000032     0.005660      0.458427
# 2     -0.18342     -0.22933     0.000024     0.004868     -0.984915
# 3     -0.17999     -0.22958     0.000026     0.005099      0.185634
# 4     -0.17904     -0.22924     0.000027     0.005175     -0.820907
# 5     -0.17783     -0.22492     0.000023     0.004819      0.763941
# 6     -0.17462     -0.22933     0.000027     0.005203     -0.817497
# 7     -0.16912     -0.22984     0.000041     0.006366      0.810470
# 8     -0.16476     -0.23316     0.000051     0.007146     -0.503793
# 9     -0.16551     -0.23220     0.000045     0.006696      0.838548
#
# [10 rows x 54 columns]
#    LA_xacc_mean  LA_xacc_max  LA_xacc_min  LA_xacc_var  LA_xacc_std  \
# 0      3.403317       3.4875       3.2682     0.001583     0.039790
# 1      3.427302       3.6630       3.3168     0.004305     0.065614
# 2      3.400870       3.5168       3.3315     0.001007     0.031732
# 3      3.391002       3.5311       3.2608     0.001792     0.042328
# 4      3.359974       3.4434       3.3069     0.000633     0.025160
# 5      3.342987       3.4531       3.2776     0.001201     0.034659
# 6      3.313230       3.3895       3.2606     0.000519     0.022774
# 7      3.310750       3.4093       3.2532     0.000998     0.031585
# 8      3.326566       3.4358       3.2385     0.001228     0.035039
# 9      3.321195       3.4089       3.2578     0.000739     0.027192
#
#    LA_xacc_skew  LA_yacc_mean  LA_yacc_max  LA_yacc_min  LA_yacc_var  ...  \
# 0     -0.744647     -8.375713      -8.2927      -8.4821     0.001178  ...
# 1      1.000107     -8.397591      -8.3118      -8.5017     0.001098  ...
# 2      0.978319     -8.439138      -8.3599      -8.5204     0.000684  ...
# 3      0.117935     -8.441421      -8.3207      -8.5446     0.001862  ...
# 4      1.051627     -8.454854      -8.3202      -8.5561     0.001061  ...
# 5      0.761024     -8.489431      -8.4197      -8.5919     0.000842  ...
# 6      0.369784     -8.513732      -8.3613      -8.6013     0.000890  ...
# 7      0.607063     -8.533283      -8.4381      -8.5938     0.000661  ...
# 8      0.028676     -8.525914      -8.4162      -8.6980     0.001726  ...
# 9      0.774842     -8.527843      -8.4499      -8.6249     0.000780  ...
#
#    LA_ymag_min   LA_ymag_var  LA_ymag_std  LA_ymag_skew  LA_zmag_mean  \
# 0      0.33748  3.275688e-06     0.001810     -0.215069      0.072273
# 1      0.33000  1.729914e-05     0.004159     -0.611251      0.074557
# 2      0.33307  1.731341e-06     0.001316     -0.506255      0.075852
# 3      0.33431  1.947295e-06     0.001395      0.155251      0.074878
# 4      0.33631  1.010815e-06     0.001005     -0.299017      0.073398
# 5      0.33495  2.374994e-06     0.001541     -0.433770      0.076125
# 6      0.33808  8.707636e-07     0.000933     -0.387835      0.075828
# 7      0.33635  2.608857e-06     0.001615     -0.140823      0.077778
# 8      0.33607  2.279800e-06     0.001510     -0.148780      0.078499
# 9      0.33524  1.775982e-06     0.001333     -0.679683      0.077654
#
#    LA_zmag_max  LA_zmag_min  LA_zmag_var  LA_zmag_std  LA_zmag_skew
# 0     0.076374     0.067940     0.000004     0.001910     -0.166015
# 1     0.085184     0.068169     0.000022     0.004643      0.717286
# 2     0.083227     0.072507     0.000004     0.002106      1.043919
# 3     0.080059     0.069942     0.000006     0.002414      0.242524
# 4     0.077461     0.070175     0.000002     0.001482      0.606258
# 5     0.081044     0.072683     0.000004     0.001967      0.499923
# 6     0.080312     0.073012     0.000003     0.001654      0.695225
# 7     0.082577     0.073759     0.000005     0.002299      0.359200
# 8     0.082988     0.073990     0.000005     0.002198      0.080807
# 9     0.082561     0.074192     0.000003     0.001607      0.781834
#
# [10 rows x 54 columns]

# %%
# train, test, split

from sklearn.model_selection import train_test_split

X_train_RA, X_test_RA, y_train_RA, y_test_RA = train_test_split(df_RA_X, 
                                                    df_RA_Y,
                                                    test_size = 0.25, 
                                                    random_state = 21)

X_train_LA, X_test_LA, y_train_LA, y_test_LA = train_test_split(df_LA_X, 
                                                    df_LA_Y,
                                                    test_size = 0.25, 
                                                    random_state = 21)

print (X_train_RA.shape, X_test_RA.shape, y_train_RA.shape, y_test_RA.shape)
print (X_train_LA.shape, X_test_LA.shape, y_train_LA.shape, y_test_LA.shape)
# Out:
# (6840, 54) (2280, 54) (6840,) (2280,)
# (6840, 54) (2280, 54) (6840,) (2280,)

# %%
'''
    순환 데이터를 구성하기 위하여 split_sequences를 사용하였다.
    이때, 각 window마다 class의 빈도 수를 측정하여 가장 많은 빈도수를 가진 class가 target이 되는 방식을 취하였다.
'''

from collections import Counter
import numpy as np

def split_sequences(sequences, n_steps):
    X, y = list(), list()  # 빈 리스트를 생성하여 시퀀스 데이터와 레이블을 담을 공간을 만듦
    for i in range(len(sequences)):  # 전체 시퀀스 데이터를 순회
        # find the end of this pattern
        end_ix = i + n_steps  # 현재 인덱스(i)에서 n_steps만큼 떨어진 시퀀스의 끝을 계산
        # check if we are beyond the dataset
        if end_ix > len(sequences):  # 시퀀스 끝이 데이터의 범위를 넘어서는지 확인
            break  # 범위를 넘으면 루프 종료
        # gather input (X) and output parts (y)
        seq_x = sequences[i:end_ix, :-1]  # 입력 데이터 (특징 데이터)
        seq_y_values = sequences[i:end_ix, -1]  # 시퀀스 동안의 출력 데이터 (레이블들)
        
        # 가장 빈번하게 나온 레이블 찾기
        most_common_label = Counter(seq_y_values).most_common(1)[0][0]
        
        X.append(seq_x)  # 입력 데이터 추가
        y.append(most_common_label)  # 가장 많이 나온 레이블 추가
    
    return np.array(X), np.array(y)  # 리스트를 numpy 배열로 변환하여 반환

# %%
# X_train_seq_RA, y_train_seq_RA, X_test_seq_RA, y_test_seq_RA 구성

# Merge train and test X/y data to apply sequence transformation function
y_train_array_RA = np.array(y_train_RA)
train_set_RA = np.c_[X_train_RA, y_train_array_RA]

y_test_array_RA = np.array(y_test_RA)
test_set_RA = np.c_[X_test_RA, y_test_array_RA]

n_step = 3  # window 사이즈는 3으로 한다
 
X_train_seq_RA, y_train_seq_RA = split_sequences(train_set_RA, n_step)
print(X_train_seq_RA.shape, y_train_seq_RA.shape)

X_test_seq_RA, y_test_seq_RA = split_sequences(test_set_RA, n_step)
print(X_test_seq_RA.shape, y_test_seq_RA.shape)
# Out:
# (6838, 3, 54) (6838,)
# (2278, 3, 54) (2278,)

# %%
# X_train_seq_LA, y_train_seq_LA, X_test_seq_LA, y_test_seq_LA 구성

# Merge train and test X/y data to apply sequence transformation function
y_train_array_LA = np.array(y_train_LA)
train_set_LA = np.c_[X_train_LA, y_train_array_LA]

y_test_array_LA = np.array(y_test_LA)
test_set_LA = np.c_[X_test_LA, y_test_array_LA]

n_step = 3 

X_train_seq_LA, y_train_seq_LA = split_sequences(train_set_LA, n_step)
print(X_train_seq_LA.shape, y_train_seq_LA.shape)

X_test_seq_LA, y_test_seq_LA = split_sequences(test_set_LA, n_step)
print(X_test_seq_LA.shape, y_test_seq_LA.shape)
# Out:
# (6838, 3, 54) (6838,)
# (2278, 3, 54) (2278,)

# %%
# one hot encoding을 진행한다. (categorical crossentropy)

from keras.utils import to_categorical

# Convert output variables to categorical for CNN
y_train_seq_RA = to_categorical(y_train_seq_RA)
print(y_train_seq_RA.shape)

y_test_seq_RA = to_categorical(y_test_seq_RA)
print(y_test_seq_RA.shape)

# Convert output variables to categorical for CNN
y_train_seq_LA = to_categorical(y_train_seq_LA)
print(y_train_seq_LA.shape)

y_test_seq_LA = to_categorical(y_test_seq_LA)
print(y_test_seq_LA.shape)
# Out:
# (6838, 19)
# (2278, 19)
# (6838, 19)
# (2278, 19)

# %% [markdown]
# -----
#
# ### 2. RA model 구축 및 저장
# - RA model을 먼저 구축하여 그에 대한 가중치 및 bias, parameter를 저장해놓는다.
# - 추후 전이학습을 진행할 때 불러와 base model로 삼기 위해서다.
#     - **RA model을 base로 하여 LA에 맞추기 (fine tuning하여)**

# %%
'''
    n_timesteps : window를 구성하는 records 수
    n_features : 열의 갯수 (feature 갯수)
    n_outputs : 총 결과 class 갯수
'''

# Produce variables for CNN input/output shape
n_timesteps, n_features, n_outputs = X_train_seq_RA.shape[1], X_train_seq_RA.shape[2], y_train_seq_RA.shape[1]
print(n_timesteps, n_features, n_outputs)
# Out:
# 3 54 19

# %%
'''
    LSTM -> dense modeling
'''

# Build CNN model using keras. For model building suggestions, referenced:
# https://machinelearningmastery.com/deep-learning-models-for-human-activity-recognition/
# https://machinelearningmastery.com/how-to-choose-loss-functions-when-training-deep-learning-neural-networks/
# https://machinelearningmastery.com/how-to-develop-convolutional-neural-network-models-for-time-series-forecasting/

# Sequential model type
model_RA = Sequential()
model_RA.add(LSTM(units=128, input_shape = (n_timesteps, n_features)))
model_RA.add(Dense(128, activation='relu'))
model_RA.add(Dense(n_outputs, activation='softmax'))

# compile
model_RA.compile(optimizer='adam', 
              metrics=['accuracy'], 
              loss='categorical_crossentropy')
# Out:
# /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/keras/src/layers/rnn/rnn.py:204: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)

# %%
# 모델 시각화 

model_RA.summary()
keras.utils.plot_model(model_RA, show_dtype=True,
                      show_layer_activations=True,
                      show_layer_names=True, 
                       show_shapes=True,
                       show_trainable=True)
# Out:
# Model: "sequential_2"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ lstm_4 (LSTM)                   │ (None, 128)            │        93,696 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_16 (Dense)                │ (None, 128)            │        16,512 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_17 (Dense)                │ (None, 19)             │         2,451 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 112,659 (440.07 KB)
#  Trainable params: 112,659 (440.07 KB)
#  Non-trainable params: 0 (0.00 B)

# %%
# fit 

history_RA = model_RA.fit(X_train_seq_RA, 
                    y_train_seq_RA, 
                    epochs = 20, batch_size = 32, 
                    validation_split = 0.1, shuffle = True)
# Out:
# Epoch 1/20
# 193/193 ━━━━━━━━━━━━━━━━━━━━ 3s 5ms/step - accuracy: 0.1963 - loss: 2.5569 - val_accuracy: 0.5453 - val_loss: 1.3602
# Epoch 2/20
# 193/193 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.6278 - loss: 1.1691 - val_accuracy: 0.7427 - val_loss: 0.9241
# Epoch 3/20
# 193/193 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.7678 - loss: 0.7733 - val_accuracy: 0.7939 - val_loss: 0.7543
# Epoch 4/20
# 193/193 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.8237 - loss: 0.5992 - val_accuracy: 0.8275 - val_loss: 0.6825
# Epoch 5/20
# 193/193 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.8472 - loss: 0.4996 - val_accuracy: 0.8348 - val_loss: 0.6333
# Epoch 6/20
# 193/193 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.8850 - loss: 0.3854 - val_accuracy: 0.8333 - val_loss: 0.6330
# Epoch 7/20
# 193/193 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.9047 - loss: 0.3207 - val_accuracy: 0.8304 - val_loss: 0.6222
# Epoch 8/20
# 193/193 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.9206 - loss: 0.2798 - val_accuracy: 0.8670 - val_loss: 0.5579
# Epoch 9/20
# 193/193 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.9336 - loss: 0.2360 - val_accuracy: 0.8436 - val_loss: 0.5890
# Epoch 10/20
# 193/193 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.9481 - loss: 0.1861 - val_accuracy: 0.8231 - val_loss: 0.6463
# Epoch 11/20
# 193/193 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.9497 - loss: 0.1743 - val_accuracy: 0.8567 - val_loss: 0.5957
# Epoch 12/20
# 193/193 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.9681 - loss: 0.1299 - val_accuracy: 0.8319 - val_loss: 0.6315
# Epoch 13/20
# 193/193 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.9659 - loss: 0.1160 - val_accuracy: 0.8567 - val_loss: 0.5975
# Epoch 14/20
# 193/193 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.9850 - loss: 0.0715 - val_accuracy: 0.8523 - val_loss: 0.6459
# Epoch 15/20
# 193/193 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.9871 - loss: 0.0652 - val_accuracy: 0.8494 - val_loss: 0.6317
# Epoch 16/20
# 193/193 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.9882 - loss: 0.0560 - val_accuracy: 0.8640 - val_loss: 0.6371
# Epoch 17/20
# 193/193 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.9941 - loss: 0.0359 - val_accuracy: 0.8538 - val_loss: 0.6290
# Epoch 18/20
# 193/193 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.9879 - loss: 0.0492 - val_accuracy: 0.8655 - val_loss: 0.6701
# Epoch 19/20
# 193/193 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.9911 - loss: 0.0427 - val_accuracy: 0.8480 - val_loss: 0.6849
# Epoch 20/20
# 193/193 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.9948 - loss: 0.0307 - val_accuracy: 0.8611 - val_loss: 0.7167

# %%
# loss와 validation loss, acc와 validation acc를 시각화하기 위한 메소드

def draw_history (history) :
    fig, ax = plt.subplots(1, 2, figsize=(12, 5))

    ax[0].plot(history.history['loss'], label='Loss')
    ax[0].plot(history.history['val_loss'], label='Validation Loss')
    ax[0].set_title('Loss')
    ax[0].set_xlabel('Epochs')
    ax[0].set_ylabel('Loss')
    ax[0].legend()
    ax[0].grid()

    ax[1].plot(history.history['accuracy'], label='Accuracy')
    ax[1].plot(history.history['val_accuracy'], label='Validation Accuracy')
    ax[1].set_title('Accuracy')
    ax[1].set_xlabel('Epochs')
    ax[1].set_ylabel('Accuracy')
    ax[1].legend()
    ax[1].grid()

    plt.tight_layout()
    plt.show()

draw_history(history_RA)

# %%
# evaluate

print ("train score : ", model_RA.evaluate(X_train_seq_RA, y_train_seq_RA))
print ("test score : ", model_RA.evaluate(X_test_seq_RA, y_test_seq_RA))
# Out:
# 214/214 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9964 - loss: 0.0243
# train score :  [0.08920515328645706, 0.984352171421051]
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8650 - loss: 0.6808
# test score :  [0.6899632215499878, 0.862159788608551]

# %%
# confusion matrix, classification report, accuracy

from sklearn.metrics import confusion_matrix, classification_report, accuracy_score

y_test_arg=np.argmax(y_test_seq_RA, axis=1)
Y_pred = np.argmax(model_RA.predict(X_test_seq_RA),axis=1)
print('Confusion Matrix')
cm = confusion_matrix(y_test_arg, Y_pred)

# confusion matrix 시각화
plt.figure(figsize=(8, 6))  # 그래프 크기 조절 (너비 8, 높이 6)
sns.heatmap(cm, annot=True, fmt="d", cmap="Blues")
plt.show()

# classification report
report = classification_report(y_test_arg, Y_pred)
print (report)
# Out:
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# Confusion Matrix
#               precision    recall  f1-score   support
#
#            0       0.88      0.84      0.86       116
#            1       0.87      0.86      0.86       120
#            2       0.87      0.94      0.91       118
#            3       0.98      0.78      0.87       129
#            4       0.86      0.87      0.87       108
#            5       0.84      0.90      0.87       139
#            6       0.91      0.92      0.92       112
#            7       0.90      0.90      0.90       124
#            8       0.85      0.96      0.90       116
#            9       0.68      0.70      0.69       126
#           10       0.95      0.95      0.95       127
#           11       0.88      0.94      0.91       133
#           12       0.85      0.89      0.87       119
#           13       0.85      0.91      0.88       114
#           14       0.80      0.69      0.74       107
#           15       0.92      0.87      0.89       111
#           16       0.85      0.85      0.85       122
#           17       0.87      0.82      0.84       122
#           18       0.78      0.77      0.77       115
#
#     accuracy                           0.86      2278
#    macro avg       0.86      0.86      0.86      2278
# weighted avg       0.86      0.86      0.86      2278

# %%
# base loss, base accuracy 구하고 저장

base_loss,base_accuracy = model_RA.evaluate(X_test_seq_RA, y_test_seq_RA)

model_file_RA = './model/RA_model.h5'
  
tf.keras.models.save_model(model_RA, model_file_RA, include_optimizer=False)
print('model saved at ', model_file_RA)
#score,keras_file=evaluate_model(trainX,trainy,testX,testy)

score = base_accuracy*100
print('Accuracy >{:f}'.format(score))
print('Base Loss >{:.2f}'.format(base_loss))
# Out:
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8650 - loss: 0.6808
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# model saved at  ./model/RA_model.h5
# Accuracy >86.215979
# Base Loss >0.69

# %% [markdown]
# -----
#
# ### 3. LA model 구축 및 저장
# - LA model을 구축하여 그에 대한 가중치 및 bias, parameter를 저장해놓는다.
# - 추후 전이학습을 진행할 때 불러와 base model로 삼기 위해서다.
#     - **LA model을 base로 하여 RA에 맞추기 (fine tuning하여)**

# %%
'''
    LSTM -> dense modeling
'''

# Build CNN model using keras. For model building suggestions, referenced:
# https://machinelearningmastery.com/deep-learning-models-for-human-activity-recognition/
# https://machinelearningmastery.com/how-to-choose-loss-functions-when-training-deep-learning-neural-networks/
# https://machinelearningmastery.com/how-to-develop-convolutional-neural-network-models-for-time-series-forecasting/

# Sequential model type
model_LA = Sequential()
model_LA.add(LSTM(units=128, input_shape = (n_timesteps,n_features)))
model_LA.add(Dense(128, activation='relu'))
model_LA.add(Dense(n_outputs, activation='softmax'))

# compile
model_LA.compile(optimizer='adam', metrics=['accuracy'], loss='categorical_crossentropy')
# Out:
# /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/keras/src/layers/rnn/rnn.py:204: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)

# %%
# 모델 시각화

model_LA.summary()
keras.utils.plot_model(model_LA, show_dtype=True,
                      show_layer_activations=True,
                      show_layer_names=True, 
                       show_shapes=True,
                       show_trainable=True)
# Out:
# Model: "sequential_3"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ lstm_5 (LSTM)                   │ (None, 128)            │        93,696 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_18 (Dense)                │ (None, 128)            │        16,512 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_19 (Dense)                │ (None, 19)             │         2,451 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 112,659 (440.07 KB)
#  Trainable params: 112,659 (440.07 KB)
#  Non-trainable params: 0 (0.00 B)

# %%
# fit 

history_LA = model_LA.fit(X_train_seq_LA, 
                    y_train_seq_LA, 
                    epochs = 20, batch_size = 32, 
                    validation_split = 0.1, shuffle = True)
# Out:
# Epoch 1/20
# 193/193 ━━━━━━━━━━━━━━━━━━━━ 3s 7ms/step - accuracy: 0.2300 - loss: 2.4755 - val_accuracy: 0.5731 - val_loss: 1.2476
# Epoch 2/20
# 193/193 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.6295 - loss: 1.0815 - val_accuracy: 0.7003 - val_loss: 0.9067
# Epoch 3/20
# 193/193 ━━━━━━━━━━━━━━━━━━━━ 2s 10ms/step - accuracy: 0.7776 - loss: 0.7362 - val_accuracy: 0.7807 - val_loss: 0.7236
# Epoch 4/20
# 193/193 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - accuracy: 0.8448 - loss: 0.5484 - val_accuracy: 0.8114 - val_loss: 0.6438
# Epoch 5/20
# 193/193 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - accuracy: 0.8650 - loss: 0.4550 - val_accuracy: 0.8231 - val_loss: 0.6227
# Epoch 6/20
# 193/193 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - accuracy: 0.8891 - loss: 0.3846 - val_accuracy: 0.8626 - val_loss: 0.5623
# Epoch 7/20
# 193/193 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - accuracy: 0.9138 - loss: 0.3064 - val_accuracy: 0.8553 - val_loss: 0.5618
# Epoch 8/20
# 193/193 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - accuracy: 0.9216 - loss: 0.2657 - val_accuracy: 0.8582 - val_loss: 0.5300
# Epoch 9/20
# 193/193 ━━━━━━━━━━━━━━━━━━━━ 2s 9ms/step - accuracy: 0.9279 - loss: 0.2233 - val_accuracy: 0.8670 - val_loss: 0.4948
# Epoch 10/20
# 193/193 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - accuracy: 0.9531 - loss: 0.1656 - val_accuracy: 0.8655 - val_loss: 0.4997
# Epoch 11/20
# 193/193 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.9593 - loss: 0.1463 - val_accuracy: 0.8801 - val_loss: 0.5277
# Epoch 12/20
# 193/193 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - accuracy: 0.9616 - loss: 0.1261 - val_accuracy: 0.8772 - val_loss: 0.5241
# Epoch 13/20
# 193/193 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - accuracy: 0.9702 - loss: 0.1051 - val_accuracy: 0.8801 - val_loss: 0.5211
# Epoch 14/20
# 193/193 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - accuracy: 0.9855 - loss: 0.0702 - val_accuracy: 0.8684 - val_loss: 0.5299
# Epoch 15/20
# 193/193 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - accuracy: 0.9851 - loss: 0.0604 - val_accuracy: 0.8626 - val_loss: 0.5848
# Epoch 16/20
# 193/193 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - accuracy: 0.9849 - loss: 0.0631 - val_accuracy: 0.8582 - val_loss: 0.5921
# Epoch 17/20
# 193/193 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - accuracy: 0.9895 - loss: 0.0406 - val_accuracy: 0.8655 - val_loss: 0.6110
# Epoch 18/20
# 193/193 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - accuracy: 0.9903 - loss: 0.0365 - val_accuracy: 0.8611 - val_loss: 0.6219
# Epoch 19/20
# 193/193 ━━━━━━━━━━━━━━━━━━━━ 2s 9ms/step - accuracy: 0.9949 - loss: 0.0302 - val_accuracy: 0.8743 - val_loss: 0.5983
# Epoch 20/20
# 193/193 ━━━━━━━━━━━━━━━━━━━━ 2s 9ms/step - accuracy: 0.9958 - loss: 0.0233 - val_accuracy: 0.8655 - val_loss: 0.6355

# %%
# loss와 validation loss, acc와 validation acc 시각화

draw_history(history_LA)

# %%
# evaluate

print ("train score : ", model_LA.evaluate(X_train_seq_LA, y_train_seq_LA))
print ("test score : ", model_LA.evaluate(X_test_seq_LA, y_test_seq_LA))
# Out:
# 214/214 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9960 - loss: 0.0244
# train score :  [0.08179057389497757, 0.9836209416389465]
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8690 - loss: 0.5826
# test score :  [0.6115544438362122, 0.8669885993003845]

# %%
# confusion matrix, classification report, accuracy

from sklearn.metrics import confusion_matrix, classification_report, accuracy_score

y_test_arg=np.argmax(y_test_seq_LA, axis=1)
Y_pred = np.argmax(model_LA.predict(X_test_seq_LA),axis=1)
print('Confusion Matrix')
cm = confusion_matrix(y_test_arg, Y_pred)

# confusion matrix 시각화
plt.figure(figsize=(8, 6))  # 그래프 크기 조절 (너비 8, 높이 6)
sns.heatmap(cm, annot=True, fmt="d", cmap="Blues")
plt.show()

# classification report
report = classification_report(y_test_arg, Y_pred)
print (report)
# Out:
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# Confusion Matrix
#               precision    recall  f1-score   support
#
#            0       0.94      0.87      0.90       116
#            1       0.89      0.87      0.88       120
#            2       0.88      0.90      0.89       118
#            3       0.93      0.88      0.90       129
#            4       0.88      0.84      0.86       108
#            5       0.86      0.92      0.89       139
#            6       0.89      0.96      0.93       112
#            7       0.94      0.84      0.89       124
#            8       0.86      0.97      0.91       116
#            9       0.70      0.68      0.69       126
#           10       0.87      0.98      0.92       127
#           11       0.90      0.94      0.92       133
#           12       0.92      0.92      0.92       119
#           13       0.76      0.92      0.83       114
#           14       0.83      0.51      0.64       107
#           15       0.95      0.84      0.89       111
#           16       0.81      0.89      0.85       122
#           17       0.90      0.84      0.87       122
#           18       0.82      0.84      0.83       115
#
#     accuracy                           0.87      2278
#    macro avg       0.87      0.86      0.86      2278
# weighted avg       0.87      0.87      0.86      2278

# %%
# base loss, base accuracy 구하고 저장

base_loss,base_accuracy = model_LA.evaluate(X_test_seq_LA, y_test_seq_LA)

model_file_LA = './model/LA_model.h5'
  
tf.keras.models.save_model(model_LA, model_file_LA, include_optimizer=False)
print('model saved at ', model_file_LA)
#score,keras_file=evaluate_model(trainX,trainy,testX,testy)

score = base_accuracy*100
print('Accuracy >{:f}'.format(score))
print('Base Loss >{:.2f}'.format(base_loss))
# Out:
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8690 - loss: 0.5826
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# model saved at  ./model/LA_model.h5
# Accuracy >86.698860
# Base Loss >0.61

# %% [markdown]
# -----
#
# ### 4. transfer learning - LA model을 base로 둔 RA 기준의 remodeling
# 아래와 같은 순서로 진행된다.
#
# - **(1) LA (Left Arm) 모델 불러오기** : 사전 학습된 LA 모델을 로드한다.
#   - `load_model()` 함수를 사용하여 기존 모델을 불러온다.
#
# - **(2) Layer 동결 및 Fine-tuning 설정** : convolutional layers는 freezing하고, Dense layers만 재학습할 수 있도록 설정한다.
#   - Convolutional layers 혹은 LSTM은 Left Arm과 Right Arm 간 공통 특징을 잡아내므로 고정한다.
#   - Dense layers는 새로운 Right Arm 데이터에 맞춰 재학습하도록 설정한다.
#
# - **(3) RA (Right Arm) 데이터셋을 적용한 출력 레이어 수정** : Left Arm 모델의 출력 레이어를 Right Arm 기준으로 변경한다.
#   - 기존의 feature extraction 부분은 그대로 두고, 새로운 Dense 레이어를 추가한다.
#   - Right Arm 데이터에 맞는 새로운 출력 레이어를 정의한다.
#
# - **(4) RA 데이터로 모델 재학습** : Right Arm 데이터를 사용해 Fine-tuning을 진행하여 모델을 재학습한다.
#   - Dense layers만 재학습하고 나머지 레이어는 기존 가중치를 그대로 사용한다.

# %%
# base 모델 로드 (LA_model.h5)

from tensorflow.keras.models import load_model

base_model = load_model(model_file_LA)
# Out:
# WARNING:absl:No training configuration found in the save file, so the model was *not* compiled. Compile it manually.

# %%
# base 모델을 학습시켰던 LA를 대입하여 평가해본다

base_model.compile(optimizer='adam', metrics=['accuracy'], loss='categorical_crossentropy')
base_model.evaluate(X_test_seq_LA, y_test_seq_LA)

'''
    당연히 뛰어난 결과가 나오는 것이 인지상정이다. 왜냐면 이 데이터로 학습을 시켰으니깐
'''
# Out:
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8690 - loss: 0.5826
# '\n    당연히 뛰어난 결과가 나오는 것이 인지상정이다. 왜냐면 이 데이터로 학습을 시켰으니깐\n'

# %%
# RA를 대입하여 평가해본다

base_model.evaluate(X_test_seq_RA, y_test_seq_RA)

'''
    너무나도 당연한데, LA에 맞게끔 weight와 bias가 조정되어 있는 LA 모델에 RA 데이터셋을 대입하면 
    acc는 낮게, loss는 높게 구성될 수밖에 없는 것이다. 
    
    따라서 LA 모델에서 특정 layer를 freezing시키고, 나머지 Dense layer를 fine-tuning하여
    RA 데이터셋에 acc가 높게 구성될 수 있도록 해본다.
'''
# Out:
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.2333 - loss: 5.2669
# '\n    너무나도 당연한데, LA에 맞게끔 weight와 bias가 조정되어 있는 LA 모델에 RA 데이터셋을 대입하면 \n    acc는 낮게, loss는 높게 구성될 수밖에 없는 것이다. \n    \n    따라서 LA 모델에서 특정 layer를 freezing시키고, 나머지 Dense layer를 fine-tuning하여\n    RA 데이터셋에 acc가 높게 구성될 수 있도록 해본다.\n'

# %%
# 모든 convolutional layers을 동결 
# 목적 : CNN과 같은 feature selection은 기존의 패턴을 인식한 거니깐 추가적으로 가중치를 학습되지 않도록 하기 위해서임

base_model.layers[0].trainable = False  # lstm 층 동결

'''
    전이학습에서 가장 중요한 부분은 기존 모델의 가중치를 어느 정도까지 고정(freeze)하고, 어느 부분을 재학습(fine-tuning)할지 결정해야 함 
    LSTM과 같은 feature extraction에서는 Left Arm과 Right Arm 데이터 간의 공통적인 특징을 잡아낼 수 있기 때문에, 
    일반적으로 고정시키고 Dense layers만 재학습하는 경우가 많다
'''
# Out:
# '\n    전이학습에서 가장 중요한 부분은 기존 모델의 가중치를 어느 정도까지 고정(freeze)하고, 어느 부분을 재학습(fine-tuning)할지 결정해야 함 \n    LSTM과 같은 feature extraction에서는 Left Arm과 Right Arm 데이터 간의 공통적인 특징을 잡아낼 수 있기 때문에, \n    일반적으로 고정시키고 Dense layers만 재학습하는 경우가 많다\n'

# %%
# 기존 LA 모델에서 feature extraction은 가져온다
# -> dense layer를 삽입하여 새로운 RA 데이터셋에서도 가중치를 학습할 수 있도록 한다.
# -> 끝에 클래스 수만큼 노드를 배치하여 분류할 수 있도록 한다

from tensorflow.keras.layers import Dense
from tensorflow.keras.models import Model
import tensorflow as tf

input_data = tf.keras.Input(shape=(n_timesteps, n_features))

x = base_model.layers[0](input_data)  # LSTM 레이어 호출 (non trainable)
x = Dense(64, activation='relu')(x)  # 기존 모델 + 새로운 Dense
output = Dense(n_outputs, activation='softmax')(x)  # RA 데이터셋에 맞는 출력 레이어

model_LA_transfer = Model(inputs=input_data, outputs=output)

# compile
model_LA_transfer.compile(optimizer='adam', 
                 loss='categorical_crossentropy', 
                 metrics=['accuracy'])

# %%
# 시각화하여 layers 보여주기

display_layers = [(layer, layer.name, layer.trainable) for layer in model_LA_transfer.layers]
pd.DataFrame(display_layers, columns=['Layer Type', 'Layer Name', 'Layer Trainable'])
# Out:
#                                      Layer Type      Layer Name  \
# 0  <InputLayer name=input_layer_10, built=True>  input_layer_10
# 1                <LSTM name=lstm_5, built=True>          lstm_5
# 2             <Dense name=dense_20, built=True>        dense_20
# 3             <Dense name=dense_21, built=True>        dense_21
#
#    Layer Trainable
# 0             True
# 1            False
# 2             True
# 3             True

# %%
# fit

history_LA_transfer = model_LA_transfer.fit(X_train_seq_RA, y_train_seq_RA, 
                         epochs = 20, batch_size = 32, 
                         validation_split = 0.1, shuffle = True)
# Out:
# Epoch 1/20
# 193/193 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - accuracy: 0.2300 - loss: 2.5793 - val_accuracy: 0.4825 - val_loss: 1.7371
# Epoch 2/20
# 193/193 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.4951 - loss: 1.6205 - val_accuracy: 0.5643 - val_loss: 1.4397
# Epoch 3/20
# 193/193 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.5683 - loss: 1.3708 - val_accuracy: 0.5819 - val_loss: 1.3580
# Epoch 4/20
# 193/193 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.6022 - loss: 1.2595 - val_accuracy: 0.5892 - val_loss: 1.2851
# Epoch 5/20
# 193/193 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.6344 - loss: 1.1635 - val_accuracy: 0.5921 - val_loss: 1.2409
# Epoch 6/20
# 193/193 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.6504 - loss: 1.0928 - val_accuracy: 0.6228 - val_loss: 1.2068
# Epoch 7/20
# 193/193 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.6893 - loss: 1.0267 - val_accuracy: 0.6272 - val_loss: 1.1894
# Epoch 8/20
# 193/193 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.6824 - loss: 1.0194 - val_accuracy: 0.6389 - val_loss: 1.1638
# Epoch 9/20
# 193/193 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.6847 - loss: 0.9932 - val_accuracy: 0.6374 - val_loss: 1.1481
# Epoch 10/20
# 193/193 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.6883 - loss: 0.9695 - val_accuracy: 0.6360 - val_loss: 1.1483
# Epoch 11/20
# 193/193 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7039 - loss: 0.9564 - val_accuracy: 0.6389 - val_loss: 1.1261
# Epoch 12/20
# 193/193 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7057 - loss: 0.9053 - val_accuracy: 0.6316 - val_loss: 1.1442
# Epoch 13/20
# 193/193 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7244 - loss: 0.9008 - val_accuracy: 0.6520 - val_loss: 1.1327
# Epoch 14/20
# 193/193 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7146 - loss: 0.8983 - val_accuracy: 0.6491 - val_loss: 1.1037
# Epoch 15/20
# 193/193 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7374 - loss: 0.8599 - val_accuracy: 0.6637 - val_loss: 1.1012
# Epoch 16/20
# 193/193 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7331 - loss: 0.8332 - val_accuracy: 0.6550 - val_loss: 1.0784
# Epoch 17/20
# 193/193 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7452 - loss: 0.8296 - val_accuracy: 0.6447 - val_loss: 1.0809
# Epoch 18/20
# 193/193 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7392 - loss: 0.8278 - val_accuracy: 0.6243 - val_loss: 1.1385
# Epoch 19/20
# 193/193 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.7425 - loss: 0.8195 - val_accuracy: 0.6564 - val_loss: 1.0885
# Epoch 20/20
# 193/193 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7489 - loss: 0.7681 - val_accuracy: 0.6594 - val_loss: 1.0616

# %%
# loss와 validation loss, acc와 validation acc 시각화

draw_history(history_LA_transfer)

# %%
# evaluate

eval_transfer = model_LA_transfer.evaluate(X_test_seq_RA, y_test_seq_RA)

'''
    좋지 못한 acc를 보이고 있으므로, 아래와 같은 방법을 생각할 수 있겠다.
    
    1) 모든 layer의 trainable을 True로 바꾸어서 fine-tuning
    2) trainable을 False로 두어 LSTM을 하나 더 추가하여 본다
'''
# Out:
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.6766 - loss: 1.0492
# '\n    좋지 못한 acc를 보이고 있으므로, 아래와 같은 방법을 생각할 수 있겠다.\n    \n    1) 모든 layer의 trainable을 True로 바꾸어서 fine-tuning\n    2) LSTM을 하나 더 추가하여 RA에 맞는 weight를 학습시킨다\n'

# %% [markdown]
# #### fine-tuning : 모든 layer의 trainable을 True로 바꾸어 다시 학습을 진행

# %%
# 이전에 model_LA에서의 layer 중 LSTM의 trainable을 False로 바꾼 것을 번복. 다시 True로 구성
# 구성 후 modeling

base_model.layers[0].trainable = True 

input_data = tf.keras.Input(shape=(n_timesteps, n_features))

x = base_model.layers[0](input_data)  # LSTM 레이어 호출 (trainable)
x = Dense(64, activation='relu')(x)  # 기존 모델 + 새로운 Dense
output = Dense(n_outputs, activation='softmax')(x)  # RA 데이터셋에 맞는 출력 레이어

model_LA_transfer = Model(inputs=input_data, outputs=output)

# compile
model_LA_transfer.compile(optimizer='adam', 
                 loss='categorical_crossentropy', 
                 metrics=['accuracy'])

# %%
# layers 시각화, trainable 시각화, model summary

model_LA_transfer.summary()

display_layers = [(layer, layer.name, layer.trainable) for layer in model_LA_transfer.layers]
pd.DataFrame(display_layers, columns=['Layer Type', 'Layer Name', 'Layer Trainable'])
# Out:
# Model: "functional_28"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ input_layer_11 (InputLayer)     │ (None, 3, 54)          │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ lstm_5 (LSTM)                   │ (None, 128)            │        93,696 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_22 (Dense)                │ (None, 64)             │         8,256 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_23 (Dense)                │ (None, 19)             │         1,235 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 103,187 (403.07 KB)
#  Trainable params: 103,187 (403.07 KB)
#  Non-trainable params: 0 (0.00 B)
#                                      Layer Type      Layer Name  \
# 0  <InputLayer name=input_layer_11, built=True>  input_layer_11
# 1                <LSTM name=lstm_5, built=True>          lstm_5
# 2             <Dense name=dense_22, built=True>        dense_22
# 3             <Dense name=dense_23, built=True>        dense_23
#
#    Layer Trainable
# 0             True
# 1             True
# 2             True
# 3             True

# %%
# fit

history_LA_transfer = model_LA_transfer.fit(X_train_seq_RA, y_train_seq_RA, 
                         epochs = 20, batch_size = 32, 
                         validation_split = 0.1, shuffle = True)
# Out:
# Epoch 1/20
# 193/193 ━━━━━━━━━━━━━━━━━━━━ 3s 9ms/step - accuracy: 0.3301 - loss: 2.2393 - val_accuracy: 0.7427 - val_loss: 0.9826
# Epoch 2/20
# 193/193 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.7751 - loss: 0.8292 - val_accuracy: 0.8056 - val_loss: 0.7439
# Epoch 3/20
# 193/193 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.8508 - loss: 0.5597 - val_accuracy: 0.8275 - val_loss: 0.6823
# Epoch 4/20
# 193/193 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.8703 - loss: 0.4707 - val_accuracy: 0.8333 - val_loss: 0.6405
# Epoch 5/20
# 193/193 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.9029 - loss: 0.3668 - val_accuracy: 0.8275 - val_loss: 0.6363
# Epoch 6/20
# 193/193 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.9135 - loss: 0.3195 - val_accuracy: 0.8567 - val_loss: 0.5761
# Epoch 7/20
# 193/193 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.9412 - loss: 0.2422 - val_accuracy: 0.8567 - val_loss: 0.5897
# Epoch 8/20
# 193/193 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.9371 - loss: 0.2371 - val_accuracy: 0.8480 - val_loss: 0.5580
# Epoch 9/20
# 193/193 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.9582 - loss: 0.1662 - val_accuracy: 0.8699 - val_loss: 0.5706
# Epoch 10/20
# 193/193 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.9632 - loss: 0.1448 - val_accuracy: 0.8480 - val_loss: 0.5934
# Epoch 11/20
# 193/193 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.9729 - loss: 0.1104 - val_accuracy: 0.8640 - val_loss: 0.5667
# Epoch 12/20
# 193/193 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.9758 - loss: 0.1038 - val_accuracy: 0.8465 - val_loss: 0.5977
# Epoch 13/20
# 193/193 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.9866 - loss: 0.0690 - val_accuracy: 0.8596 - val_loss: 0.5776
# Epoch 14/20
# 193/193 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.9872 - loss: 0.0633 - val_accuracy: 0.8567 - val_loss: 0.6188
# Epoch 15/20
# 193/193 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.9940 - loss: 0.0448 - val_accuracy: 0.8626 - val_loss: 0.6139
# Epoch 16/20
# 193/193 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.9881 - loss: 0.0500 - val_accuracy: 0.8699 - val_loss: 0.6045
# Epoch 17/20
# 193/193 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.9973 - loss: 0.0234 - val_accuracy: 0.8596 - val_loss: 0.6537
# Epoch 18/20
# 193/193 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.9975 - loss: 0.0216 - val_accuracy: 0.8465 - val_loss: 0.6772
# Epoch 19/20
# 193/193 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.9965 - loss: 0.0238 - val_accuracy: 0.8684 - val_loss: 0.6614
# Epoch 20/20
# 193/193 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.9984 - loss: 0.0195 - val_accuracy: 0.8596 - val_loss: 0.6789

# %%
# evaluate (RA)

eval_transfer = model_LA_transfer.evaluate(X_test_seq_RA, y_test_seq_RA)
# Out:
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8765 - loss: 0.6343

# %%
# evaluate (LA)

eval_transfer = model_LA_transfer.evaluate(X_test_seq_LA, y_test_seq_LA)
# Out:
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.3077 - loss: 4.0108

# %% [markdown]
# #### experiment : trainable를 False로 다시 두어서 LSTM 층을 하나 더 추가하여 학습하기

# %%
# 이전에 model_LA에서의 layer 중 LSTM의 trainable을 다시 False로 구성 -> LSTM층 추가
# 구성 후 modeling

base_model.layers[0].trainable = False  # 다시 동결 

input_data = tf.keras.Input(shape=(n_timesteps, n_features))

'''
    이전 model에서 return_sequences=True를 설정할 수 없어,
    RepeatVector를 사용하여 LSTM으로부터 출력된 2차원 데이터를 3차원 데이터로 재구성한다.
'''

x = base_model.layers[0](input_data)  # LSTM 레이어 호출 (non trainable)
x = tf.keras.layers.RepeatVector(n_timesteps)(x)  # Reshape output to 3D for LSTM
x = LSTM(32, activation='tanh', return_sequences=False)(x)  # LSTM 새로 추가
x = Dense(32, activation='relu')(x)  # 기존 모델 + 새로운 Dense
output = Dense(n_outputs, activation='softmax')(x)  # RA 데이터셋에 맞는 출력 레이어

model_LA_transfer = tf.keras.Model(inputs=input_data, outputs=output)

# compile
model_LA_transfer.compile(optimizer='adam', 
                 loss='categorical_crossentropy', 
                 metrics=['accuracy'])

# %%
# layers 시각화, trainable 시각화, model summary

model_LA_transfer.summary()

display_layers = [(layer, layer.name, layer.trainable) for layer in model_LA_transfer.layers]
pd.DataFrame(display_layers, columns=['Layer Type', 'Layer Name', 'Layer Trainable'])
# Out:
# Model: "functional_29"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ input_layer_12 (InputLayer)     │ (None, 3, 54)          │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ lstm_5 (LSTM)                   │ (None, 128)            │        93,696 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ repeat_vector_2 (RepeatVector)  │ (None, 3, 128)         │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ lstm_6 (LSTM)                   │ (None, 32)             │        20,608 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_24 (Dense)                │ (None, 32)             │         1,056 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_25 (Dense)                │ (None, 19)             │           627 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 115,987 (453.07 KB)
#  Trainable params: 22,291 (87.07 KB)
#  Non-trainable params: 93,696 (366.00 KB)
#                                         Layer Type       Layer Name  \
# 0     <InputLayer name=input_layer_12, built=True>   input_layer_12
# 1                   <LSTM name=lstm_5, built=True>           lstm_5
# 2  <RepeatVector name=repeat_vector_2, built=True>  repeat_vector_2
# 3                   <LSTM name=lstm_6, built=True>           lstm_6
# 4                <Dense name=dense_24, built=True>         dense_24
# 5                <Dense name=dense_25, built=True>         dense_25
#
#    Layer Trainable
# 0             True
# 1            False
# 2             True
# 3             True
# 4             True
# 5             True

# %%
# fit

history_LA_transfer = model_LA_transfer.fit(X_train_seq_LA, y_train_seq_LA, 
                         epochs = 20, batch_size = 32, 
                         validation_split = 0.1, shuffle = True)
# Out:
# Epoch 1/20
# 193/193 ━━━━━━━━━━━━━━━━━━━━ 3s 5ms/step - accuracy: 0.3010 - loss: 2.4409 - val_accuracy: 0.7164 - val_loss: 1.0784
# Epoch 2/20
# 193/193 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.7385 - loss: 0.9499 - val_accuracy: 0.7807 - val_loss: 0.8315
# Epoch 3/20
# 193/193 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.7980 - loss: 0.6864 - val_accuracy: 0.7749 - val_loss: 0.7815
# Epoch 4/20
# 193/193 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.8213 - loss: 0.6198 - val_accuracy: 0.7924 - val_loss: 0.7368
# Epoch 5/20
# 193/193 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.8374 - loss: 0.5634 - val_accuracy: 0.8056 - val_loss: 0.7103
# Epoch 6/20
# 193/193 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.8650 - loss: 0.4714 - val_accuracy: 0.7909 - val_loss: 0.7069
# Epoch 7/20
# 193/193 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.8690 - loss: 0.4517 - val_accuracy: 0.8231 - val_loss: 0.6826
# Epoch 8/20
# 193/193 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.8855 - loss: 0.3917 - val_accuracy: 0.8275 - val_loss: 0.6883
# Epoch 9/20
# 193/193 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.8908 - loss: 0.3751 - val_accuracy: 0.8216 - val_loss: 0.6883
# Epoch 10/20
# 193/193 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.8973 - loss: 0.3370 - val_accuracy: 0.8129 - val_loss: 0.6937
# Epoch 11/20
# 193/193 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.9142 - loss: 0.3137 - val_accuracy: 0.8202 - val_loss: 0.7047
# Epoch 12/20
# 193/193 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.9228 - loss: 0.2778 - val_accuracy: 0.8056 - val_loss: 0.7212
# Epoch 13/20
# 193/193 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.9332 - loss: 0.2513 - val_accuracy: 0.8187 - val_loss: 0.7203
# Epoch 14/20
# 193/193 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.9380 - loss: 0.2258 - val_accuracy: 0.8070 - val_loss: 0.7353
# Epoch 15/20
# 193/193 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.9408 - loss: 0.2203 - val_accuracy: 0.8173 - val_loss: 0.7450
# Epoch 16/20
# 193/193 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.9446 - loss: 0.2004 - val_accuracy: 0.8275 - val_loss: 0.7722
# Epoch 17/20
# 193/193 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.9500 - loss: 0.1812 - val_accuracy: 0.8070 - val_loss: 0.7778
# Epoch 18/20
# 193/193 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.9528 - loss: 0.1707 - val_accuracy: 0.8099 - val_loss: 0.7971
# Epoch 19/20
# 193/193 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.9594 - loss: 0.1570 - val_accuracy: 0.8070 - val_loss: 0.8324
# Epoch 20/20
# 193/193 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.9622 - loss: 0.1367 - val_accuracy: 0.8056 - val_loss: 0.8579

# %%
# evaluate (RA)

eval_transfer = model_LA_transfer.evaluate(X_test_seq_RA, y_test_seq_RA)
# Out:
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.3599 - loss: 3.2156

# %%
# evaluate (LA)

eval_transfer = model_LA_transfer.evaluate(X_test_seq_LA, y_test_seq_LA)

# 이러면 또 LA에 맞게끔 학습된다.
# Out:
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8157 - loss: 0.7917

# %% [markdown]
# ---
#
# ### 5. transfer learning - RA Model을 base로 둔 LA 기준의 remodeling
#
# 아래와 같은 순서로 진행된다.
#
# - **(1) RA (Right Arm) 모델 불러오기**: 사전 학습된 RA 모델을 로드한다.
#   - `load_model()` 함수를 사용하여 기존 모델을 불러온다.
#
# - **(2) Layer 동 및 Fine-tuning 설정**: convolutional layers는 freezing하고, Dense layers만 재학습할 수 있도록 설정한다.
#   - Convolutional layers 또는 LSTM은 Left Arm과 Right Arm 간 공통 특징을 잡아내므로 고정한다.
#   - Dense layers는 새로운 left arm 데이터에 맞춰 재학습하도록 설정한다.
#
# - **(3) LA (Left Arm) 데이터셋을 적용한 출력 레이어 수정**: Left Arm 모델의 출력 레이어를 Right Arm 기준으로 변경한다.
#   - 기존의 feature extraction 부분은 그대로 두고, 새로운 Dense 레이어를 추가한다.
#   - left Arm 데이터에 맞는 새로운 출력 레이어를 정의한다.
#
# - **(4) LA 데이터로 모델 재학습**: left Arm 데이터를 사용해 Fine-tuning을 진행하여 모델을 재학습한다.
#   - Dense layers만 재학습하고 나머지 레이어는 기존 가중치를 그대로 사용한다.

# %%
# base 모델 로드 (RA_model.h5)

from tensorflow.keras.models import load_model

base_model = load_model(model_file_RA)
# Out:
# WARNING:absl:No training configuration found in the save file, so the model was *not* compiled. Compile it manually.

# %%
# base 모델을 학습시켰던 RA를 대입하여 평가해본다

base_model.compile(optimizer='adam', metrics=['accuracy'], loss='categorical_crossentropy')
base_model.evaluate(X_test_seq_RA, y_test_seq_RA)
# Out:
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.8650 - loss: 0.6808
# [0.6899632215499878, 0.862159788608551]

# %%
# LA를 대입하여 평가해본다

base_model.evaluate(X_test_seq_LA, y_test_seq_LA)
# Out:
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.2478 - loss: 7.3532
# [7.256664276123047, 0.24539069831371307]

# %%
# 모든 convolutional layers을 동결 
# 목적 : CNN과 같은 feature selection은 기존의 패턴을 인식한 거니깐 추가적으로 가중치를 학습되지 않도록 하기 위해서임

base_model.layers[0].trainable = False  # lstm 층 동결

# %%
# 기존 RA 모델에서 feature extraction은 가져온다
# -> dense layer를 삽입하여 새로운 LA 데이터셋에서도 가중치를 학습할 수 있도록 한다.
# -> 끝에 클래스 수만큼 노드를 배치하여 분류할 수 있도록 한다

from tensorflow.keras.layers import Dense
from tensorflow.keras.models import Model
import tensorflow as tf

input_data = tf.keras.Input(shape=(n_timesteps, n_features))

x = base_model.layers[0](input_data)  # LSTM 레이어 호출 (non trainable)
x = Dense(64, activation='relu')(x)  # 기존 모델 + 새로운 Dense
output = Dense(n_outputs, activation='softmax')(x)  # LA 데이터셋에 맞는 출력 레이어

model_RA_transfer = Model(inputs=input_data, outputs=output)

# compile
model_RA_transfer.compile(optimizer='adam', 
                 loss='categorical_crossentropy', 
                 metrics=['accuracy'])

# %%
# layers 시각화, trainable 시각화, model summary

model_RA_transfer.summary()

display_layers = [(layer, layer.name, layer.trainable) for layer in model_RA_transfer.layers]
pd.DataFrame(display_layers, columns=['Layer Type', 'Layer Name', 'Layer Trainable'])
# Out:
# Model: "functional_33"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ input_layer_13 (InputLayer)     │ (None, 3, 54)          │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ lstm_4 (LSTM)                   │ (None, 128)            │        93,696 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_26 (Dense)                │ (None, 64)             │         8,256 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_27 (Dense)                │ (None, 19)             │         1,235 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 103,187 (403.07 KB)
#  Trainable params: 9,491 (37.07 KB)
#  Non-trainable params: 93,696 (366.00 KB)
#                                      Layer Type      Layer Name  \
# 0  <InputLayer name=input_layer_13, built=True>  input_layer_13
# 1                <LSTM name=lstm_4, built=True>          lstm_4
# 2             <Dense name=dense_26, built=True>        dense_26
# 3             <Dense name=dense_27, built=True>        dense_27
#
#    Layer Trainable
# 0             True
# 1            False
# 2             True
# 3             True

# %%
# fit

history_RA_transfer = model_RA_transfer.fit(X_train_seq_LA, y_train_seq_LA, 
                         epochs = 20, batch_size = 32, 
                         validation_split = 0.1, shuffle = True)
# Out:
# Epoch 1/20
# 193/193 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - accuracy: 0.2495 - loss: 2.4863 - val_accuracy: 0.5541 - val_loss: 1.4954
# Epoch 2/20
# 193/193 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.5707 - loss: 1.4001 - val_accuracy: 0.6126 - val_loss: 1.2495
# Epoch 3/20
# 193/193 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.6312 - loss: 1.1731 - val_accuracy: 0.6506 - val_loss: 1.1405
# Epoch 4/20
# 193/193 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.6587 - loss: 1.0820 - val_accuracy: 0.6623 - val_loss: 1.1023
# Epoch 5/20
# 193/193 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.6880 - loss: 1.0251 - val_accuracy: 0.6637 - val_loss: 1.0575
# Epoch 6/20
# 193/193 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.7017 - loss: 0.9464 - val_accuracy: 0.6711 - val_loss: 1.0603
# Epoch 7/20
# 193/193 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.7134 - loss: 0.9216 - val_accuracy: 0.6769 - val_loss: 1.0120
# Epoch 8/20
# 193/193 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.7230 - loss: 0.8612 - val_accuracy: 0.6784 - val_loss: 1.0073
# Epoch 9/20
# 193/193 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.7418 - loss: 0.8212 - val_accuracy: 0.6842 - val_loss: 1.0038
# Epoch 10/20
# 193/193 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.7515 - loss: 0.7818 - val_accuracy: 0.6740 - val_loss: 1.0106
# Epoch 11/20
# 193/193 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.7435 - loss: 0.7942 - val_accuracy: 0.6974 - val_loss: 0.9806
# Epoch 12/20
# 193/193 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.7536 - loss: 0.7836 - val_accuracy: 0.6988 - val_loss: 0.9485
# Epoch 13/20
# 193/193 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.7717 - loss: 0.7390 - val_accuracy: 0.7061 - val_loss: 0.9681
# Epoch 14/20
# 193/193 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.7720 - loss: 0.7167 - val_accuracy: 0.7032 - val_loss: 0.9537
# Epoch 15/20
# 193/193 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.7811 - loss: 0.7073 - val_accuracy: 0.7120 - val_loss: 0.9442
# Epoch 16/20
# 193/193 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.7891 - loss: 0.6846 - val_accuracy: 0.6974 - val_loss: 0.9546
# Epoch 17/20
# 193/193 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.7901 - loss: 0.6919 - val_accuracy: 0.7091 - val_loss: 0.9447
# Epoch 18/20
# 193/193 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.7968 - loss: 0.6533 - val_accuracy: 0.7237 - val_loss: 0.9433
# Epoch 19/20
# 193/193 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.8043 - loss: 0.6481 - val_accuracy: 0.7032 - val_loss: 0.9754
# Epoch 20/20
# 193/193 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.7953 - loss: 0.6527 - val_accuracy: 0.7032 - val_loss: 0.9476

# %%
# loss와 validation loss, acc와 validation acc 시각화

draw_history(history_RA_transfer)

# %%
# evaluate

eval_transfer = model_RA_transfer.evaluate(X_test_seq_LA, y_test_seq_LA)

'''
    좋지 못한 acc를 보이고 있으므로, 아래와 같은 방법을 생각할 수 있겠다.
    
    1) 모든 layer의 trainable을 True로 바꾸어서 fine-tuning
    2) trainable을 False로 두어 LSTM을 하나 더 추가하여 본다
'''
# Out:
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.6961 - loss: 0.9439
# '\n    좋지 못한 acc를 보이고 있으므로, 아래와 같은 방법을 생각할 수 있겠다.\n    \n    1) 모든 layer의 trainable을 True로 바꾸어 fine-tuning\n    2) LSTM을 하나 더 추가한다.\n'

# %% [markdown]
# #### fine-tuning : 모든 layer의 trainable을 True로 바꾸어 다시 학습을 진행

# %%
# 이전에 model RA에서의 layer 중 LSTM의 trainable을 False로 바꾼 것을 번복. 다시 True로 구성
# 구성 후 modeling

base_model.layers[0].trainable = True 

input_data = tf.keras.Input(shape=(n_timesteps, n_features))

x = base_model.layers[0](input_data)  # LSTM 레이어 호출 (trainable)
x = Dense(64, activation='relu')(x)  # 기존 모델 + 새로운 Dense
output = Dense(n_outputs, activation='softmax')(x)  # RA 데이터셋에 맞는 출력 레이어

model_RA_transfer = Model(inputs=input_data, outputs=output)

# compile
model_RA_transfer.compile(optimizer='adam', 
                 loss='categorical_crossentropy', 
                 metrics=['accuracy'])

# %%
# layers 시각화, trainable 시각화, model summary

model_RA_transfer.summary()

display_layers = [(layer, layer.name, layer.trainable) for layer in model_RA_transfer.layers]
pd.DataFrame(display_layers, columns=['Layer Type', 'Layer Name', 'Layer Trainable'])
# Out:
# Model: "functional_34"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ input_layer_14 (InputLayer)     │ (None, 3, 54)          │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ lstm_4 (LSTM)                   │ (None, 128)            │        93,696 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_28 (Dense)                │ (None, 64)             │         8,256 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_29 (Dense)                │ (None, 19)             │         1,235 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 103,187 (403.07 KB)
#  Trainable params: 103,187 (403.07 KB)
#  Non-trainable params: 0 (0.00 B)
#                                      Layer Type      Layer Name  \
# 0  <InputLayer name=input_layer_14, built=True>  input_layer_14
# 1                <LSTM name=lstm_4, built=True>          lstm_4
# 2             <Dense name=dense_28, built=True>        dense_28
# 3             <Dense name=dense_29, built=True>        dense_29
#
#    Layer Trainable
# 0             True
# 1             True
# 2             True
# 3             True

# %%
# fit

history_RA_transfer = model_RA_transfer.fit(X_train_seq_LA, y_train_seq_LA, 
                         epochs = 20, batch_size = 32, 
                         validation_split = 0.1, shuffle = True)
# Out:
# Epoch 1/20
# 193/193 ━━━━━━━━━━━━━━━━━━━━ 3s 6ms/step - accuracy: 0.3800 - loss: 2.1623 - val_accuracy: 0.7500 - val_loss: 0.9138
# Epoch 2/20
# 193/193 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.7906 - loss: 0.7489 - val_accuracy: 0.8231 - val_loss: 0.6671
# Epoch 3/20
# 193/193 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.8598 - loss: 0.5286 - val_accuracy: 0.8406 - val_loss: 0.6175
# Epoch 4/20
# 193/193 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.8911 - loss: 0.4063 - val_accuracy: 0.8728 - val_loss: 0.5188
# Epoch 5/20
# 193/193 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.9121 - loss: 0.3449 - val_accuracy: 0.8728 - val_loss: 0.5168
# Epoch 6/20
# 193/193 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.9276 - loss: 0.2685 - val_accuracy: 0.8772 - val_loss: 0.5043
# Epoch 7/20
# 193/193 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.9364 - loss: 0.2269 - val_accuracy: 0.8743 - val_loss: 0.4962
# Epoch 8/20
# 193/193 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.9476 - loss: 0.1992 - val_accuracy: 0.8699 - val_loss: 0.4991
# Epoch 9/20
# 193/193 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.9598 - loss: 0.1491 - val_accuracy: 0.8728 - val_loss: 0.5024
# Epoch 10/20
# 193/193 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.9725 - loss: 0.1211 - val_accuracy: 0.8743 - val_loss: 0.5097
# Epoch 11/20
# 193/193 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.9764 - loss: 0.0982 - val_accuracy: 0.8801 - val_loss: 0.4818
# Epoch 12/20
# 193/193 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.9843 - loss: 0.0793 - val_accuracy: 0.8816 - val_loss: 0.5166
# Epoch 13/20
# 193/193 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.9892 - loss: 0.0599 - val_accuracy: 0.8830 - val_loss: 0.4970
# Epoch 14/20
# 193/193 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.9878 - loss: 0.0542 - val_accuracy: 0.8699 - val_loss: 0.5962
# Epoch 15/20
# 193/193 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.9911 - loss: 0.0452 - val_accuracy: 0.8728 - val_loss: 0.5333
# Epoch 16/20
# 193/193 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.9924 - loss: 0.0404 - val_accuracy: 0.8757 - val_loss: 0.5773
# Epoch 17/20
# 193/193 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.9933 - loss: 0.0300 - val_accuracy: 0.8830 - val_loss: 0.5754
# Epoch 18/20
# 193/193 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.9973 - loss: 0.0220 - val_accuracy: 0.8757 - val_loss: 0.5819
# Epoch 19/20
# 193/193 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.9991 - loss: 0.0134 - val_accuracy: 0.8845 - val_loss: 0.6003
# Epoch 20/20
# 193/193 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.9994 - loss: 0.0108 - val_accuracy: 0.8684 - val_loss: 0.6404

# %%
# evaluate (LA)

eval_transfer = model_RA_transfer.evaluate(X_test_seq_LA, y_test_seq_LA)
# Out:
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9047 - loss: 0.5313

# %%
# evaluate (RA)

eval_transfer = model_RA_transfer.evaluate(X_test_seq_RA, y_test_seq_RA)
# Out:
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.2947 - loss: 4.5786

# %% [markdown]
# #### experiment : trainable를 False로 다시 두어서 LSTM 층을 하나 더 추가하여 학습하기

# %%
# 이전에 model_RA에서의 layer 중 LSTM의 trainable을 다시 False로 구성 -> LSTM층 추가
# 구성 후 modeling

base_model.layers[0].trainable = False  # 다시 동결 

input_data = tf.keras.Input(shape=(n_timesteps, n_features))

'''
    이전 model에서 return_sequences=True를 설정할 수 없어,
    RepeatVector를 사용하여 LSTM으로부터 출력된 2차원 데이터를 3차원 데이터로 재구성한다.
'''

x = base_model.layers[0](input_data)  # LSTM 레이어 호출 (non trainable)
x = tf.keras.layers.RepeatVector(n_timesteps)(x)  # Reshape output to 3D for LSTM
x = LSTM(32, activation='tanh', return_sequences=False)(x)  # LSTM 새로 추가
x = Dense(32, activation='relu')(x)  # 기존 모델 + 새로운 Dense
output = Dense(n_outputs, activation='softmax')(x)  # LA 데이터셋에 맞는 출력 레이어

model_RA_transfer = tf.keras.Model(inputs=input_data, outputs=output)

# compile
model_RA_transfer.compile(optimizer='adam', 
                 loss='categorical_crossentropy', 
                 metrics=['accuracy'])

# %%
# layers 시각화, trainable 시각화, model summary

model_RA_transfer.summary()

display_layers = [(layer, layer.name, layer.trainable) for layer in model_RA_transfer.layers]
pd.DataFrame(display_layers, columns=['Layer Type', 'Layer Name', 'Layer Trainable'])
# Out:
# Model: "functional_35"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ input_layer_15 (InputLayer)     │ (None, 3, 54)          │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ lstm_4 (LSTM)                   │ (None, 128)            │        93,696 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ repeat_vector_3 (RepeatVector)  │ (None, 3, 128)         │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ lstm_7 (LSTM)                   │ (None, 32)             │        20,608 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_30 (Dense)                │ (None, 32)             │         1,056 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_31 (Dense)                │ (None, 19)             │           627 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 115,987 (453.07 KB)
#  Trainable params: 22,291 (87.07 KB)
#  Non-trainable params: 93,696 (366.00 KB)
#                                         Layer Type       Layer Name  \
# 0     <InputLayer name=input_layer_15, built=True>   input_layer_15
# 1                   <LSTM name=lstm_4, built=True>           lstm_4
# 2  <RepeatVector name=repeat_vector_3, built=True>  repeat_vector_3
# 3                   <LSTM name=lstm_7, built=True>           lstm_7
# 4                <Dense name=dense_30, built=True>         dense_30
# 5                <Dense name=dense_31, built=True>         dense_31
#
#    Layer Trainable
# 0             True
# 1            False
# 2             True
# 3             True
# 4             True
# 5             True

# %%
# fit

history_RA_transfer = model_RA_transfer.fit(X_train_seq_LA, y_train_seq_LA, 
                         epochs = 20, batch_size = 32, 
                         validation_split = 0.1, shuffle = True)
# Out:
# Epoch 1/20
# 193/193 ━━━━━━━━━━━━━━━━━━━━ 3s 4ms/step - accuracy: 0.4014 - loss: 2.2149 - val_accuracy: 0.8450 - val_loss: 0.7389
# Epoch 2/20
# 193/193 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.8986 - loss: 0.4335 - val_accuracy: 0.8816 - val_loss: 0.5615
# Epoch 3/20
# 193/193 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.9536 - loss: 0.2077 - val_accuracy: 0.8772 - val_loss: 0.5511
# Epoch 4/20
# 193/193 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.9681 - loss: 0.1417 - val_accuracy: 0.8787 - val_loss: 0.5823
# Epoch 5/20
# 193/193 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.9838 - loss: 0.0843 - val_accuracy: 0.8743 - val_loss: 0.5931
# Epoch 6/20
# 193/193 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.9904 - loss: 0.0556 - val_accuracy: 0.8728 - val_loss: 0.6174
# Epoch 7/20
# 193/193 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.9954 - loss: 0.0414 - val_accuracy: 0.8830 - val_loss: 0.6329
# Epoch 8/20
# 193/193 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.9963 - loss: 0.0319 - val_accuracy: 0.8699 - val_loss: 0.6779
# Epoch 9/20
# 193/193 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.9992 - loss: 0.0186 - val_accuracy: 0.8772 - val_loss: 0.6864
# Epoch 10/20
# 193/193 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.9989 - loss: 0.0152 - val_accuracy: 0.8772 - val_loss: 0.7153
# Epoch 11/20
# 193/193 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.9999 - loss: 0.0112 - val_accuracy: 0.8801 - val_loss: 0.7269
# Epoch 12/20
# 193/193 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.9995 - loss: 0.0089 - val_accuracy: 0.8757 - val_loss: 0.7564
# Epoch 13/20
# 193/193 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 1.0000 - loss: 0.0068 - val_accuracy: 0.8772 - val_loss: 0.7727
# Epoch 14/20
# 193/193 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 1.0000 - loss: 0.0054 - val_accuracy: 0.8801 - val_loss: 0.8027
# Epoch 15/20
# 193/193 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 1.0000 - loss: 0.0042 - val_accuracy: 0.8772 - val_loss: 0.8221
# Epoch 16/20
# 193/193 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 1.0000 - loss: 0.0035 - val_accuracy: 0.8713 - val_loss: 0.8319
# Epoch 17/20
# 193/193 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 1.0000 - loss: 0.0028 - val_accuracy: 0.8699 - val_loss: 0.8567
# Epoch 18/20
# 193/193 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 1.0000 - loss: 0.0024 - val_accuracy: 0.8743 - val_loss: 0.8634
# Epoch 19/20
# 193/193 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 1.0000 - loss: 0.0020 - val_accuracy: 0.8787 - val_loss: 0.8752
# Epoch 20/20
# 193/193 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 1.0000 - loss: 0.0016 - val_accuracy: 0.8743 - val_loss: 0.9002

# %%
# evaluate (RA)

eval_transfer = model_LA_transfer.evaluate(X_test_seq_RA, y_test_seq_RA)
# Out:
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.3599 - loss: 3.2156

# %%
# evaluate (LA)

eval_transfer = model_LA_transfer.evaluate(X_test_seq_LA, y_test_seq_LA)
# Out:
# 72/72 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8157 - loss: 0.7917
