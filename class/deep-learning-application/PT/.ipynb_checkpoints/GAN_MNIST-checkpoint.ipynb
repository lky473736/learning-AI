# %% [markdown]
# ## learning-AI : deep learning application (61357002)
# ### PT : MNIST GAN
#
# **MNIST 데이터셋을 이용하여 GAN 실습**
#
# <br>
#
# - **임규연 (lky473736)**
# - 2024.10.30.에 문서 작성
# - **Reference**
#     - https://github.com/shinyflight/Simple-GAN-TensorFlow-2.0/blob/master/GAN.py
#     - https://ddongwon.tistory.com/124
#     - https://colab.research.google.com/drive/12CqGv89Z14jXR5RHLFI9XAEXQ4YhlK5R?source=post_page-----a073a5425ef2--------------------------------#scrollTo=a891995d-3de8-45a7-b88c-4a24a65a4547
#     - https://www.tensorflow.org/tutorials/generative/dcgan?hl=ko
#
#
# ## <span id='dl'><mark>DL</mark></span>
#
# MNIST dataset을 이용하여 적대적 생성 신경망인 **GAN : Generative Adversarial Networks을 실습**해본다. GAN은 두 개의 신경망, 즉 **생성기(Generator)와 판별기(Discriminator)로 구성**되어 있다. 생성기는 랜덤 노이즈(z)를 입력으로 받아 가짜 이미지를 생성하는 역할을 하며, 그 목표는 판별기를 속일 수 있는 진짜 같은 이미지를 만들어내는 것이다. 반면, 판별기는 진짜 이미지와 생성기가 만든 가짜 이미지를 입력받아 이들이 진짜인지 가짜인지 구별하는 역할을 하며, 진짜와 가짜 이미지를 정확히 분류하는 것이 목표이다.

# %%
import pandas as pd
from sklearn.model_selection import StratifiedShuffleSplit
from scipy.stats import skew
import os
import csv
import matplotlib.pyplot as plt
import seaborn as sns
import tensorflow as tf
from tensorflow import keras
import numpy as np
import scipy
from tqdm import tqdm
from tensorflow.keras import layers, models, optimizers
# Out:
# 2024-10-30 23:49:47.121641: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.

# %%
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import layers

# cnn model vary kernel size
from numpy import mean
from numpy import std
from numpy import dstack
from pandas import read_csv
from matplotlib import pyplot
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense
from tensorflow.keras.layers import Flatten
from tensorflow.keras.layers import Dropout
from keras.utils import to_categorical

import tensorflow.keras
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Dropout, Flatten, Reshape, LSTM, Conv1D, MaxPooling1D
from tensorflow.keras.layers import TimeDistributed, Conv1D, MaxPooling1D

# %%
import tensorflow as tf
from tensorflow.keras.layers import Dense, LeakyReLU, Reshape, Flatten
from tensorflow.keras.datasets import mnist
import numpy as np
import matplotlib.pyplot as plt

# %%
import numpy as np
import matplotlib.pyplot as plt
from keras.datasets import mnist
from keras.models import Sequential
from keras.layers import Dense, Reshape, Flatten, Dropout
from keras.layers import BatchNormalization
from keras.optimizers import Adam

# %% [markdown]
# -----

# %% [markdown]
# ### GAN
#
# <img src="https://media.licdn.com/dms/image/D5612AQHkJCQXbWOMaQ/article-cover_image-shrink_600_2000/0/1682400466378?e=2147483647&v=beta&t=x7lcQ2xx6gWaS0HPnftVbspyA8fTQXivsEf5_q9gAig" width="500px">
#
# GAN의 작동 순서는 Generator가 랜덤 노이즈를 입력받아 가짜 이미지를 생성하고, 이를 Discriminator에 전달하여 진짜와 가짜를 구분하는 방식으로 동작한다. Discriminator는 실제 이미지와 생성된 가짜 이미지를 입력받아 이진 분류를 수행하며, 이 과정에서 두 네트워크가 서로 경쟁하며 발전하는 구조이다.
#
# Generator는 기본적으로 Decoder 구조와 유사한 형태를 가지는데, 저차원의 랜덤 노이즈를 입력받아 Dense layer를 통해 특징을 확장하고 upsampling 과정을 거쳐 고차원의 이미지를 생성한다. 이 과정에서 tf.keras.layers의 Dense, Conv2DTranspose, BatchNormalization, LeakyReLU가 주로 사용되며, 마지막 출력층에는 Tanh 활성화 함수를 적용한다.
#
# Discriminator는 Encoder 구조와 유사하게 구성되며, 고차원의 이미지를 입력받아 Conv2D layer를 통해 특징을 추출하고 점차 차원을 축소하여 최종적으로 이진 분류를 수행한다. tf.keras.layers의 Conv2D, BatchNormalization, LeakyReLU, Dropout이 주로 사용되며, 마지막 층에는 Dense layer와 Sigmoid 활성화 함수를 통해 진짜/가짜 확률을 출력한다. 이러한 구조는 기본적인 Autoencoder에서 Encoder 부분과 유사한 형태를 보이지만, 목적함수와 학습 방식에서 차이가 있다.
#
# 여기서는 **Dense layer (full connected layer)만을 이용하여 구성한다.**

# %%
# Load the dataset (MNIST)
(x_train, _), (_, _) = tf.keras.datasets.mnist.load_data()  # Load MNIST dataset, ignore test labels
x_train = x_train / 255.0  # Normalize images to the range [0, 1] for better training
x_train = np.expand_dims(x_train, axis=-1)  # Add a channel dimension (shape: [batch_size, 28, 28, 1])

# %%
# Generator Model
def build_generator():
    model = models.Sequential()
    # (None, 100)
    model.add(layers.Dense(128, activation="relu", input_dim=100))  # Input is 100-dim noise
    # (None, 128)
    model.add(layers.Dense(784, activation="sigmoid"))  # Output layer for generating flattened 28x28 image
    # (None, 784)
    model.add(layers.Reshape((28, 28, 1)))
    # (None, 28, 28, 1)
    return model

# %%
# Discriminator Model
def build_discriminator():
    model = models.Sequential()
    # (None,28, 28, 1)
    model.add(layers.Flatten(input_shape=(28, 28, 1)))  # Flatten 28x28 image into a vector
    # (None, 784)
    model.add(layers.Dense(128, activation="relu"))
    # (None, 128)
    model.add(layers.Dense(1, activation="sigmoid"))  # Output layer for binary classification (real or fake)
    # (None, 1)
    return model

# %%
generator = build_generator()
discriminator = build_discriminator()

generator.summary()
discriminator.summary()
# Out:
# /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/keras/src/layers/core/dense.py:87: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/keras/src/layers/reshaping/flatten.py:37: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ dense (Dense)                   │ (None, 128)            │        12,928 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_1 (Dense)                 │ (None, 784)            │       101,136 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ reshape (Reshape)               │ (None, 28, 28, 1)      │             0 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 114,064 (445.56 KB)
#  Trainable params: 114,064 (445.56 KB)
#  Non-trainable params: 0 (0.00 B)
# Model: "sequential_1"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ flatten (Flatten)               │ (None, 784)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_2 (Dense)                 │ (None, 128)            │       100,480 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_3 (Dense)                 │ (None, 1)              │           129 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 100,609 (393.00 KB)
#  Trainable params: 100,609 (393.00 KB)
#  Non-trainable params: 0 (0.00 B)

# %%
# Optimizers for both generator and discriminator
generator_optimizer = optimizers.Adam(learning_rate=0.0001)
discriminator_optimizer = optimizers.Adam(learning_rate=0.0001)

# %%
loss_fn = tf.keras.losses.BinaryCrossentropy(from_logits=False)  #For binary classification tasks (real vs fake)

# Custom training loop for GAN
@tf.function  # For optimization (Tensorflow decorator)
def train_step(real_images):
    batch_size = tf.shape(real_images)[0]  # Get the current batch size

    # Generate fake images
    random_noise = tf.random.normal([batch_size, 100])  # Sample random noise
    generated_images = generator(random_noise)  # Generate images from noise

    real_labels = tf.ones((batch_size, 1))  # Labels for real images (1)
    fake_labels = tf.zeros((batch_size, 1))  # Labels for fake images (0)

    # Train the discriminator on real images
    with tf.GradientTape() as disc_tape: #automatically computes gradients as we go for various steps
        real_output = discriminator(real_images)  # Get discriminator's output for real images
        fake_output = discriminator(generated_images)  # Get output for generated images
        disc_real_loss = loss_fn(real_labels, real_output)  # Calculate loss for real images
        disc_fake_loss = loss_fn(fake_labels, fake_output)  # Calculate loss for fake images
        disc_loss = (disc_real_loss + disc_fake_loss) / 2  # Average loss

    # Apply gradients to the discriminator
    gradients_of_discriminator = disc_tape.gradient(disc_loss, discriminator.trainable_variables)  # Compute gradients of disc_loss wrt trainable variables (weights)
    discriminator_optimizer.apply_gradients(zip(gradients_of_discriminator, discriminator.trainable_variables))  # Update weights

    # Train the generator (wants the discriminator to classify the fake images as real)
    misleading_labels = tf.ones((batch_size, 1))  # Generator's goal is to produce images classified as real
    with tf.GradientTape() as gen_tape:
        generated_images = generator(random_noise)  # Generate new images
        fake_output = discriminator(generated_images)  # Discriminator's output for generated images
        gen_loss = loss_fn(misleading_labels, fake_output)  # Calculate loss for generator
    
    # Apply gradients to the generator
    gradients_of_generator = gen_tape.gradient(gen_loss, generator.trainable_variables)  # Compute gradients
    generator_optimizer.apply_gradients(zip(gradients_of_generator, generator.trainable_variables))  # Update weights

    return disc_loss, gen_loss

# %%
# Training function for the entire GAN model
def train_gan(generator, discriminator, dataset, epochs, batch_size):
    disc_losses = []
    gen_losses = []

    for epoch in range(epochs):
        for real_images in dataset:
            d_loss, g_loss = train_step(real_images)
        
        disc_losses.append(d_loss.numpy())
        gen_losses.append(g_loss.numpy())

        print(f"Epoch {epoch+1}, Discriminator Loss: {d_loss.numpy()}, Generator Loss: {g_loss.numpy()}")
        
        if (epoch + 1) % 10 == 0:
            generate_and_save_images(generator, epoch + 1)

    plot_loss_graphs(disc_losses, gen_losses)

# %%
# Function to generate and save images
def generate_and_save_images(generator, epoch, num_examples=16):
    # Generate random noise as input for the generator
    random_noise = tf.random.normal([num_examples, 100])
    generated_images = generator(random_noise)

    # Rescale generated images from [-1, 1] to [0, 255] for visualization
    generated_images = (generated_images * 127.5 + 127.5).numpy()

    plt.figure(figsize=(4, 4))
    for i in range(generated_images.shape[0]):
        plt.subplot(4, 4, i + 1)
        plt.imshow(generated_images[i, :, :, 0], cmap='gray')  # Display in grayscale
        plt.axis('off')

    plt.show()

# %%
# Save the model
def save_model(generator, discriminator):
    generator.save('generator_model.h5')
    discriminator.save('discriminator_model.h5')

# %%
# Load the model
def load_model():
    loaded_generator = models.load_model('generator_model.h5')
    loaded_discriminator = models.load_model('discriminator_model.h5')
    return loaded_generator, loaded_discriminator

# %%
# Generate images from a saved generator model
def generate_images_from_saved_model():
    loaded_generator, _ = load_model()
    
    # Generate random noise as input for the generator
    random_noise = tf.random.normal([16, 100])
    # Use the generator to create images from the random noise
    generated_images = loaded_generator(random_noise)

    # Rescale images from [-1, 1] to [0, 255] for visualization
    generated_images = (generated_images * 127.5 + 127.5).numpy()

    plt.figure(figsize=(4, 4))
    for i in range(generated_images.shape[0]):
        plt.subplot(4, 4, i+1)
        plt.imshow(generated_images[i, :, :, 0], cmap='gray')
        plt.axis('off')

    plt.show()

# %%
# Plot loss graphs
def plot_loss_graphs(disc_losses, gen_losses):
    plt.figure(figsize=(10, 5))
    plt.plot(disc_losses, label='Discriminator Loss')
    plt.plot(gen_losses, label='Generator Loss')
    plt.xlabel('Epochs')
    plt.ylabel('Loss')
    plt.title('GAN Loss Over Time')
    plt.legend()
    plt.show()

# %%
# Show real images
def show_real_images(dataset, num_images=16):
    # Retrieve a batch of real images from the dataset
    real_images = next(iter(dataset))  # Get the next batch from the dataset iterator
    real_images = real_images[:num_images]  # Select the specified number of images

    plt.figure(figsize=(4, 4))
    for i in range(real_images.shape[0]):
        plt.subplot(4, 4, i + 1)
        plt.imshow(real_images[i, :, :, 0], cmap='gray')
        plt.axis('off')

    plt.show()

# %%
# 배치 크기 설정
batch_size = 64 

# 훈련 데이터를 TensorFlow 데이터셋으로 변환하고, 셔플하고, 배치 처리
dataset = tf.data.Dataset.from_tensor_slices(x_train).shuffle(buffer_size=1024).batch(batch_size)

# %%
# Show MNIST dataset
show_real_images(dataset)

# %%
# Train the GAN
train_gan(generator, discriminator, dataset, epochs=500, batch_size=64) # Minimum Epochs : 500
# Out:
# 2024-10-30 23:49:54.155616: W tensorflow/core/framework/local_rendezvous.cc:404] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence
# Epoch 1, Discriminator Loss: 0.1185092180967331, Generator Loss: 2.63132905960083
# 2024-10-30 23:49:58.283433: W tensorflow/core/framework/local_rendezvous.cc:404] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence
# Epoch 2, Discriminator Loss: 0.09030688554048538, Generator Loss: 2.239762783050537
# 2024-10-30 23:50:04.075756: W tensorflow/core/framework/local_rendezvous.cc:404] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence
# Epoch 3, Discriminator Loss: 0.14377480745315552, Generator Loss: 1.6985876560211182
# 2024-10-30 23:50:11.267475: W tensorflow/core/framework/local_rendezvous.cc:404] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence
# Epoch 4, Discriminator Loss: 0.07463262230157852, Generator Loss: 2.5559802055358887
# 2024-10-30 23:50:19.438907: W tensorflow/core/framework/local_rendezvous.cc:404] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence
# Epoch 5, Discriminator Loss: 0.1986241638660431, Generator Loss: 2.535675048828125
# 2024-10-30 23:50:28.775606: W tensorflow/core/framework/local_rendezvous.cc:404] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence
# Epoch 6, Discriminator Loss: 0.10452470928430557, Generator Loss: 2.7725017070770264
# 2024-10-30 23:50:38.001628: W tensorflow/core/framework/local_rendezvous.cc:404] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence
# Epoch 7, Discriminator Loss: 0.11624415218830109, Generator Loss: 2.765328884124756
# 2024-10-30 23:50:46.962859: W tensorflow/core/framework/local_rendezvous.cc:404] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence
# Epoch 8, Discriminator Loss: 0.2018253654241562, Generator Loss: 2.3385019302368164
# 2024-10-30 23:50:56.957384: W tensorflow/core/framework/local_rendezvous.cc:404] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence
# Epoch 9, Discriminator Loss: 0.12980549037456512, Generator Loss: 2.6531615257263184
# 2024-10-30 23:51:07.843060: W tensorflow/core/framework/local_rendezvous.cc:404] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence
# Epoch 10, Discriminator Loss: 0.18572473526000977, Generator Loss: 2.4040608406066895
# 2024-10-30 23:51:19.350895: W tensorflow/core/framework/local_rendezvous.cc:404] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence
# Epoch 11, Discriminator Loss: 0.1881590336561203, Generator Loss: 2.284409523010254
# 2024-10-30 23:51:31.446687: W tensorflow/core/framework/local_rendezvous.cc:404] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence
# Epoch 12, Discriminator Loss: 0.21566906571388245, Generator Loss: 2.2285900115966797
# 2024-10-30 23:51:43.273851: W tensorflow/core/framework/local_rendezvous.cc:404] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence
# Epoch 13, Discriminator Loss: 0.20416319370269775, Generator Loss: 2.640590190887451
# 2024-10-30 23:51:55.958889: W tensorflow/core/framework/local_rendezvous.cc:404] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence
# Epoch 14, Discriminator Loss: 0.14057330787181854, Generator Loss: 2.313047170639038
# 2024-10-30 23:52:09.218268: W tensorflow/core/framework/local_rendezvous.cc:404] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence
# Epoch 15, Discriminator Loss: 0.21078702807426453, Generator Loss: 2.5489449501037598
# 2024-10-30 23:52:21.953146: W tensorflow/core/framework/local_rendezvous.cc:404] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence
# Epoch 16, Discriminator Loss: 0.17093557119369507, Generator Loss: 2.54373836517334
# 2024-10-30 23:52:35.059132: W tensorflow/core/framework/local_rendezvous.cc:404] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence
# Epoch 17, Discriminator Loss: 0.37104588747024536, Generator Loss: 2.176070213317871
# 2024-10-30 23:52:47.748680: W tensorflow/core/framework/local_rendezvous.cc:404] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence
# Epoch 18, Discriminator Loss: 0.25301384925842285, Generator Loss: 2.258626937866211
# 2024-10-30 23:52:59.043760: W tensorflow/core/framework/local_rendezvous.cc:404] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence
# Epoch 19, Discriminator Loss: 0.17231260240077972, Generator Loss: 2.175537109375
# Epoch 20, Discriminator Loss: 0.24977536499500275, Generator Loss: 1.923548698425293
# 2024-10-30 23:53:10.593950: W tensorflow/core/framework/local_rendezvous.cc:404] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence
# 2024-10-30 23:53:23.061360: W tensorflow/core/framework/local_rendezvous.cc:404] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence
# Epoch 21, Discriminator Loss: 0.26357561349868774, Generator Loss: 2.2654991149902344
# 2024-10-30 23:53:33.642572: W tensorflow/core/framework/local_rendezvous.cc:404] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence
# Epoch 22, Discriminator Loss: 0.2568000555038452, Generator Loss: 2.340153694152832
# 2024-10-30 23:53:44.973127: W tensorflow/core/framework/local_rendezvous.cc:404] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence
# Epoch 23, Discriminator Loss: 0.29592323303222656, Generator Loss: 2.1487905979156494
# 2024-10-30 23:53:57.046512: W tensorflow/core/framework/local_rendezvous.cc:404] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence
# Epoch 24, Discriminator Loss: 0.1829896867275238, Generator Loss: 2.474475860595703
# 2024-10-30 23:54:07.044849: W tensorflow/core/framework/local_rendezvous.cc:404] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence
# Epoch 25, Discriminator Loss: 0.18913418054580688, Generator Loss: 2.684046745300293
# 2024-10-30 23:54:17.983297: W tensorflow/core/framework/local_rendezvous.cc:404] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence
# Epoch 26, Discriminator Loss: 0.31738534569740295, Generator Loss: 2.362614154815674
# 2024-10-30 23:54:29.871778: W tensorflow/core/framework/local_rendezvous.cc:404] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence
# Epoch 27, Discriminator Loss: 0.29030734300613403, Generator Loss: 2.786072015762329
# 2024-10-30 23:54:42.722275: W tensorflow/core/framework/local_rendezvous.cc:404] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence
# Epoch 28, Discriminator Loss: 0.1783224642276764, Generator Loss: 2.3564229011535645
# 2024-10-30 23:54:56.368204: W tensorflow/core/framework/local_rendezvous.cc:404] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence
# Epoch 29, Discriminator Loss: 0.1496710330247879, Generator Loss: 2.6583452224731445
# 2024-10-30 23:55:09.738488: W tensorflow/core/framework/local_rendezvous.cc:404] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence
# Epoch 30, Discriminator Loss: 0.2747647166252136, Generator Loss: 2.2515969276428223
# 2024-10-30 23:55:24.214561: W tensorflow/core/framework/local_rendezvous.cc:404] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence
# Epoch 31, Discriminator Loss: 0.32800737023353577, Generator Loss: 2.7574057579040527
# 2024-10-30 23:55:38.038240: W tensorflow/core/framework/local_rendezvous.cc:404] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence
# Epoch 32, Discriminator Loss: 0.2355586439371109, Generator Loss: 2.3740105628967285
# 2024-10-30 23:55:50.548835: W tensorflow/core/framework/local_rendezvous.cc:404] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence
# Epoch 33, Discriminator Loss: 0.23228785395622253, Generator Loss: 2.4621524810791016
# 2024-10-30 23:56:04.057139: W tensorflow/core/framework/local_rendezvous.cc:404] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence
# Epoch 34, Discriminator Loss: 0.1639220416545868, Generator Loss: 2.894385814666748
# 2024-10-30 23:56:16.410906: W tensorflow/core/framework/local_rendezvous.cc:404] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence
# Epoch 35, Discriminator Loss: 0.1648620218038559, Generator Loss: 2.5947437286376953
# 2024-10-30 23:56:29.960103: W tensorflow/core/framework/local_rendezvous.cc:404] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence
# Epoch 36, Discriminator Loss: 0.34698230028152466, Generator Loss: 2.229600191116333
# 2024-10-30 23:56:42.363217: W tensorflow/core/framework/local_rendezvous.cc:404] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence
# Epoch 37, Discriminator Loss: 0.19299396872520447, Generator Loss: 2.615550994873047
# 2024-10-30 23:56:53.602604: W tensorflow/core/framework/local_rendezvous.cc:404] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence
# Epoch 38, Discriminator Loss: 0.15526151657104492, Generator Loss: 2.65371036529541
# 2024-10-30 23:57:05.981241: W tensorflow/core/framework/local_rendezvous.cc:404] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence
# Epoch 39, Discriminator Loss: 0.13632982969284058, Generator Loss: 2.4807322025299072
# 2024-10-30 23:57:19.617973: W tensorflow/core/framework/local_rendezvous.cc:404] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence
# Epoch 40, Discriminator Loss: 0.1655091494321823, Generator Loss: 3.491631031036377
# 2024-10-30 23:57:34.538056: W tensorflow/core/framework/local_rendezvous.cc:404] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence
# Epoch 41, Discriminator Loss: 0.18741807341575623, Generator Loss: 2.6036720275878906
# 2024-10-30 23:57:49.835779: W tensorflow/core/framework/local_rendezvous.cc:404] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence
# Epoch 42, Discriminator Loss: 0.34110647439956665, Generator Loss: 2.4185121059417725
# 2024-10-30 23:58:03.223686: W tensorflow/core/framework/local_rendezvous.cc:404] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence
# Epoch 43, Discriminator Loss: 0.5208150148391724, Generator Loss: 2.3417587280273438
# 2024-10-30 23:58:16.750519: W tensorflow/core/framework/local_rendezvous.cc:404] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence
# Epoch 44, Discriminator Loss: 0.31175845861434937, Generator Loss: 2.877052068710327
# 2024-10-30 23:58:31.407087: W tensorflow/core/framework/local_rendezvous.cc:404] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence
# Epoch 45, Discriminator Loss: 0.2050338238477707, Generator Loss: 2.2555577754974365
# 2024-10-30 23:58:44.776153: W tensorflow/core/framework/local_rendezvous.cc:404] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence
# Epoch 46, Discriminator Loss: 0.1770871877670288, Generator Loss: 2.673285722732544
# 2024-10-30 23:58:59.415787: W tensorflow/core/framework/local_rendezvous.cc:404] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence
# Epoch 47, Discriminator Loss: 0.16060976684093475, Generator Loss: 3.2108654975891113
# 2024-10-30 23:59:14.769326: W tensorflow/core/framework/local_rendezvous.cc:404] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence
# Epoch 48, Discriminator Loss: 0.23034410178661346, Generator Loss: 3.165313720703125
# 2024-10-30 23:59:27.727670: W tensorflow/core/framework/local_rendezvous.cc:404] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence
# Epoch 49, Discriminator Loss: 0.17856743931770325, Generator Loss: 2.7252087593078613
# 2024-10-30 23:59:40.078047: W tensorflow/core/framework/local_rendezvous.cc:404] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence
# Epoch 50, Discriminator Loss: 0.19294124841690063, Generator Loss: 2.7637150287628174
# 2024-10-30 23:59:50.502584: W tensorflow/core/framework/local_rendezvous.cc:404] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence
# Epoch 51, Discriminator Loss: 0.1842556893825531, Generator Loss: 2.917623519897461
# 2024-10-31 00:00:01.370263: W tensorflow/core/framework/local_rendezvous.cc:404] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence
# Epoch 52, Discriminator Loss: 0.21639549732208252, Generator Loss: 2.892643928527832
# 2024-10-31 00:00:11.997976: W tensorflow/core/framework/local_rendezvous.cc:404] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence
# Epoch 53, Discriminator Loss: 0.23922882974147797, Generator Loss: 2.886104106903076
# 2024-10-31 00:00:23.857993: W tensorflow/core/framework/local_rendezvous.cc:404] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence
# Epoch 54, Discriminator Loss: 0.2279067039489746, Generator Loss: 2.4815850257873535
# 2024-10-31 00:00:35.241582: W tensorflow/core/framework/local_rendezvous.cc:404] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence
# Epoch 55, Discriminator Loss: 0.2447662651538849, Generator Loss: 2.4806180000305176
# 2024-10-31 00:00:46.538682: W tensorflow/core/framework/local_rendezvous.cc:404] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence
# Epoch 56, Discriminator Loss: 0.2976899743080139, Generator Loss: 2.2577195167541504
# 2024-10-31 00:00:58.682426: W tensorflow/core/framework/local_rendezvous.cc:404] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence
# Epoch 57, Discriminator Loss: 0.13571973145008087, Generator Loss: 2.8563950061798096
# 2024-10-31 00:01:10.170358: W tensorflow/core/framework/local_rendezvous.cc:404] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence
# Epoch 58, Discriminator Loss: 0.2499505877494812, Generator Loss: 2.7533884048461914
# 2024-10-31 00:01:20.816247: W tensorflow/core/framework/local_rendezvous.cc:404] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence
# Epoch 59, Discriminator Loss: 1.0951510667800903, Generator Loss: 1.3641411066055298
# 2024-10-31 00:01:30.594348: W tensorflow/core/framework/local_rendezvous.cc:404] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence
# Epoch 60, Discriminator Loss: 0.1474226713180542, Generator Loss: 4.24717903137207
# 2024-10-31 00:01:40.703464: W tensorflow/core/framework/local_rendezvous.cc:404] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence
# Epoch 61, Discriminator Loss: 0.11242391169071198, Generator Loss: 3.57131290435791
# 2024-10-31 00:01:51.032456: W tensorflow/core/framework/local_rendezvous.cc:404] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence
# Epoch 62, Discriminator Loss: 0.2628173828125, Generator Loss: 2.5399880409240723
# 2024-10-31 00:02:01.476160: W tensorflow/core/framework/local_rendezvous.cc:404] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence
# Epoch 63, Discriminator Loss: 0.2031693011522293, Generator Loss: 3.14259672164917
# 2024-10-31 00:02:11.738673: W tensorflow/core/framework/local_rendezvous.cc:404] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence
# Epoch 64, Discriminator Loss: 0.1733744889497757, Generator Loss: 2.66379976272583
# 2024-10-31 00:02:20.501141: W tensorflow/core/framework/local_rendezvous.cc:404] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence
# Epoch 65, Discriminator Loss: 0.703684389591217, Generator Loss: 1.71929931640625
# 2024-10-31 00:02:30.333291: W tensorflow/core/framework/local_rendezvous.cc:404] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence
# Epoch 66, Discriminator Loss: 0.14239919185638428, Generator Loss: 3.17936110496521
# 2024-10-31 00:02:40.893205: W tensorflow/core/framework/local_rendezvous.cc:404] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence
# Epoch 67, Discriminator Loss: 0.33138322830200195, Generator Loss: 2.7001421451568604
# 2024-10-31 00:02:52.977705: W tensorflow/core/framework/local_rendezvous.cc:404] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence
# Epoch 68, Discriminator Loss: 0.24073244631290436, Generator Loss: 2.66291880607605
# 2024-10-31 00:03:05.389932: W tensorflow/core/framework/local_rendezvous.cc:404] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence
# Epoch 69, Discriminator Loss: 0.21811778843402863, Generator Loss: 2.5666732788085938
# 2024-10-31 00:03:17.901880: W tensorflow/core/framework/local_rendezvous.cc:404] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence
# Epoch 70, Discriminator Loss: 0.214338019490242, Generator Loss: 2.7489166259765625
# 2024-10-31 00:03:30.442914: W tensorflow/core/framework/local_rendezvous.cc:404] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence
# Epoch 71, Discriminator Loss: 0.20838290452957153, Generator Loss: 2.598449230194092
# 2024-10-31 00:03:41.306012: W tensorflow/core/framework/local_rendezvous.cc:404] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence
# Epoch 72, Discriminator Loss: 0.12827643752098083, Generator Loss: 2.863163948059082
# 2024-10-31 00:03:52.448078: W tensorflow/core/framework/local_rendezvous.cc:404] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence
# Epoch 73, Discriminator Loss: 0.18577077984809875, Generator Loss: 2.940229654312134
# 2024-10-31 00:04:04.047419: W tensorflow/core/framework/local_rendezvous.cc:404] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence
# Epoch 74, Discriminator Loss: 0.24338452517986298, Generator Loss: 2.7616238594055176
# 2024-10-31 00:04:15.776309: W tensorflow/core/framework/local_rendezvous.cc:404] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence
# Epoch 75, Discriminator Loss: 0.2829931080341339, Generator Loss: 2.555253505706787
# 2024-10-31 00:04:26.480587: W tensorflow/core/framework/local_rendezvous.cc:404] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence
# Epoch 76, Discriminator Loss: 0.9865739941596985, Generator Loss: 1.1760578155517578
# 2024-10-31 00:04:37.687605: W tensorflow/core/framework/local_rendezvous.cc:404] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence
# Epoch 77, Discriminator Loss: 0.18240472674369812, Generator Loss: 3.2213573455810547
# 2024-10-31 00:04:49.011854: W tensorflow/core/framework/local_rendezvous.cc:404] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence
# Epoch 78, Discriminator Loss: 0.3948631286621094, Generator Loss: 1.966881513595581
# 2024-10-31 00:04:58.935288: W tensorflow/core/framework/local_rendezvous.cc:404] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence
# Epoch 79, Discriminator Loss: 0.17928001284599304, Generator Loss: 3.489384174346924
# 2024-10-31 00:05:08.872710: W tensorflow/core/framework/local_rendezvous.cc:404] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence
# Epoch 80, Discriminator Loss: 0.1758013367652893, Generator Loss: 2.9610371589660645
# 2024-10-31 00:05:19.817522: W tensorflow/core/framework/local_rendezvous.cc:404] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence
# Epoch 81, Discriminator Loss: 0.3104632496833801, Generator Loss: 2.4846181869506836
# 2024-10-31 00:05:30.475062: W tensorflow/core/framework/local_rendezvous.cc:404] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence
# Epoch 82, Discriminator Loss: 0.24011275172233582, Generator Loss: 2.604886054992676
# 2024-10-31 00:05:42.019139: W tensorflow/core/framework/local_rendezvous.cc:404] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence
# Epoch 83, Discriminator Loss: 0.2442522794008255, Generator Loss: 2.57675838470459
# 2024-10-31 00:05:54.046309: W tensorflow/core/framework/local_rendezvous.cc:404] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence
# Epoch 84, Discriminator Loss: 0.6544970273971558, Generator Loss: 1.7631535530090332
# 2024-10-31 00:06:04.881242: W tensorflow/core/framework/local_rendezvous.cc:404] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence
# Epoch 85, Discriminator Loss: 0.17339329421520233, Generator Loss: 3.0454154014587402
# 2024-10-31 00:06:17.218430: W tensorflow/core/framework/local_rendezvous.cc:404] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence
# Epoch 86, Discriminator Loss: 0.3332877457141876, Generator Loss: 2.7009243965148926
# 2024-10-31 00:06:28.318584: W tensorflow/core/framework/local_rendezvous.cc:404] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence
# Epoch 87, Discriminator Loss: 0.27587735652923584, Generator Loss: 3.0181288719177246
# 2024-10-31 00:06:39.288931: W tensorflow/core/framework/local_rendezvous.cc:404] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence
# Epoch 88, Discriminator Loss: 0.29963576793670654, Generator Loss: 3.398258686065674
# 2024-10-31 00:06:51.075049: W tensorflow/core/framework/local_rendezvous.cc:404] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence
# Epoch 89, Discriminator Loss: 0.3590908646583557, Generator Loss: 2.535435199737549
# 2024-10-31 00:07:01.820607: W tensorflow/core/framework/local_rendezvous.cc:404] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence
# Epoch 90, Discriminator Loss: 1.2903122901916504, Generator Loss: 1.0140937566757202
# 2024-10-31 00:07:13.467647: W tensorflow/core/framework/local_rendezvous.cc:404] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence
# Epoch 91, Discriminator Loss: 0.31096917390823364, Generator Loss: 2.2923495769500732
# 2024-10-31 00:07:25.987630: W tensorflow/core/framework/local_rendezvous.cc:404] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence
# Epoch 92, Discriminator Loss: 0.10269387811422348, Generator Loss: 3.3386707305908203
# 2024-10-31 00:07:38.491436: W tensorflow/core/framework/local_rendezvous.cc:404] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence
# Epoch 93, Discriminator Loss: 0.470032274723053, Generator Loss: 1.920318841934204
# 2024-10-31 00:07:50.468800: W tensorflow/core/framework/local_rendezvous.cc:404] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence
# Epoch 94, Discriminator Loss: 0.32811439037323, Generator Loss: 2.2329416275024414
# 2024-10-31 00:08:03.974132: W tensorflow/core/framework/local_rendezvous.cc:404] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence
# Epoch 95, Discriminator Loss: 0.15964871644973755, Generator Loss: 2.6805622577667236
# 2024-10-31 00:08:17.177416: W tensorflow/core/framework/local_rendezvous.cc:404] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence
# Epoch 96, Discriminator Loss: 0.44225794076919556, Generator Loss: 2.117558240890503
# 2024-10-31 00:08:27.025070: W tensorflow/core/framework/local_rendezvous.cc:404] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence
# Epoch 97, Discriminator Loss: 0.20716144144535065, Generator Loss: 2.194932222366333
# 2024-10-31 00:08:36.238125: W tensorflow/core/framework/local_rendezvous.cc:404] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence
# Epoch 98, Discriminator Loss: 0.3893601894378662, Generator Loss: 2.397385597229004
# 2024-10-31 00:08:46.339847: W tensorflow/core/framework/local_rendezvous.cc:404] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence
# Epoch 99, Discriminator Loss: 0.3632891774177551, Generator Loss: 2.5168700218200684
# 2024-10-31 00:08:57.322769: W tensorflow/core/framework/local_rendezvous.cc:404] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence
# Epoch 100, Discriminator Loss: 0.18644486367702484, Generator Loss: 2.852961540222168
# 2024-10-31 00:09:09.940208: W tensorflow/core/framework/local_rendezvous.cc:404] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence
# Epoch 101, Discriminator Loss: 0.3860662579536438, Generator Loss: 2.4901857376098633
# 2024-10-31 00:09:20.862495: W tensorflow/core/framework/local_rendezvous.cc:404] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence
# Epoch 102, Discriminator Loss: 0.16466237604618073, Generator Loss: 2.8010854721069336
# 2024-10-31 00:09:32.177016: W tensorflow/core/framework/local_rendezvous.cc:404] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence
# Epoch 103, Discriminator Loss: 0.28671199083328247, Generator Loss: 2.610468864440918
# 2024-10-31 00:09:44.435816: W tensorflow/core/framework/local_rendezvous.cc:404] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence
# Epoch 104, Discriminator Loss: 0.25092557072639465, Generator Loss: 2.267042875289917
# 2024-10-31 00:09:57.583360: W tensorflow/core/framework/local_rendezvous.cc:404] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence
# Epoch 105, Discriminator Loss: 0.4674743711948395, Generator Loss: 1.7289191484451294
# 2024-10-31 00:10:11.349519: W tensorflow/core/framework/local_rendezvous.cc:404] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence
# Epoch 106, Discriminator Loss: 0.2262723445892334, Generator Loss: 2.9102139472961426
# 2024-10-31 00:10:23.717969: W tensorflow/core/framework/local_rendezvous.cc:404] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence
# Epoch 107, Discriminator Loss: 0.24361813068389893, Generator Loss: 2.5317933559417725
# 2024-10-31 00:10:35.447224: W tensorflow/core/framework/local_rendezvous.cc:404] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence
# Epoch 108, Discriminator Loss: 0.24301546812057495, Generator Loss: 2.547966480255127
# 2024-10-31 00:10:45.370276: W tensorflow/core/framework/local_rendezvous.cc:404] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence
# Epoch 109, Discriminator Loss: 0.6484930515289307, Generator Loss: 1.570335865020752
# 2024-10-31 00:10:55.653543: W tensorflow/core/framework/local_rendezvous.cc:404] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence
# Epoch 110, Discriminator Loss: 0.23858171701431274, Generator Loss: 2.7345378398895264
# 2024-10-31 00:11:05.710369: W tensorflow/core/framework/local_rendezvous.cc:404] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence
# Epoch 111, Discriminator Loss: 0.7336947917938232, Generator Loss: 1.1572496891021729
# 2024-10-31 00:11:16.340006: W tensorflow/core/framework/local_rendezvous.cc:404] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence
# Epoch 112, Discriminator Loss: 0.19800859689712524, Generator Loss: 2.521164894104004
# 2024-10-31 00:11:28.442415: W tensorflow/core/framework/local_rendezvous.cc:404] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence
# Epoch 113, Discriminator Loss: 0.24037283658981323, Generator Loss: 2.082949638366699
# 2024-10-31 00:11:41.259387: W tensorflow/core/framework/local_rendezvous.cc:404] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence
# Epoch 114, Discriminator Loss: 0.2956974506378174, Generator Loss: 2.203701972961426
# 2024-10-31 00:11:51.395102: W tensorflow/core/framework/local_rendezvous.cc:404] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence
# Epoch 115, Discriminator Loss: 0.25909721851348877, Generator Loss: 2.4493117332458496
# 2024-10-31 00:12:02.102435: W tensorflow/core/framework/local_rendezvous.cc:404] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence
# Epoch 116, Discriminator Loss: 0.2430812120437622, Generator Loss: 2.346022129058838
# 2024-10-31 00:12:13.348673: W tensorflow/core/framework/local_rendezvous.cc:404] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence
# Epoch 117, Discriminator Loss: 0.2445462942123413, Generator Loss: 2.6078176498413086
# 2024-10-31 00:12:25.517149: W tensorflow/core/framework/local_rendezvous.cc:404] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence
# Epoch 118, Discriminator Loss: 0.22003167867660522, Generator Loss: 2.40669584274292
# 2024-10-31 00:12:38.238634: W tensorflow/core/framework/local_rendezvous.cc:404] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence
# Epoch 119, Discriminator Loss: 0.22874358296394348, Generator Loss: 2.2454934120178223
# 2024-10-31 00:12:50.781170: W tensorflow/core/framework/local_rendezvous.cc:404] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence
# Epoch 120, Discriminator Loss: 0.2792930603027344, Generator Loss: 2.4121322631835938
# 2024-10-31 00:13:04.440219: W tensorflow/core/framework/local_rendezvous.cc:404] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence
# Epoch 121, Discriminator Loss: 0.3910670578479767, Generator Loss: 1.8509955406188965
# 2024-10-31 00:13:14.889777: W tensorflow/core/framework/local_rendezvous.cc:404] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence
# Epoch 122, Discriminator Loss: 0.8694882988929749, Generator Loss: 1.318044662475586
# 2024-10-31 00:13:26.084309: W tensorflow/core/framework/local_rendezvous.cc:404] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence
# Epoch 123, Discriminator Loss: 0.5288934707641602, Generator Loss: 1.8511756658554077
# 2024-10-31 00:13:37.403883: W tensorflow/core/framework/local_rendezvous.cc:404] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence
# Epoch 124, Discriminator Loss: 0.3392690420150757, Generator Loss: 1.6212291717529297
# 2024-10-31 00:13:48.785581: W tensorflow/core/framework/local_rendezvous.cc:404] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence
# Epoch 125, Discriminator Loss: 0.2099279910326004, Generator Loss: 2.507969379425049
# 2024-10-31 00:14:02.297958: W tensorflow/core/framework/local_rendezvous.cc:404] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence
# Epoch 126, Discriminator Loss: 0.34250301122665405, Generator Loss: 1.9689979553222656
# 2024-10-31 00:14:13.715108: W tensorflow/core/framework/local_rendezvous.cc:404] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence
# Epoch 127, Discriminator Loss: 0.2874928116798401, Generator Loss: 2.128844738006592
# 2024-10-31 00:14:26.145872: W tensorflow/core/framework/local_rendezvous.cc:404] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence
# Epoch 128, Discriminator Loss: 0.3476034998893738, Generator Loss: 2.1621150970458984
# 2024-10-31 00:14:38.932706: W tensorflow/core/framework/local_rendezvous.cc:404] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence
# Epoch 129, Discriminator Loss: 0.39694109559059143, Generator Loss: 2.1763784885406494
# Epoch 130, Discriminator Loss: 0.2496662139892578, Generator Loss: 2.456462860107422
# 2024-10-31 00:14:48.248784: W tensorflow/core/framework/local_rendezvous.cc:404] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence
# 2024-10-31 00:14:59.699981: W tensorflow/core/framework/local_rendezvous.cc:404] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence
# Epoch 131, Discriminator Loss: 0.2911420464515686, Generator Loss: 2.072249412536621
# 2024-10-31 00:15:12.049940: W tensorflow/core/framework/local_rendezvous.cc:404] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence
# Epoch 132, Discriminator Loss: 0.35577642917633057, Generator Loss: 1.8719978332519531
# 2024-10-31 00:15:24.181008: W tensorflow/core/framework/local_rendezvous.cc:404] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence
# Epoch 133, Discriminator Loss: 0.33490270376205444, Generator Loss: 1.8431062698364258
# 2024-10-31 00:15:34.594132: W tensorflow/core/framework/local_rendezvous.cc:404] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence
# Epoch 134, Discriminator Loss: 0.4030453860759735, Generator Loss: 2.0905394554138184
# 2024-10-31 00:15:44.814010: W tensorflow/core/framework/local_rendezvous.cc:404] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence
# Epoch 135, Discriminator Loss: 0.3190067410469055, Generator Loss: 1.7359591722488403
# 2024-10-31 00:15:57.134392: W tensorflow/core/framework/local_rendezvous.cc:404] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence
# Epoch 136, Discriminator Loss: 0.30792444944381714, Generator Loss: 2.0658392906188965
# 2024-10-31 00:16:10.193683: W tensorflow/core/framework/local_rendezvous.cc:404] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence
# Epoch 137, Discriminator Loss: 0.2371196150779724, Generator Loss: 2.6576006412506104
# 2024-10-31 00:16:23.881935: W tensorflow/core/framework/local_rendezvous.cc:404] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence
# Epoch 138, Discriminator Loss: 0.3493240475654602, Generator Loss: 2.0134220123291016
# 2024-10-31 00:16:37.428992: W tensorflow/core/framework/local_rendezvous.cc:404] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence
# Epoch 139, Discriminator Loss: 0.22636720538139343, Generator Loss: 2.475363254547119
# Epoch 140, Discriminator Loss: 0.26031702756881714, Generator Loss: 2.3622589111328125
# 2024-10-31 00:16:49.383541: W tensorflow/core/framework/local_rendezvous.cc:404] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence
# 2024-10-31 00:17:01.233122: W tensorflow/core/framework/local_rendezvous.cc:404] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence
# Epoch 141, Discriminator Loss: 0.3088478446006775, Generator Loss: 2.0502452850341797
# 2024-10-31 00:17:14.435218: W tensorflow/core/framework/local_rendezvous.cc:404] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence
# Epoch 142, Discriminator Loss: 0.21410693228244781, Generator Loss: 2.214841365814209
# 2024-10-31 00:17:26.376069: W tensorflow/core/framework/local_rendezvous.cc:404] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence
# Epoch 143, Discriminator Loss: 0.4202408194541931, Generator Loss: 1.6890681982040405
# 2024-10-31 00:17:39.334767: W tensorflow/core/framework/local_rendezvous.cc:404] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence
# Epoch 144, Discriminator Loss: 0.3980554938316345, Generator Loss: 2.0826802253723145
# 2024-10-31 00:17:53.631403: W tensorflow/core/framework/local_rendezvous.cc:404] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence
# Epoch 145, Discriminator Loss: 0.37574607133865356, Generator Loss: 1.9862968921661377
# 2024-10-31 00:18:07.424263: W tensorflow/core/framework/local_rendezvous.cc:404] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence
# Epoch 146, Discriminator Loss: 0.20360659062862396, Generator Loss: 2.311445713043213
# 2024-10-31 00:18:20.487422: W tensorflow/core/framework/local_rendezvous.cc:404] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence
# Epoch 147, Discriminator Loss: 0.3506788909435272, Generator Loss: 2.1529197692871094
# 2024-10-31 00:18:32.455095: W tensorflow/core/framework/local_rendezvous.cc:404] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence
# Epoch 148, Discriminator Loss: 0.24046596884727478, Generator Loss: 2.170544147491455
# 2024-10-31 00:18:43.994962: W tensorflow/core/framework/local_rendezvous.cc:404] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence
# Epoch 149, Discriminator Loss: 0.27573704719543457, Generator Loss: 2.2215445041656494
# 2024-10-31 00:18:56.042993: W tensorflow/core/framework/local_rendezvous.cc:404] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence
# Epoch 150, Discriminator Loss: 0.26730459928512573, Generator Loss: 2.2219746112823486
# 2024-10-31 00:19:09.768389: W tensorflow/core/framework/local_rendezvous.cc:404] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence
# Epoch 151, Discriminator Loss: 0.2948717474937439, Generator Loss: 2.184725284576416
# 2024-10-31 00:19:24.194966: W tensorflow/core/framework/local_rendezvous.cc:404] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence
# Epoch 152, Discriminator Loss: 0.3421095609664917, Generator Loss: 2.1771836280822754
# 2024-10-31 00:19:37.527095: W tensorflow/core/framework/local_rendezvous.cc:404] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence
# Epoch 153, Discriminator Loss: 0.3948027491569519, Generator Loss: 1.8594591617584229
# 2024-10-31 00:19:49.502649: W tensorflow/core/framework/local_rendezvous.cc:404] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence
# Epoch 154, Discriminator Loss: 0.21414834260940552, Generator Loss: 2.728175640106201
# 2024-10-31 00:20:02.548508: W tensorflow/core/framework/local_rendezvous.cc:404] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence
# Epoch 155, Discriminator Loss: 0.25550878047943115, Generator Loss: 2.5343689918518066
# 2024-10-31 00:20:16.340427: W tensorflow/core/framework/local_rendezvous.cc:404] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence
# Epoch 156, Discriminator Loss: 0.4332546591758728, Generator Loss: 2.288884162902832
# 2024-10-31 00:20:27.283170: W tensorflow/core/framework/local_rendezvous.cc:404] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence
# Epoch 157, Discriminator Loss: 0.46683546900749207, Generator Loss: 2.0964255332946777
# 2024-10-31 00:20:39.110007: W tensorflow/core/framework/local_rendezvous.cc:404] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence
# Epoch 158, Discriminator Loss: 0.25312116742134094, Generator Loss: 2.445903778076172
# 2024-10-31 00:20:51.926551: W tensorflow/core/framework/local_rendezvous.cc:404] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence
# Epoch 159, Discriminator Loss: 0.2688695788383484, Generator Loss: 2.7394630908966064
# 2024-10-31 00:21:05.963370: W tensorflow/core/framework/local_rendezvous.cc:404] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence
# Epoch 160, Discriminator Loss: 0.3128027319908142, Generator Loss: 2.3940281867980957
# 2024-10-31 00:21:18.519191: W tensorflow/core/framework/local_rendezvous.cc:404] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence
# Epoch 161, Discriminator Loss: 0.3900796175003052, Generator Loss: 1.8794327974319458
# 2024-10-31 00:21:31.650445: W tensorflow/core/framework/local_rendezvous.cc:404] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence
# Epoch 162, Discriminator Loss: 0.32603979110717773, Generator Loss: 2.155703544616699
# 2024-10-31 00:21:45.991254: W tensorflow/core/framework/local_rendezvous.cc:404] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence
# Epoch 163, Discriminator Loss: 0.3614214062690735, Generator Loss: 2.304891586303711
# 2024-10-31 00:22:03.322154: W tensorflow/core/framework/local_rendezvous.cc:404] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence
# Epoch 164, Discriminator Loss: 0.22251996397972107, Generator Loss: 2.0858607292175293
# 2024-10-31 00:22:17.405369: W tensorflow/core/framework/local_rendezvous.cc:404] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence
# Epoch 165, Discriminator Loss: 0.2129574567079544, Generator Loss: 2.4477460384368896
# 2024-10-31 00:22:30.286481: W tensorflow/core/framework/local_rendezvous.cc:404] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence
# Epoch 166, Discriminator Loss: 0.26977092027664185, Generator Loss: 2.091951847076416
# 2024-10-31 00:22:43.409582: W tensorflow/core/framework/local_rendezvous.cc:404] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence
# Epoch 167, Discriminator Loss: 0.2027880847454071, Generator Loss: 2.427889823913574
# 2024-10-31 00:22:54.050754: W tensorflow/core/framework/local_rendezvous.cc:404] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence
# Epoch 168, Discriminator Loss: 0.2648633122444153, Generator Loss: 2.1943111419677734
# 2024-10-31 00:23:05.619057: W tensorflow/core/framework/local_rendezvous.cc:404] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence
# Epoch 169, Discriminator Loss: 0.3125801086425781, Generator Loss: 2.306002140045166
# 2024-10-31 00:23:19.300596: W tensorflow/core/framework/local_rendezvous.cc:404] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence
# Epoch 170, Discriminator Loss: 0.3336470425128937, Generator Loss: 1.9517472982406616
# 2024-10-31 00:23:35.374201: W tensorflow/core/framework/local_rendezvous.cc:404] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence
# Epoch 171, Discriminator Loss: 0.3167794346809387, Generator Loss: 1.7567062377929688
# 2024-10-31 00:23:49.799207: W tensorflow/core/framework/local_rendezvous.cc:404] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence
# Epoch 172, Discriminator Loss: 0.32953035831451416, Generator Loss: 1.9689017534255981
# 2024-10-31 00:24:02.918456: W tensorflow/core/framework/local_rendezvous.cc:404] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence
# Epoch 173, Discriminator Loss: 0.2675706744194031, Generator Loss: 2.255631923675537
# 2024-10-31 00:24:14.543427: W tensorflow/core/framework/local_rendezvous.cc:404] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence
# Epoch 174, Discriminator Loss: 0.36154705286026, Generator Loss: 2.016958236694336
# 2024-10-31 00:24:23.998437: W tensorflow/core/framework/local_rendezvous.cc:404] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence
# Epoch 175, Discriminator Loss: 0.43442386388778687, Generator Loss: 2.0802206993103027
# 2024-10-31 00:24:34.398405: W tensorflow/core/framework/local_rendezvous.cc:404] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence
# Epoch 176, Discriminator Loss: 0.31320852041244507, Generator Loss: 1.8349580764770508
# 2024-10-31 00:24:45.824859: W tensorflow/core/framework/local_rendezvous.cc:404] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence
# Epoch 177, Discriminator Loss: 0.18135955929756165, Generator Loss: 2.519223690032959
# 2024-10-31 00:24:58.634705: W tensorflow/core/framework/local_rendezvous.cc:404] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence
# Epoch 178, Discriminator Loss: 0.33061420917510986, Generator Loss: 2.19008207321167
# 2024-10-31 00:25:11.380752: W tensorflow/core/framework/local_rendezvous.cc:404] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence
# Epoch 179, Discriminator Loss: 0.29011011123657227, Generator Loss: 2.1668758392333984
# 2024-10-31 00:25:25.132335: W tensorflow/core/framework/local_rendezvous.cc:404] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence
# Epoch 180, Discriminator Loss: 0.30162811279296875, Generator Loss: 2.099287509918213
# 2024-10-31 00:25:39.751916: W tensorflow/core/framework/local_rendezvous.cc:404] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence
# Epoch 181, Discriminator Loss: 0.29449233412742615, Generator Loss: 2.326256275177002
# 2024-10-31 00:25:55.981590: W tensorflow/core/framework/local_rendezvous.cc:404] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence
# Epoch 182, Discriminator Loss: 0.2450512945652008, Generator Loss: 2.6642489433288574
# 2024-10-31 00:26:11.633966: W tensorflow/core/framework/local_rendezvous.cc:404] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence
# Epoch 183, Discriminator Loss: 0.35414600372314453, Generator Loss: 2.2238917350769043
# 2024-10-31 00:26:27.268223: W tensorflow/core/framework/local_rendezvous.cc:404] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence
# Epoch 184, Discriminator Loss: 0.40576040744781494, Generator Loss: 2.0735507011413574
# 2024-10-31 00:26:41.372646: W tensorflow/core/framework/local_rendezvous.cc:404] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence
# Epoch 185, Discriminator Loss: 0.8891067504882812, Generator Loss: 1.3189282417297363
# 2024-10-31 00:26:55.528910: W tensorflow/core/framework/local_rendezvous.cc:404] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence
# Epoch 186, Discriminator Loss: 0.3436667323112488, Generator Loss: 2.2380552291870117
# 2024-10-31 00:27:08.069268: W tensorflow/core/framework/local_rendezvous.cc:404] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence
# Epoch 187, Discriminator Loss: 0.2790568172931671, Generator Loss: 2.252554178237915
# 2024-10-31 00:27:19.441957: W tensorflow/core/framework/local_rendezvous.cc:404] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence
# Epoch 188, Discriminator Loss: 0.2679755389690399, Generator Loss: 2.207723617553711
# 2024-10-31 00:27:32.570977: W tensorflow/core/framework/local_rendezvous.cc:404] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence
# Epoch 189, Discriminator Loss: 0.24310970306396484, Generator Loss: 2.4826173782348633
# 2024-10-31 00:27:45.805139: W tensorflow/core/framework/local_rendezvous.cc:404] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence
# Epoch 190, Discriminator Loss: 0.2779344320297241, Generator Loss: 2.557953357696533
# 2024-10-31 00:28:00.218930: W tensorflow/core/framework/local_rendezvous.cc:404] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence
# Epoch 191, Discriminator Loss: 0.3623170852661133, Generator Loss: 2.3589820861816406
# 2024-10-31 00:28:15.217318: W tensorflow/core/framework/local_rendezvous.cc:404] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence
# Epoch 192, Discriminator Loss: 0.29061511158943176, Generator Loss: 2.2276391983032227
# 2024-10-31 00:28:31.064466: W tensorflow/core/framework/local_rendezvous.cc:404] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence
# Epoch 193, Discriminator Loss: 0.2740294933319092, Generator Loss: 2.610710620880127
# 2024-10-31 00:28:47.273695: W tensorflow/core/framework/local_rendezvous.cc:404] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence
# Epoch 194, Discriminator Loss: 0.19375964999198914, Generator Loss: 2.5402021408081055
# 2024-10-31 00:29:02.541359: W tensorflow/core/framework/local_rendezvous.cc:404] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence
# Epoch 195, Discriminator Loss: 0.28835389018058777, Generator Loss: 2.141636371612549
# 2024-10-31 00:29:16.914049: W tensorflow/core/framework/local_rendezvous.cc:404] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence
# Epoch 196, Discriminator Loss: 0.3128858804702759, Generator Loss: 2.100619316101074
# 2024-10-31 00:29:31.621348: W tensorflow/core/framework/local_rendezvous.cc:404] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence
# Epoch 197, Discriminator Loss: 0.27467870712280273, Generator Loss: 2.4307188987731934
# 2024-10-31 00:29:47.369959: W tensorflow/core/framework/local_rendezvous.cc:404] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence
# Epoch 198, Discriminator Loss: 0.3541913628578186, Generator Loss: 2.3230245113372803
# 2024-10-31 00:30:01.217696: W tensorflow/core/framework/local_rendezvous.cc:404] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence
# Epoch 199, Discriminator Loss: 0.3063969612121582, Generator Loss: 2.0990686416625977
# Epoch 200, Discriminator Loss: 0.15638390183448792, Generator Loss: 2.6116089820861816
# 2024-10-31 00:30:14.853291: W tensorflow/core/framework/local_rendezvous.cc:404] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence
# 2024-10-31 00:30:25.794423: W tensorflow/core/framework/local_rendezvous.cc:404] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence
# Epoch 201, Discriminator Loss: 0.2613160014152527, Generator Loss: 2.102640151977539
# ...
# Epoch 434, Discriminator Loss: 0.20613427460193634, Generator Loss: 2.4803433418273926
# 2024-10-31 01:24:04.325815: W tensorflow/core/framework/local_rendezvous.cc:404] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence
# Epoch 435, Discriminator Loss: 0.2882622480392456, Generator Loss: 2.9013710021972656
# 2024-10-31 01:24:17.567524: W tensorflow/core/framework/local_rendezvous.cc:404] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence
# Epoch 436, Discriminator Loss: 0.28033339977264404, Generator Loss: 2.7359585762023926
# 2024-10-31 01:24:31.808020: W tensorflow/core/framework/local_rendezvous.cc:404] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence
# Epoch 437, Discriminator Loss: 0.14220747351646423, Generator Loss: 3.073875904083252
# 2024-10-31 01:24:46.772568: W tensorflow/core/framework/local_rendezvous.cc:404] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence
# Epoch 438, Discriminator Loss: 0.21760240197181702, Generator Loss: 2.280735492706299
# 2024-10-31 01:25:01.066955: W tensorflow/core/framework/local_rendezvous.cc:404] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence
# Epoch 439, Discriminator Loss: 0.14771628379821777, Generator Loss: 2.6212258338928223
# Epoch 440, Discriminator Loss: 0.30766740441322327, Generator Loss: 2.298771858215332
# 2024-10-31 01:25:14.672040: W tensorflow/core/framework/local_rendezvous.cc:404] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence
# 2024-10-31 01:25:26.236869: W tensorflow/core/framework/local_rendezvous.cc:404] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence
# Epoch 441, Discriminator Loss: 0.2096668928861618, Generator Loss: 2.581709861755371
# 2024-10-31 01:25:37.541311: W tensorflow/core/framework/local_rendezvous.cc:404] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence
# Epoch 442, Discriminator Loss: 0.16353166103363037, Generator Loss: 3.161688804626465
# 2024-10-31 01:25:50.192401: W tensorflow/core/framework/local_rendezvous.cc:404] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence
# Epoch 443, Discriminator Loss: 0.219906747341156, Generator Loss: 2.677706241607666
# 2024-10-31 01:26:01.486474: W tensorflow/core/framework/local_rendezvous.cc:404] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence
# Epoch 444, Discriminator Loss: 0.30621039867401123, Generator Loss: 1.9899516105651855
# 2024-10-31 01:26:13.798666: W tensorflow/core/framework/local_rendezvous.cc:404] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence
# Epoch 445, Discriminator Loss: 0.25800207257270813, Generator Loss: 2.549948215484619
# 2024-10-31 01:26:26.615256: W tensorflow/core/framework/local_rendezvous.cc:404] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence
# Epoch 446, Discriminator Loss: 0.23146399855613708, Generator Loss: 2.5309197902679443
# 2024-10-31 01:26:40.350586: W tensorflow/core/framework/local_rendezvous.cc:404] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence
# Epoch 447, Discriminator Loss: 0.181516632437706, Generator Loss: 2.515493392944336
# 2024-10-31 01:26:53.740445: W tensorflow/core/framework/local_rendezvous.cc:404] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence
# Epoch 448, Discriminator Loss: 0.2573976516723633, Generator Loss: 2.733534336090088
# 2024-10-31 01:27:06.513064: W tensorflow/core/framework/local_rendezvous.cc:404] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence
# Epoch 449, Discriminator Loss: 0.14888513088226318, Generator Loss: 2.8051815032958984
# Epoch 450, Discriminator Loss: 0.21409741044044495, Generator Loss: 2.6942665576934814
# 2024-10-31 01:27:19.180533: W tensorflow/core/framework/local_rendezvous.cc:404] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence
# 2024-10-31 01:27:31.135272: W tensorflow/core/framework/local_rendezvous.cc:404] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence
# Epoch 451, Discriminator Loss: 0.27312591671943665, Generator Loss: 3.008939266204834
# 2024-10-31 01:27:42.820854: W tensorflow/core/framework/local_rendezvous.cc:404] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence
# Epoch 452, Discriminator Loss: 0.1792656034231186, Generator Loss: 2.5909037590026855
# 2024-10-31 01:27:55.283090: W tensorflow/core/framework/local_rendezvous.cc:404] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence
# Epoch 453, Discriminator Loss: 0.3192210793495178, Generator Loss: 3.1088972091674805
# 2024-10-31 01:28:08.744590: W tensorflow/core/framework/local_rendezvous.cc:404] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence
# Epoch 454, Discriminator Loss: 0.3015610873699188, Generator Loss: 2.326075315475464
# 2024-10-31 01:28:23.322385: W tensorflow/core/framework/local_rendezvous.cc:404] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence
# Epoch 455, Discriminator Loss: 0.23000870645046234, Generator Loss: 2.2893810272216797
# 2024-10-31 01:28:38.897612: W tensorflow/core/framework/local_rendezvous.cc:404] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence
# Epoch 456, Discriminator Loss: 0.24673080444335938, Generator Loss: 2.583669424057007
# 2024-10-31 01:28:54.751144: W tensorflow/core/framework/local_rendezvous.cc:404] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence
# Epoch 457, Discriminator Loss: 0.22550344467163086, Generator Loss: 2.280979633331299
# 2024-10-31 01:29:09.575549: W tensorflow/core/framework/local_rendezvous.cc:404] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence
# Epoch 458, Discriminator Loss: 0.22099104523658752, Generator Loss: 2.773787260055542
# 2024-10-31 01:29:22.536504: W tensorflow/core/framework/local_rendezvous.cc:404] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence
# Epoch 459, Discriminator Loss: 0.23578938841819763, Generator Loss: 3.0318877696990967
# Epoch 460, Discriminator Loss: 0.2699185609817505, Generator Loss: 2.791203022003174
# 2024-10-31 01:29:34.789770: W tensorflow/core/framework/local_rendezvous.cc:404] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence
# 2024-10-31 01:29:47.334833: W tensorflow/core/framework/local_rendezvous.cc:404] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence
# Epoch 461, Discriminator Loss: 0.19784745573997498, Generator Loss: 2.8852522373199463
# 2024-10-31 01:29:57.931132: W tensorflow/core/framework/local_rendezvous.cc:404] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence
# Epoch 462, Discriminator Loss: 0.22051095962524414, Generator Loss: 2.6254944801330566
# 2024-10-31 01:30:09.795501: W tensorflow/core/framework/local_rendezvous.cc:404] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence
# Epoch 463, Discriminator Loss: 0.26017558574676514, Generator Loss: 2.896381378173828
# 2024-10-31 01:30:23.486777: W tensorflow/core/framework/local_rendezvous.cc:404] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence
# Epoch 464, Discriminator Loss: 0.16075003147125244, Generator Loss: 3.169969081878662
# 2024-10-31 01:30:37.903383: W tensorflow/core/framework/local_rendezvous.cc:404] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence
# Epoch 465, Discriminator Loss: 0.1805819869041443, Generator Loss: 3.6381337642669678
# 2024-10-31 01:30:52.900175: W tensorflow/core/framework/local_rendezvous.cc:404] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence
# Epoch 466, Discriminator Loss: 0.21143557131290436, Generator Loss: 2.848628282546997
# 2024-10-31 01:31:06.606324: W tensorflow/core/framework/local_rendezvous.cc:404] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence
# Epoch 467, Discriminator Loss: 0.19569498300552368, Generator Loss: 2.9370181560516357
# 2024-10-31 01:31:21.009346: W tensorflow/core/framework/local_rendezvous.cc:404] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence
# Epoch 468, Discriminator Loss: 0.17506840825080872, Generator Loss: 2.9492578506469727
# 2024-10-31 01:31:35.110304: W tensorflow/core/framework/local_rendezvous.cc:404] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence
# Epoch 469, Discriminator Loss: 0.25139719247817993, Generator Loss: 2.536750316619873
# Epoch 470, Discriminator Loss: 0.25443407893180847, Generator Loss: 2.8533449172973633
# 2024-10-31 01:31:49.184483: W tensorflow/core/framework/local_rendezvous.cc:404] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence
# 2024-10-31 01:32:02.817009: W tensorflow/core/framework/local_rendezvous.cc:404] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence
# Epoch 471, Discriminator Loss: 0.15456561744213104, Generator Loss: 2.895308256149292
# 2024-10-31 01:32:16.985427: W tensorflow/core/framework/local_rendezvous.cc:404] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence
# Epoch 472, Discriminator Loss: 0.16492299735546112, Generator Loss: 2.891192674636841
# 2024-10-31 01:32:31.677281: W tensorflow/core/framework/local_rendezvous.cc:404] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence
# Epoch 473, Discriminator Loss: 0.30474674701690674, Generator Loss: 2.5848097801208496
# 2024-10-31 01:32:45.126720: W tensorflow/core/framework/local_rendezvous.cc:404] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence
# Epoch 474, Discriminator Loss: 0.2608156204223633, Generator Loss: 2.6155521869659424
# 2024-10-31 01:32:55.943744: W tensorflow/core/framework/local_rendezvous.cc:404] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence
# Epoch 475, Discriminator Loss: 0.30764421820640564, Generator Loss: 2.694852352142334
# 2024-10-31 01:33:07.993949: W tensorflow/core/framework/local_rendezvous.cc:404] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence
# Epoch 476, Discriminator Loss: 0.22418200969696045, Generator Loss: 2.9499106407165527
# 2024-10-31 01:33:21.027967: W tensorflow/core/framework/local_rendezvous.cc:404] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence
# Epoch 477, Discriminator Loss: 0.16328877210617065, Generator Loss: 2.9342381954193115
# 2024-10-31 01:33:34.942779: W tensorflow/core/framework/local_rendezvous.cc:404] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence
# Epoch 478, Discriminator Loss: 0.2859150171279907, Generator Loss: 2.2688357830047607
# 2024-10-31 01:33:48.150592: W tensorflow/core/framework/local_rendezvous.cc:404] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence
# Epoch 479, Discriminator Loss: 0.2023962140083313, Generator Loss: 2.667527675628662
# 2024-10-31 01:34:02.865511: W tensorflow/core/framework/local_rendezvous.cc:404] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence
# Epoch 480, Discriminator Loss: 0.2985769808292389, Generator Loss: 3.246171712875366
# 2024-10-31 01:34:16.544007: W tensorflow/core/framework/local_rendezvous.cc:404] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence
# Epoch 481, Discriminator Loss: 0.2996717691421509, Generator Loss: 2.718506097793579
# 2024-10-31 01:34:28.174696: W tensorflow/core/framework/local_rendezvous.cc:404] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence
# Epoch 482, Discriminator Loss: 0.2469797432422638, Generator Loss: 2.7931785583496094
# 2024-10-31 01:34:40.053578: W tensorflow/core/framework/local_rendezvous.cc:404] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence
# Epoch 483, Discriminator Loss: 0.16366787254810333, Generator Loss: 2.8039064407348633
# 2024-10-31 01:34:50.311541: W tensorflow/core/framework/local_rendezvous.cc:404] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence
# Epoch 484, Discriminator Loss: 0.2850065231323242, Generator Loss: 2.3670945167541504
# 2024-10-31 01:35:02.256768: W tensorflow/core/framework/local_rendezvous.cc:404] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence
# Epoch 485, Discriminator Loss: 0.23819981515407562, Generator Loss: 2.764155626296997
# 2024-10-31 01:35:15.919822: W tensorflow/core/framework/local_rendezvous.cc:404] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence
# Epoch 486, Discriminator Loss: 0.1847546398639679, Generator Loss: 2.811528205871582
# 2024-10-31 01:35:28.251513: W tensorflow/core/framework/local_rendezvous.cc:404] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence
# Epoch 487, Discriminator Loss: 0.2995518147945404, Generator Loss: 2.5774803161621094
# 2024-10-31 01:35:41.282353: W tensorflow/core/framework/local_rendezvous.cc:404] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence
# Epoch 488, Discriminator Loss: 0.24513867497444153, Generator Loss: 2.59843373298645
# 2024-10-31 01:35:54.634408: W tensorflow/core/framework/local_rendezvous.cc:404] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence
# Epoch 489, Discriminator Loss: 0.26578250527381897, Generator Loss: 3.0098912715911865
# Epoch 490, Discriminator Loss: 0.1970532238483429, Generator Loss: 2.7687735557556152
# 2024-10-31 01:36:07.811074: W tensorflow/core/framework/local_rendezvous.cc:404] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence
# 2024-10-31 01:36:20.526109: W tensorflow/core/framework/local_rendezvous.cc:404] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence
# Epoch 491, Discriminator Loss: 0.2212766408920288, Generator Loss: 2.396867513656616
# 2024-10-31 01:36:32.841416: W tensorflow/core/framework/local_rendezvous.cc:404] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence
# Epoch 492, Discriminator Loss: 0.13548973202705383, Generator Loss: 2.774686574935913
# 2024-10-31 01:36:46.261131: W tensorflow/core/framework/local_rendezvous.cc:404] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence
# Epoch 493, Discriminator Loss: 0.19254764914512634, Generator Loss: 2.379427909851074
# 2024-10-31 01:36:59.847320: W tensorflow/core/framework/local_rendezvous.cc:404] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence
# Epoch 494, Discriminator Loss: 0.3733814060688019, Generator Loss: 2.4519777297973633
# 2024-10-31 01:37:14.546849: W tensorflow/core/framework/local_rendezvous.cc:404] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence
# Epoch 495, Discriminator Loss: 0.13666221499443054, Generator Loss: 2.7942466735839844
# 2024-10-31 01:37:29.772658: W tensorflow/core/framework/local_rendezvous.cc:404] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence
# Epoch 496, Discriminator Loss: 0.14223793148994446, Generator Loss: 2.3002569675445557
# 2024-10-31 01:37:46.331118: W tensorflow/core/framework/local_rendezvous.cc:404] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence
# Epoch 497, Discriminator Loss: 0.18493345379829407, Generator Loss: 2.637725353240967
# 2024-10-31 01:38:01.508043: W tensorflow/core/framework/local_rendezvous.cc:404] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence
# Epoch 498, Discriminator Loss: 0.18871349096298218, Generator Loss: 2.6045830249786377
# 2024-10-31 01:38:11.773362: W tensorflow/core/framework/local_rendezvous.cc:404] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence
# Epoch 499, Discriminator Loss: 0.30097752809524536, Generator Loss: 2.396962881088257
# 2024-10-31 01:38:21.926979: W tensorflow/core/framework/local_rendezvous.cc:404] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence
# Epoch 500, Discriminator Loss: 0.30023664236068726, Generator Loss: 2.734693765640259

# %%
# Save the trained models
save_model(generator, discriminator)
# Out:
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.

# %%
# Generate images from the saved generator model after training
generate_images_from_saved_model()
# Out:
# WARNING:absl:No training configuration found in the save file, so the model was *not* compiled. Compile it manually.
# WARNING:absl:No training configuration found in the save file, so the model was *not* compiled. Compile it manually.
