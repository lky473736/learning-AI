# %% [markdown]
# ## learning-AI101 : abalone classification (DL)
# ### 전복 데이터를 Dense layer struction을 통한 DNN 방식의 classification
#
# <br>
#
# - **임규연 (lky473736)**
# - 2024.08.02.에 문서 작성
# - **dataset** : https://archive.ics.uci.edu/dataset/1/abalone
# - **data abstract** : Predicting the age of abalone from physical measurements.  The age of abalone is determined by cutting the shell through the cone, staining it, and counting the number of rings through a microscope -- a boring and time-consuming task.  Other measurements, which are easier to obtain, are used to predict the age.  Further information, such as weather patterns and location (hence food availability) may be required to solve the problem. From the original data examples with missing values were removed (the majority having the predicted value missing), and the ranges of the continuous values have been scaled for use with an ANN (by dividing by 200).
#
# ------

# %% [markdown]
# -----
#
# ## <span id='dl'><mark>DL</mark></span>
#
# deep learning으로 abalone을 classification한다. 목차는 아래와 같다.
#
# - **1. EDA and preprocessing**
# - **2. SGDClassifier를 통한 ML에서의 확률적 경사 하강법 적용**
# - **3. ANN (fully connected)**
# - **4. DNN**

# %%
# 라이브러리 import

import numpy as np
import pandas as pd
import seaborn as sns
import tensorflow as tf
import matplotlib.pyplot as plt
import seaborn as sns
from tensorflow import keras
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler, LabelEncoder

# %% [markdown]
# ------
#
# ### 1. EDA and preprocessing
# - 데이터 시각화 및 필요한 정보를 얻어낸다.
# - 결측치 제거, outlier 제거 등의 데이터 전처리를 수행한다.

# %%
# 데이터 읽기

header = ['Sex', 'Length', 'Diameter', 'Height', 'Whole_weight', 
          'Shucked_weight', 'Viscera_weight', 'Shell_weight', 'Rings']
df = pd.read_csv("./data/abalone/abalone.csv", names = header)
df
# Out:
#      Sex  Length  Diameter  ...  Viscera_weight  Shell_weight  Rings
# 0      M   0.455     0.365  ...          0.1010        0.1500     15
# 1      M   0.350     0.265  ...          0.0485        0.0700      7
# 2      F   0.530     0.420  ...          0.1415        0.2100      9
# 3      M   0.440     0.365  ...          0.1140        0.1550     10
# 4      I   0.330     0.255  ...          0.0395        0.0550      7
# ...   ..     ...       ...  ...             ...           ...    ...
# 4172   F   0.565     0.450  ...          0.2390        0.2490     11
# 4173   M   0.590     0.440  ...          0.2145        0.2605     10
# 4174   M   0.600     0.475  ...          0.2875        0.3080      9
# 4175   F   0.625     0.485  ...          0.2610        0.2960     10
# 4176   M   0.710     0.555  ...          0.3765        0.4950     12
#
# [4177 rows x 9 columns]
#      Sex  Length  Diameter  ...  Viscera_weight  Shell_weight  Rings
# 0      M   0.455     0.365  ...          0.1010        0.1500     15
# 1      M   0.350     0.265  ...          0.0485        0.0700      7
# 2      F   0.530     0.420  ...          0.1415        0.2100      9
# 3      M   0.440     0.365  ...          0.1140        0.1550     10
# 4      I   0.330     0.255  ...          0.0395        0.0550      7
# ...   ..     ...       ...  ...             ...           ...    ...
# 4172   F   0.565     0.450  ...          0.2390        0.2490     11
# 4173   M   0.590     0.440  ...          0.2145        0.2605     10
# 4174   M   0.600     0.475  ...          0.2875        0.3080      9
# 4175   F   0.625     0.485  ...          0.2610        0.2960     10
# 4176   M   0.710     0.555  ...          0.3765        0.4950     12
#
# [4177 rows x 9 columns]

# %%
# df의 행의 갯수, 열의 갯수, feature 파악

df.shape, df.columns
# Out:
# ((4177, 9),
#  Index(['Sex', 'Length', 'Diameter', 'Height', 'Whole_weight', 'Shucked_weight',
#         'Viscera_weight', 'Shell_weight', 'Rings'],
#        dtype='object'))

# %%
# df의 기본적인 정보 및 기초통계량

df.info()
df.describe()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4177 entries, 0 to 4176
# Data columns (total 9 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Sex             4177 non-null   object
#  1   Length          4177 non-null   float64
#  2   Diameter        4177 non-null   float64
#  3   Height          4177 non-null   float64
#  4   Whole_weight    4177 non-null   float64
#  5   Shucked_weight  4177 non-null   float64
#  6   Viscera_weight  4177 non-null   float64
#  7   Shell_weight    4177 non-null   float64
#  8   Rings           4177 non-null   int64
# dtypes: float64(7), int64(1), object(1)
# memory usage: 293.8+ KB
#             Length     Diameter  ...  Shell_weight        Rings
# count  4177.000000  4177.000000  ...   4177.000000  4177.000000
# mean      0.523992     0.407881  ...      0.238831     9.933684
# std       0.120093     0.099240  ...      0.139203     3.224169
# min       0.075000     0.055000  ...      0.001500     1.000000
# 25%       0.450000     0.350000  ...      0.130000     8.000000
# 50%       0.545000     0.425000  ...      0.234000     9.000000
# 75%       0.615000     0.480000  ...      0.329000    11.000000
# max       0.815000     0.650000  ...      1.005000    29.000000
#
# [8 rows x 8 columns]

# %%
# seaborn countplot을 통한 각 레이블 도수 확인

sns.countplot (data=df, x='Rings')
plt.xlabel ("Rings")
plt.ylabel ("Number")
plt.title ("Target")
plt.show()

# %%
# target의 class 도수를 확인 (숫자로)

df['Rings'].value_counts()
# Out:
# Rings
# 9     689
# 10    634
# 8     568
# 11    487
# 7     391
# 12    267
# 6     259
# 13    203
# 14    126
# 5     115
# 15    103
# 16     67
# 17     58
# 4      57
# 18     42
# 19     32
# 20     26
# 3      15
# 21     14
# 23      9
# 22      6
# 27      2
# 24      2
# 1       1
# 26      1
# 29      1
# 2       1
# 25      1
# Name: count, dtype: int64

# %%
# Sex 특성 제거 및 Rings의 재구성

print (df.columns)
df = df.drop(columns=['Sex']) # Sex 특성 제거

for ix in df.index :
    row = df.loc[ix]
    if row.Rings <= 8 :
        df.loc[ix, 'Rings'] = 0 # 'young'
    elif row.Rings >= 11 :
        df.loc[ix, 'Rings'] = 2 # 'old'
    elif row.Rings >=9 and row.Rings <= 10 :
        df.loc[ix, 'Rings'] = 1 # 'medium'
        
df.head()
# Out:
# Index(['Sex', 'Length', 'Diameter', 'Height', 'Whole_weight', 'Shucked_weight',
#        'Viscera_weight', 'Shell_weight', 'Rings'],
#       dtype='object')
#    Length  Diameter  Height  ...  Viscera_weight  Shell_weight  Rings
# 0   0.455     0.365   0.095  ...          0.1010         0.150      2
# 1   0.350     0.265   0.090  ...          0.0485         0.070      0
# 2   0.530     0.420   0.135  ...          0.1415         0.210      1
# 3   0.440     0.365   0.125  ...          0.1140         0.155      1
# 4   0.330     0.255   0.080  ...          0.0395         0.055      0
#
# [5 rows x 8 columns]

# %%
# 각 클래스별 갯수를 시각화

unique, counts = np.unique(df['Rings'].to_numpy(), return_counts=True)
class_counts = dict(zip(unique, counts))

plt.bar("young", class_counts[0], label="young")
plt.bar("medium", class_counts[1], label="medium")
plt.bar("old", class_counts[2], label="old")
plt.legend()
plt.show()

# %%
# 결측치 확인

df.isnull().sum()
# Out:
# Length            0
# Diameter          0
# Height            0
# Whole_weight      0
# Shucked_weight    0
# Viscera_weight    0
# Shell_weight      0
# Rings             0
# dtype: int64

# %%
# 결측치 제거

df = df.dropna()
df.isnull().sum()
# Out:
# Length            0
# Diameter          0
# Height            0
# Whole_weight      0
# Shucked_weight    0
# Viscera_weight    0
# Shell_weight      0
# Rings             0
# dtype: int64

# %%
# pairplot를 사용해 각 feature의 상관관계 알아보기

import warnings 
warnings.filterwarnings("ignore", category=FutureWarning, module="seaborn")

sns.pairplot(df, vars=('Length', 'Diameter', 'Height', 
                       'Whole_weight', 'Shucked_weight', 'Viscera_weight', 
                       'Shell_weight', 'Rings',), hue ='Rings')
plt.show()

# %%
# seaborn을 통하여 heatmap 시각화

correlation_matrix = df[['Length', 'Diameter', 'Height', 
                         'Whole_weight', 'Shucked_weight', 
                         'Viscera_weight', 'Shell_weight', 'Rings']].corr() # feature (target 제외)
plt.figure(figsize=(10, 8)) 
sns.heatmap(correlation_matrix, annot=True, cmap='RdBu', square=True,
            linewidths=1, linecolor='black', cbar_kws={"shrink": 0.8})

plt.title('Correlation Heatmap of Abalone Dataset', fontsize=16)
plt.show()

# %%
# 각 컬럼별 히스토 그램 확인

fig = plt.figure(figsize = (15, 20))
ax = fig.gca()
df.hist (ax = ax)
plt.show()
# Out:
# /var/folders/_z/gryfr07n59jgb3wrd062h1ym0000gn/T/ipykernel_50429/3231520240.py:5: UserWarning: To output multiple subplots, the figure containing the passed axes is being cleared.
#   df.hist (ax = ax)

# %%
# abalone_input, abalone_target 만들기

abalone_input = df.drop('Rings', axis=1)
abalone_target = df['Rings']

print(abalone_target.value_counts())
abalone_input.head()
# Out:
# Rings
# 2    1447
# 0    1407
# 1    1323
# Name: count, dtype: int64
#    Length  Diameter  Height  ...  Shucked_weight  Viscera_weight  Shell_weight
# 0   0.455     0.365   0.095  ...          0.2245          0.1010         0.150
# 1   0.350     0.265   0.090  ...          0.0995          0.0485         0.070
# 2   0.530     0.420   0.135  ...          0.2565          0.1415         0.210
# 3   0.440     0.365   0.125  ...          0.2155          0.1140         0.155
# 4   0.330     0.255   0.080  ...          0.0895          0.0395         0.055
#
# [5 rows x 7 columns]

# %% [markdown]
# -------
#
# ### 2. SGDClassifier를 통한 ML에서의 확률적 경사 하강법 적용
# deep learning을 하기 전, deep learning의 weight 및 bias 조정법인 **SGD (Stochastic Gradient Descent)** 를 scikit-learn으로 구현 후 classification score를 확인해본다. parameter는 random search를 통하여 최적화할 것이며, 자세한 조정범위는 아래에 서술한다.
# - loss function : log_loss (logistic regression (sigmoid))
# - max_iter : 10~50 (randint)

# %%
# data split 및 normalization

from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler

raisin_input = df[df.columns[:-1]]
raisin_target = df[df.columns[-1]]

X_train, X_test, y_train, y_test = train_test_split(abalone_input, abalone_target, 
                                                   stratify=abalone_target, test_size=0.2)

ss = StandardScaler()
X_train_scaled = ss.fit_transform(X_train)
X_test_scaled = ss.transform(X_test)

# %%
# random search를 통한 hyperparameter tuning

from sklearn.linear_model import SGDClassifier
from scipy.stats import randint, uniform
from sklearn.model_selection import RandomizedSearchCV

param = {
    'max_iter' : randint(10, 50)
}

sc = SGDClassifier(loss='log_loss')
rs = RandomizedSearchCV(sc, param, n_iter=50, n_jobs=-1)
rs.fit (X_train_scaled, y_train)
# Out:
# /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/sklearn/linear_model/_stochastic_gradient.py:713: ConvergenceWarning: Maximum number of iteration reached before convergence. Consider increasing max_iter to improve the fit.
#   warnings.warn(
# /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/sklearn/linear_model/_stochastic_gradient.py:713: ConvergenceWarning: Maximum number of iteration reached before convergence. Consider increasing max_iter to improve the fit.
#   warnings.warn(
# /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/sklearn/linear_model/_stochastic_gradient.py:713: ConvergenceWarning: Maximum number of iteration reached before convergence. Consider increasing max_iter to improve the fit.
#   warnings.warn(
# /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/sklearn/linear_model/_stochastic_gradient.py:713: ConvergenceWarning: Maximum number of iteration reached before convergence. Consider increasing max_iter to improve the fit.
#   warnings.warn(
# /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/sklearn/linear_model/_stochastic_gradient.py:713: ConvergenceWarning: Maximum number of iteration reached before convergence. Consider increasing max_iter to improve the fit.
#   warnings.warn(
# /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/sklearn/linear_model/_stochastic_gradient.py:713: ConvergenceWarning: Maximum number of iteration reached before convergence. Consider increasing max_iter to improve the fit.
#   warnings.warn(
# /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/sklearn/linear_model/_stochastic_gradient.py:713: ConvergenceWarning: Maximum number of iteration reached before convergence. Consider increasing max_iter to improve the fit.
#   warnings.warn(
# /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/sklearn/linear_model/_stochastic_gradient.py:713: ConvergenceWarning: Maximum number of iteration reached before convergence. Consider increasing max_iter to improve the fit.
#   warnings.warn(
# /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/sklearn/linear_model/_stochastic_gradient.py:713: ConvergenceWarning: Maximum number of iteration reached before convergence. Consider increasing max_iter to improve the fit.
#   warnings.warn(
# /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/sklearn/linear_model/_stochastic_gradient.py:713: ConvergenceWarning: Maximum number of iteration reached before convergence. Consider increasing max_iter to improve the fit.
#   warnings.warn(
# /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/sklearn/linear_model/_stochastic_gradient.py:713: ConvergenceWarning: Maximum number of iteration reached before convergence. Consider increasing max_iter to improve the fit.
#   warnings.warn(
# /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/sklearn/linear_model/_stochastic_gradient.py:713: ConvergenceWarning: Maximum number of iteration reached before convergence. Consider increasing max_iter to improve the fit.
#   warnings.warn(
# /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/sklearn/linear_model/_stochastic_gradient.py:713: ConvergenceWarning: Maximum number of iteration reached before convergence. Consider increasing max_iter to improve the fit.
#   warnings.warn(
# /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/sklearn/linear_model/_stochastic_gradient.py:713: ConvergenceWarning: Maximum number of iteration reached before convergence. Consider increasing max_iter to improve the fit.
#   warnings.warn(
# /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/sklearn/linear_model/_stochastic_gradient.py:713: ConvergenceWarning: Maximum number of iteration reached before convergence. Consider increasing max_iter to improve the fit.
#   warnings.warn(
# /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/sklearn/linear_model/_stochastic_gradient.py:713: ConvergenceWarning: Maximum number of iteration reached before convergence. Consider increasing max_iter to improve the fit.
#   warnings.warn(
# /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/sklearn/linear_model/_stochastic_gradient.py:713: ConvergenceWarning: Maximum number of iteration reached before convergence. Consider increasing max_iter to improve the fit.
#   warnings.warn(
# /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/sklearn/linear_model/_stochastic_gradient.py:713: ConvergenceWarning: Maximum number of iteration reached before convergence. Consider increasing max_iter to improve the fit.
#   warnings.warn(
# /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/sklearn/linear_model/_stochastic_gradient.py:713: ConvergenceWarning: Maximum number of iteration reached before convergence. Consider increasing max_iter to improve the fit.
#   warnings.warn(
# /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/sklearn/linear_model/_stochastic_gradient.py:713: ConvergenceWarning: Maximum number of iteration reached before convergence. Consider increasing max_iter to improve the fit.
#   warnings.warn(
# /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/sklearn/linear_model/_stochastic_gradient.py:713: ConvergenceWarning: Maximum number of iteration reached before convergence. Consider increasing max_iter to improve the fit.
#   warnings.warn(
# /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/sklearn/linear_model/_stochastic_gradient.py:713: ConvergenceWarning: Maximum number of iteration reached before convergence. Consider increasing max_iter to improve the fit.
#   warnings.warn(
# /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/sklearn/linear_model/_stochastic_gradient.py:713: ConvergenceWarning: Maximum number of iteration reached before convergence. Consider increasing max_iter to improve the fit.
#   warnings.warn(
# /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/sklearn/linear_model/_stochastic_gradient.py:713: ConvergenceWarning: Maximum number of iteration reached before convergence. Consider increasing max_iter to improve the fit.
#   warnings.warn(
# /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/sklearn/linear_model/_stochastic_gradient.py:713: ConvergenceWarning: Maximum number of iteration reached before convergence. Consider increasing max_iter to improve the fit.
#   warnings.warn(
# /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/sklearn/linear_model/_stochastic_gradient.py:713: ConvergenceWarning: Maximum number of iteration reached before convergence. Consider increasing max_iter to improve the fit.
#   warnings.warn(
# /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/sklearn/linear_model/_stochastic_gradient.py:713: ConvergenceWarning: Maximum number of iteration reached before convergence. Consider increasing max_iter to improve the fit.
#   warnings.warn(
# /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/sklearn/linear_model/_stochastic_gradient.py:713: ConvergenceWarning: Maximum number of iteration reached before convergence. Consider increasing max_iter to improve the fit.
#   warnings.warn(
# /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/sklearn/linear_model/_stochastic_gradient.py:713: ConvergenceWarning: Maximum number of iteration reached before convergence. Consider increasing max_iter to improve the fit.
#   warnings.warn(
# /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/sklearn/linear_model/_stochastic_gradient.py:713: ConvergenceWarning: Maximum number of iteration reached before convergence. Consider increasing max_iter to improve the fit.
#   warnings.warn(
# /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/sklearn/linear_model/_stochastic_gradient.py:713: ConvergenceWarning: Maximum number of iteration reached before convergence. Consider increasing max_iter to improve the fit.
#   warnings.warn(
# /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/sklearn/linear_model/_stochastic_gradient.py:713: ConvergenceWarning: Maximum number of iteration reached before convergence. Consider increasing max_iter to improve the fit.
#   warnings.warn(
# /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/sklearn/linear_model/_stochastic_gradient.py:713: ConvergenceWarning: Maximum number of iteration reached before convergence. Consider increasing max_iter to improve the fit.
#   warnings.warn(
# /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/sklearn/linear_model/_stochastic_gradient.py:713: ConvergenceWarning: Maximum number of iteration reached before convergence. Consider increasing max_iter to improve the fit.
#   warnings.warn(
# /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/sklearn/linear_model/_stochastic_gradient.py:713: ConvergenceWarning: Maximum number of iteration reached before convergence. Consider increasing max_iter to improve the fit.
#   warnings.warn(
# /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/sklearn/linear_model/_stochastic_gradient.py:713: ConvergenceWarning: Maximum number of iteration reached before convergence. Consider increasing max_iter to improve the fit.
#   warnings.warn(
# /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/sklearn/linear_model/_stochastic_gradient.py:713: ConvergenceWarning: Maximum number of iteration reached before convergence. Consider increasing max_iter to improve the fit.
#   warnings.warn(
# /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/sklearn/linear_model/_stochastic_gradient.py:713: ConvergenceWarning: Maximum number of iteration reached before convergence. Consider increasing max_iter to improve the fit.
#   warnings.warn(
# /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/sklearn/linear_model/_stochastic_gradient.py:713: ConvergenceWarning: Maximum number of iteration reached before convergence. Consider increasing max_iter to improve the fit.
#   warnings.warn(
# /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/sklearn/linear_model/_stochastic_gradient.py:713: ConvergenceWarning: Maximum number of iteration reached before convergence. Consider increasing max_iter to improve the fit.
#   warnings.warn(
# /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/sklearn/linear_model/_stochastic_gradient.py:713: ConvergenceWarning: Maximum number of iteration reached before convergence. Consider increasing max_iter to improve the fit.
#   warnings.warn(
# /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/sklearn/linear_model/_stochastic_gradient.py:713: ConvergenceWarning: Maximum number of iteration reached before convergence. Consider increasing max_iter to improve the fit.
#   warnings.warn(
# /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/sklearn/linear_model/_stochastic_gradient.py:713: ConvergenceWarning: Maximum number of iteration reached before convergence. Consider increasing max_iter to improve the fit.
#   warnings.warn(
# /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/sklearn/linear_model/_stochastic_gradient.py:713: ConvergenceWarning: Maximum number of iteration reached before convergence. Consider increasing max_iter to improve the fit.
#   warnings.warn(
# /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/sklearn/linear_model/_stochastic_gradient.py:713: ConvergenceWarning: Maximum number of iteration reached before convergence. Consider increasing max_iter to improve the fit.
#   warnings.warn(
# /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/sklearn/linear_model/_stochastic_gradient.py:713: ConvergenceWarning: Maximum number of iteration reached before convergence. Consider increasing max_iter to improve the fit.
#   warnings.warn(
# /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/sklearn/linear_model/_stochastic_gradient.py:713: ConvergenceWarning: Maximum number of iteration reached before convergence. Consider increasing max_iter to improve the fit.
#   warnings.warn(
# /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/sklearn/linear_model/_stochastic_gradient.py:713: ConvergenceWarning: Maximum number of iteration reached before convergence. Consider increasing max_iter to improve the fit.
#   warnings.warn(
# /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/sklearn/linear_model/_stochastic_gradient.py:713: ConvergenceWarning: Maximum number of iteration reached before convergence. Consider increasing max_iter to improve the fit.
#   warnings.warn(
# /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/sklearn/linear_model/_stochastic_gradient.py:713: ConvergenceWarning: Maximum number of iteration reached before convergence. Consider increasing max_iter to improve the fit.
#   warnings.warn(
# /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/sklearn/linear_model/_stochastic_gradient.py:713: ConvergenceWarning: Maximum number of iteration reached before convergence. Consider increasing max_iter to improve the fit.
#   warnings.warn(
# /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/sklearn/linear_model/_stochastic_gradient.py:713: ConvergenceWarning: Maximum number of iteration reached before convergence. Consider increasing max_iter to improve the fit.
#   warnings.warn(
# /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/sklearn/linear_model/_stochastic_gradient.py:713: ConvergenceWarning: Maximum number of iteration reached before convergence. Consider increasing max_iter to improve the fit.
#   warnings.warn(
# /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/sklearn/linear_model/_stochastic_gradient.py:713: ConvergenceWarning: Maximum number of iteration reached before convergence. Consider increasing max_iter to improve the fit.
#   warnings.warn(
# /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/sklearn/linear_model/_stochastic_gradient.py:713: ConvergenceWarning: Maximum number of iteration reached before convergence. Consider increasing max_iter to improve the fit.
#   warnings.warn(
# /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/sklearn/linear_model/_stochastic_gradient.py:713: ConvergenceWarning: Maximum number of iteration reached before convergence. Consider increasing max_iter to improve the fit.
#   warnings.warn(
# /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/sklearn/linear_model/_stochastic_gradient.py:713: ConvergenceWarning: Maximum number of iteration reached before convergence. Consider increasing max_iter to improve the fit.
#   warnings.warn(
# /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/sklearn/linear_model/_stochastic_gradient.py:713: ConvergenceWarning: Maximum number of iteration reached before convergence. Consider increasing max_iter to improve the fit.
#   warnings.warn(
# /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/sklearn/linear_model/_stochastic_gradient.py:713: ConvergenceWarning: Maximum number of iteration reached before convergence. Consider increasing max_iter to improve the fit.
#   warnings.warn(
# /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/sklearn/linear_model/_stochastic_gradient.py:713: ConvergenceWarning: Maximum number of iteration reached before convergence. Consider increasing max_iter to improve the fit.
#   warnings.warn(
# /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/sklearn/linear_model/_stochastic_gradient.py:713: ConvergenceWarning: Maximum number of iteration reached before convergence. Consider increasing max_iter to improve the fit.
#   warnings.warn(
# /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/sklearn/linear_model/_stochastic_gradient.py:713: ConvergenceWarning: Maximum number of iteration reached before convergence. Consider increasing max_iter to improve the fit.
#   warnings.warn(
# /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/sklearn/linear_model/_stochastic_gradient.py:713: ConvergenceWarning: Maximum number of iteration reached before convergence. Consider increasing max_iter to improve the fit.
#   warnings.warn(
# /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/sklearn/linear_model/_stochastic_gradient.py:713: ConvergenceWarning: Maximum number of iteration reached before convergence. Consider increasing max_iter to improve the fit.
#   warnings.warn(
# /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/sklearn/linear_model/_stochastic_gradient.py:713: ConvergenceWarning: Maximum number of iteration reached before convergence. Consider increasing max_iter to improve the fit.
#   warnings.warn(
# /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/sklearn/linear_model/_stochastic_gradient.py:713: ConvergenceWarning: Maximum number of iteration reached before convergence. Consider increasing max_iter to improve the fit.
#   warnings.warn(
# /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/sklearn/linear_model/_stochastic_gradient.py:713: ConvergenceWarning: Maximum number of iteration reached before convergence. Consider increasing max_iter to improve the fit.
#   warnings.warn(
# /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/sklearn/linear_model/_stochastic_gradient.py:713: ConvergenceWarning: Maximum number of iteration reached before convergence. Consider increasing max_iter to improve the fit.
#   warnings.warn(
# /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/sklearn/linear_model/_stochastic_gradient.py:713: ConvergenceWarning: Maximum number of iteration reached before convergence. Consider increasing max_iter to improve the fit.
#   warnings.warn(
# /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/sklearn/linear_model/_stochastic_gradient.py:713: ConvergenceWarning: Maximum number of iteration reached before convergence. Consider increasing max_iter to improve the fit.
#   warnings.warn(
# /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/sklearn/linear_model/_stochastic_gradient.py:713: ConvergenceWarning: Maximum number of iteration reached before convergence. Consider increasing max_iter to improve the fit.
#   warnings.warn(
# /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/sklearn/linear_model/_stochastic_gradient.py:713: ConvergenceWarning: Maximum number of iteration reached before convergence. Consider increasing max_iter to improve the fit.
#   warnings.warn(
# /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/sklearn/linear_model/_stochastic_gradient.py:713: ConvergenceWarning: Maximum number of iteration reached before convergence. Consider increasing max_iter to improve the fit.
#   warnings.warn(
# /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/sklearn/linear_model/_stochastic_gradient.py:713: ConvergenceWarning: Maximum number of iteration reached before convergence. Consider increasing max_iter to improve the fit.
#   warnings.warn(
# /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/sklearn/linear_model/_stochastic_gradient.py:713: ConvergenceWarning: Maximum number of iteration reached before convergence. Consider increasing max_iter to improve the fit.
#   warnings.warn(
# /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/sklearn/linear_model/_stochastic_gradient.py:713: ConvergenceWarning: Maximum number of iteration reached before convergence. Consider increasing max_iter to improve the fit.
#   warnings.warn(
# /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/sklearn/linear_model/_stochastic_gradient.py:713: ConvergenceWarning: Maximum number of iteration reached before convergence. Consider increasing max_iter to improve the fit.
#   warnings.warn(
# /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/sklearn/linear_model/_stochastic_gradient.py:713: ConvergenceWarning: Maximum number of iteration reached before convergence. Consider increasing max_iter to improve the fit.
#   warnings.warn(
# /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/sklearn/linear_model/_stochastic_gradient.py:713: ConvergenceWarning: Maximum number of iteration reached before convergence. Consider increasing max_iter to improve the fit.
#   warnings.warn(
# /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/sklearn/linear_model/_stochastic_gradient.py:713: ConvergenceWarning: Maximum number of iteration reached before convergence. Consider increasing max_iter to improve the fit.
#   warnings.warn(
# /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/sklearn/linear_model/_stochastic_gradient.py:713: ConvergenceWarning: Maximum number of iteration reached before convergence. Consider increasing max_iter to improve the fit.
#   warnings.warn(
# /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/sklearn/linear_model/_stochastic_gradient.py:713: ConvergenceWarning: Maximum number of iteration reached before convergence. Consider increasing max_iter to improve the fit.
#   warnings.warn(
# /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/sklearn/linear_model/_stochastic_gradient.py:713: ConvergenceWarning: Maximum number of iteration reached before convergence. Consider increasing max_iter to improve the fit.
#   warnings.warn(
# /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/sklearn/linear_model/_stochastic_gradient.py:713: ConvergenceWarning: Maximum number of iteration reached before convergence. Consider increasing max_iter to improve the fit.
#   warnings.warn(
# /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/sklearn/linear_model/_stochastic_gradient.py:713: ConvergenceWarning: Maximum number of iteration reached before convergence. Consider increasing max_iter to improve the fit.
#   warnings.warn(
# /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/sklearn/linear_model/_stochastic_gradient.py:713: ConvergenceWarning: Maximum number of iteration reached before convergence. Consider increasing max_iter to improve the fit.
#   warnings.warn(
# /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/sklearn/linear_model/_stochastic_gradient.py:713: ConvergenceWarning: Maximum number of iteration reached before convergence. Consider increasing max_iter to improve the fit.
#   warnings.warn(
# /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/sklearn/linear_model/_stochastic_gradient.py:713: ConvergenceWarning: Maximum number of iteration reached before convergence. Consider increasing max_iter to improve the fit.
#   warnings.warn(
# /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/sklearn/linear_model/_stochastic_gradient.py:713: ConvergenceWarning: Maximum number of iteration reached before convergence. Consider increasing max_iter to improve the fit.
#   warnings.warn(
# /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/sklearn/linear_model/_stochastic_gradient.py:713: ConvergenceWarning: Maximum number of iteration reached before convergence. Consider increasing max_iter to improve the fit.
#   warnings.warn(
# /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/sklearn/linear_model/_stochastic_gradient.py:713: ConvergenceWarning: Maximum number of iteration reached before convergence. Consider increasing max_iter to improve the fit.
#   warnings.warn(
# /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/sklearn/linear_model/_stochastic_gradient.py:713: ConvergenceWarning: Maximum number of iteration reached before convergence. Consider increasing max_iter to improve the fit.
#   warnings.warn(
# /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/sklearn/linear_model/_stochastic_gradient.py:713: ConvergenceWarning: Maximum number of iteration reached before convergence. Consider increasing max_iter to improve the fit.
#   warnings.warn(
# /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/sklearn/linear_model/_stochastic_gradient.py:713: ConvergenceWarning: Maximum number of iteration reached before convergence. Consider increasing max_iter to improve the fit.
#   warnings.warn(
# /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/sklearn/linear_model/_stochastic_gradient.py:713: ConvergenceWarning: Maximum number of iteration reached before convergence. Consider increasing max_iter to improve the fit.
#   warnings.warn(
# /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/sklearn/linear_model/_stochastic_gradient.py:713: ConvergenceWarning: Maximum number of iteration reached before convergence. Consider increasing max_iter to improve the fit.
#   warnings.warn(
# /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/sklearn/linear_model/_stochastic_gradient.py:713: ConvergenceWarning: Maximum number of iteration reached before convergence. Consider increasing max_iter to improve the fit.
#   warnings.warn(
# /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/sklearn/linear_model/_stochastic_gradient.py:713: ConvergenceWarning: Maximum number of iteration reached before convergence. Consider increasing max_iter to improve the fit.
#   warnings.warn(
# /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/sklearn/linear_model/_stochastic_gradient.py:713: ConvergenceWarning: Maximum number of iteration reached before convergence. Consider increasing max_iter to improve the fit.
#   warnings.warn(
# /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/sklearn/linear_model/_stochastic_gradient.py:713: ConvergenceWarning: Maximum number of iteration reached before convergence. Consider increasing max_iter to improve the fit.
#   warnings.warn(
# /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/sklearn/linear_model/_stochastic_gradient.py:713: ConvergenceWarning: Maximum number of iteration reached before convergence. Consider increasing max_iter to improve the fit.
#   warnings.warn(
# /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/sklearn/linear_model/_stochastic_gradient.py:713: ConvergenceWarning: Maximum number of iteration reached before convergence. Consider increasing max_iter to improve the fit.
#   warnings.warn(
# /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/sklearn/linear_model/_stochastic_gradient.py:713: ConvergenceWarning: Maximum number of iteration reached before convergence. Consider increasing max_iter to improve the fit.
#   warnings.warn(
# /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/sklearn/linear_model/_stochastic_gradient.py:713: ConvergenceWarning: Maximum number of iteration reached before convergence. Consider increasing max_iter to improve the fit.
#   warnings.warn(
# /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/sklearn/linear_model/_stochastic_gradient.py:713: ConvergenceWarning: Maximum number of iteration reached before convergence. Consider increasing max_iter to improve the fit.
#   warnings.warn(
# /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/sklearn/linear_model/_stochastic_gradient.py:713: ConvergenceWarning: Maximum number of iteration reached before convergence. Consider increasing max_iter to improve the fit.
#   warnings.warn(
# /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/sklearn/linear_model/_stochastic_gradient.py:713: ConvergenceWarning: Maximum number of iteration reached before convergence. Consider increasing max_iter to improve the fit.
#   warnings.warn(
# /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/sklearn/linear_model/_stochastic_gradient.py:713: ConvergenceWarning: Maximum number of iteration reached before convergence. Consider increasing max_iter to improve the fit.
#   warnings.warn(
# /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/sklearn/linear_model/_stochastic_gradient.py:713: ConvergenceWarning: Maximum number of iteration reached before convergence. Consider increasing max_iter to improve the fit.
#   warnings.warn(
# /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/sklearn/linear_model/_stochastic_gradient.py:713: ConvergenceWarning: Maximum number of iteration reached before convergence. Consider increasing max_iter to improve the fit.
#   warnings.warn(
# /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/sklearn/linear_model/_stochastic_gradient.py:713: ConvergenceWarning: Maximum number of iteration reached before convergence. Consider increasing max_iter to improve the fit.
#   warnings.warn(
# /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/sklearn/linear_model/_stochastic_gradient.py:713: ConvergenceWarning: Maximum number of iteration reached before convergence. Consider increasing max_iter to improve the fit.
#   warnings.warn(
# /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/sklearn/linear_model/_stochastic_gradient.py:713: ConvergenceWarning: Maximum number of iteration reached before convergence. Consider increasing max_iter to improve the fit.
#   warnings.warn(
# /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/sklearn/linear_model/_stochastic_gradient.py:713: ConvergenceWarning: Maximum number of iteration reached before convergence. Consider increasing max_iter to improve the fit.
#   warnings.warn(
# /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/sklearn/linear_model/_stochastic_gradient.py:713: ConvergenceWarning: Maximum number of iteration reached before convergence. Consider increasing max_iter to improve the fit.
#   warnings.warn(
# /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/sklearn/linear_model/_stochastic_gradient.py:713: ConvergenceWarning: Maximum number of iteration reached before convergence. Consider increasing max_iter to improve the fit.
#   warnings.warn(
# /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/sklearn/linear_model/_stochastic_gradient.py:713: ConvergenceWarning: Maximum number of iteration reached before convergence. Consider increasing max_iter to improve the fit.
#   warnings.warn(
# /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/sklearn/linear_model/_stochastic_gradient.py:713: ConvergenceWarning: Maximum number of iteration reached before convergence. Consider increasing max_iter to improve the fit.
#   warnings.warn(
# /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/sklearn/linear_model/_stochastic_gradient.py:713: ConvergenceWarning: Maximum number of iteration reached before convergence. Consider increasing max_iter to improve the fit.
#   warnings.warn(
# /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/sklearn/linear_model/_stochastic_gradient.py:713: ConvergenceWarning: Maximum number of iteration reached before convergence. Consider increasing max_iter to improve the fit.
#   warnings.warn(
# /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/sklearn/linear_model/_stochastic_gradient.py:713: ConvergenceWarning: Maximum number of iteration reached before convergence. Consider increasing max_iter to improve the fit.
#   warnings.warn(
# /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/sklearn/linear_model/_stochastic_gradient.py:713: ConvergenceWarning: Maximum number of iteration reached before convergence. Consider increasing max_iter to improve the fit.
#   warnings.warn(
# /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/sklearn/linear_model/_stochastic_gradient.py:713: ConvergenceWarning: Maximum number of iteration reached before convergence. Consider increasing max_iter to improve the fit.
#   warnings.warn(
# /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/sklearn/linear_model/_stochastic_gradient.py:713: ConvergenceWarning: Maximum number of iteration reached before convergence. Consider increasing max_iter to improve the fit.
#   warnings.warn(
# /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/sklearn/linear_model/_stochastic_gradient.py:713: ConvergenceWarning: Maximum number of iteration reached before convergence. Consider increasing max_iter to improve the fit.
#   warnings.warn(
# /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/sklearn/linear_model/_stochastic_gradient.py:713: ConvergenceWarning: Maximum number of iteration reached before convergence. Consider increasing max_iter to improve the fit.
#   warnings.warn(
# /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/sklearn/linear_model/_stochastic_gradient.py:713: ConvergenceWarning: Maximum number of iteration reached before convergence. Consider increasing max_iter to improve the fit.
#   warnings.warn(
# /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/sklearn/linear_model/_stochastic_gradient.py:713: ConvergenceWarning: Maximum number of iteration reached before convergence. Consider increasing max_iter to improve the fit.
#   warnings.warn(
# /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/sklearn/linear_model/_stochastic_gradient.py:713: ConvergenceWarning: Maximum number of iteration reached before convergence. Consider increasing max_iter to improve the fit.
#   warnings.warn(
# /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/sklearn/linear_model/_stochastic_gradient.py:713: ConvergenceWarning: Maximum number of iteration reached before convergence. Consider increasing max_iter to improve the fit.
#   warnings.warn(
# /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/sklearn/linear_model/_stochastic_gradient.py:713: ConvergenceWarning: Maximum number of iteration reached before convergence. Consider increasing max_iter to improve the fit.
#   warnings.warn(
# /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/sklearn/linear_model/_stochastic_gradient.py:713: ConvergenceWarning: Maximum number of iteration reached before convergence. Consider increasing max_iter to improve the fit.
#   warnings.warn(
# /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/sklearn/linear_model/_stochastic_gradient.py:713: ConvergenceWarning: Maximum number of iteration reached before convergence. Consider increasing max_iter to improve the fit.
#   warnings.warn(
# /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/sklearn/linear_model/_stochastic_gradient.py:713: ConvergenceWarning: Maximum number of iteration reached before convergence. Consider increasing max_iter to improve the fit.
#   warnings.warn(
# /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/sklearn/linear_model/_stochastic_gradient.py:713: ConvergenceWarning: Maximum number of iteration reached before convergence. Consider increasing max_iter to improve the fit.
#   warnings.warn(
# /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/sklearn/linear_model/_stochastic_gradient.py:713: ConvergenceWarning: Maximum number of iteration reached before convergence. Consider increasing max_iter to improve the fit.
#   warnings.warn(
# /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/sklearn/linear_model/_stochastic_gradient.py:713: ConvergenceWarning: Maximum number of iteration reached before convergence. Consider increasing max_iter to improve the fit.
#   warnings.warn(
# /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/sklearn/linear_model/_stochastic_gradient.py:713: ConvergenceWarning: Maximum number of iteration reached before convergence. Consider increasing max_iter to improve the fit.
#   warnings.warn(
# /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/sklearn/linear_model/_stochastic_gradient.py:713: ConvergenceWarning: Maximum number of iteration reached before convergence. Consider increasing max_iter to improve the fit.
#   warnings.warn(
# /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/sklearn/linear_model/_stochastic_gradient.py:713: ConvergenceWarning: Maximum number of iteration reached before convergence. Consider increasing max_iter to improve the fit.
#   warnings.warn(
# /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/sklearn/linear_model/_stochastic_gradient.py:713: ConvergenceWarning: Maximum number of iteration reached before convergence. Consider increasing max_iter to improve the fit.
#   warnings.warn(
# /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/sklearn/linear_model/_stochastic_gradient.py:713: ConvergenceWarning: Maximum number of iteration reached before convergence. Consider increasing max_iter to improve the fit.
#   warnings.warn(
# /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/sklearn/linear_model/_stochastic_gradient.py:713: ConvergenceWarning: Maximum number of iteration reached before convergence. Consider increasing max_iter to improve the fit.
#   warnings.warn(
# /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/sklearn/linear_model/_stochastic_gradient.py:713: ConvergenceWarning: Maximum number of iteration reached before convergence. Consider increasing max_iter to improve the fit.
#   warnings.warn(
# /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/sklearn/linear_model/_stochastic_gradient.py:713: ConvergenceWarning: Maximum number of iteration reached before convergence. Consider increasing max_iter to improve the fit.
#   warnings.warn(
# /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/sklearn/linear_model/_stochastic_gradient.py:713: ConvergenceWarning: Maximum number of iteration reached before convergence. Consider increasing max_iter to improve the fit.
#   warnings.warn(
# /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/sklearn/linear_model/_stochastic_gradient.py:713: ConvergenceWarning: Maximum number of iteration reached before convergence. Consider increasing max_iter to improve the fit.
#   warnings.warn(
# /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/sklearn/linear_model/_stochastic_gradient.py:713: ConvergenceWarning: Maximum number of iteration reached before convergence. Consider increasing max_iter to improve the fit.
#   warnings.warn(
# /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/sklearn/linear_model/_stochastic_gradient.py:713: ConvergenceWarning: Maximum number of iteration reached before convergence. Consider increasing max_iter to improve the fit.
#   warnings.warn(
# /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/sklearn/linear_model/_stochastic_gradient.py:713: ConvergenceWarning: Maximum number of iteration reached before convergence. Consider increasing max_iter to improve the fit.
#   warnings.warn(
# /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/sklearn/linear_model/_stochastic_gradient.py:713: ConvergenceWarning: Maximum number of iteration reached before convergence. Consider increasing max_iter to improve the fit.
#   warnings.warn(
# /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/sklearn/linear_model/_stochastic_gradient.py:713: ConvergenceWarning: Maximum number of iteration reached before convergence. Consider increasing max_iter to improve the fit.
#   warnings.warn(
# /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/sklearn/linear_model/_stochastic_gradient.py:713: ConvergenceWarning: Maximum number of iteration reached before convergence. Consider increasing max_iter to improve the fit.
#   warnings.warn(
# /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/sklearn/linear_model/_stochastic_gradient.py:713: ConvergenceWarning: Maximum number of iteration reached before convergence. Consider increasing max_iter to improve the fit.
#   warnings.warn(
# /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/sklearn/linear_model/_stochastic_gradient.py:713: ConvergenceWarning: Maximum number of iteration reached before convergence. Consider increasing max_iter to improve the fit.
#   warnings.warn(
# /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/sklearn/linear_model/_stochastic_gradient.py:713: ConvergenceWarning: Maximum number of iteration reached before convergence. Consider increasing max_iter to improve the fit.
#   warnings.warn(
# /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/sklearn/linear_model/_stochastic_gradient.py:713: ConvergenceWarning: Maximum number of iteration reached before convergence. Consider increasing max_iter to improve the fit.
#   warnings.warn(
# /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/sklearn/linear_model/_stochastic_gradient.py:713: ConvergenceWarning: Maximum number of iteration reached before convergence. Consider increasing max_iter to improve the fit.
#   warnings.warn(
# /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/sklearn/linear_model/_stochastic_gradient.py:713: ConvergenceWarning: Maximum number of iteration reached before convergence. Consider increasing max_iter to improve the fit.
#   warnings.warn(
# /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/sklearn/linear_model/_stochastic_gradient.py:713: ConvergenceWarning: Maximum number of iteration reached before convergence. Consider increasing max_iter to improve the fit.
#   warnings.warn(
# /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/sklearn/linear_model/_stochastic_gradient.py:713: ConvergenceWarning: Maximum number of iteration reached before convergence. Consider increasing max_iter to improve the fit.
#   warnings.warn(
# /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/sklearn/linear_model/_stochastic_gradient.py:713: ConvergenceWarning: Maximum number of iteration reached before convergence. Consider increasing max_iter to improve the fit.
#   warnings.warn(
# /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/sklearn/linear_model/_stochastic_gradient.py:713: ConvergenceWarning: Maximum number of iteration reached before convergence. Consider increasing max_iter to improve the fit.
#   warnings.warn(
# /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/sklearn/linear_model/_stochastic_gradient.py:713: ConvergenceWarning: Maximum number of iteration reached before convergence. Consider increasing max_iter to improve the fit.
#   warnings.warn(
# /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/sklearn/linear_model/_stochastic_gradient.py:713: ConvergenceWarning: Maximum number of iteration reached before convergence. Consider increasing max_iter to improve the fit.
#   warnings.warn(
# /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/sklearn/linear_model/_stochastic_gradient.py:713: ConvergenceWarning: Maximum number of iteration reached before convergence. Consider increasing max_iter to improve the fit.
#   warnings.warn(
# /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/sklearn/linear_model/_stochastic_gradient.py:713: ConvergenceWarning: Maximum number of iteration reached before convergence. Consider increasing max_iter to improve the fit.
#   warnings.warn(
# /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/sklearn/linear_model/_stochastic_gradient.py:713: ConvergenceWarning: Maximum number of iteration reached before convergence. Consider increasing max_iter to improve the fit.
#   warnings.warn(
# /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/sklearn/linear_model/_stochastic_gradient.py:713: ConvergenceWarning: Maximum number of iteration reached before convergence. Consider increasing max_iter to improve the fit.
#   warnings.warn(
# /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/sklearn/linear_model/_stochastic_gradient.py:713: ConvergenceWarning: Maximum number of iteration reached before convergence. Consider increasing max_iter to improve the fit.
#   warnings.warn(
# /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/sklearn/linear_model/_stochastic_gradient.py:713: ConvergenceWarning: Maximum number of iteration reached before convergence. Consider increasing max_iter to improve the fit.
#   warnings.warn(
# /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/sklearn/linear_model/_stochastic_gradient.py:713: ConvergenceWarning: Maximum number of iteration reached before convergence. Consider increasing max_iter to improve the fit.
#   warnings.warn(
# /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/sklearn/linear_model/_stochastic_gradient.py:713: ConvergenceWarning: Maximum number of iteration reached before convergence. Consider increasing max_iter to improve the fit.
#   warnings.warn(
# /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/sklearn/linear_model/_stochastic_gradient.py:713: ConvergenceWarning: Maximum number of iteration reached before convergence. Consider increasing max_iter to improve the fit.
#   warnings.warn(
# /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/sklearn/linear_model/_stochastic_gradient.py:713: ConvergenceWarning: Maximum number of iteration reached before convergence. Consider increasing max_iter to improve the fit.
#   warnings.warn(
# /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/sklearn/linear_model/_stochastic_gradient.py:713: ConvergenceWarning: Maximum number of iteration reached before convergence. Consider increasing max_iter to improve the fit.
#   warnings.warn(
# /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/sklearn/linear_model/_stochastic_gradient.py:713: ConvergenceWarning: Maximum number of iteration reached before convergence. Consider increasing max_iter to improve the fit.
#   warnings.warn(
# /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/sklearn/linear_model/_stochastic_gradient.py:713: ConvergenceWarning: Maximum number of iteration reached before convergence. Consider increasing max_iter to improve the fit.
#   warnings.warn(
# /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/sklearn/linear_model/_stochastic_gradient.py:713: ConvergenceWarning: Maximum number of iteration reached before convergence. Consider increasing max_iter to improve the fit.
#   warnings.warn(
# /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/sklearn/linear_model/_stochastic_gradient.py:713: ConvergenceWarning: Maximum number of iteration reached before convergence. Consider increasing max_iter to improve the fit.
#   warnings.warn(
# /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/sklearn/linear_model/_stochastic_gradient.py:713: ConvergenceWarning: Maximum number of iteration reached before convergence. Consider increasing max_iter to improve the fit.
#   warnings.warn(
# /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/sklearn/linear_model/_stochastic_gradient.py:713: ConvergenceWarning: Maximum number of iteration reached before convergence. Consider increasing max_iter to improve the fit.
#   warnings.warn(
# /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/sklearn/linear_model/_stochastic_gradient.py:713: ConvergenceWarning: Maximum number of iteration reached before convergence. Consider increasing max_iter to improve the fit.
#   warnings.warn(
# /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/sklearn/linear_model/_stochastic_gradient.py:713: ConvergenceWarning: Maximum number of iteration reached before convergence. Consider increasing max_iter to improve the fit.
#   warnings.warn(
# /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/sklearn/linear_model/_stochastic_gradient.py:713: ConvergenceWarning: Maximum number of iteration reached before convergence. Consider increasing max_iter to improve the fit.
#   warnings.warn(
# /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/sklearn/linear_model/_stochastic_gradient.py:713: ConvergenceWarning: Maximum number of iteration reached before convergence. Consider increasing max_iter to improve the fit.
#   warnings.warn(
# /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/sklearn/linear_model/_stochastic_gradient.py:713: ConvergenceWarning: Maximum number of iteration reached before convergence. Consider increasing max_iter to improve the fit.
#   warnings.warn(
# /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/sklearn/linear_model/_stochastic_gradient.py:713: ConvergenceWarning: Maximum number of iteration reached before convergence. Consider increasing max_iter to improve the fit.
#   warnings.warn(
# /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/sklearn/linear_model/_stochastic_gradient.py:713: ConvergenceWarning: Maximum number of iteration reached before convergence. Consider increasing max_iter to improve the fit.
#   warnings.warn(
# /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/sklearn/linear_model/_stochastic_gradient.py:713: ConvergenceWarning: Maximum number of iteration reached before convergence. Consider increasing max_iter to improve the fit.
#   warnings.warn(
# /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/sklearn/linear_model/_stochastic_gradient.py:713: ConvergenceWarning: Maximum number of iteration reached before convergence. Consider increasing max_iter to improve the fit.
#   warnings.warn(
# /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/sklearn/linear_model/_stochastic_gradient.py:713: ConvergenceWarning: Maximum number of iteration reached before convergence. Consider increasing max_iter to improve the fit.
#   warnings.warn(
# /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/sklearn/linear_model/_stochastic_gradient.py:713: ConvergenceWarning: Maximum number of iteration reached before convergence. Consider increasing max_iter to improve the fit.
#   warnings.warn(
# /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/sklearn/linear_model/_stochastic_gradient.py:713: ConvergenceWarning: Maximum number of iteration reached before convergence. Consider increasing max_iter to improve the fit.
#   warnings.warn(
# /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/sklearn/linear_model/_stochastic_gradient.py:713: ConvergenceWarning: Maximum number of iteration reached before convergence. Consider increasing max_iter to improve the fit.
#   warnings.warn(
# /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/sklearn/linear_model/_stochastic_gradient.py:713: ConvergenceWarning: Maximum number of iteration reached before convergence. Consider increasing max_iter to improve the fit.
#   warnings.warn(
# /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/sklearn/linear_model/_stochastic_gradient.py:713: ConvergenceWarning: Maximum number of iteration reached before convergence. Consider increasing max_iter to improve the fit.
#   warnings.warn(
# /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/sklearn/linear_model/_stochastic_gradient.py:713: ConvergenceWarning: Maximum number of iteration reached before convergence. Consider increasing max_iter to improve the fit.
#   warnings.warn(
# /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/sklearn/linear_model/_stochastic_gradient.py:713: ConvergenceWarning: Maximum number of iteration reached before convergence. Consider increasing max_iter to improve the fit.
#   warnings.warn(
# /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/sklearn/linear_model/_stochastic_gradient.py:713: ConvergenceWarning: Maximum number of iteration reached before convergence. Consider increasing max_iter to improve the fit.
#   warnings.warn(
# /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/sklearn/linear_model/_stochastic_gradient.py:713: ConvergenceWarning: Maximum number of iteration reached before convergence. Consider increasing max_iter to improve the fit.
#   warnings.warn(
# /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/sklearn/linear_model/_stochastic_gradient.py:713: ConvergenceWarning: Maximum number of iteration reached before convergence. Consider increasing max_iter to improve the fit.
#   warnings.warn(
# /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/sklearn/linear_model/_stochastic_gradient.py:713: ConvergenceWarning: Maximum number of iteration reached before convergence. Consider increasing max_iter to improve the fit.
#   warnings.warn(
# /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/sklearn/linear_model/_stochastic_gradient.py:713: ConvergenceWarning: Maximum number of iteration reached before convergence. Consider increasing max_iter to improve the fit.
#   warnings.warn(
# /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/sklearn/linear_model/_stochastic_gradient.py:713: ConvergenceWarning: Maximum number of iteration reached before convergence. Consider increasing max_iter to improve the fit.
#   warnings.warn(
# /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/sklearn/linear_model/_stochastic_gradient.py:713: ConvergenceWarning: Maximum number of iteration reached before convergence. Consider increasing max_iter to improve the fit.
#   warnings.warn(
# /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/sklearn/linear_model/_stochastic_gradient.py:713: ConvergenceWarning: Maximum number of iteration reached before convergence. Consider increasing max_iter to improve the fit.
#   warnings.warn(
# /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/sklearn/linear_model/_stochastic_gradient.py:713: ConvergenceWarning: Maximum number of iteration reached before convergence. Consider increasing max_iter to improve the fit.
#   warnings.warn(
# /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/sklearn/linear_model/_stochastic_gradient.py:713: ConvergenceWarning: Maximum number of iteration reached before convergence. Consider increasing max_iter to improve the fit.
#   warnings.warn(
# /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/sklearn/linear_model/_stochastic_gradient.py:713: ConvergenceWarning: Maximum number of iteration reached before convergence. Consider increasing max_iter to improve the fit.
#   warnings.warn(
# /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/sklearn/linear_model/_stochastic_gradient.py:713: ConvergenceWarning: Maximum number of iteration reached before convergence. Consider increasing max_iter to improve the fit.
#   warnings.warn(
# /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/sklearn/linear_model/_stochastic_gradient.py:713: ConvergenceWarning: Maximum number of iteration reached before convergence. Consider increasing max_iter to improve the fit.
#   warnings.warn(
# /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/sklearn/linear_model/_stochastic_gradient.py:713: ConvergenceWarning: Maximum number of iteration reached before convergence. Consider increasing max_iter to improve the fit.
#   warnings.warn(
# /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/sklearn/linear_model/_stochastic_gradient.py:713: ConvergenceWarning: Maximum number of iteration reached before convergence. Consider increasing max_iter to improve the fit.
#   warnings.warn(
# /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/sklearn/linear_model/_stochastic_gradient.py:713: ConvergenceWarning: Maximum number of iteration reached before convergence. Consider increasing max_iter to improve the fit.
#   warnings.warn(
# /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/sklearn/linear_model/_stochastic_gradient.py:713: ConvergenceWarning: Maximum number of iteration reached before convergence. Consider increasing max_iter to improve the fit.
#   warnings.warn(
# /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/sklearn/linear_model/_stochastic_gradient.py:713: ConvergenceWarning: Maximum number of iteration reached before convergence. Consider increasing max_iter to improve the fit.
#   warnings.warn(
# RandomizedSearchCV(estimator=SGDClassifier(loss='log_loss'), n_iter=50,
#                    n_jobs=-1,
#                    param_distributions={'max_iter': <scipy.stats._distn_infrastructure.rv_discrete_frozen object at 0x16fdd5a50>})

# %%
# 하이퍼파라미터 조합별 성능 시각화

# 각 하이퍼파라미터 조합별 교차 검증 스코어 가져오기
results = rs.cv_results_
mean_scores = results['mean_test_score']
params = results['params']

# 시각화를 위한 데이터 준비
max_iter_values = [params[i]['max_iter'] for i in range(len(params))]

# 가로 방향으로 막대 그래프로 교차 검증 스코어 시각화
fig, ax = plt.subplots(figsize=(8, 10))
bars = ax.barh(range(len(mean_scores)), mean_scores, tick_label=[f"{compo}" for compo in max_iter_values])
ax.set_xlabel('Mean CV Accuracy')
ax.set_title('Random Search Scores')
plt.xlim((0, 1))
plt.tight_layout()
plt.show()

# %%
# best score, best model, train score, test score

sc = rs.best_estimator_
print ("best score : ", rs.best_score_)
print ("best estimator (model) : ", sc)

sc_score = [sc.score(X_train_scaled, y_train), sc.score(X_test_scaled, y_test)]
print (f"train score, test score : {sc_score}")
# Out:
# best score :  0.6393289653876104
# best estimator (model) :  SGDClassifier(loss='log_loss', max_iter=14)
# train score, test score : [0.6375336725531278, 0.6543062200956937]

# %%
# confusion matrix 및 report
# validation dataset과 test dataset을 따로 report 및 matrix drawing

from sklearn.metrics import classification_report, confusion_matrix

y_train_pred = sc.predict(X_train_scaled)
y_test_pred = sc.predict(X_test_scaled)

cm_train = confusion_matrix(y_train, y_train_pred)
print ("- train data confusion matrix -\n")
print (cm_train)

print ('\n --------------- \n')

cm_test = confusion_matrix(y_test, y_test_pred)
print ("- test data confusion matrix -\n")
print (cm_test)

print ('\n --------------- \n')

cr_train = classification_report(y_train, y_train_pred)
print ("- train data report of classification -\n")
print (cr_train)

print ('\n --------------- \n')

cr_test = classification_report(y_test, y_test_pred)
print ("- test data report of classification -\n")
print (cr_test)

print ('\n --------------- \n')
# Out:
# - train data confusion matrix -
#
# [[869 220  37]
#  [228 598 232]
#  [131 363 663]]
#
#  ---------------
#
# - test data confusion matrix -
#
# [[224  51   6]
#  [ 64 145  56]
#  [ 33  79 178]]
#
#  ---------------
#
# - train data report of classification -
#
#               precision    recall  f1-score   support
#
#            0       0.71      0.77      0.74      1126
#            1       0.51      0.57      0.53      1058
#            2       0.71      0.57      0.63      1157
#
#     accuracy                           0.64      3341
#    macro avg       0.64      0.64      0.64      3341
# weighted avg       0.65      0.64      0.64      3341
#
#
#  ---------------
#
# - test data report of classification -
#
#               precision    recall  f1-score   support
#
#            0       0.70      0.80      0.74       281
#            1       0.53      0.55      0.54       265
#            2       0.74      0.61      0.67       290
#
#     accuracy                           0.65       836
#    macro avg       0.66      0.65      0.65       836
# weighted avg       0.66      0.65      0.65       836
#
#
#  ---------------

# %% [markdown]
# ------
#
# ### 3. ANN (fully connected)
# - hidden layer를 구성하지 않고, 입력층과 출력층만 존재하는 인공신경망을 struction할 것이다.
# - 기존 train set에서 validation set을 하나 더 구성하여 추후 evaluation에 사용할 예정이다.
# - 또한 one-hot encoding하여 target값을 encoding하고 loss function은 categorical_crossentropy를 사용한다.
#     - one-hot encoding하는 방식 중 scikit-learn 내장 메소드인 OneHotEncoder를 사용한다.

# %%
# train set에서 validation set을 하나 더 구성

X_train_scaled, X_val_scaled, y_train, y_val = train_test_split(X_train_scaled, y_train,
                                                               test_size=0.2, 
                                                               stratify=y_train)

print (X_train_scaled.shape, X_val_scaled.shape)
# Out:
# (2672, 7) (669, 7)

# %%
# one-hot encoding

y_train = y_train.values.reshape(-1, 1)
y_test = y_test.values.reshape(-1, 1)
y_val = y_val.values.reshape(-1, 1)

from sklearn.preprocessing import LabelEncoder

le = LabelEncoder()
y_train_en = le.fit_transform(y_train)
y_val_en = le.transform(y_val)
y_test_en = le.transform(y_test)
# Out:
# /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/sklearn/preprocessing/_label.py:114: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/sklearn/preprocessing/_label.py:132: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, dtype=self.classes_.dtype, warn=True)
# /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/sklearn/preprocessing/_label.py:132: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, dtype=self.classes_.dtype, warn=True)

# %%
# 이진 라벨로 구성하기 위한 categorical transition 수행

from tensorflow.keras.utils import to_categorical

y_train = to_categorical(y_train_en, num_classes=3)
y_test = to_categorical(y_test_en, num_classes=3)
y_val = to_categorical(y_val_en, num_classes=3)

# %%
# modelling (다중 분류)

print ("records shape : ", df.iloc[0].shape)

model = keras.Sequential([
    keras.layers.Flatten(input_shape=(7, )), 
    keras.layers.Dense(3, activation='softmax')
])

model.summary()
keras.utils.plot_model(model, show_shapes=True)
# Out:
# records shape :  (8,)
# Model: "sequential_2"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  flatten_2 (Flatten)         (None, 7)                 0
#
#  dense_2 (Dense)             (None, 3)                 24
#
# =================================================================
# Total params: 24 (96.00 Byte)
# Trainable params: 24 (96.00 Byte)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %%
# compile

model.compile(optimizer='adam', loss='categorical_crossentropy', metrics='accuracy')

# %%
# fit
# early stopping callback을 통하여 overfitting 방지

early_stopping_cb = keras.callbacks.EarlyStopping(patience=5, 
                                                 restore_best_weights=True)

history = model.fit(X_train_scaled, y_train, epochs=100, 
                    validation_data=(X_val_scaled, y_val),
                   callbacks=[early_stopping_cb], 
                    verbose=True)

print (history.history)
# Out:
# Epoch 1/100
# 84/84 [==============================] - 0s 2ms/step - loss: 0.7734 - accuracy: 0.6396 - val_loss: 0.7856 - val_accuracy: 0.6263
# Epoch 2/100
# 84/84 [==============================] - 0s 1ms/step - loss: 0.7730 - accuracy: 0.6381 - val_loss: 0.7856 - val_accuracy: 0.6263
# Epoch 3/100
# 84/84 [==============================] - 0s 1ms/step - loss: 0.7728 - accuracy: 0.6377 - val_loss: 0.7856 - val_accuracy: 0.6338
# Epoch 4/100
# 84/84 [==============================] - 0s 1ms/step - loss: 0.7728 - accuracy: 0.6366 - val_loss: 0.7853 - val_accuracy: 0.6308
# Epoch 5/100
# 84/84 [==============================] - 0s 1ms/step - loss: 0.7726 - accuracy: 0.6359 - val_loss: 0.7854 - val_accuracy: 0.6308
# Epoch 6/100
# 84/84 [==============================] - 0s 1ms/step - loss: 0.7727 - accuracy: 0.6366 - val_loss: 0.7855 - val_accuracy: 0.6308
# Epoch 7/100
# 84/84 [==============================] - 0s 1ms/step - loss: 0.7725 - accuracy: 0.6377 - val_loss: 0.7851 - val_accuracy: 0.6293
# Epoch 8/100
# 84/84 [==============================] - 0s 1ms/step - loss: 0.7725 - accuracy: 0.6377 - val_loss: 0.7852 - val_accuracy: 0.6263
# Epoch 9/100
# 84/84 [==============================] - 0s 1ms/step - loss: 0.7722 - accuracy: 0.6396 - val_loss: 0.7855 - val_accuracy: 0.6278
# Epoch 10/100
# 84/84 [==============================] - 0s 1ms/step - loss: 0.7720 - accuracy: 0.6377 - val_loss: 0.7853 - val_accuracy: 0.6293
# Epoch 11/100
# 84/84 [==============================] - 0s 1ms/step - loss: 0.7720 - accuracy: 0.6359 - val_loss: 0.7854 - val_accuracy: 0.6278
# Epoch 12/100
# 84/84 [==============================] - 0s 1ms/step - loss: 0.7721 - accuracy: 0.6370 - val_loss: 0.7851 - val_accuracy: 0.6308
# Epoch 13/100
# 84/84 [==============================] - 0s 1ms/step - loss: 0.7720 - accuracy: 0.6392 - val_loss: 0.7851 - val_accuracy: 0.6308
# Epoch 14/100
# 84/84 [==============================] - 0s 1ms/step - loss: 0.7717 - accuracy: 0.6385 - val_loss: 0.7852 - val_accuracy: 0.6293
# Epoch 15/100
# 84/84 [==============================] - 0s 1ms/step - loss: 0.7717 - accuracy: 0.6374 - val_loss: 0.7852 - val_accuracy: 0.6293
# Epoch 16/100
# 84/84 [==============================] - 0s 1ms/step - loss: 0.7716 - accuracy: 0.6400 - val_loss: 0.7849 - val_accuracy: 0.6293
# Epoch 17/100
# 84/84 [==============================] - 0s 1ms/step - loss: 0.7716 - accuracy: 0.6381 - val_loss: 0.7847 - val_accuracy: 0.6323
# Epoch 18/100
# 84/84 [==============================] - 0s 1ms/step - loss: 0.7714 - accuracy: 0.6381 - val_loss: 0.7849 - val_accuracy: 0.6278
# Epoch 19/100
# 84/84 [==============================] - 0s 1ms/step - loss: 0.7714 - accuracy: 0.6392 - val_loss: 0.7847 - val_accuracy: 0.6308
# Epoch 20/100
# 84/84 [==============================] - 0s 1ms/step - loss: 0.7717 - accuracy: 0.6403 - val_loss: 0.7848 - val_accuracy: 0.6293
# Epoch 21/100
# 84/84 [==============================] - 0s 1ms/step - loss: 0.7711 - accuracy: 0.6374 - val_loss: 0.7848 - val_accuracy: 0.6293
# Epoch 22/100
# 84/84 [==============================] - 0s 1ms/step - loss: 0.7713 - accuracy: 0.6377 - val_loss: 0.7846 - val_accuracy: 0.6263
# Epoch 23/100
# 84/84 [==============================] - 0s 1ms/step - loss: 0.7712 - accuracy: 0.6374 - val_loss: 0.7848 - val_accuracy: 0.6293
# Epoch 24/100
# 84/84 [==============================] - 0s 1ms/step - loss: 0.7710 - accuracy: 0.6374 - val_loss: 0.7847 - val_accuracy: 0.6263
# Epoch 25/100
# 84/84 [==============================] - 0s 1ms/step - loss: 0.7709 - accuracy: 0.6377 - val_loss: 0.7852 - val_accuracy: 0.6278
# Epoch 26/100
# 84/84 [==============================] - 0s 1ms/step - loss: 0.7709 - accuracy: 0.6388 - val_loss: 0.7848 - val_accuracy: 0.6278
# Epoch 27/100
# 84/84 [==============================] - 0s 1ms/step - loss: 0.7707 - accuracy: 0.6392 - val_loss: 0.7845 - val_accuracy: 0.6308
# Epoch 28/100
# 84/84 [==============================] - 0s 1ms/step - loss: 0.7708 - accuracy: 0.6362 - val_loss: 0.7846 - val_accuracy: 0.6278
# Epoch 29/100
# 84/84 [==============================] - 0s 1ms/step - loss: 0.7707 - accuracy: 0.6366 - val_loss: 0.7848 - val_accuracy: 0.6278
# Epoch 30/100
# 84/84 [==============================] - 0s 1ms/step - loss: 0.7705 - accuracy: 0.6415 - val_loss: 0.7847 - val_accuracy: 0.6293
# Epoch 31/100
# 84/84 [==============================] - 0s 1ms/step - loss: 0.7704 - accuracy: 0.6385 - val_loss: 0.7844 - val_accuracy: 0.6308
# Epoch 32/100
# 84/84 [==============================] - 0s 1ms/step - loss: 0.7704 - accuracy: 0.6377 - val_loss: 0.7847 - val_accuracy: 0.6323
# Epoch 33/100
# 84/84 [==============================] - 0s 1ms/step - loss: 0.7704 - accuracy: 0.6418 - val_loss: 0.7845 - val_accuracy: 0.6308
# Epoch 34/100
# 84/84 [==============================] - 0s 1ms/step - loss: 0.7704 - accuracy: 0.6388 - val_loss: 0.7846 - val_accuracy: 0.6278
# Epoch 35/100
# 84/84 [==============================] - 0s 1ms/step - loss: 0.7703 - accuracy: 0.6385 - val_loss: 0.7846 - val_accuracy: 0.6278
# Epoch 36/100
# 84/84 [==============================] - 0s 1ms/step - loss: 0.7701 - accuracy: 0.6400 - val_loss: 0.7844 - val_accuracy: 0.6293
# {'loss': [0.7734290957450867, 0.7730482816696167, 0.7727676033973694, 0.7727605104446411, 0.7726409435272217, 0.772697389125824, 0.7725463509559631, 0.7724769115447998, 0.7722241878509521, 0.7720373272895813, 0.7720048427581787, 0.7721253633499146, 0.7720224261283875, 0.7716807126998901, 0.7717415690422058, 0.7716095447540283, 0.771594762802124, 0.7713527083396912, 0.7713937163352966, 0.7717142701148987, 0.7710763812065125, 0.7712964415550232, 0.7711524367332458, 0.7709883451461792, 0.7708619832992554, 0.7708714604377747, 0.7707123756408691, 0.7708481550216675, 0.7707495093345642, 0.7705280184745789, 0.770447313785553, 0.7704272270202637, 0.770386815071106, 0.770351767539978, 0.7703008651733398, 0.7701320052146912], 'accuracy': [0.6395958065986633, 0.6380987763404846, 0.6377245783805847, 0.6366018056869507, 0.6358532905578613, 0.6366018056869507, 0.6377245783805847, 0.6377245783805847, 0.6395958065986633, 0.6377245783805847, 0.6358532905578613, 0.6369760632514954, 0.6392215490341187, 0.6384730339050293, 0.63735032081604, 0.639970064163208, 0.6380987763404846, 0.6380987763404846, 0.6392215490341187, 0.6403443217277527, 0.63735032081604, 0.6377245783805847, 0.63735032081604, 0.63735032081604, 0.6377245783805847, 0.638847291469574, 0.6392215490341187, 0.636227548122406, 0.6366018056869507, 0.6414670944213867, 0.6384730339050293, 0.6377245783805847, 0.6418412923812866, 0.638847291469574, 0.6384730339050293, 0.639970064163208], 'val_loss': [0.7856056690216064, 0.7855777740478516, 0.7856321334838867, 0.7853268384933472, 0.7853628993034363, 0.7855456471443176, 0.7851261496543884, 0.7852221131324768, 0.7855037450790405, 0.7853089570999146, 0.7853648066520691, 0.7850506901741028, 0.7850603461265564, 0.785205066204071, 0.7851974964141846, 0.7849322557449341, 0.7847240567207336, 0.7849307060241699, 0.7847498059272766, 0.7848080396652222, 0.7847691178321838, 0.7846323251724243, 0.7848472595214844, 0.7847384810447693, 0.7851710319519043, 0.7848281860351562, 0.7844538688659668, 0.7845510244369507, 0.7847694158554077, 0.7847100496292114, 0.7843595147132874, 0.7846528887748718, 0.7845270037651062, 0.7845957279205322, 0.7845630645751953, 0.7843608856201172], 'val_accuracy': [0.6263079047203064, 0.6263079047203064, 0.6337817907333374, 0.6307922005653381, 0.6307922005653381, 0.6307922005653381, 0.6292974352836609, 0.6263079047203064, 0.6278026700019836, 0.6292974352836609, 0.6278026700019836, 0.6307922005653381, 0.6307922005653381, 0.6292974352836609, 0.6292974352836609, 0.6292974352836609, 0.6322869658470154, 0.6278026700019836, 0.6307922005653381, 0.6292974352836609, 0.6292974352836609, 0.6263079047203064, 0.6292974352836609, 0.6263079047203064, 0.6278026700019836, 0.6278026700019836, 0.6307922005653381, 0.6278026700019836, 0.6278026700019836, 0.6292974352836609, 0.6307922005653381, 0.6322869658470154, 0.6307922005653381, 0.6278026700019836, 0.6278026700019836, 0.6292974352836609]}

# %%
# loss 시각화

plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.xlabel('number of epoch')
plt.ylabel('loss')
plt.legend (['train loss', 'validation loss'])
plt.show()

# %%
# evaluate

model.evaluate(X_val_scaled, y_val)
# Out:
# 21/21 [==============================] - 0s 1ms/step - loss: 0.7844 - accuracy: 0.6308
# [0.7843595147132874, 0.6307922005653381]

# %%
# confusion matrix 및 report
# validation dataset과 test dataset을 따로 report 및 matrix drawing


y_val_pred = model.predict(X_val_scaled )
y_test_pred = model.predict(X_test_scaled)

y_val_pred_classes = np.argmax(y_val_pred, axis=1)
y_test_pred_classes = np.argmax(y_test_pred, axis=1)

############

cm_val = confusion_matrix(y_val_en, y_val_pred_classes)
print ("- validation data confusion matrix -\n")
print (cm_val)

print ('\n --------------- \n')

cm_test = confusion_matrix(y_test_en, y_test_pred_classes)
print ("- test data confusion matrix -\n")
print (cm_test)

print ('\n --------------- \n')

cr_val = classification_report(y_val_en, y_val_pred_classes)
print ("- validation data report of classification -\n")
print (cr_val)

print ('\n --------------- \n')

cr_test = classification_report(y_test_en, y_test_pred_classes)
print ("- test data report of classification -\n")
print (cr_test)

print ('\n --------------- \n')
# Out:
# 21/21 [==============================] - 0s 850us/step
# 27/27 [==============================] - 0s 1ms/step
# - validation data confusion matrix -
#
# [[180  34  11]
#  [ 64  93  55]
#  [ 25  58 149]]
#
#  ---------------
#
# - test data confusion matrix -
#
# [[231  46   4]
#  [ 72 117  76]
#  [ 28  59 203]]
#
#  ---------------
#
# - validation data report of classification -
#
#               precision    recall  f1-score   support
#
#            0       0.67      0.80      0.73       225
#            1       0.50      0.44      0.47       212
#            2       0.69      0.64      0.67       232
#
#     accuracy                           0.63       669
#    macro avg       0.62      0.63      0.62       669
# weighted avg       0.62      0.63      0.62       669
#
#
#  ---------------
#
# - test data report of classification -
#
#               precision    recall  f1-score   support
#
#            0       0.70      0.82      0.75       281
#            1       0.53      0.44      0.48       265
#            2       0.72      0.70      0.71       290
#
#     accuracy                           0.66       836
#    macro avg       0.65      0.65      0.65       836
# weighted avg       0.65      0.66      0.65       836
#
#
#  ---------------

# %% [markdown]
# -------
#
# ### 3. DNN
# - hidden layer을 충분히 구성하여 신경망을 struction할 것임
#     - parameter는 최소한 15000개 이상으로 증폭, 각 node의 activation은 relu 사용
#     - epoch는 100으로 고정
# - 아래와 같이 experiment할 예정이다.
#     - optimizer는 **적응형 학습율 optimizer인 adam을 사용한다.**
#     - validation loss 감소를 위하여 **dropout 층을 추가 후, callback으로 early stopping을 도입**한다.
#         - patiences는 10로 한다.

# %%
# modelling DNN

print ("records shape : ", df.iloc[0].shape)

model = keras.Sequential([
    keras.layers.Flatten(input_shape=(7, )), 
    keras.layers.Dense(256, activation='relu'), 
    keras.layers.Dense(128, activation='relu'),
    keras.layers.Dropout(0.2),
    keras.layers.Dense(64, activation='relu'),
    keras.layers.Dense(32, activation='relu'),
    keras.layers.Dropout(0.2),
    keras.layers.Dense(16, activation='relu'),
    keras.layers.Dense(3, activation='softmax')
])

model.summary()
keras.utils.plot_model(model, show_shapes=True)
# Out:
# records shape :  (8,)
# Model: "sequential_7"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  flatten_7 (Flatten)         (None, 7)                 0
#
#  dense_27 (Dense)            (None, 256)               2048
#
#  dense_28 (Dense)            (None, 128)               32896
#
#  dropout_12 (Dropout)        (None, 128)               0
#
#  dense_29 (Dense)            (None, 64)                8256
#
#  dense_30 (Dense)            (None, 32)                2080
#
#  dropout_13 (Dropout)        (None, 32)                0
#
#  dense_31 (Dense)            (None, 16)                528
#
#  dense_32 (Dense)            (None, 3)                 51
#
# =================================================================
# Total params: 45859 (179.14 KB)
# Trainable params: 45859 (179.14 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %%
# compile

adam = keras.optimizers.Adam(learning_rate=0.001)
model.compile(optimizer=adam, loss='categorical_crossentropy', metrics='accuracy')

# %%
# callback 설정 및 fit

early_stopping_cb = keras.callbacks.EarlyStopping(patience=10, 
                                                 restore_best_weights=True)

history = model.fit(X_train_scaled, y_train, epochs=100, 
                    validation_data=(X_val_scaled, y_val), batch_size=18, 
                    callbacks=early_stopping_cb, verbose=True)
# Out:
# Epoch 1/100
# 149/149 [==============================] - 1s 3ms/step - loss: 0.8813 - accuracy: 0.5707 - val_loss: 0.8246 - val_accuracy: 0.6248
# Epoch 2/100
# 149/149 [==============================] - 0s 2ms/step - loss: 0.8045 - accuracy: 0.6183 - val_loss: 0.7926 - val_accuracy: 0.6457
# Epoch 3/100
# 149/149 [==============================] - 0s 2ms/step - loss: 0.7834 - accuracy: 0.6355 - val_loss: 0.7896 - val_accuracy: 0.6457
# Epoch 4/100
# 149/149 [==============================] - 0s 2ms/step - loss: 0.7743 - accuracy: 0.6336 - val_loss: 0.7721 - val_accuracy: 0.6442
# Epoch 5/100
# 149/149 [==============================] - 0s 2ms/step - loss: 0.7505 - accuracy: 0.6497 - val_loss: 0.7589 - val_accuracy: 0.6637
# Epoch 6/100
# 149/149 [==============================] - 0s 2ms/step - loss: 0.7426 - accuracy: 0.6546 - val_loss: 0.7664 - val_accuracy: 0.6368
# Epoch 7/100
# 149/149 [==============================] - 0s 2ms/step - loss: 0.7503 - accuracy: 0.6519 - val_loss: 0.7567 - val_accuracy: 0.6472
# Epoch 8/100
# 149/149 [==============================] - 0s 2ms/step - loss: 0.7380 - accuracy: 0.6568 - val_loss: 0.7553 - val_accuracy: 0.6532
# Epoch 9/100
# 149/149 [==============================] - 0s 2ms/step - loss: 0.7386 - accuracy: 0.6531 - val_loss: 0.7632 - val_accuracy: 0.6637
# Epoch 10/100
# 149/149 [==============================] - 0s 2ms/step - loss: 0.7428 - accuracy: 0.6542 - val_loss: 0.7662 - val_accuracy: 0.6428
# Epoch 11/100
# 149/149 [==============================] - 0s 2ms/step - loss: 0.7397 - accuracy: 0.6583 - val_loss: 0.7547 - val_accuracy: 0.6472
# Epoch 12/100
# 149/149 [==============================] - 0s 2ms/step - loss: 0.7240 - accuracy: 0.6654 - val_loss: 0.7524 - val_accuracy: 0.6562
# Epoch 13/100
# 149/149 [==============================] - 0s 2ms/step - loss: 0.7258 - accuracy: 0.6583 - val_loss: 0.7575 - val_accuracy: 0.6562
# Epoch 14/100
# 149/149 [==============================] - 0s 2ms/step - loss: 0.7266 - accuracy: 0.6598 - val_loss: 0.7511 - val_accuracy: 0.6442
# Epoch 15/100
# 149/149 [==============================] - 0s 2ms/step - loss: 0.7214 - accuracy: 0.6643 - val_loss: 0.7564 - val_accuracy: 0.6517
# Epoch 16/100
# 149/149 [==============================] - 0s 2ms/step - loss: 0.7242 - accuracy: 0.6699 - val_loss: 0.7492 - val_accuracy: 0.6577
# Epoch 17/100
# 149/149 [==============================] - 0s 2ms/step - loss: 0.7141 - accuracy: 0.6673 - val_loss: 0.7604 - val_accuracy: 0.6413
# Epoch 18/100
# 149/149 [==============================] - 0s 2ms/step - loss: 0.7218 - accuracy: 0.6621 - val_loss: 0.7618 - val_accuracy: 0.6547
# Epoch 19/100
# 149/149 [==============================] - 0s 2ms/step - loss: 0.7159 - accuracy: 0.6624 - val_loss: 0.7765 - val_accuracy: 0.6502
# Epoch 20/100
# 149/149 [==============================] - 0s 2ms/step - loss: 0.7131 - accuracy: 0.6662 - val_loss: 0.7822 - val_accuracy: 0.6472
# Epoch 21/100
# 149/149 [==============================] - 0s 2ms/step - loss: 0.7195 - accuracy: 0.6680 - val_loss: 0.7569 - val_accuracy: 0.6577
# Epoch 22/100
# 149/149 [==============================] - 0s 2ms/step - loss: 0.7084 - accuracy: 0.6710 - val_loss: 0.7551 - val_accuracy: 0.6532
# Epoch 23/100
# 149/149 [==============================] - 0s 2ms/step - loss: 0.7061 - accuracy: 0.6737 - val_loss: 0.7604 - val_accuracy: 0.6472
# Epoch 24/100
# 149/149 [==============================] - 0s 2ms/step - loss: 0.7008 - accuracy: 0.6740 - val_loss: 0.7535 - val_accuracy: 0.6442
# Epoch 25/100
# 149/149 [==============================] - 0s 2ms/step - loss: 0.7099 - accuracy: 0.6699 - val_loss: 0.7464 - val_accuracy: 0.6502
# Epoch 26/100
# 149/149 [==============================] - 0s 2ms/step - loss: 0.7033 - accuracy: 0.6722 - val_loss: 0.7684 - val_accuracy: 0.6487
# Epoch 27/100
# 149/149 [==============================] - 0s 2ms/step - loss: 0.6993 - accuracy: 0.6785 - val_loss: 0.7468 - val_accuracy: 0.6562
# Epoch 28/100
# 149/149 [==============================] - 0s 2ms/step - loss: 0.6987 - accuracy: 0.6707 - val_loss: 0.7601 - val_accuracy: 0.6562
# Epoch 29/100
# 149/149 [==============================] - 0s 2ms/step - loss: 0.6955 - accuracy: 0.6744 - val_loss: 0.7528 - val_accuracy: 0.6428
# Epoch 30/100
# 149/149 [==============================] - 0s 2ms/step - loss: 0.6924 - accuracy: 0.6793 - val_loss: 0.7704 - val_accuracy: 0.6428
# Epoch 31/100
# 149/149 [==============================] - 0s 2ms/step - loss: 0.6983 - accuracy: 0.6733 - val_loss: 0.7407 - val_accuracy: 0.6502
# Epoch 32/100
# 149/149 [==============================] - 0s 2ms/step - loss: 0.6891 - accuracy: 0.6804 - val_loss: 0.7560 - val_accuracy: 0.6428
# Epoch 33/100
# 149/149 [==============================] - 0s 2ms/step - loss: 0.6838 - accuracy: 0.6823 - val_loss: 0.7503 - val_accuracy: 0.6472
# Epoch 34/100
# 149/149 [==============================] - 0s 2ms/step - loss: 0.6811 - accuracy: 0.6808 - val_loss: 0.7880 - val_accuracy: 0.6338
# Epoch 35/100
# 149/149 [==============================] - 0s 2ms/step - loss: 0.6980 - accuracy: 0.6819 - val_loss: 0.7608 - val_accuracy: 0.6517
# Epoch 36/100
# 149/149 [==============================] - 0s 2ms/step - loss: 0.6843 - accuracy: 0.6796 - val_loss: 0.8121 - val_accuracy: 0.6442
# Epoch 37/100
# 149/149 [==============================] - 0s 2ms/step - loss: 0.6860 - accuracy: 0.6879 - val_loss: 0.7827 - val_accuracy: 0.6398
# Epoch 38/100
# 149/149 [==============================] - 0s 2ms/step - loss: 0.6713 - accuracy: 0.6864 - val_loss: 0.7622 - val_accuracy: 0.6502
# Epoch 39/100
# 149/149 [==============================] - 0s 2ms/step - loss: 0.6745 - accuracy: 0.6894 - val_loss: 0.7708 - val_accuracy: 0.6457
# Epoch 40/100
# 149/149 [==============================] - 0s 2ms/step - loss: 0.6806 - accuracy: 0.6823 - val_loss: 0.7476 - val_accuracy: 0.6457
# Epoch 41/100
# 149/149 [==============================] - 0s 2ms/step - loss: 0.6789 - accuracy: 0.6894 - val_loss: 0.7680 - val_accuracy: 0.6428

# %%
# loss 시각화

plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.xlabel('number of epoch')
plt.ylabel('loss')
plt.legend (['train loss', 'validation loss'])
plt.show()

# %%
# evaluate

model.evaluate(X_val_scaled, y_val)
# Out:
# 21/21 [==============================] - 0s 1ms/step - loss: 0.8182 - accuracy: 0.6143
# [0.8182211518287659, 0.6143497824668884]

# %%
# confusion matrix 및 report
# validation dataset과 test dataset을 따로 report 및 matrix drawing


y_val_pred = model.predict(X_val_scaled )
y_test_pred = model.predict(X_test_scaled)

y_val_pred_classes = np.argmax(y_val_pred, axis=1)
y_test_pred_classes = np.argmax(y_test_pred, axis=1)

############

cm_val = confusion_matrix(y_val_en, y_val_pred_classes)
print ("- validation data confusion matrix -\n")
print (cm_val)

print ('\n --------------- \n')

cm_test = confusion_matrix(y_test_en, y_test_pred_classes)
print ("- test data confusion matrix -\n")
print (cm_test)

print ('\n --------------- \n')

cr_val = classification_report(y_val_en, y_val_pred_classes)
print ("- validation data report of classification -\n")
print (cr_val)

print ('\n --------------- \n')

cr_test = classification_report(y_test_en, y_test_pred_classes)
print ("- test data report of classification -\n")
print (cr_test)

print ('\n --------------- \n')
# Out:
# 21/21 [==============================] - 0s 1ms/step
# 27/27 [==============================] - 0s 1ms/step
# - validation data confusion matrix -
#
# [[169  46  10]
#  [ 57 100  55]
#  [ 19  71 142]]
#
#  ---------------
#
# - test data confusion matrix -
#
# [[222  49  10]
#  [ 57 140  68]
#  [ 19  66 205]]
#
#  ---------------
#
# - validation data report of classification -
#
#               precision    recall  f1-score   support
#
#            0       0.69      0.75      0.72       225
#            1       0.46      0.47      0.47       212
#            2       0.69      0.61      0.65       232
#
#     accuracy                           0.61       669
#    macro avg       0.61      0.61      0.61       669
# weighted avg       0.62      0.61      0.61       669
#
#
#  ---------------
#
# - test data report of classification -
#
#               precision    recall  f1-score   support
#
#            0       0.74      0.79      0.77       281
#            1       0.55      0.53      0.54       265
#            2       0.72      0.71      0.72       290
#
#     accuracy                           0.68       836
#    macro avg       0.67      0.68      0.67       836
# weighted avg       0.68      0.68      0.68       836
#
#
#  ---------------
