# %% [markdown]
# # Compare the performance of the model trained on augmented data (basic) and raw data : PAMAP2
#
# 2024.10.09. ~ 2024.10.12.<br>
# Gyuyeon Lim (lky473736)
#
# <br>
#
# - **Reference**
#     - https://github.com/uchidalab/time_series_augmentation/blob/master/utils/augmentation.py
#     - https://github.com/terryum/Data-Augmentation-For-Wearable-Sensor-Data/blob/master/Example_DataAugmentation_TimeseriesData.ipynb
#
# <br>
#
# ### Abstract
#
# This study evaluates the impact of data augmentation techniques on the performance of machine learning models trained on the PAMAP2 dataset. Specifically, we compare models trained on raw data and those trained on data enhanced through basic augmentation methods such as **Jitter**, **Scaling**, **Permutation**, **Magnitude Warp**, **Time Warp**, **Random Guided Warp**, **Window Slice**, and **Window Warp**. These augmentation techniques aim to address class imbalance and enhance model robustness by generating diverse patterns from the original time-series data. The objective is to assess whether these transformations can improve model accuracy and generalization, ultimately providing insights into the efficacy of data augmentation for time-series classification tasks.
#
#
# - **Data**
#     - PAMAP2 dataset : https://archive.ics.uci.edu/dataset/231/pamap2+physical+activity+monitoring
#     - data abstract : The PAMAP2 Physical Activity Monitoring dataset contains data of 18 different physical activities (such as walking, cycling, playing soccer, etc.), performed by 9 subjects wearing 3 inertial measurement units and a heart rate monitor. The dataset can be used for activity recognition and intensity estimation, while developing and applying algorithms of data processing, segmentation, feature extraction and classification.
#
#     - window size : 100 (will use way of sliding window)
#
# - **Model**
#     - CNN-LSTM
#     - U-net
#     - transformer-encoder
#
# - **Way of Augmentation**
#     - **Jitter**: Adds noise to the input data to generate augmented data.
#     - **Scaling**: Scales the input data by a random factor to create augmented data.
#     - **Permutation**: Shuffles the input data within specific segments to generate new patterns.
#     - **Magnitude Warp**: Smoothly distorts certain points of the input data to generate augmented data.
#     - **Time Warp**: Warps the time axis to create new data.
#     - **Random Guided Warp**: Uses DTW or ShapeDTW to select a random pattern within the same class and applies warping.
#     - **Window Slice**: Randomly selects a segment of the data and reduces it.
#     - **Window Warp**: Stretches or compresses specific segments to create new patterns.
#
#
# -----
#
# ### data load, preprocessing

# %%
import pandas as pd
from sklearn.model_selection import StratifiedShuffleSplit
from scipy.stats import skew
import os
import csv
import matplotlib.pyplot as plt
import seaborn as sns
import tensorflow as tf
from tensorflow import keras
import numpy as np
import scipy
from tqdm import tqdm
# Out:
# 2024-10-12 17:08:25.882838: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.

# %%
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import layers

# cnn model vary kernel size
from numpy import mean
from numpy import std
from numpy import dstack
from pandas import read_csv
from matplotlib import pyplot
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Input
from tensorflow.keras.layers import Flatten
from tensorflow.keras.layers import Dropout
from keras.utils import to_categorical

import tensorflow.keras
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Dropout, Flatten, Reshape, LSTM, Conv1D, MaxPooling1D
from tensorflow.keras.layers import TimeDistributed, Conv1D, MaxPooling1D

# %%
# ignoring future warnings
import warnings
warnings.simplefilter('ignore')

# %% [markdown]
# ---

# %%
# column names of the data

columns = ['time_stamp', 'activity_id', 'heart_rate', 'hand_temperature', 'hand_3D_acceleration_16_x',  'hand_3D_acceleration_16_y',
         'hand_3D_acceleration_16_z', 'hand_3D_acceleration_6_x', 'hand_3D_acceleration_6_y', 'hand_3D_acceleration_6_z', 'hand_3D_gyroscope_x',
         'hand_3D_gyroscope_y',  'hand_3D_gyroscope_z', 'hand_3D_magnetometer_x', 'hand_3D_magnetometer_y', 'hand_3D_magnetometer_z',
         'hand_4D_orientation_x', 'hand_4D_orientation_y', 'hand_4D_orientation_z', 'hand_4D_orientation_w', 'chest_temperature', 'chest_3D_acceleration_16_x',
         'chest_3D_acceleration_16_y', 'chest_3D_acceleration_16_z', 'chest_3D_acceleration_6_x', 'chest_3D_acceleration_6_y',  'chest_3D_acceleration_6_z',
         'chest_3D_gyroscope_x', 'chest_3D_gyroscope_y', 'chest_3D_gyroscope_z', 'chest_3D_magnetometer_x', 'chest_3D_magnetometer_y',
         'chest_3D_magnetometer_z', 'chest_4D_orientation_x', 'chest_4D_orientation_y', 'chest_4D_orientation_z', 'chest_4D_orientation_w',
         'ankle_temperature', 'ankle_3D_acceleration_16_x', 'ankle_3D_acceleration_16_y', 'ankle_3D_acceleration_16_z', 'ankle_3D_acceleration_6_x',
         'ankle_3D_acceleration_6_y', 'ankle_3D_acceleration_6_z', 'ankle_3D_gyroscope_x', 'ankle_3D_gyroscope_y', 'ankle_3D_gyroscope_z',
         'ankle_3D_magnetometer_x', 'ankle_3D_magnetometer_y', 'ankle_3D_magnetometer_z', 'ankle_4D_orientation_x', 'ankle_4D_orientation_y',
         'ankle_4D_orientation_z', 'ankle_4D_orientation_w']

# %%
# data load

def load_data() :
    root = os.path.join('..', '..', '..', 'data', 'PAMAP', 'PAMAP')
    data_list = []  
    
    for i in range(101, 106) : # 101.dat, 102.dat, 103.dat, 104.dat, 105.dat
        '''
            there is 10 files in PAMAP
            but doing all files at this, this must has the flooded issue of memory
            so i will use only 5 files
        '''
        path = os.path.join(root, f"{i}.dat")
        df = pd.read_table(path, header=None, sep='\s+')
        
        print (f"{i}.dat is {df.shape}")
        
        df.columns = columns
        df['id'] = i
        
        print (f"{len(df['activity_id'].unique())}")
        
        data_list.append(df)  

    #  data = pd.concat(data_list, ignore_index=True)
    # data.reset_index(drop=True, inplace=True)
    
    return data_list

df_list = load_data()
# Out:
# 101.dat is (376417, 54)
# 13
# 102.dat is (447000, 54)
# 13
# 103.dat is (252833, 54)
# 9
# 104.dat is (329576, 54)
# 12
# 105.dat is (374783, 54)
# 13

# %%
# concatenation the dataframe

df = pd.concat(df_list, ignore_index=True)
df.reset_index(drop=True, inplace=True)

df
# Out:
#          time_stamp  activity_id  heart_rate  hand_temperature  \
# 0              8.38            0       104.0           30.0000
# 1              8.39            0         NaN           30.0000
# 2              8.40            0         NaN           30.0000
# 3              8.41            0         NaN           30.0000
# 4              8.42            0         NaN           30.0000
# ...             ...          ...         ...               ...
# 1780604     3753.48           24         NaN           33.8125
# 1780605     3753.49           24         NaN           33.8125
# 1780606     3753.50           24         NaN           33.8125
# 1780607     3753.51           24         NaN           33.8125
# 1780608     3753.52           24       182.0           33.8125
#
#          hand_3D_acceleration_16_x  hand_3D_acceleration_16_y  \
# 0                          2.37223                   8.600740
# 1                          2.18837                   8.565600
# 2                          2.37357                   8.601070
# 3                          2.07473                   8.528530
# 4                          2.22936                   8.831220
# ...                            ...                        ...
# 1780604                   -2.43654                  -0.655505
# 1780605                   -2.72148                  -0.270088
# 1780606                   -2.69395                   0.229159
# 1780607                   -2.62461                   0.729121
# 1780608                   -2.25617                   1.528920
#
#          hand_3D_acceleration_16_z  hand_3D_acceleration_6_x  \
# 0                          3.51048                   2.43954
# 1                          3.66179                   2.39494
# 2                          3.54898                   2.30514
# 3                          3.66021                   2.33528
# 4                          3.70000                   2.23055
# ...                            ...                       ...
# 1780604                   -4.72814                  -2.35051
# 1780605                   -4.31035                  -2.40802
# 1780606                   -3.61885                  -2.50771
# 1780607                   -2.81126                  -2.46646
# 1780608                   -2.15415                  -2.09151
#
#          hand_3D_acceleration_6_y  hand_3D_acceleration_6_z  ...  \
# 0                        8.761650                   3.35465  ...
# 1                        8.550810                   3.64207  ...
# 2                        8.536440                   3.73280  ...
# 3                        8.536220                   3.73277  ...
# 4                        8.597410                   3.76295  ...
# ...                           ...                       ...  ...
# 1780604                 -0.635334                  -4.91018  ...
# 1780605                 -0.589344                  -4.62331  ...
# 1780606                 -0.376741                  -4.14045  ...
# 1780607                  0.167377                  -3.35644  ...
# 1780608                  0.814942                  -2.42200  ...
#
#          ankle_3D_gyroscope_y  ankle_3D_gyroscope_z  ankle_3D_magnetometer_x  \
# 0                    0.009250             -0.017580                 -61.1888
# 1                   -0.004638              0.000368                 -59.8479
# 2                    0.000148              0.022495                 -60.7361
# 3                   -0.020301              0.011275                 -60.4091
# 4                   -0.014303             -0.002823                 -61.5199
# ...                       ...                   ...                      ...
# 1780604              0.242415              0.934088                 -46.2344
# 1780605              0.084749              0.792861                 -46.7418
# 1780606             -0.077675              0.563650                 -46.7372
# 1780607             -0.093296              0.363001                 -46.9957
# 1780608             -0.175977              0.161455                 -46.8587
#
#          ankle_3D_magnetometer_y  ankle_3D_magnetometer_z  \
# 0                      -38.95990                -58.14380
# 1                      -38.89190                -58.52530
# 2                      -39.41380                -58.39990
# 3                      -38.76350                -58.39560
# 4                      -39.38790                -58.26940
# ...                          ...                      ...
# 1780604                 -5.06546                 -2.71978
# 1780605                 -4.90974                 -2.15442
# 1780606                 -4.90871                 -1.72891
# 1780607                 -4.89665                 -2.01350
# 1780608                 -4.90098                 -1.16202
#
#          ankle_4D_orientation_x  ankle_4D_orientation_y  \
# 0                      1.000000                0.000000
# 1                      1.000000                0.000000
# 2                      1.000000                0.000000
# 3                      1.000000                0.000000
# 4                      1.000000                0.000000
# ...                         ...                     ...
# 1780604                0.469287                0.059003
# 1780605                0.470816                0.060165
# 1780606                0.471456                0.059840
# 1780607                0.471882                0.057498
# 1780608                0.471803                0.053696
#
#          ankle_4D_orientation_z  ankle_4D_orientation_w   id
# 0                      0.000000                0.000000  101
# 1                      0.000000                0.000000  101
# 2                      0.000000                0.000000  101
# 3                      0.000000                0.000000  101
# 4                      0.000000                0.000000  101
# ...                         ...                     ...  ...
# 1780604                0.849955                0.232087  105
# 1780605                0.850537                0.226494  105
# 1780606                0.851859                0.220192  105
# 1780607                0.853724                0.212546  105
# 1780608                0.856126                0.203881  105
#
# [1780609 rows x 55 columns]

# %%
# A function that checks the percentage of missing values,unique values,percentage of one catagory values and type against each column.

'''
    Unique_values : the component that not null
    Missing values : null
    Peercentage of Missing values : number of null / number of all samples
    Data Type : dtype of each cols
'''

def statistics(df):
    stats = []
    for col in df.columns:
        stats.append((col, df[col].nunique(), df[col].isnull().sum(), df[col].isnull().sum() * 100 / df.shape[0], df[col].dtype))

    stats_df = pd.DataFrame(stats, columns=['Feature', 'Unique_values', 'Missing values', 'Percentage of Missing Values', 'Data Type'])
    stats_df.set_index('Feature', drop=True, inplace=True)
    stats_df.drop(stats_df[stats_df['Missing values'] == 0].index, axis=0, inplace=True)
    stats_df.sort_values('Percentage of Missing Values', ascending=False, inplace=True)
    return stats_df

statistics(df).T
# Out:
# Feature                      heart_rate hand_3D_gyroscope_z hand_temperature  \
# Unique_values                       127             1338175              130
# Missing values                  1617991                8460             8460
# Percentage of Missing Values  90.867282            0.475118         0.475118
# Data Type                       float64             float64          float64
#
# Feature                      hand_4D_orientation_z hand_4D_orientation_y  \
# Unique_values                               901491                953022
# Missing values                                8460                  8460
# Percentage of Missing Values              0.475118              0.475118
# Data Type                                  float64               float64
#
# Feature                      hand_4D_orientation_x hand_3D_magnetometer_z  \
# Unique_values                               788561                 886435
# Missing values                                8460                   8460
# Percentage of Missing Values              0.475118               0.475118
# Data Type                                  float64                float64
#
# Feature                      hand_3D_magnetometer_y hand_3D_magnetometer_x  \
# Unique_values                                861768                 930699
# Missing values                                 8460                   8460
# Percentage of Missing Values               0.475118               0.475118
# Data Type                                   float64                float64
#
# Feature                      hand_4D_orientation_w  ...  \
# Unique_values                               975161  ...
# Missing values                                8460  ...
# Percentage of Missing Values              0.475118  ...
# Data Type                                  float64  ...
#
# Feature                      chest_3D_acceleration_6_y chest_3D_gyroscope_x  \
# Unique_values                                   623957              1314554
# Missing values                                    1604                 1604
# Percentage of Missing Values                  0.090082             0.090082
# Data Type                                      float64              float64
#
# Feature                      chest_4D_orientation_z chest_3D_gyroscope_z  \
# Unique_values                               1002273              1303028
# Missing values                                 1604                 1604
# Percentage of Missing Values               0.090082             0.090082
# Data Type                                   float64              float64
#
# Feature                      chest_3D_magnetometer_x chest_3D_magnetometer_y  \
# Unique_values                                1052684                  567411
# Missing values                                  1604                    1604
# Percentage of Missing Values                0.090082                0.090082
# Data Type                                    float64                 float64
#
# Feature                      chest_3D_magnetometer_z chest_4D_orientation_x  \
# Unique_values                                 971211                 690583
# Missing values                                  1604                   1604
# Percentage of Missing Values                0.090082               0.090082
# Data Type                                    float64                float64
#
# Feature                      chest_4D_orientation_y chest_3D_gyroscope_y
# Unique_values                                743287              1362079
# Missing values                                 1604                 1604
# Percentage of Missing Values               0.090082             0.090082
# Data Type                                   float64              float64
#
# [4 rows x 52 columns]

# %%
# Function that fills the null values with either the mean or median based on a normal test

def fillnull(columns, df=df):
    from scipy.stats import normaltest
    # Iterating Numerical columns
    for i in columns:
        # Finding Normality of feature
        st, p = normaltest(df[i].dropna())

        # Checking if normal or not
        if p > 0.05:
            # Filling with mean if normal
            df[i].fillna(df[i].mean(), inplace=True)
        else:
            # Filling with median if not normal
            df[i].fillna(df[i].median(), inplace=True)
            
# Taking out column names that have null values
num_cols = statistics(df).index

# Applying function
fillnull(num_cols)

# %%
# Acitvity_id = 0 is not an valid activity so it should be dropped
df.drop(df[df['activity_id']==0].index, inplace=True, axis=0)

# %%
# As it can be seen here there is no null values any longer in the dataframe.
print (df.isnull().sum())
print (~any(df.isnull()))
# Out:
# time_stamp                    0
# activity_id                   0
# heart_rate                    0
# hand_temperature              0
# hand_3D_acceleration_16_x     0
# hand_3D_acceleration_16_y     0
# hand_3D_acceleration_16_z     0
# hand_3D_acceleration_6_x      0
# hand_3D_acceleration_6_y      0
# hand_3D_acceleration_6_z      0
# hand_3D_gyroscope_x           0
# hand_3D_gyroscope_y           0
# hand_3D_gyroscope_z           0
# hand_3D_magnetometer_x        0
# hand_3D_magnetometer_y        0
# hand_3D_magnetometer_z        0
# hand_4D_orientation_x         0
# hand_4D_orientation_y         0
# hand_4D_orientation_z         0
# hand_4D_orientation_w         0
# chest_temperature             0
# chest_3D_acceleration_16_x    0
# chest_3D_acceleration_16_y    0
# chest_3D_acceleration_16_z    0
# chest_3D_acceleration_6_x     0
# chest_3D_acceleration_6_y     0
# chest_3D_acceleration_6_z     0
# chest_3D_gyroscope_x          0
# chest_3D_gyroscope_y          0
# chest_3D_gyroscope_z          0
# chest_3D_magnetometer_x       0
# chest_3D_magnetometer_y       0
# chest_3D_magnetometer_z       0
# chest_4D_orientation_x        0
# chest_4D_orientation_y        0
# chest_4D_orientation_z        0
# chest_4D_orientation_w        0
# ankle_temperature             0
# ankle_3D_acceleration_16_x    0
# ankle_3D_acceleration_16_y    0
# ankle_3D_acceleration_16_z    0
# ankle_3D_acceleration_6_x     0
# ankle_3D_acceleration_6_y     0
# ankle_3D_acceleration_6_z     0
# ankle_3D_gyroscope_x          0
# ankle_3D_gyroscope_y          0
# ankle_3D_gyroscope_z          0
# ankle_3D_magnetometer_x       0
# ankle_3D_magnetometer_y       0
# ankle_3D_magnetometer_z       0
# ankle_4D_orientation_x        0
# ankle_4D_orientation_y        0
# ankle_4D_orientation_z        0
# ankle_4D_orientation_w        0
# id                            0
# dtype: int64
# -2

# %%
# information of dataframe

df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 1191507 entries, 2928 to 1780608
# Data columns (total 55 columns):
#  #   Column                      Non-Null Count    Dtype
# ---  ------                      --------------    -----
#  0   time_stamp                  1191507 non-null  float64
#  1   activity_id                 1191507 non-null  int64
#  2   heart_rate                  1191507 non-null  float64
#  3   hand_temperature            1191507 non-null  float64
#  4   hand_3D_acceleration_16_x   1191507 non-null  float64
#  5   hand_3D_acceleration_16_y   1191507 non-null  float64
#  6   hand_3D_acceleration_16_z   1191507 non-null  float64
#  7   hand_3D_acceleration_6_x    1191507 non-null  float64
#  8   hand_3D_acceleration_6_y    1191507 non-null  float64
#  9   hand_3D_acceleration_6_z    1191507 non-null  float64
#  10  hand_3D_gyroscope_x         1191507 non-null  float64
#  11  hand_3D_gyroscope_y         1191507 non-null  float64
#  12  hand_3D_gyroscope_z         1191507 non-null  float64
#  13  hand_3D_magnetometer_x      1191507 non-null  float64
#  14  hand_3D_magnetometer_y      1191507 non-null  float64
#  15  hand_3D_magnetometer_z      1191507 non-null  float64
#  16  hand_4D_orientation_x       1191507 non-null  float64
#  17  hand_4D_orientation_y       1191507 non-null  float64
#  18  hand_4D_orientation_z       1191507 non-null  float64
#  19  hand_4D_orientation_w       1191507 non-null  float64
#  20  chest_temperature           1191507 non-null  float64
#  21  chest_3D_acceleration_16_x  1191507 non-null  float64
#  22  chest_3D_acceleration_16_y  1191507 non-null  float64
#  23  chest_3D_acceleration_16_z  1191507 non-null  float64
#  24  chest_3D_acceleration_6_x   1191507 non-null  float64
#  25  chest_3D_acceleration_6_y   1191507 non-null  float64
#  26  chest_3D_acceleration_6_z   1191507 non-null  float64
#  27  chest_3D_gyroscope_x        1191507 non-null  float64
#  28  chest_3D_gyroscope_y        1191507 non-null  float64
#  29  chest_3D_gyroscope_z        1191507 non-null  float64
#  30  chest_3D_magnetometer_x     1191507 non-null  float64
#  31  chest_3D_magnetometer_y     1191507 non-null  float64
#  32  chest_3D_magnetometer_z     1191507 non-null  float64
#  33  chest_4D_orientation_x      1191507 non-null  float64
#  34  chest_4D_orientation_y      1191507 non-null  float64
#  35  chest_4D_orientation_z      1191507 non-null  float64
#  36  chest_4D_orientation_w      1191507 non-null  float64
#  37  ankle_temperature           1191507 non-null  float64
#  38  ankle_3D_acceleration_16_x  1191507 non-null  float64
#  39  ankle_3D_acceleration_16_y  1191507 non-null  float64
#  40  ankle_3D_acceleration_16_z  1191507 non-null  float64
#  41  ankle_3D_acceleration_6_x   1191507 non-null  float64
#  42  ankle_3D_acceleration_6_y   1191507 non-null  float64
#  43  ankle_3D_acceleration_6_z   1191507 non-null  float64
#  44  ankle_3D_gyroscope_x        1191507 non-null  float64
#  45  ankle_3D_gyroscope_y        1191507 non-null  float64
#  46  ankle_3D_gyroscope_z        1191507 non-null  float64
#  47  ankle_3D_magnetometer_x     1191507 non-null  float64
#  48  ankle_3D_magnetometer_y     1191507 non-null  float64
#  49  ankle_3D_magnetometer_z     1191507 non-null  float64
#  50  ankle_4D_orientation_x      1191507 non-null  float64
#  51  ankle_4D_orientation_y      1191507 non-null  float64
#  52  ankle_4D_orientation_z      1191507 non-null  float64
#  53  ankle_4D_orientation_w      1191507 non-null  float64
#  54  id                          1191507 non-null  int64
# dtypes: float64(53), int64(2)
# memory usage: 509.1 MB

# %%
# delete cols that doesn't need

df = df.drop (['time_stamp', 'id'], axis=1)
df.columns
# Out:
# Index(['activity_id', 'heart_rate', 'hand_temperature',
#        'hand_3D_acceleration_16_x', 'hand_3D_acceleration_16_y',
#        'hand_3D_acceleration_16_z', 'hand_3D_acceleration_6_x',
#        'hand_3D_acceleration_6_y', 'hand_3D_acceleration_6_z',
#        'hand_3D_gyroscope_x', 'hand_3D_gyroscope_y', 'hand_3D_gyroscope_z',
#        'hand_3D_magnetometer_x', 'hand_3D_magnetometer_y',
#        'hand_3D_magnetometer_z', 'hand_4D_orientation_x',
#        'hand_4D_orientation_y', 'hand_4D_orientation_z',
#        'hand_4D_orientation_w', 'chest_temperature',
#        'chest_3D_acceleration_16_x', 'chest_3D_acceleration_16_y',
#        'chest_3D_acceleration_16_z', 'chest_3D_acceleration_6_x',
#        'chest_3D_acceleration_6_y', 'chest_3D_acceleration_6_z',
#        'chest_3D_gyroscope_x', 'chest_3D_gyroscope_y', 'chest_3D_gyroscope_z',
#        'chest_3D_magnetometer_x', 'chest_3D_magnetometer_y',
#        'chest_3D_magnetometer_z', 'chest_4D_orientation_x',
#        'chest_4D_orientation_y', 'chest_4D_orientation_z',
#        'chest_4D_orientation_w', 'ankle_temperature',
#        'ankle_3D_acceleration_16_x', 'ankle_3D_acceleration_16_y',
#        'ankle_3D_acceleration_16_z', 'ankle_3D_acceleration_6_x',
#        'ankle_3D_acceleration_6_y', 'ankle_3D_acceleration_6_z',
#        'ankle_3D_gyroscope_x', 'ankle_3D_gyroscope_y', 'ankle_3D_gyroscope_z',
#        'ankle_3D_magnetometer_x', 'ankle_3D_magnetometer_y',
#        'ankle_3D_magnetometer_z', 'ankle_4D_orientation_x',
#        'ankle_4D_orientation_y', 'ankle_4D_orientation_z',
#        'ankle_4D_orientation_w'],
#       dtype='object')

# %%
# see that target is 0-based

print (df['activity_id'].unique())


'''
    we need to encoding now to 0-based
    (labelencoding)
'''
# Out:
# [ 1  2  3 17 16 12 13  4  7  6  5 24]
# '\n    we need to encoding now to 0-based\n    (labelencoding)\n'

# %%
# label encoding

from sklearn.preprocessing import LabelEncoder

encoder = LabelEncoder()
df['activity_id'] = encoder.fit_transform(df['activity_id'])

print (df['activity_id'].unique())
# Out:
# [ 0  1  2 10  9  7  8  3  6  5  4 11]

# %%
# activity_id - countplot, value_count

import math

target = np.unique(df['activity_id'])

width = 1
for compo in target : 
    plt.bar(width, len(df[df['activity_id'] == compo]), 
            label=compo)
    width += 1
    
plt.xticks([], [])

plt.legend()
plt.show()

print (df['activity_id'].value_counts())

'''
    This situation solved using SMOTE and oversampling random position at records before bunches of documents.
    But this data is time-series, has depandancy of time.
    
    so i will the original augmentation that Terry Taewoong Um offered. 
    That file will be uploaded at './augmentation'
'''
# Out:
# activity_id
# 3     147787
# 10    138457
# 1     126942
# 0     119407
# 2     114664
# 9     108431
# 6     103808
# 5      95959
# 7      74596
# 8      72399
# 4      55150
# 11     33907
# Name: count, dtype: int64
# "\n    This situation solved using SMOTE and oversampling random position at records before bunches of documents.\n    But this data is time-series, has depandancy of time.\n    \n    so i will the original augmentation that Terry Taewoong Um offered. \n    That file will be uploaded at './augmentation'\n"

# %%
# Z-score normalization

from sklearn.preprocessing import StandardScaler

X = df[[feature_name for feature_name in df.columns if feature_name != 'activity_id']]
y = df['activity_id']

SS = StandardScaler()
X = SS.fit_transform(X)

df = pd.DataFrame(data=X, 
                        columns = [feature_name for feature_name in df.columns if feature_name != 'activity_id'])
df['activity_id'] = y.values

df
# Out:
#          heart_rate  hand_temperature  hand_3D_acceleration_16_x  \
# 0          0.025599         -1.335739                   1.165974
# 1          0.025599         -1.335739                   1.178712
# 2          0.025599         -1.335739                   1.178536
# 3          0.025599         -1.335739                   1.166423
# 4         -1.517477         -1.335739                   1.180224
# ...             ...               ...                        ...
# 1191502    0.025599          0.581406                   0.393008
# 1191503    0.025599          0.581406                   0.345661
# 1191504    0.025599          0.581406                   0.350236
# 1191505    0.025599          0.581406                   0.361758
# 1191506    9.026873          0.581406                   0.422979
#
#          hand_3D_acceleration_16_y  hand_3D_acceleration_16_z  \
# 0                         0.667456                   0.509138
# 1                         0.549345                   0.550260
# 2                         0.445999                   0.570868
# 3                         0.446242                   0.590725
# 4                         0.468630                   0.641306
# ...                            ...                        ...
# 1191502                  -1.073161                  -2.190360
# 1191503                  -0.998076                  -2.081029
# 1191504                  -0.900814                  -1.900071
# 1191505                  -0.803413                  -1.688733
# 1191506                  -0.647600                  -1.516775
#
#          hand_3D_acceleration_6_x  hand_3D_acceleration_6_y  \
# 0                        1.153912                  0.721969
# 1                        1.158347                  0.641905
# 2                        1.157675                  0.547066
# 3                        1.149760                  0.467124
# 4                        1.147352                  0.464194
# ...                           ...                       ...
# 1191502                  0.394122                 -1.081483
# 1191503                  0.384617                 -1.072457
# 1191504                  0.368142                 -1.030732
# 1191505                  0.374959                 -0.923945
# 1191506                  0.436925                 -0.796855
#
#          hand_3D_acceleration_6_z  hand_3D_gyroscope_x  hand_3D_gyroscope_y  \
# 0                        0.511290            -0.018115             0.005574
# 1                        0.515457            -0.142765            -0.007331
# 2                        0.515737            -0.192436            -0.022545
# 3                        0.539641            -0.158594            -0.014183
# 4                        0.559371            -0.066801            -0.054050
# ...                           ...                  ...                  ...
# 1191502                 -2.278103            -2.896949             3.339643
# 1191503                 -2.203190            -3.387448             3.497035
# 1191504                 -2.077096            -3.706136             3.655365
# 1191505                 -1.872360            -3.880426             3.755465
# 1191506                 -1.628340            -3.956077             3.724783
#
#          ...  ankle_3D_gyroscope_y  ankle_3D_gyroscope_z  \
# 0        ...              0.013685             -0.007186
# 1        ...              0.061741             -0.005011
# 2        ...             -0.027746             -0.010578
# 3        ...              0.028559              0.005694
# 4        ...             -0.021804             -0.011316
# ...      ...                   ...                   ...
# 1191502  ...              0.466650              0.469399
# 1191503  ...              0.202268              0.397208
# 1191504  ...             -0.070092              0.280041
# 1191505  ...             -0.096286              0.177475
# 1191506  ...             -0.234929              0.074450
#
#          ankle_3D_magnetometer_x  ankle_3D_magnetometer_y  \
# 0                      -1.403480                -1.652451
# 1                      -1.392634                -1.628131
# 2                      -1.365037                -1.604186
# 3                      -1.386272                -1.663147
# 4                      -1.358189                -1.664028
# ...                          ...                      ...
# 1191502                -0.658382                -0.230610
# 1191503                -0.683800                -0.223647
# 1191504                -0.683570                -0.223601
# 1191505                -0.696519                -0.223062
# 1191506                -0.689656                -0.223255
#
#          ankle_3D_magnetometer_z  ankle_4D_orientation_x  \
# 0                      -3.639552                1.658053
# 1                      -3.639358                1.658053
# 2                      -3.651275                1.658053
# 3                      -3.615859                1.658053
# 4                      -3.616092                1.658053
# ...                          ...                     ...
# 1191502                -0.947115                0.117552
# 1191503                -0.919762                0.121990
# 1191504                -0.899175                0.123848
# 1191505                -0.912944                0.125084
# 1191506                -0.871748                0.124855
#
#          ankle_4D_orientation_y  ankle_4D_orientation_z  \
# 0                      0.061127               -0.895793
# 1                      0.061127               -0.895793
# 2                      0.061127               -0.895793
# 3                      0.061127               -0.895793
# 4                      0.061127               -0.895793
# ...                         ...                     ...
# 1191502                0.169896                1.899105
# 1191503                0.172038                1.901018
# 1191504                0.171440                1.905366
# 1191505                0.167121                1.911498
# 1191506                0.160112                1.919397
#
#          ankle_4D_orientation_w  activity_id
# 0                      0.158995            0
# 1                      0.158995            0
# 2                      0.158995            0
# 3                      0.158995            0
# 4                      0.158995            0
# ...                         ...          ...
# 1191502                0.647290           11
# 1191503                0.635522           11
# 1191504                0.622263           11
# 1191505                0.606177           11
# 1191506                0.587946           11
#
# [1191507 rows x 53 columns]

# %%
# input, target split

input_PAMAP = df.drop('activity_id', axis=1)
target_PAMAP = df['activity_id']

input_PAMAP.shape, target_PAMAP.shape
# Out:
# ((1191507, 52), (1191507,))

# %% [markdown]
# ------
#
# ### sliding window : split_sequences_freq()
#
# <img src="https://velog.velcdn.com/images/wlwl99/post/e0ebddc2-e075-41e5-bec6-ac424364d1da/image.png" width=400px>
#
# The function above is designed using the **sliding window technique**, but this time the target is determined by **frequency** rather than the last value. Sliding window is a common approach used in two-pointer algorithms, where elements are selected by sliding across the dataset, as illustrated in the earlier figure.
#
# In this function, **`len(sequences)` represents the number of records (rows) in the DataFrame**. The loop iterates through each row, with `i` representing the current row index. `end_ix` is calculated by adding `n_steps` to the current row index, where `n_steps` is the size of the window. Here, the **window slides over the data, selecting a block of rows**.
#
# The loop terminates if `end_ix` exceeds the total number of rows in the DataFrame. Inside the loop, `seq_x` is the input data that selects the rows between the `i`-th and `end_ix - 1`-th row, excluding the last column (target column). `seq_y` is the corresponding target data, which includes the values in the last column for those rows.
#
# Instead of using the last target value as in the previous approach, **the most frequent target class within the window** is selected as the target. This is done using the `Counter` from the `collections` module, which finds the most common class in `seq_y`. Finally, the input data (`X`) and the most frequent class (`y`) are stored for each window.

# %%
# sliding window (judging by frequency)

from collections import Counter

def split_sequences_freq(sequences, n_steps):
    X, y = list(), list()
    
    # Check if sequences is a DataFrame, convert if necessary
    if not isinstance(sequences, pd.DataFrame):
        sequences = pd.DataFrame(sequences)

    for i in range(len(sequences)):
        end_ix = i + n_steps

        if end_ix > len(sequences):
            break

        seq_x = sequences.iloc[i:end_ix, :-1].values
        seq_y = sequences.iloc[i:end_ix, -1].values   
        
        # Find the most frequent class in seq_y
        most_frequent_class = Counter(seq_y).most_common(1)[0][0]
        
        X.append(seq_x)
        y.append(int(most_frequent_class))

    return np.array(X), np.array(y)

# %% [markdown]
# ------
#
# ### Modeling

# %%
# CNN-LSTM

def build_CNN_LSTM(input_shape, target_size):
    model = keras.Sequential()
    
    model.add(layers.Conv1D(128, kernel_size=4, padding='same', strides=1, input_shape=input_shape, activation='selu'))
    model.add(layers.MaxPooling1D(4, padding='same'))
    model.add(layers.Dropout(0.3))
    
    model.add(layers.Conv1D(64, kernel_size=3, padding='same', strides=1, activation='selu'))
    model.add(layers.MaxPooling1D(3, padding='same'))
    model.add(layers.Dropout(0.2))
    
    model.add(layers.Conv1D(32, kernel_size=2, padding='same', strides=1, activation='selu'))
    model.add(layers.MaxPooling1D(2, padding='same'))
    model.add(layers.Dropout(0.1))
    
    model.add(layers.LSTM(64, activation='tanh', return_sequences=True))
    model.add(layers.LSTM(32, activation='tanh'))
    model.add(layers.Dropout(0.1))
    
    model.add(layers.Dense(128, activation='relu'))
    model.add(layers.Dense(64, activation='relu'))
    model.add(layers.Dropout(0.1))
    
    model.add(layers.Dense(target_size, activation='softmax'))
    
    return model

# %%
from tensorflow.keras import layers, models

def build_unet_1d_custom(input_shape, num_classes):
    inputs = layers.Input(shape=input_shape)
    
    # Encoder
    c1 = layers.Conv1D(64, kernel_size=3, activation='relu', padding='same')(inputs)
    c1 = layers.Conv1D(64, kernel_size=3, activation='relu', padding='same')(c1)
    p1 = layers.Conv1D(64, kernel_size=3, strides=2, activation='relu', padding='same')(c1)  # Downsampling

    c2 = layers.Conv1D(32, kernel_size=3, activation='relu', padding='same')(p1)
    c2 = layers.Conv1D(32, kernel_size=3, activation='relu', padding='same')(c2)
    p2 = layers.Conv1D(32, kernel_size=3, strides=2, activation='relu', padding='same')(c2)  # Downsampling

    # Bottleneck
    b1 = layers.Conv1D(16, kernel_size=3, activation='relu', padding='same')(p2)
    b1 = layers.Conv1D(16, kernel_size=3, activation='relu', padding='same')(b1)

    # Decoder
    u2 = layers.Conv1DTranspose(32, kernel_size=2, strides=2, padding='same')(b1)  # Upsampling
    # Adjust shape before concatenation
    if u2.shape[1] != c2.shape[1]:
        diff = c2.shape[1] - u2.shape[1]
        if diff > 0:
            u2 = layers.ZeroPadding1D(padding=(0, diff))(u2)
        else:
            u2 = layers.Cropping1D(cropping=(-diff, 0))(u2)
    
    u2 = layers.concatenate([u2, c2], axis=-1)  # Connect to encoder
    c3 = layers.Conv1D(32, kernel_size=3, activation='relu', padding='same')(u2)
    c3 = layers.Conv1D(32, kernel_size=3, activation='relu', padding='same')(c3)

    u3 = layers.Conv1DTranspose(64, kernel_size=2, strides=2, padding='same')(c3)  # Upsampling
    # Adjust shape before concatenation
    if u3.shape[1] != c1.shape[1]:
        diff = c1.shape[1] - u3.shape[1]
        if diff > 0:
            u3 = layers.ZeroPadding1D(padding=(0, diff))(u3)
        else:
            u3 = layers.Cropping1D(cropping=(-diff, 0))(u3)
    
    u3 = layers.concatenate([u3, c1], axis=-1)  # Connect to encoder
    c4 = layers.Conv1D(64, kernel_size=3, activation='relu', padding='same')(u3)
    c4 = layers.Conv1D(64, kernel_size=3, activation='relu', padding='same')(c4)

    # Output layer
    outputs = layers.Conv1D(num_classes, kernel_size=1, activation='softmax')(c4)

    model = models.Model(inputs=[inputs], outputs=[outputs])
    
    return model

# %%
# transformer-encoder

def transformer_encoder(inputs, head_size, num_heads, ff_dim, dropout=0):
    # Attention and Normalization
    x = keras.layers.MultiHeadAttention(
        key_dim=head_size, num_heads=num_heads, dropout=dropout
    )(inputs, inputs)
    x = keras.layers.Dropout(dropout)(x)
    x = keras.layers.LayerNormalization(epsilon=1e-6)(x)
    res = x + inputs

    # Feed Forward Part
    x = keras.layers.Conv1D(filters=ff_dim, kernel_size=1, activation="relu")(res)
    x = keras.layers.Dropout(dropout)(x)
    x = keras.layers.Conv1D(filters=inputs.shape[-1], kernel_size=1)(x)
    x = keras.layers.LayerNormalization(epsilon=1e-6)(x)
    return x + res

def build_transformer(
    input_shape,
    head_size,
    num_heads,
    ff_dim,
    num_transformer_blocks,
    mlp_units,
    dropout=0,
    mlp_dropout=0,
    n_classes=0
):
    inputs = keras.Input(shape=input_shape)
    x = inputs
    for _ in range(num_transformer_blocks):
        x = transformer_encoder(x, head_size, num_heads, ff_dim, dropout)

    x = keras.layers.GlobalAveragePooling1D(data_format="channels_first")(x)
    for dim in mlp_units:
        x = keras.layers.Dense(dim, activation="relu")(x)
        x = keras.layers.Dropout(mlp_dropout)(x)
    outputs = keras.layers.Dense(n_classes, activation="softmax")(x) # label
    return keras.Model(inputs, outputs)

# %%
# build pipeline to fit

from memory_profiler import profile

@profile # to protect memory overflow
def run_all_model (X, y, models) :
    histories = {
        'CNN-LSTM' : None,
        'UNet' : None,
        'transformer_encoder' : None
    }
    
    early_stopping_cb = keras.callbacks.EarlyStopping(patience=15, restore_best_weights=True)

    for idx, model in enumerate(models) : 
        print ()    
        history = model.fit(X, y, epochs=100, 
                            validation_split=0.2,
                            batch_size=256,
                            callbacks=[early_stopping_cb], 
                            verbose=True, shuffle=True)
        
        try : 
            if idx == 0 : 
                histories['CNN-LSTM'] = history
            elif idx == 1 : 
                histories['UNet'] = history
            else : 
                histories['transformer_encoder'] = history
                
        except : 
            print ("error occured : something were wrong")
            pass
    
    return histories

def activate_all_model (X, y, input_shape, n_classes) :
    CNN_LSTM = build_CNN_LSTM(input_shape=input_shape,
                             target_size=n_classes)
    UNet = build_unet_1d_custom(input_shape=input_shape,
                               num_classes=n_classes)
    transformer_encoder = build_transformer(
                                input_shape=input_shape,
                                head_size=128,
                                num_heads=4,
                                ff_dim=4,
                                num_transformer_blocks=4,
                                mlp_units=[128],
                                mlp_dropout=0.4,
                                dropout=0.25, # fixed parameter!
                                n_classes=n_classes
                            )
    
    CNN_LSTM.compile (optimizer='adam', metrics=['accuracy'], 
                     loss='sparse_categorical_crossentropy')
    UNet.compile (optimizer='adam', metrics=['accuracy'], 
                     loss='sparse_categorical_crossentropy')
    transformer_encoder.compile (optimizer='adam', metrics=['accuracy'], 
                     loss='sparse_categorical_crossentropy')
    
    models = [CNN_LSTM, UNet, transformer_encoder]
    
    return run_all_model(X, y, models)

# %% [markdown]
# ------
#
# ### original dataframe (no augmentation)

# %%
# no augmentation. train set, test set split

from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(input_PAMAP,
                                                    target_PAMAP,
                                                    stratify=target_PAMAP,
                                                    test_size = 0.2, shuffle=True) 

# X_train, X_val, y_train, y_val = train_test_split(X_train,
#                                                     y_train,
#                                                     stratify=y_train,
#                                                     test_size = 0.2, shuffle=True) 

X_train.shape, X_test.shape
# Out:
# ((953205, 52), (238302, 52))

# %%
# no augmentation. so just use split_sequence_frequency

train_set = np.c_[X_train, y_train]
test_set = np.c_[X_test, y_test]

X_train_seq, y_train_seq = split_sequences_freq(train_set, 100) # tie 100 records
print ("train : ", X_train_seq.shape, y_train_seq.shape)

X_test_seq, y_test_seq = split_sequences_freq(test_set, 100) # tie 100 records
print ("test : ", X_test_seq.shape, y_test_seq.shape)
# Out:
# train :  (953106, 100, 52) (953106,)
# test :  (238203, 100, 52) (238203,)

# %%
# compile -> fit -> return histories

input_shape = (X_train_seq.shape[1], X_train_seq.shape[2])
n_classes = 12
histories = activate_all_model(X_train_seq, y_train_seq, input_shape, n_classes)
# Out:
# ERROR: Could not find file /var/folders/_z/gryfr07n59jgb3wrd062h1ym0000gn/T/ipykernel_4492/390686915.py
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[26], line 5
#       3 input_shape = (X_train_seq.shape[1], X_train_seq.shape[2])
#       4 n_classes = 12
# ----> 5 histories = activate_all_model(X_train_seq, y_train_seq, input_shape, n_classes)
#
# Cell In[23], line 63, in activate_all_model(X, y, input_shape, n_classes)
#      58 transformer_encoder.compile (optimizer='adam', metrics=['accuracy'],
#      59                  loss='sparse_categorical_crossentropy')
#      61 models = [CNN_LSTM, UNet, transformer_encoder]
# ---> 63 return run_all_model(X, y, models)
#
# File /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/memory_profiler.py:1188, in profile.<locals>.wrapper(*args, **kwargs)
#    1185 @wraps(wrapped=func)
#    1186 def wrapper(*args, **kwargs):
#    1187     prof = get_prof()
# -> 1188     val = prof(func)(*args, **kwargs)
#    1189     show_results_bound(prof)
#    1190     return val
#
# File /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/memory_profiler.py:761, in LineProfiler.wrap_function.<locals>.f(*args, **kwds)
#     759 def f(*args, **kwds):
#     760     with self._count_ctxmgr():
# --> 761         return func(*args, **kwds)
#
# Cell In[23], line 17, in run_all_model(X, y, models)
#      15 for idx, model in enumerate(models) :
#      16     print ()
# ---> 17     history = model.fit(X, y, epochs=100,
#      18                         validation_split=0.2,
#      19                         batch_size=256,
#      20                         callbacks=[early_stopping_cb],
#      21                         verbose=True, shuffle=True)
#      23     try :
#      24         if idx == 0 :
#
# File /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/keras/src/utils/traceback_utils.py:117, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#     115 filtered_tb = None
#     116 try:
# --> 117     return fn(*args, **kwargs)
#     118 except Exception as e:
#     119     filtered_tb = _process_traceback_frames(e.__traceback__)
#
# File /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/keras/src/backend/tensorflow/trainer.py:270, in TensorFlowTrainer.fit(self, x, y, batch_size, epochs, verbose, callbacks, validation_split, validation_data, shuffle, class_weight, sample_weight, initial_epoch, steps_per_epoch, validation_steps, validation_batch_size, validation_freq)
#     262 self._eval_epoch_iterator = None
#     263 if validation_split and validation_data is None:
#     264     # Create the validation data using the training data. Only supported
#     265     # for TF/numpy/jax arrays.
#     266     (
#     267         x,
#     268         y,
#     269         sample_weight,
# --> 270     ), validation_data = array_slicing.train_validation_split(
#     271         (x, y, sample_weight), validation_split=validation_split
#     272     )
#     274 if validation_data is not None:
#     275     (
#     276         val_x,
#     277         val_y,
#     278         val_sample_weight,
#     279     ) = data_adapter_utils.unpack_x_y_sample_weight(validation_data)
#
# File /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/keras/src/trainers/data_adapters/array_slicing.py:503, in train_validation_split(arrays, validation_split)
#     500         return t
#     501     return t[start:end]
# --> 503 sliceables = convert_to_sliceable(arrays)
#     504 train_arrays = tree.map_structure(
#     505     lambda x: _split(x, start=0, end=split_at), sliceables
#     506 )
#     507 val_arrays = tree.map_structure(
#     508     lambda x: _split(x, start=split_at, end=batch_dim), sliceables
#     509 )
#
# File /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/keras/src/trainers/data_adapters/array_slicing.py:448, in convert_to_sliceable(arrays, target_backend)
#     444         sliceable_class = NumpySliceable
#     446     return sliceable_class(x)
# --> 448 return tree.map_structure(convert_single_array, arrays)
#
# File /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/keras/src/tree/tree_api.py:148, in map_structure(func, *structures)
#     124 @keras_export("keras.tree.map_structure")
#     125 def map_structure(func, *structures):
#     126     """Maps `func` through given structures.
#     127
#     128     Examples:
#    (...)
#     146         A new structure with the same layout as the given ones.
#     147     """
# --> 148     return tree_impl.map_structure(func, *structures)
#
# File /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/keras/src/tree/optree_impl.py:79, in map_structure(func, *structures)
#      77 for other in structures[1:]:
#      78     assert_same_structure(structures[0], other, check_types=False)
# ---> 79 return optree.tree_map(
#      80     func, *structures, none_is_leaf=True, namespace="keras"
#      81 )
#
# File /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/optree/ops.py:747, in tree_map(func, tree, is_leaf, none_is_leaf, namespace, *rests)
#     745 leaves, treespec = _C.flatten(tree, is_leaf, none_is_leaf, namespace)
#     746 flat_args = [leaves] + [treespec.flatten_up_to(r) for r in rests]
# --> 747 return treespec.unflatten(map(func, *flat_args))
#
# File /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/keras/src/trainers/data_adapters/array_slicing.py:425, in convert_to_sliceable.<locals>.convert_single_array(x)
#     422         cast_dtype = backend.floatx()
#     424 if cast_dtype is not None:
# --> 425     x = sliceable_class.cast(x, cast_dtype)
#     427 # Step 3. Apply target backend specific logic and optimizations.
#     428 if target_backend is None:
#
# File /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/keras/src/trainers/data_adapters/array_slicing.py:62, in Sliceable.cast(cls, x, dtype)
#      52 @classmethod
#      53 def cast(cls, x, dtype):
#      54     """Cast a tensor to a different dtype.
#      55
#      56     Only called on a full array as provided by the user.
#    (...)
#      60     Returns: the cast tensor.
#      61     """
# ---> 62     return x.astype(dtype)
#
# KeyboardInterrupt:

# %%
# compile ->
