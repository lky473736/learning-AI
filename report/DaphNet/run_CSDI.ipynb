# %%
# !mkdir -p data/daphnet/raw

# %%
# !mkdir -p data/daphnet/processed

# %%
# !mkdir -p experiments/daphnet

# %%
# !python data/daphnet/preprocess_daphnet.py
# Out:
# Processing data/daphnet/raw/S01R01.txt...
# Before discarding 0: (151987, 9) (151987,)
# After discarding 0: (92800, 9) (92800,)
# Normal slices: 667, abnormal slices: 58
# Train slices: 508 Test slices: 217
# Final shapes:
# (65024, 9) (65024,)
# (27776, 9) (27776,)

# %%
# !cat configs/config_daphnet.json
# Out:
# {
#   "data": {
#     "root": "data/daphnet/processed",
#     "masking_ratio": 0.5,
#     "window_length": 128,
#     "overlap": true,
#     "segments": 10,
#     "batch_size": 64,
#     "features": 9
#   },
#   "training": {
#     "work_dir": "experiments/daphnet",
#     "masking_ratio": 0.7,
#     "lr": 1.0e-4,
#     "epochs": 50
#   },
#   "networks": {
#     "time_embedding": 64,
#     "feature_embedding": 8,
#     "masking_strategy": "random"
#   },
#   "diffusion": {
#     "layers": 2,
#     "channels": 32,
#     "num_heads": 4,
#     "embedding_dim": 64,
#     "beta_start": 0.0001,
#     "beta_end": 0.5,
#     "num_steps": 500,
#     "scheduler": "quad"
#   },
#   "etc": {
#     "device": "cuda:0",
#     "seed": 42
#   }
# }

# %%
# !python test.py --model experiments/daphnet/model_epoch_35.pth --config configs/config_daphnet.json --output_dir results --sample 0.3
# Out:
# Sampled 129 batches from test strategy 0 (original: 432)
# Sampled 129 batches from test strategy 1 (original: 432)
# Counting class distribution in sampled test strategy 0...
# Counting class distribution in sampled test strategy 1...
#
# ===== Sampled Class Distribution =====
# Test Strategy 0:
#   Normal (class 0): 838156
#   Abnormal (class 1): 218612
#   Total: 1056768
#   Ratio (Normal:Abnormal): 3.83:1
#
# Test Strategy 1:
#   Normal (class 0): 864408
#   Abnormal (class 1): 192360
#   Total: 1056768
#   Ratio (Normal:Abnormal): 4.49:1
# /usr/local/lib/python3.11/dist-packages/torch/nn/modules/transformer.py:382: UserWarning: enable_nested_tensor is True, but self.use_nested_tensor is False because encoder_layer.self_attn.batch_first was not True(use batch_first for better inference performance)
#   warnings.warn(
# Evaluating on test strategy 0:
# 100%|██████████████████| 129/129 [19:44<00:00,  9.18s/it, processed_batches=129]
# ...

# %%
# !python custom_test.py --model experiments/daphnet/model_epoch_35.pth --config configs/config_daphnet.json --output_dir custom_results
# Out:
# ...
#   1%|▍                                         | 9/964 [00:00<00:02, 330.13it/s]
# Finding all abnormal samples from test data...
# ...
# 100%|████████████████████████████████████████| 432/432 [00:00<00:00, 577.42it/s]
# Total abnormal batches found: 230
# Collected 9 normal batches from training data
# Collected 2 abnormal batches from test data (10% of all abnormal)
#
# ===== Custom Test Set Distribution =====
# Normal samples from train: 73728
# Abnormal samples from test: 14155
# Total samples: 87883
# Ratio (Normal:Abnormal): 5.21:1
# /usr/local/lib/python3.11/dist-packages/torch/nn/modules/transformer.py:382: UserWarning: enable_nested_tensor is True, but self.use_nested_tensor is False because encoder_layer.self_attn.batch_first was not True(use batch_first for better inference performance)
#   warnings.warn(
# Evaluating on custom test set:
# 100%|█████████████████████| 11/11 [01:41<00:00,  9.22s/it, processed_batches=11]
# ...

# %%
# !python main.py -c configs/config_daphnet.json
# Out:
# /usr/local/lib/python3.11/dist-packages/torch/nn/modules/transformer.py:382: UserWarning: enable_nested_tensor is True, but self.use_nested_tensor is False because encoder_layer.self_attn.batch_first was not True(use batch_first for better inference performance)
#   warnings.warn(
# ...
# 100%|█████████| 964/964 [01:01<00:00, 15.74it/s, avg_epoch_loss=0.0198, epoch=1]
#
# ...
#   0%|  | 0/51 [00:04<?, ?it/s, mse_total=3.07e+7, mae_total=4.62e+3, batch_no=1]
#   2%| | 1/51 [00:04<03:50,  4.61s/it, mse_total=3.07e+7, mae_total=4.62e+3, batc
#   2%| | 1/51 [00:09<03:50,  4.61s/it, mse_total=3.19e+7, mae_total=4.7e+3, batch
#   4%| | 2/51 [00:09<03:45,  4.60s/it, mse_total=3.19e+7, mae_total=4.7e+3, batch
#   4%| | 2/51 [00:13<03:45,  4.60s/it, mse_total=3.2e+7, mae_total=4.71e+3, batch
#   6%| | 3/51 [00:13<03:40,  4.60s/it, mse_total=3.2e+7, mae_total=4.71e+3, batch
#   6%| | 3/51 [00:18<03:40,  4.60s/it, mse_total=3.21e+7, mae_total=4.72e+3, batc
# ...
