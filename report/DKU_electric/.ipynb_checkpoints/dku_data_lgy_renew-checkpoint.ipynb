# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import tensorflow as tf
from tensorflow.keras import layers, models, optimizers, callbacks
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.metrics import confusion_matrix, classification_report, f1_score, precision_score, recall_score, accuracy_score
import os
import glob
import csv
# Out:
# 2025-05-22 05:32:05.989540: E external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:9261] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2025-05-22 05:32:05.989605: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:607] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2025-05-22 05:32:05.990686: E external/local_xla/xla/stream_executor/cuda/cuda_blas.cc:1515] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2025-05-22 05:32:05.996525: I tensorflow/core/platform/cpu_feature_guard.cc:182] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.

# %%
df1 = pd.read_csv("/workspace/rtu_data_full.csv")

# %%
df1.info()
df1.describe().T
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 33696013 entries, 0 to 33696012
# Data columns (total 19 columns):
#  #   Column                Dtype
# ---  ------                -----
#  0   module(equipment)     object
#  1   timestamp             int64
#  2   localtime             int64
#  3   operation             int64
#  4   voltageR              float64
#  5   voltageS              float64
#  6   voltageT              float64
#  7   voltageRS             float64
#  8   voltageST             float64
#  9   voltageTR             float64
#  10  currentR              float64
#  11  currentS              float64
#  12  currentT              float64
#  13  activePower           float64
#  14  powerFactorR          float64
#  15  powerFactorS          float64
#  16  powerFactorT          float64
#  17  reactivePowerLagging  float64
#  18  accumActiveEnergy     int64
# dtypes: float64(14), int64(4), object(1)
# memory usage: 4.8+ GB
#                            count          mean           std           min  \
# timestamp             33696013.0  1.739519e+12  3.739821e+09  1.733040e+12
# localtime             33696013.0  2.024839e+13  3.665090e+09  2.024120e+13
# operation             33696013.0  1.000000e+00  0.000000e+00  1.000000e+00
# voltageR              33696013.0  2.149938e+02  2.902114e+00  1.901000e+02
# voltageS              33696013.0  2.149947e+02  2.902552e+00  1.901400e+02
# voltageT              33696013.0  2.149943e+02  2.902357e+00  1.901800e+02
# voltageRS             33696013.0  3.723700e+02  3.573077e+00  3.308300e+02
# voltageST             33696013.0  3.723705e+02  3.572666e+00  3.299500e+02
# voltageTR             33696013.0  3.723697e+02  3.572804e+00  3.305600e+02
# currentR              33696013.0  1.749940e+01  7.217217e+00  5.000000e+00
# currentS              33696013.0  1.749925e+01  7.217180e+00  5.000000e+00
# currentT              33696013.0  1.750193e+01  7.216743e+00  5.000000e+00
# activePower           33696013.0  3.009952e+03  7.171454e+02  8.644400e+02
# powerFactorR          33696013.0  9.246882e+01  4.405299e+00  6.000000e+01
# powerFactorS          33696013.0  9.247004e+01  4.405555e+00  6.000000e+01
# powerFactorT          33696013.0  9.246884e+01  4.405619e+00  6.000000e+01
# reactivePowerLagging  33696013.0  6.019452e+02  2.290785e+02  8.944000e+01
# accumActiveEnergy     33696013.0  8.103413e+06  3.344950e+06  1.129004e+06
#
#                                25%           50%           75%           max
# timestamp             1.736280e+12  1.739520e+12  1.742756e+12  1.745996e+12
# localtime             2.025011e+13  2.025021e+13  2.025032e+13  2.025043e+13
# operation             1.000000e+00  1.000000e+00  1.000000e+00  1.000000e+00
# voltageR              2.125000e+02  2.150000e+02  2.175000e+02  2.200000e+02
# voltageS              2.125000e+02  2.150000e+02  2.175000e+02  2.200000e+02
# voltageT              2.125000e+02  2.150000e+02  2.175000e+02  2.200000e+02
# voltageRS             3.698400e+02  3.723800e+02  3.749200e+02  3.810400e+02
# voltageST             3.698400e+02  3.723800e+02  3.749100e+02  3.810400e+02
# voltageTR             3.698400e+02  3.723800e+02  3.749200e+02  3.810400e+02
# currentR              1.125000e+01  1.750000e+01  2.375000e+01  3.000000e+01
# currentS              1.125000e+01  1.750000e+01  2.375000e+01  3.000000e+01
# currentT              1.125000e+01  1.750000e+01  2.375000e+01  3.000000e+01
# activePower           2.503820e+03  3.009850e+03  3.515890e+03  5.220930e+03
# powerFactorR          8.873000e+01  9.249000e+01  9.624000e+01  1.000000e+02
# powerFactorS          8.873000e+01  9.249000e+01  9.625000e+01  1.000000e+02
# powerFactorT          8.873000e+01  9.249000e+01  9.624000e+01  1.000000e+02
# reactivePowerLagging  4.231400e+02  5.739700e+02  7.554100e+02  1.550630e+03
# accumActiveEnergy     5.393998e+06  8.103386e+06  1.081253e+07  1.543817e+07

# %%
print (df1.isnull().sum())
print (df1.shape)
print (df1.columns)
# Out:
# module(equipment)       0
# timestamp               0
# localtime               0
# operation               0
# voltageR                0
# voltageS                0
# voltageT                0
# voltageRS               0
# voltageST               0
# voltageTR               0
# currentR                0
# currentS                0
# currentT                0
# activePower             0
# powerFactorR            0
# powerFactorS            0
# powerFactorT            0
# reactivePowerLagging    0
# accumActiveEnergy       0
# dtype: int64
# (33696013, 19)
# Index(['module(equipment)', 'timestamp', 'localtime', 'operation', 'voltageR',
#        'voltageS', 'voltageT', 'voltageRS', 'voltageST', 'voltageTR',
#        'currentR', 'currentS', 'currentT', 'activePower', 'powerFactorR',
#        'powerFactorS', 'powerFactorT', 'reactivePowerLagging',
#        'accumActiveEnergy'],
#       dtype='object')

# %%
column_name = 'module(equipment)'

unique_values = df1[column_name].unique()
print(f"'{column_name}' {unique_values}")

for value in unique_values:
    count = len(df1[df1[column_name] == value])
    print(f"'{value}': {count}")
# Out:
# 'module(equipment)' ['1(PM-3)' '2(L-1전등)' '3(분쇄기(2))' '4(분쇄기(1))' '5(좌측분전반)' '11(우측분전반1)'
#  '12(4호기)' '13(3호기)' '14(2호기)' '15(예비건조기)' '16(호이스트)' '17(6호기)'
#  '18(우측분전반2)']
# '1(PM-3)': 2592001
# '2(L-1전등)': 2592001
# '3(분쇄기(2))': 2592001
# '4(분쇄기(1))': 2592001
# '5(좌측분전반)': 2592001
# '11(우측분전반1)': 2592001
# '12(4호기)': 2592001
# '13(3호기)': 2592001
# '14(2호기)': 2592001
# '15(예비건조기)': 2592001
# '16(호이스트)': 2592001
# '17(6호기)': 2592001
# '18(우측분전반2)': 2592001

# %%
df_indexed = df1.set_index(['timestamp', 'localtime', 'module(equipment)'])
df_wide = df_indexed.unstack('module(equipment)')

df_wide.columns = [f"{col[1][:col[1].index('(')]}_{col[0]}" for col in df_wide.columns]
df_wide = df_wide.reset_index()

# %%
for i in range (len(df_wide.columns)) : 
    print (df_wide.columns[i])
# Out:
# timestamp
# localtime
# 1_operation
# 11_operation
# 12_operation
# 13_operation
# 14_operation
# 15_operation
# 16_operation
# 17_operation
# 18_operation
# 2_operation
# 3_operation
# 4_operation
# 5_operation
# 1_voltageR
# 11_voltageR
# 12_voltageR
# 13_voltageR
# 14_voltageR
# 15_voltageR
# 16_voltageR
# 17_voltageR
# 18_voltageR
# 2_voltageR
# 3_voltageR
# 4_voltageR
# 5_voltageR
# 1_voltageS
# 11_voltageS
# 12_voltageS
# 13_voltageS
# 14_voltageS
# 15_voltageS
# 16_voltageS
# 17_voltageS
# 18_voltageS
# 2_voltageS
# 3_voltageS
# 4_voltageS
# 5_voltageS
# 1_voltageT
# 11_voltageT
# 12_voltageT
# 13_voltageT
# 14_voltageT
# 15_voltageT
# 16_voltageT
# 17_voltageT
# 18_voltageT
# 2_voltageT
# 3_voltageT
# 4_voltageT
# 5_voltageT
# 1_voltageRS
# 11_voltageRS
# 12_voltageRS
# 13_voltageRS
# 14_voltageRS
# 15_voltageRS
# 16_voltageRS
# 17_voltageRS
# 18_voltageRS
# 2_voltageRS
# 3_voltageRS
# 4_voltageRS
# 5_voltageRS
# 1_voltageST
# 11_voltageST
# 12_voltageST
# 13_voltageST
# 14_voltageST
# 15_voltageST
# 16_voltageST
# 17_voltageST
# 18_voltageST
# 2_voltageST
# 3_voltageST
# 4_voltageST
# 5_voltageST
# 1_voltageTR
# 11_voltageTR
# 12_voltageTR
# 13_voltageTR
# 14_voltageTR
# 15_voltageTR
# 16_voltageTR
# 17_voltageTR
# 18_voltageTR
# 2_voltageTR
# 3_voltageTR
# 4_voltageTR
# 5_voltageTR
# 1_currentR
# 11_currentR
# 12_currentR
# 13_currentR
# 14_currentR
# 15_currentR
# 16_currentR
# 17_currentR
# 18_currentR
# 2_currentR
# 3_currentR
# 4_currentR
# 5_currentR
# 1_currentS
# 11_currentS
# 12_currentS
# 13_currentS
# 14_currentS
# 15_currentS
# 16_currentS
# 17_currentS
# 18_currentS
# 2_currentS
# 3_currentS
# 4_currentS
# 5_currentS
# 1_currentT
# 11_currentT
# 12_currentT
# 13_currentT
# 14_currentT
# 15_currentT
# 16_currentT
# 17_currentT
# 18_currentT
# 2_currentT
# 3_currentT
# 4_currentT
# 5_currentT
# 1_activePower
# 11_activePower
# 12_activePower
# 13_activePower
# 14_activePower
# 15_activePower
# 16_activePower
# 17_activePower
# 18_activePower
# 2_activePower
# 3_activePower
# 4_activePower
# 5_activePower
# 1_powerFactorR
# 11_powerFactorR
# 12_powerFactorR
# 13_powerFactorR
# 14_powerFactorR
# 15_powerFactorR
# 16_powerFactorR
# 17_powerFactorR
# 18_powerFactorR
# 2_powerFactorR
# 3_powerFactorR
# 4_powerFactorR
# 5_powerFactorR
# 1_powerFactorS
# 11_powerFactorS
# 12_powerFactorS
# 13_powerFactorS
# 14_powerFactorS
# 15_powerFactorS
# 16_powerFactorS
# 17_powerFactorS
# 18_powerFactorS
# 2_powerFactorS
# 3_powerFactorS
# 4_powerFactorS
# 5_powerFactorS
# 1_powerFactorT
# 11_powerFactorT
# 12_powerFactorT
# 13_powerFactorT
# 14_powerFactorT
# 15_powerFactorT
# 16_powerFactorT
# 17_powerFactorT
# 18_powerFactorT
# 2_powerFactorT
# 3_powerFactorT
# 4_powerFactorT
# 5_powerFactorT
# 1_reactivePowerLagging
# 11_reactivePowerLagging
# 12_reactivePowerLagging
# 13_reactivePowerLagging
# 14_reactivePowerLagging
# 15_reactivePowerLagging
# 16_reactivePowerLagging
# 17_reactivePowerLagging
# 18_reactivePowerLagging
# 2_reactivePowerLagging
# 3_reactivePowerLagging
# 4_reactivePowerLagging
# 5_reactivePowerLagging
# 1_accumActiveEnergy
# 11_accumActiveEnergy
# 12_accumActiveEnergy
# 13_accumActiveEnergy
# 14_accumActiveEnergy
# 15_accumActiveEnergy
# 16_accumActiveEnergy
# 17_accumActiveEnergy
# 18_accumActiveEnergy
# 2_accumActiveEnergy
# 3_accumActiveEnergy
# 4_accumActiveEnergy
# 5_accumActiveEnergy

# %%
important_features = []
for equipment in ['1', '2', '3', '4', '5', '11', '12', '13', '14', '15', '16', '17', '18']:
    important_features.extend([
        f'{equipment}_activePower',
        f'{equipment}_accumActiveEnergy', 
        f'{equipment}_operation',
        f'{equipment}_voltageR',
        f'{equipment}_voltageS', 
        f'{equipment}_voltageT',
        f'{equipment}_currentR',
        f'{equipment}_currentS',
        f'{equipment}_currentT'
    ])

df_important = df_wide[['timestamp', 'localtime'] + important_features].copy()

# %%
df_important['total_activePower'] = sum([df_important[f'{equipment}_activePower'] for equipment in ['1', '2', '3', '4', '5', '11', '12', '13', '14', '15', '16', '17', '18']])
df_important['total_operation'] = sum([df_important[f'{equipment}_operation'] for equipment in ['1', '2', '3', '4', '5', '11', '12', '13', '14', '15', '16', '17', '18']])

# %%
df_important['datetime'] = pd.to_datetime(df_important['timestamp'], unit='ms')
df_important['hour'] = df_important['datetime'].dt.hour
df_important['day'] = df_important['datetime'].dt.day
df_important['weekday'] = df_important['datetime'].dt.weekday
df_important['is_weekend'] = (df_important['weekday'] >= 5).astype(int)

# %%
df_important = df_important.sort_values('timestamp').reset_index(drop=True)
df_important.head()
# Out:
#        timestamp       localtime  1_activePower  1_accumActiveEnergy  \
# 0  1733040000000  20241201000000        2961.61              1955004
# 1  1733040005000  20241201000005        3017.48              1955008
# 2  1733040010000  20241201000010        2408.01              1955011
# 3  1733040015000  20241201000015        3289.33              1955016
# 4  1733040020000  20241201000020        3069.31              1955020
#
#    1_operation  1_voltageR  1_voltageS  1_voltageT  1_currentR  1_currentS  \
# 0            1      214.38      214.45      219.10       15.16       15.53
# 1            1      214.05      211.74      218.68       25.70        7.07
# 2            1      215.79      214.92      211.10       13.64       14.87
# 3            1      210.39      214.92      215.57       25.76       26.35
# 4            1      216.71      216.37      215.65        8.65       29.49
#
#    ...  18_currentR  18_currentS  18_currentT  total_activePower  \
# 0  ...        18.70         9.71        25.52           35170.41
# 1  ...        11.18        29.47        13.38           40919.00
# 2  ...        23.18        26.97        24.94           40123.25
# 3  ...        28.25        19.21         6.53           40927.77
# 4  ...         9.19        19.51        16.25           38327.94
#
#    total_operation            datetime  hour  day  weekday  is_weekend
# 0               13 2024-12-01 08:00:00     8    1        6           1
# 1               13 2024-12-01 08:00:05     8    1        6           1
# 2               13 2024-12-01 08:00:10     8    1        6           1
# 3               13 2024-12-01 08:00:15     8    1        6           1
# 4               13 2024-12-01 08:00:20     8    1        6           1
#
# [5 rows x 126 columns]

# %%
print("Creating hourly aggregation...")
df_important['datetime'] = pd.to_datetime(df_important['timestamp'], unit='ms')
df_important['hour_key'] = df_important['datetime'].dt.floor('H')

# 시간별 집계
df_hourly = df_important.groupby('hour_key').agg({
    'total_activePower': 'mean',
    'total_operation': 'mean',
    'hour': 'first',
    'day': 'first', 
    'weekday': 'first',
    'is_weekend': 'first',
    **{col: 'mean' for col in important_features}
}).reset_index()

print(f"Hourly data shape: {df_hourly.shape}")
print(f"Original data shape: {df_important.shape}")
# Out:
# Creating hourly aggregation...
# /tmp/ipykernel_1584/585415138.py:3: FutureWarning: 'H' is deprecated and will be removed in a future version, please use 'h' instead.
#   df_important['hour_key'] = df_important['datetime'].dt.floor('H')
# Hourly data shape: (3600, 124)
# Original data shape: (2592001, 127)

# %%
import time
import tqdm

print("Correlation analysis starting...")
correlation_start = time.time()

target_col = 'total_activePower'

feature_cols = [col for col in df_hourly.columns if col not in ['hour_key', target_col]]
correlations = df_hourly[feature_cols + [target_col]].corr()[target_col].abs().sort_values(ascending=False)

correlation_end = time.time()
print(f"Correlation analysis completed! Time: {correlation_end - correlation_start:.2f}s")

print("Top 50 correlations with target:")
print("=" * 50)
for i, (col, corr) in enumerate(correlations.head(50).items()):
    if col != target_col:
        print(f"{i+1:2d}. {col:<35} | {corr:.4f}")
# Out:
# Correlation analysis starting...
# Correlation analysis completed! Time: 0.10s
# Top 50 correlations with target:
# ==================================================
#  2. 12_activePower                      | 0.2741
#  3. 11_activePower                      | 0.2707
#  4. 14_activePower                      | 0.2640
#  5. 5_activePower                       | 0.2610
#  6. 18_activePower                      | 0.2609
#  7. 13_activePower                      | 0.2602
#  8. 16_activePower                      | 0.2516
#  9. 4_activePower                       | 0.2435
# 10. 17_activePower                      | 0.2235
# 11. 2_activePower                       | 0.2228
# 12. 1_activePower                       | 0.2010
# 13. 3_activePower                       | 0.1947
# 14. 12_currentR                         | 0.1853
# 15. 15_activePower                      | 0.1841
# 16. 17_currentR                         | 0.1808
# 17. 4_currentR                          | 0.1770
# 18. 11_currentS                         | 0.1754
# 19. 14_currentT                         | 0.1731
# 20. 14_currentR                         | 0.1720
# 21. 11_currentR                         | 0.1695
# 22. 1_currentR                          | 0.1683
# 23. 4_currentS                          | 0.1658
# 24. 16_currentT                         | 0.1644
# 25. 12_currentS                         | 0.1641
# 26. 5_currentT                          | 0.1580
# 27. 3_currentT                          | 0.1540
# 28. 2_currentT                          | 0.1537
# 29. 5_currentR                          | 0.1535
# 30. 5_currentS                          | 0.1520
# 31. 18_currentS                         | 0.1446
# 32. 12_currentT                         | 0.1433
# 33. 1_currentT                          | 0.1421
# 34. 13_currentT                         | 0.1370
# 35. 14_currentS                         | 0.1364
# 36. 18_currentR                         | 0.1362
# 37. 15_currentS                         | 0.1359
# 38. 13_currentS                         | 0.1356
# 39. 2_currentR                          | 0.1341
# 40. 17_currentS                         | 0.1323
# 41. 15_currentR                         | 0.1321
# 42. 16_currentR                         | 0.1305
# 43. 3_currentS                          | 0.1304
# 44. 13_currentR                         | 0.1296
# 45. 15_currentT                         | 0.1284
# 46. 17_currentT                         | 0.1282
# 47. 18_currentT                         | 0.1258
# 48. 4_currentT                          | 0.1226
# 49. 11_currentT                         | 0.1203
# 50. 16_currentS                         | 0.1174

# %%
top_10_features = correlations.head(11).index.tolist()
top_10_features.remove(target_col)
top_10_features = top_10_features[:10]

print(f"Selected TOP 10 features:")
print("=" * 50)
for i, feature in enumerate(top_10_features, 1):
    corr_value = correlations[feature]
    print(f"{i:2d}. {feature:<35} | {corr_value:.4f}")
# Out:
# Selected TOP 10 features:
# ==================================================
#  1. 12_activePower                      | 0.2741
#  2. 11_activePower                      | 0.2707
#  3. 14_activePower                      | 0.2640
#  4. 5_activePower                       | 0.2610
#  5. 18_activePower                      | 0.2609
#  6. 13_activePower                      | 0.2602
#  7. 16_activePower                      | 0.2516
#  8. 4_activePower                       | 0.2435
#  9. 17_activePower                      | 0.2235
# 10. 2_activePower                       | 0.2228

# %%
selected_cols = ['hour_key'] + top_10_features + [target_col]
df_reduced = df_hourly[selected_cols].copy()

print(f"Data size reduction:")
print(f"   Original: {df_important.shape}")
print(f"   Reduced:  {df_reduced.shape}")
print(f"   Features: {len(df_important.columns)} -> {len(df_reduced.columns)}")
print(f"   Reduction: {(1 - len(df_reduced.columns)/len(df_important.columns))*100:.1f}%")
# Out:
# Data size reduction:
#    Original: (2592001, 127)
#    Reduced:  (3600, 12)
#    Features: 127 -> 12
#    Reduction: 90.6%

# %%
from tqdm import tqdm
import time
import numpy as np

def split_sequences(data, window_size, target_col, feature_cols):
   print("Creating sliding windows...")
   start_time = time.time()
   
   feature_data = data[feature_cols].values
   target_data = data[target_col].values
   
   total_samples = len(data) - window_size
   num_features = len(feature_cols)
   
   print(f"Total samples: {total_samples:,}")
   print(f"Window size: {window_size}, Features: {num_features}")
   
   X = np.zeros((total_samples, window_size, num_features))
   y = np.zeros(total_samples)
   
   for i in tqdm(range(total_samples), desc="Creating windows"):
       X[i] = feature_data[i:i+window_size]
       y[i] = target_data[i+window_size]
   
   end_time = time.time()
   print(f"Windowing completed! Time: {end_time - start_time:.2f}s")
   
   return X, y

window_size = 24
selected_feature_cols = [col for col in df_reduced.columns if col not in ['hour_key']]

X, y = split_sequences(df_reduced, window_size, target_col, selected_feature_cols)
# Out:
# Creating sliding windows...
# Total samples: 3,576
# Window size: 24, Features: 11
# Creating windows: 100%|██████████| 3576/3576 [00:00<00:00, 883791.83it/s]
# Windowing completed! Time: 0.01s

# %%
print(f"Windowing results:")
print(f"   X shape: {X.shape}")
print(f"   y shape: {y.shape}")
print(f"   Memory usage: {X.nbytes / 1024**2:.1f} MB")
# Out:
# Windowing results:
#    X shape: (3576, 24, 11)
#    y shape: (3576,)
#    Memory usage: 7.2 MB

# %%
from sklearn.preprocessing import MinMaxScaler

scaler_X = MinMaxScaler()
scaler_y = MinMaxScaler()

X_2d = X.reshape(-1, X.shape[-1])
X_scaled_2d = scaler_X.fit_transform(X_2d)
X_scaled = X_scaled_2d.reshape(X.shape)

y_scaled = scaler_y.fit_transform(y.reshape(-1, 1)).flatten()

print("Scaling completed!")
# Out:
# Scaling completed!

# %%
split_idx = int(len(X_scaled) * 0.8)

X_train, X_test = X_scaled[:split_idx], X_scaled[split_idx:]
y_train, y_test = y_scaled[:split_idx], y_scaled[split_idx:]

X_train_flat = X_train.reshape(X_train.shape[0], -1)
X_test_flat = X_test.reshape(X_test.shape[0], -1)

print(f"Split results:")
print(f"   Train: X={X_train.shape}, y={y_train.shape}")
print(f"   Test:  X={X_test.shape}, y={y_test.shape}")
print(f"   Train flat: {X_train_flat.shape}")
print(f"   Test flat: {X_test_flat.shape}")
# Out:
# Split results:
#    Train: X=(2860, 24, 11), y=(2860,)
#    Test:  X=(716, 24, 11), y=(716,)
#    Train flat: (2860, 264)
#    Test flat: (716, 264)

# %%
import xgboost as xgb
from sklearn.metrics import mean_absolute_error, mean_squared_error
import numpy as np

print("Training XGBoost with GPU...")
xgb_model = xgb.XGBRegressor(
   n_estimators=1000,
   max_depth=6,
   learning_rate=0.1,
   tree_method='gpu_hist',
   gpu_id=0,
   random_state=42,
   n_jobs=-1
)

xgb_model.fit(X_train_flat, y_train)
xgb_pred = xgb_model.predict(X_test_flat)

xgb_mae = mean_absolute_error(y_test, xgb_pred)
xgb_rmse = np.sqrt(mean_squared_error(y_test, xgb_pred))

print(f"XGBoost - MAE: {xgb_mae:.4f}, RMSE: {xgb_rmse:.4f}")
# Out:
# Training XGBoost with GPU...
# /usr/local/lib/python3.11/dist-packages/xgboost/training.py:183: UserWarning: [05:36:17] WARNING: /workspace/src/common/error_msg.cc:45: `gpu_id` is deprecated since2.0.0, use `device` instead. E.g. device=cpu/cuda/cuda:0
#   bst.update(dtrain, iteration=i, fobj=obj)
# /usr/local/lib/python3.11/dist-packages/xgboost/training.py:183: UserWarning: [05:36:17] WARNING: /workspace/src/common/error_msg.cc:27: The tree method `gpu_hist` is deprecated since 2.0.0. To use GPU training, set the `device` parameter to CUDA instead.
#
#     E.g. tree_method = "hist", device = "cuda"
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# XGBoost - MAE: 0.1240, RMSE: 0.1529
# /usr/local/lib/python3.11/dist-packages/xgboost/core.py:2676: UserWarning: [05:36:20] WARNING: /workspace/src/common/error_msg.cc:27: The tree method `gpu_hist` is deprecated since 2.0.0. To use GPU training, set the `device` parameter to CUDA instead.
#
#     E.g. tree_method = "hist", device = "cuda"
#
#   if len(data.shape) != 1 and self.num_features() != data.shape[1]:
# /usr/local/lib/python3.11/dist-packages/xgboost/core.py:729: UserWarning: [05:36:20] WARNING: /workspace/src/common/error_msg.cc:58: Falling back to prediction using DMatrix due to mismatched devices. This might lead to higher memory usage and slower performance. XGBoost is running on: cuda:0, while the input data is on: cpu.
# Potential solutions:
# - Use a data structure that matches the device ordinal in the booster.
# - Set the device for booster before call to inplace_predict.
#
# This warning will only be shown once.
#
#   return func(**kwargs)

# %%
import lightgbm as lgb


print("Training LightGBM with GPU...")
lgb_model = lgb.LGBMRegressor(
    n_estimators=1000,
    max_depth=6,
    learning_rate=0.1,
        random_state=42,
    n_jobs=-1
)

lgb_model.fit(X_train_flat, y_train)
lgb_pred = lgb_model.predict(X_test_flat)

lgb_mae = mean_absolute_error(y_test, lgb_pred)
lgb_rmse = np.sqrt(mean_squared_error(y_test, lgb_pred))

print(f"LightGBM - MAE: {lgb_mae:.4f}, RMSE: {lgb_rmse:.4f}")
# Out:
# Training LightGBM with GPU...
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.006889 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 67320
# [LightGBM] [Info] Number of data points in the train set: 2860, number of used features: 264
# [LightGBM] [Info] Start training from score 0.524479
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# LightGBM - MAE: 0.1249, RMSE: 0.1537
# /usr/local/lib/python3.11/dist-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but LGBMRegressor was fitted with feature names
#   warnings.warn(

# %%
import catboost as cb

print("Training CatBoost with GPU...")
cat_model = cb.CatBoostRegressor(
    iterations=1000,
    depth=6,
    learning_rate=0.1,
    task_type='GPU',
    random_seed=42,
    verbose=False
)

cat_model.fit(X_train_flat, y_train)
cat_pred = cat_model.predict(X_test_flat)

cat_mae = mean_absolute_error(y_test, cat_pred)
cat_rmse = np.sqrt(mean_squared_error(y_test, cat_pred))

print(f"CatBoost - MAE: {cat_mae:.4f}, RMSE: {cat_rmse:.4f}")
# Out:
# Training CatBoost with GPU...
# CatBoost - MAE: 0.1259, RMSE: 0.1558

# %%
ensemble_pred = (xgb_pred + lgb_pred + cat_pred) / 3

ensemble_mae = mean_absolute_error(y_test, ensemble_pred)
ensemble_rmse = np.sqrt(mean_squared_error(y_test, ensemble_pred))

print(f"Ensemble - MAE: {ensemble_mae:.4f}, RMSE: {ensemble_rmse:.4f}")
# Out:
# Ensemble - MAE: 0.1235, RMSE: 0.1517

# %%
import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Conv1D, GRU, Dense, Dropout

print("Training CNN-GRU with GPU...")
with tf.device('/GPU:0'):
    cnn_gru_model = Sequential([
        Conv1D(filters=64, kernel_size=3, activation='relu', input_shape=(X_train.shape[1], X_train.shape[2])),
        Conv1D(filters=32, kernel_size=3, activation='relu'),
        GRU(50, return_sequences=False),
        Dropout(0.2),
        Dense(25, activation='relu'),
        Dense(1)
    ])

cnn_gru_model.compile(optimizer='adam', loss='mse', metrics=['mae'])

history = cnn_gru_model.fit(
    X_train, y_train,
    epochs=50,
    batch_size=512,
    validation_split=0.2,
    verbose=1
)

cnn_gru_pred = cnn_gru_model.predict(X_test).flatten()

cnn_gru_mae = mean_absolute_error(y_test, cnn_gru_pred)
cnn_gru_rmse = np.sqrt(mean_squared_error(y_test, cnn_gru_pred))

print(f"CNN-GRU - MAE: {cnn_gru_mae:.4f}, RMSE: {cnn_gru_rmse:.4f}")
# Out:
# Training CNN-GRU with GPU...
# 2025-05-22 05:38:31.021393: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1929] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 46816 MB memory:  -> device: 0, name: NVIDIA RTX A6000, pci bus id: 0000:c6:00.0, compute capability: 8.6
# Epoch 1/50
# 2025-05-22 05:38:33.692962: I external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:454] Loaded cuDNN version 8907
# 2025-05-22 05:38:35.076892: I external/local_xla/xla/service/service.cc:168] XLA service 0x7faed1853220 initialized for platform CUDA (this does not guarantee that XLA will be used). Devices:
# 2025-05-22 05:38:35.076934: I external/local_xla/xla/service/service.cc:176]   StreamExecutor device (0): NVIDIA RTX A6000, Compute Capability 8.6
# 2025-05-22 05:38:35.082132: I tensorflow/compiler/mlir/tensorflow/utils/dump_mlir_util.cc:269] disabling MLIR crash reproducer, set env var `MLIR_CRASH_REPRODUCER_DIRECTORY` to enable.
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# I0000 00:00:1747892315.164586    4249 device_compiler.h:186] Compiled cluster using XLA!  This line is logged at most once for the lifetime of the process.
# 5/5 [==============================] - 5s 169ms/step - loss: 0.2404 - mae: 0.4626 - val_loss: 0.1098 - val_mae: 0.2997
# Epoch 2/50
# 5/5 [==============================] - 0s 19ms/step - loss: 0.0617 - mae: 0.2054 - val_loss: 0.0372 - val_mae: 0.1562
# Epoch 3/50
# 5/5 [==============================] - 0s 58ms/step - loss: 0.0557 - mae: 0.1922 - val_loss: 0.0328 - val_mae: 0.1447
# Epoch 4/50
# 5/5 [==============================] - 0s 14ms/step - loss: 0.0301 - mae: 0.1385 - val_loss: 0.0304 - val_mae: 0.1391
# Epoch 5/50
# 5/5 [==============================] - 0s 15ms/step - loss: 0.0338 - mae: 0.1482 - val_loss: 0.0292 - val_mae: 0.1360
# Epoch 6/50
# 5/5 [==============================] - 0s 13ms/step - loss: 0.0283 - mae: 0.1346 - val_loss: 0.0222 - val_mae: 0.1171
# Epoch 7/50
# 5/5 [==============================] - 0s 13ms/step - loss: 0.0269 - mae: 0.1314 - val_loss: 0.0230 - val_mae: 0.1196
# Epoch 8/50
# 5/5 [==============================] - 0s 13ms/step - loss: 0.0251 - mae: 0.1263 - val_loss: 0.0224 - val_mae: 0.1175
# Epoch 9/50
# 5/5 [==============================] - 0s 15ms/step - loss: 0.0244 - mae: 0.1245 - val_loss: 0.0238 - val_mae: 0.1217
# Epoch 10/50
# 5/5 [==============================] - 0s 14ms/step - loss: 0.0242 - mae: 0.1233 - val_loss: 0.0226 - val_mae: 0.1182
# Epoch 11/50
# 5/5 [==============================] - 0s 16ms/step - loss: 0.0232 - mae: 0.1205 - val_loss: 0.0220 - val_mae: 0.1165
# Epoch 12/50
# 5/5 [==============================] - 0s 58ms/step - loss: 0.0239 - mae: 0.1242 - val_loss: 0.0222 - val_mae: 0.1170
# Epoch 13/50
# 5/5 [==============================] - 0s 15ms/step - loss: 0.0234 - mae: 0.1210 - val_loss: 0.0228 - val_mae: 0.1188
# Epoch 14/50
# 5/5 [==============================] - 0s 17ms/step - loss: 0.0237 - mae: 0.1216 - val_loss: 0.0223 - val_mae: 0.1170
# Epoch 15/50
# 5/5 [==============================] - 0s 14ms/step - loss: 0.0230 - mae: 0.1205 - val_loss: 0.0221 - val_mae: 0.1166
# Epoch 16/50
# 5/5 [==============================] - 0s 16ms/step - loss: 0.0229 - mae: 0.1204 - val_loss: 0.0224 - val_mae: 0.1174
# Epoch 17/50
# 5/5 [==============================] - 0s 15ms/step - loss: 0.0222 - mae: 0.1176 - val_loss: 0.0224 - val_mae: 0.1176
# Epoch 18/50
# 5/5 [==============================] - 0s 14ms/step - loss: 0.0224 - mae: 0.1194 - val_loss: 0.0224 - val_mae: 0.1176
# Epoch 19/50
# 5/5 [==============================] - 0s 15ms/step - loss: 0.0225 - mae: 0.1197 - val_loss: 0.0228 - val_mae: 0.1187
# Epoch 20/50
# 5/5 [==============================] - 0s 15ms/step - loss: 0.0226 - mae: 0.1191 - val_loss: 0.0229 - val_mae: 0.1189
# Epoch 21/50
# 5/5 [==============================] - 0s 58ms/step - loss: 0.0226 - mae: 0.1191 - val_loss: 0.0230 - val_mae: 0.1194
# Epoch 22/50
# 5/5 [==============================] - 0s 15ms/step - loss: 0.0225 - mae: 0.1196 - val_loss: 0.0229 - val_mae: 0.1189
# Epoch 23/50
# 5/5 [==============================] - 0s 17ms/step - loss: 0.0219 - mae: 0.1172 - val_loss: 0.0229 - val_mae: 0.1191
# Epoch 24/50
# 5/5 [==============================] - 0s 14ms/step - loss: 0.0224 - mae: 0.1191 - val_loss: 0.0226 - val_mae: 0.1182
# Epoch 25/50
# 5/5 [==============================] - 0s 16ms/step - loss: 0.0224 - mae: 0.1187 - val_loss: 0.0229 - val_mae: 0.1191
# Epoch 26/50
# 5/5 [==============================] - 0s 17ms/step - loss: 0.0218 - mae: 0.1169 - val_loss: 0.0227 - val_mae: 0.1185
# Epoch 27/50
# 5/5 [==============================] - 0s 14ms/step - loss: 0.0224 - mae: 0.1186 - val_loss: 0.0228 - val_mae: 0.1187
# Epoch 28/50
# 5/5 [==============================] - 0s 17ms/step - loss: 0.0219 - mae: 0.1173 - val_loss: 0.0230 - val_mae: 0.1194
# Epoch 29/50
# 5/5 [==============================] - 0s 72ms/step - loss: 0.0220 - mae: 0.1171 - val_loss: 0.0227 - val_mae: 0.1186
# Epoch 30/50
# 5/5 [==============================] - 0s 17ms/step - loss: 0.0221 - mae: 0.1181 - val_loss: 0.0228 - val_mae: 0.1187
# Epoch 31/50
# 5/5 [==============================] - 0s 17ms/step - loss: 0.0220 - mae: 0.1175 - val_loss: 0.0228 - val_mae: 0.1188
# Epoch 32/50
# 5/5 [==============================] - 0s 18ms/step - loss: 0.0218 - mae: 0.1174 - val_loss: 0.0226 - val_mae: 0.1183
# Epoch 33/50
# 5/5 [==============================] - 0s 14ms/step - loss: 0.0217 - mae: 0.1172 - val_loss: 0.0227 - val_mae: 0.1184
# Epoch 34/50
# 5/5 [==============================] - 0s 16ms/step - loss: 0.0219 - mae: 0.1176 - val_loss: 0.0224 - val_mae: 0.1177
# Epoch 35/50
# 5/5 [==============================] - 0s 16ms/step - loss: 0.0221 - mae: 0.1178 - val_loss: 0.0227 - val_mae: 0.1184
# Epoch 36/50
# 5/5 [==============================] - 0s 17ms/step - loss: 0.0216 - mae: 0.1158 - val_loss: 0.0227 - val_mae: 0.1184
# Epoch 37/50
# 5/5 [==============================] - 0s 62ms/step - loss: 0.0217 - mae: 0.1170 - val_loss: 0.0229 - val_mae: 0.1191
# Epoch 38/50
# 5/5 [==============================] - 0s 16ms/step - loss: 0.0222 - mae: 0.1181 - val_loss: 0.0226 - val_mae: 0.1183
# Epoch 39/50
# 5/5 [==============================] - 0s 14ms/step - loss: 0.0216 - mae: 0.1165 - val_loss: 0.0227 - val_mae: 0.1183
# Epoch 40/50
# 5/5 [==============================] - 0s 16ms/step - loss: 0.0217 - mae: 0.1172 - val_loss: 0.0228 - val_mae: 0.1188
# Epoch 41/50
# 5/5 [==============================] - 0s 18ms/step - loss: 0.0221 - mae: 0.1184 - val_loss: 0.0228 - val_mae: 0.1187
# Epoch 42/50
# 5/5 [==============================] - 0s 17ms/step - loss: 0.0217 - mae: 0.1165 - val_loss: 0.0226 - val_mae: 0.1183
# Epoch 43/50
# 5/5 [==============================] - 0s 13ms/step - loss: 0.0217 - mae: 0.1170 - val_loss: 0.0228 - val_mae: 0.1187
# Epoch 44/50
# 5/5 [==============================] - 0s 17ms/step - loss: 0.0211 - mae: 0.1155 - val_loss: 0.0226 - val_mae: 0.1181
# Epoch 45/50
# 5/5 [==============================] - 0s 69ms/step - loss: 0.0216 - mae: 0.1167 - val_loss: 0.0227 - val_mae: 0.1186
# Epoch 46/50
# 5/5 [==============================] - 0s 19ms/step - loss: 0.0218 - mae: 0.1172 - val_loss: 0.0229 - val_mae: 0.1190
# Epoch 47/50
# 5/5 [==============================] - 0s 19ms/step - loss: 0.0215 - mae: 0.1162 - val_loss: 0.0224 - val_mae: 0.1176
# Epoch 48/50
# 5/5 [==============================] - 0s 14ms/step - loss: 0.0218 - mae: 0.1170 - val_loss: 0.0230 - val_mae: 0.1193
# Epoch 49/50
# 5/5 [==============================] - 0s 15ms/step - loss: 0.0218 - mae: 0.1178 - val_loss: 0.0224 - val_mae: 0.1178
# Epoch 50/50
# 5/5 [==============================] - 0s 18ms/step - loss: 0.0217 - mae: 0.1170 - val_loss: 0.0231 - val_mae: 0.1195
# 23/23 [==============================] - 1s 4ms/step
# CNN-GRU - MAE: 0.1243, RMSE: 0.1535

# %%
from tensorflow.keras.layers import Add, BatchNormalization
from tensorflow.keras.models import Model
from tensorflow.keras.layers import Input

def residual_block(x, filters, kernel_size=3):
    shortcut = x
    
    x = Conv1D(filters=filters, kernel_size=kernel_size, activation='relu', padding='same')(x)
    x = BatchNormalization()(x)
    x = Conv1D(filters=filters, kernel_size=kernel_size, activation='relu', padding='same')(x)
    x = BatchNormalization()(x)
    
    if shortcut.shape[-1] != filters:
        shortcut = Conv1D(filters=filters, kernel_size=1, padding='same')(shortcut)
    
    x = Add()([x, shortcut])
    x = tf.keras.activations.relu(x)
    
    return x

print("Training Residual CNN-GRU with GPU...")
with tf.device('/GPU:0'):
    input_layer = Input(shape=(X_train.shape[1], X_train.shape[2]))

    x = Conv1D(filters=64, kernel_size=3, activation='relu', padding='same')(input_layer)
    x = BatchNormalization()(x)

    x = residual_block(x, 64)
    x = residual_block(x, 64)
    x = residual_block(x, 32)

    x = GRU(50, return_sequences=False)(x)
    x = Dropout(0.3)(x)
    x = Dense(25, activation='relu')(x)
    output = Dense(1)(x)

    residual_model = Model(inputs=input_layer, outputs=output)
    residual_model.compile(optimizer='adam', loss='mse', metrics=['mae'])

history_residual = residual_model.fit(
    X_train, y_train,
    epochs=50,
    batch_size=512,
    validation_split=0.2,
    verbose=1
)

residual_pred = residual_model.predict(X_test).flatten()

residual_mae = mean_absolute_error(y_test, residual_pred)
residual_rmse = np.sqrt(mean_squared_error(y_test, residual_pred))

print(f"Residual CNN-GRU - MAE: {residual_mae:.4f}, RMSE: {residual_rmse:.4f}")
# Out:
# Training Residual CNN-GRU with GPU...
# Epoch 1/50
# 5/5 [==============================] - 7s 360ms/step - loss: 0.1896 - mae: 0.3479 - val_loss: 0.2195 - val_mae: 0.4447
# Epoch 2/50
# 5/5 [==============================] - 0s 22ms/step - loss: 0.0962 - mae: 0.2502 - val_loss: 0.1892 - val_mae: 0.4093
# Epoch 3/50
# 5/5 [==============================] - 0s 28ms/step - loss: 0.0694 - mae: 0.2084 - val_loss: 0.2147 - val_mae: 0.4394
# Epoch 4/50
# 5/5 [==============================] - 0s 22ms/step - loss: 0.0482 - mae: 0.1761 - val_loss: 0.2168 - val_mae: 0.4417
# Epoch 5/50
# 5/5 [==============================] - 0s 73ms/step - loss: 0.0412 - mae: 0.1625 - val_loss: 0.2043 - val_mae: 0.4273
# Epoch 6/50
# 5/5 [==============================] - 0s 21ms/step - loss: 0.0359 - mae: 0.1498 - val_loss: 0.2050 - val_mae: 0.4281
# Epoch 7/50
# 5/5 [==============================] - 0s 22ms/step - loss: 0.0323 - mae: 0.1420 - val_loss: 0.1953 - val_mae: 0.4166
# Epoch 8/50
# 5/5 [==============================] - 0s 22ms/step - loss: 0.0284 - mae: 0.1326 - val_loss: 0.1855 - val_mae: 0.4048
# Epoch 9/50
# 5/5 [==============================] - 0s 21ms/step - loss: 0.0264 - mae: 0.1294 - val_loss: 0.1782 - val_mae: 0.3958
# Epoch 10/50
# 5/5 [==============================] - 0s 24ms/step - loss: 0.0233 - mae: 0.1219 - val_loss: 0.1718 - val_mae: 0.3878
# Epoch 11/50
# 5/5 [==============================] - 0s 65ms/step - loss: 0.0227 - mae: 0.1189 - val_loss: 0.1653 - val_mae: 0.3795
# Epoch 12/50
# 5/5 [==============================] - 0s 24ms/step - loss: 0.0210 - mae: 0.1141 - val_loss: 0.1617 - val_mae: 0.3749
# Epoch 13/50
# 5/5 [==============================] - 0s 22ms/step - loss: 0.0203 - mae: 0.1119 - val_loss: 0.1566 - val_mae: 0.3680
# Epoch 14/50
# 5/5 [==============================] - 0s 23ms/step - loss: 0.0178 - mae: 0.1056 - val_loss: 0.1557 - val_mae: 0.3668
# Epoch 15/50
# 5/5 [==============================] - 0s 22ms/step - loss: 0.0175 - mae: 0.1037 - val_loss: 0.1500 - val_mae: 0.3591
# Epoch 16/50
# 5/5 [==============================] - 0s 23ms/step - loss: 0.0160 - mae: 0.1001 - val_loss: 0.1515 - val_mae: 0.3611
# Epoch 17/50
# 5/5 [==============================] - 0s 56ms/step - loss: 0.0149 - mae: 0.0963 - val_loss: 0.1417 - val_mae: 0.3476
# Epoch 18/50
# 5/5 [==============================] - 0s 26ms/step - loss: 0.0145 - mae: 0.0942 - val_loss: 0.1384 - val_mae: 0.3429
# Epoch 19/50
# 5/5 [==============================] - 0s 24ms/step - loss: 0.0136 - mae: 0.0913 - val_loss: 0.1291 - val_mae: 0.3294
# Epoch 20/50
# 5/5 [==============================] - 0s 24ms/step - loss: 0.0127 - mae: 0.0890 - val_loss: 0.1300 - val_mae: 0.3307
# Epoch 21/50
# 5/5 [==============================] - 0s 38ms/step - loss: 0.0122 - mae: 0.0860 - val_loss: 0.1264 - val_mae: 0.3253
# Epoch 22/50
# 5/5 [==============================] - 0s 62ms/step - loss: 0.0118 - mae: 0.0863 - val_loss: 0.1261 - val_mae: 0.3248
# Epoch 23/50
# 5/5 [==============================] - 0s 26ms/step - loss: 0.0103 - mae: 0.0795 - val_loss: 0.1212 - val_mae: 0.3174
# Epoch 24/50
# 5/5 [==============================] - 0s 32ms/step - loss: 0.0107 - mae: 0.0814 - val_loss: 0.1200 - val_mae: 0.3155
# Epoch 25/50
# 5/5 [==============================] - 0s 26ms/step - loss: 0.0101 - mae: 0.0795 - val_loss: 0.1200 - val_mae: 0.3154
# Epoch 26/50
# 5/5 [==============================] - 0s 27ms/step - loss: 0.0098 - mae: 0.0783 - val_loss: 0.1211 - val_mae: 0.3171
# Epoch 27/50
# 5/5 [==============================] - 0s 61ms/step - loss: 0.0097 - mae: 0.0768 - val_loss: 0.1210 - val_mae: 0.3169
# Epoch 28/50
# 5/5 [==============================] - 0s 28ms/step - loss: 0.0091 - mae: 0.0740 - val_loss: 0.1127 - val_mae: 0.3038
# Epoch 29/50
# 5/5 [==============================] - 0s 18ms/step - loss: 0.0085 - mae: 0.0729 - val_loss: 0.1153 - val_mae: 0.3079
# Epoch 30/50
# 5/5 [==============================] - 0s 26ms/step - loss: 0.0084 - mae: 0.0722 - val_loss: 0.1087 - val_mae: 0.2974
# Epoch 31/50
# 5/5 [==============================] - 0s 26ms/step - loss: 0.0080 - mae: 0.0703 - val_loss: 0.1074 - val_mae: 0.2953
# Epoch 32/50
# 5/5 [==============================] - 0s 78ms/step - loss: 0.0075 - mae: 0.0671 - val_loss: 0.1033 - val_mae: 0.2884
# Epoch 33/50
# 5/5 [==============================] - 0s 23ms/step - loss: 0.0074 - mae: 0.0672 - val_loss: 0.1028 - val_mae: 0.2876
# Epoch 34/50
# 5/5 [==============================] - 0s 29ms/step - loss: 0.0069 - mae: 0.0651 - val_loss: 0.1018 - val_mae: 0.2858
# Epoch 35/50
# 5/5 [==============================] - 0s 22ms/step - loss: 0.0074 - mae: 0.0668 - val_loss: 0.0972 - val_mae: 0.2779
# Epoch 36/50
# 5/5 [==============================] - 0s 22ms/step - loss: 0.0066 - mae: 0.0636 - val_loss: 0.1017 - val_mae: 0.2855
# Epoch 37/50
# 5/5 [==============================] - 0s 24ms/step - loss: 0.0064 - mae: 0.0628 - val_loss: 0.0997 - val_mae: 0.2820
# Epoch 38/50
# 5/5 [==============================] - 0s 57ms/step - loss: 0.0063 - mae: 0.0627 - val_loss: 0.0957 - val_mae: 0.2750
# Epoch 39/50
# 5/5 [==============================] - 0s 25ms/step - loss: 0.0062 - mae: 0.0625 - val_loss: 0.0896 - val_mae: 0.2640
# Epoch 40/50
# 5/5 [==============================] - 0s 26ms/step - loss: 0.0064 - mae: 0.0625 - val_loss: 0.0858 - val_mae: 0.2571
# Epoch 41/50
# 5/5 [==============================] - 0s 27ms/step - loss: 0.0059 - mae: 0.0603 - val_loss: 0.0846 - val_mae: 0.2547
# Epoch 42/50
# 5/5 [==============================] - 0s 22ms/step - loss: 0.0060 - mae: 0.0606 - val_loss: 0.0850 - val_mae: 0.2554
# Epoch 43/50
# 5/5 [==============================] - 0s 74ms/step - loss: 0.0054 - mae: 0.0582 - val_loss: 0.0893 - val_mae: 0.2629
# Epoch 44/50
# 5/5 [==============================] - 0s 23ms/step - loss: 0.0054 - mae: 0.0577 - val_loss: 0.0881 - val_mae: 0.2608
# Epoch 45/50
# 5/5 [==============================] - 0s 23ms/step - loss: 0.0056 - mae: 0.0591 - val_loss: 0.0869 - val_mae: 0.2584
# Epoch 46/50
# 5/5 [==============================] - 0s 23ms/step - loss: 0.0055 - mae: 0.0582 - val_loss: 0.0765 - val_mae: 0.2393
# Epoch 47/50
# 5/5 [==============================] - 0s 25ms/step - loss: 0.0054 - mae: 0.0577 - val_loss: 0.0762 - val_mae: 0.2386
# Epoch 48/50
# 5/5 [==============================] - 0s 78ms/step - loss: 0.0054 - mae: 0.0579 - val_loss: 0.0814 - val_mae: 0.2481
# Epoch 49/50
# 5/5 [==============================] - 0s 22ms/step - loss: 0.0053 - mae: 0.0562 - val_loss: 0.0807 - val_mae: 0.2471
# Epoch 50/50
# 5/5 [==============================] - 0s 23ms/step - loss: 0.0051 - mae: 0.0563 - val_loss: 0.0786 - val_mae: 0.2432
# 23/23 [==============================] - 1s 9ms/step
# Residual CNN-GRU - MAE: 0.2424, RMSE: 0.2808

# %%
from tensorflow.keras.layers import MultiHeadAttention, LayerNormalization

print("Training Attention CNN-Residual-GRU with GPU...")
with tf.device('/GPU:0'):
    input_layer = Input(shape=(X_train.shape[1], X_train.shape[2]))

    x = Conv1D(filters=64, kernel_size=3, activation='relu', padding='same')(input_layer)
    x = BatchNormalization()(x)

    x = residual_block(x, 64)
    x = residual_block(x, 32)

    attention_output = MultiHeadAttention(
        num_heads=4, 
        key_dim=32
    )(x, x)

    x = Add()([x, attention_output])
    x = LayerNormalization()(x)

    x = GRU(50, return_sequences=False)(x)
    x = Dropout(0.3)(x)
    x = Dense(25, activation='relu')(x)
    output = Dense(1)(x)

    attention_model = Model(inputs=input_layer, outputs=output)
    attention_model.compile(optimizer='adam', loss='mse', metrics=['mae'])

history_attention = attention_model.fit(
    X_train, y_train,
    epochs=50,
    batch_size=512,
    validation_split=0.2,
    verbose=1
)

attention_pred = attention_model.predict(X_test).flatten()

attention_mae = mean_absolute_error(y_test, attention_pred)
attention_rmse = np.sqrt(mean_squared_error(y_test, attention_pred))

print(f"Attention CNN-Residual-GRU - MAE: {attention_mae:.4f}, RMSE: {attention_rmse:.4f}")
# Out:
# Training Attention CNN-Residual-GRU with GPU...
# Epoch 1/50
# 5/5 [==============================] - 6s 134ms/step - loss: 0.1065 - mae: 0.2560 - val_loss: 0.0266 - val_mae: 0.1307
# Epoch 2/50
# 5/5 [==============================] - 0s 79ms/step - loss: 0.0545 - mae: 0.1884 - val_loss: 0.0410 - val_mae: 0.1669
# Epoch 3/50
# 5/5 [==============================] - 0s 26ms/step - loss: 0.0374 - mae: 0.1551 - val_loss: 0.0634 - val_mae: 0.2146
# Epoch 4/50
# 5/5 [==============================] - 0s 25ms/step - loss: 0.0330 - mae: 0.1451 - val_loss: 0.0808 - val_mae: 0.2475
# Epoch 5/50
# 5/5 [==============================] - 0s 23ms/step - loss: 0.0325 - mae: 0.1436 - val_loss: 0.0881 - val_mae: 0.2607
# Epoch 6/50
# 5/5 [==============================] - 0s 23ms/step - loss: 0.0274 - mae: 0.1322 - val_loss: 0.0705 - val_mae: 0.2290
# Epoch 7/50
# 5/5 [==============================] - 0s 73ms/step - loss: 0.0268 - mae: 0.1305 - val_loss: 0.0649 - val_mae: 0.2178
# Epoch 8/50
# 5/5 [==============================] - 0s 29ms/step - loss: 0.0255 - mae: 0.1266 - val_loss: 0.0466 - val_mae: 0.1790
# Epoch 9/50
# 5/5 [==============================] - 0s 27ms/step - loss: 0.0242 - mae: 0.1246 - val_loss: 0.0497 - val_mae: 0.1859
# Epoch 10/50
# 5/5 [==============================] - 0s 24ms/step - loss: 0.0241 - mae: 0.1237 - val_loss: 0.0436 - val_mae: 0.1724
# Epoch 11/50
# 5/5 [==============================] - 0s 25ms/step - loss: 0.0223 - mae: 0.1193 - val_loss: 0.0514 - val_mae: 0.1893
# Epoch 12/50
# 5/5 [==============================] - 0s 68ms/step - loss: 0.0225 - mae: 0.1190 - val_loss: 0.0458 - val_mae: 0.1765
# Epoch 13/50
# 5/5 [==============================] - 0s 23ms/step - loss: 0.0219 - mae: 0.1183 - val_loss: 0.0435 - val_mae: 0.1710
# Epoch 14/50
# 5/5 [==============================] - 0s 24ms/step - loss: 0.0224 - mae: 0.1187 - val_loss: 0.0364 - val_mae: 0.1543
# Epoch 15/50
# 5/5 [==============================] - 0s 23ms/step - loss: 0.0207 - mae: 0.1142 - val_loss: 0.0368 - val_mae: 0.1551
# Epoch 16/50
# 5/5 [==============================] - 0s 26ms/step - loss: 0.0194 - mae: 0.1097 - val_loss: 0.0373 - val_mae: 0.1563
# Epoch 17/50
# 5/5 [==============================] - 0s 77ms/step - loss: 0.0192 - mae: 0.1094 - val_loss: 0.0378 - val_mae: 0.1571
# Epoch 18/50
# 5/5 [==============================] - 0s 25ms/step - loss: 0.0189 - mae: 0.1088 - val_loss: 0.0418 - val_mae: 0.1667
# Epoch 19/50
# 5/5 [==============================] - 0s 23ms/step - loss: 0.0183 - mae: 0.1081 - val_loss: 0.0400 - val_mae: 0.1625
# Epoch 20/50
# 5/5 [==============================] - 0s 24ms/step - loss: 0.0175 - mae: 0.1058 - val_loss: 0.0415 - val_mae: 0.1659
# Epoch 21/50
# 5/5 [==============================] - 0s 20ms/step - loss: 0.0168 - mae: 0.1031 - val_loss: 0.0498 - val_mae: 0.1843
# Epoch 22/50
# 5/5 [==============================] - 0s 85ms/step - loss: 0.0162 - mae: 0.1011 - val_loss: 0.0373 - val_mae: 0.1560
# Epoch 23/50
# 5/5 [==============================] - 0s 26ms/step - loss: 0.0156 - mae: 0.1000 - val_loss: 0.0386 - val_mae: 0.1590
# Epoch 24/50
# 5/5 [==============================] - 0s 23ms/step - loss: 0.0145 - mae: 0.0962 - val_loss: 0.0406 - val_mae: 0.1636
# Epoch 25/50
# 5/5 [==============================] - 0s 24ms/step - loss: 0.0143 - mae: 0.0949 - val_loss: 0.0382 - val_mae: 0.1577
# Epoch 26/50
# 5/5 [==============================] - 0s 25ms/step - loss: 0.0132 - mae: 0.0907 - val_loss: 0.0413 - val_mae: 0.1646
# Epoch 27/50
# 5/5 [==============================] - 0s 74ms/step - loss: 0.0124 - mae: 0.0884 - val_loss: 0.0533 - val_mae: 0.1909
# Epoch 28/50
# 5/5 [==============================] - 0s 27ms/step - loss: 0.0116 - mae: 0.0850 - val_loss: 0.0530 - val_mae: 0.1902
# Epoch 29/50
# 5/5 [==============================] - 0s 22ms/step - loss: 0.0108 - mae: 0.0820 - val_loss: 0.0566 - val_mae: 0.1975
# Epoch 30/50
# 5/5 [==============================] - 0s 24ms/step - loss: 0.0103 - mae: 0.0810 - val_loss: 0.0561 - val_mae: 0.1964
# Epoch 31/50
# 5/5 [==============================] - 0s 23ms/step - loss: 0.0096 - mae: 0.0782 - val_loss: 0.0507 - val_mae: 0.1850
# Epoch 32/50
# 5/5 [==============================] - 0s 78ms/step - loss: 0.0095 - mae: 0.0770 - val_loss: 0.0564 - val_mae: 0.1969
# Epoch 33/50
# 5/5 [==============================] - 0s 26ms/step - loss: 0.0086 - mae: 0.0736 - val_loss: 0.0587 - val_mae: 0.2015
# Epoch 34/50
# 5/5 [==============================] - 0s 25ms/step - loss: 0.0082 - mae: 0.0714 - val_loss: 0.0538 - val_mae: 0.1916
# Epoch 35/50
# 5/5 [==============================] - 0s 25ms/step - loss: 0.0084 - mae: 0.0713 - val_loss: 0.0571 - val_mae: 0.1983
# Epoch 36/50
# 5/5 [==============================] - 0s 24ms/step - loss: 0.0078 - mae: 0.0702 - val_loss: 0.0625 - val_mae: 0.2092
# Epoch 37/50
# 5/5 [==============================] - 0s 74ms/step - loss: 0.0076 - mae: 0.0687 - val_loss: 0.0730 - val_mae: 0.2295
# Epoch 38/50
# 5/5 [==============================] - 0s 25ms/step - loss: 0.0072 - mae: 0.0674 - val_loss: 0.0778 - val_mae: 0.2378
# Epoch 39/50
# 5/5 [==============================] - 0s 26ms/step - loss: 0.0071 - mae: 0.0671 - val_loss: 0.0811 - val_mae: 0.2437
# Epoch 40/50
# 5/5 [==============================] - 0s 24ms/step - loss: 0.0064 - mae: 0.0627 - val_loss: 0.0927 - val_mae: 0.2639
# Epoch 41/50
# 5/5 [==============================] - 0s 25ms/step - loss: 0.0068 - mae: 0.0650 - val_loss: 0.1045 - val_mae: 0.2828
# Epoch 42/50
# 5/5 [==============================] - 0s 80ms/step - loss: 0.0072 - mae: 0.0669 - val_loss: 0.1098 - val_mae: 0.2909
# Epoch 43/50
# 5/5 [==============================] - 0s 24ms/step - loss: 0.0073 - mae: 0.0674 - val_loss: 0.1088 - val_mae: 0.2901
# Epoch 44/50
# 5/5 [==============================] - 0s 28ms/step - loss: 0.0076 - mae: 0.0693 - val_loss: 0.1120 - val_mae: 0.2952
# Epoch 45/50
# 5/5 [==============================] - 0s 24ms/step - loss: 0.0076 - mae: 0.0697 - val_loss: 0.1146 - val_mae: 0.2989
# Epoch 46/50
# 5/5 [==============================] - 0s 24ms/step - loss: 0.0068 - mae: 0.0651 - val_loss: 0.1078 - val_mae: 0.2883
# Epoch 47/50
# 5/5 [==============================] - 0s 72ms/step - loss: 0.0060 - mae: 0.0618 - val_loss: 0.1000 - val_mae: 0.2765
# Epoch 48/50
# 5/5 [==============================] - 0s 22ms/step - loss: 0.0056 - mae: 0.0597 - val_loss: 0.0948 - val_mae: 0.2677
# Epoch 49/50
# 5/5 [==============================] - 0s 24ms/step - loss: 0.0052 - mae: 0.0566 - val_loss: 0.1070 - val_mae: 0.2872
# Epoch 50/50
# 5/5 [==============================] - 0s 22ms/step - loss: 0.0051 - mae: 0.0558 - val_loss: 0.1142 - val_mae: 0.2982
# 23/23 [==============================] - 1s 3ms/step
# Attention CNN-Residual-GRU - MAE: 0.3027, RMSE: 0.3421

# %%
print("="*60)
print("FINAL RESULTS COMPARISON")
print("="*60)
print(f"XGBoost                  - MAE: {xgb_mae:.4f}, RMSE: {xgb_rmse:.4f}")
print(f"LightGBM                 - MAE: {lgb_mae:.4f}, RMSE: {lgb_rmse:.4f}")
print(f"CatBoost                 - MAE: {cat_mae:.4f}, RMSE: {cat_rmse:.4f}")
print(f"Ensemble (XGB+LGB+CAT)   - MAE: {ensemble_mae:.4f}, RMSE: {ensemble_rmse:.4f}")
print(f"CNN-GRU                  - MAE: {cnn_gru_mae:.4f}, RMSE: {cnn_gru_rmse:.4f}")
print(f"Residual-CNN-GRU         - MAE: {residual_mae:.4f}, RMSE: {residual_rmse:.4f}")
print(f"Attention-CNN-Res-GRU    - MAE: {attention_mae:.4f}, RMSE: {attention_rmse:.4f}")
print("="*60)
# Out:
# ============================================================
# FINAL RESULTS COMPARISON
# ============================================================
# XGBoost                  - MAE: 0.1240, RMSE: 0.1529
# LightGBM                 - MAE: 0.1249, RMSE: 0.1537
# CatBoost                 - MAE: 0.1259, RMSE: 0.1558
# Ensemble (XGB+LGB+CAT)   - MAE: 0.1235, RMSE: 0.1517
# CNN-GRU                  - MAE: 0.1243, RMSE: 0.1535
# Residual-CNN-GRU         - MAE: 0.2424, RMSE: 0.2808
# Attention-CNN-Res-GRU    - MAE: 0.3027, RMSE: 0.3421
# ============================================================
