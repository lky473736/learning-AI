# %% [markdown]
# ## learning-AI101 : glass regression (DL)
# ### 유리 데이터를 Dense layer struction을 통한 DNN 방식 및 CNN으로의 regression
#
# <br>
#
# - **임규연 (lky473736)**
# - 2024.08.04. ~ 2024.08.05. 문서 작성
# - **dataset** : https://archive.ics.uci.edu/dataset/42/glass+identification
# - **kaggle** : https://www.kaggle.com/datasets/uciml/glass
# - **data abstract** : Vina conducted a comparison test of her rule-based system, BEAGLE, the nearest-neighbor algorithm, and discriminant analysis.  BEAGLE is a product available through VRS Consulting, Inc.; 4676 Admiralty Way, Suite 206; Marina Del Ray, CA 90292 (213) 827-7890 and FAX: -3189. In determining whether the glass was a type of "float" glass or not. The study of classification of types of glass was motivated by criminological investigation.  At the scene of the crime, the glass left can be used as evidence...if it is correctly identified!
#
# ------

# %% [markdown]
# ## <span id='dl'><mark>DL</mark></span>
#
# deep learning으로 glass을 regression한다. 목차는 아래와 같다.
#
# - **1. 데이터 분석, 시각화 및 전처리**
# - **2. SGDRegressor를 통한 ML에서의 확률적 경사 하강법 적용**
# - **3. ANN (fully connected)**
# - **4. DNN**
# - **5. CNN**

# %%
# 라이브러리 import

import numpy as np
import pandas as pd
import seaborn as sns
import tensorflow as tf
import matplotlib.pyplot as plt
import seaborn as sns
from tensorflow import keras
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler, LabelEncoder
# Out:
# 2024-08-06 12:52:43.602073: I tensorflow/core/platform/cpu_feature_guard.cc:182] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.

# %% [markdown]
# ------
#
# ### 1. 데이터 분석, 시각화 및 전처리
# - 데이터 로드 및 필요한 정보, 기초통계량을 get한다.
# - 결측치 제거, outlier 제거 등의 데이터 전처리를 수행한다.
# - cell 순서는 아래와 같다.
#     - (1) 데이터 읽기 및 head 파악
#     - (2) 데이터 info (결측치 파악), 데이터 크기
#     - (3) 데이터 기초통계량 확인
#     - (4) heatmap
#     - (5) feature, input data split
#         - ./ML_regression_glass에서는 **Mg가 target이 되며, 나머지 특성 중 상관계수가 높았던 feature만 extraction하여 본 regression의 feature**가 되었다.
#         - 따라서 이번에도 그렇게 진행할 예정인데, feature의 수가 얼마 되지 않아 score가 제대로 나지 않을 수 있기에 **PolynormialFeature를 통하여 feature를 내적**하여 늘리겠다.
#     - (6) train set, test set, validation set split
#     - (7) input data : apply PolynormialFeature
#     - (8) scaling (z-score normalization)

# %%
# (1) 데이터 읽기 및 head 파악

columns = ['id', 'RI', 'Na', 'Mg', 
          'Al', 'Si', 'K', 'Ca', 
          'Ba', 'Fe', 'target']
df = pd.read_csv("./data/glass/glass.csv", names=columns)
df.head()
# Out:
#    id       RI     Na    Mg    Al     Si     K    Ca   Ba   Fe  target
# 0   1  1.52101  13.64  4.49  1.10  71.78  0.06  8.75  0.0  0.0       1
# 1   2  1.51761  13.89  3.60  1.36  72.73  0.48  7.83  0.0  0.0       1
# 2   3  1.51618  13.53  3.55  1.54  72.99  0.39  7.78  0.0  0.0       1
# 3   4  1.51766  13.21  3.69  1.29  72.61  0.57  8.22  0.0  0.0       1
# 4   5  1.51742  13.27  3.62  1.24  73.08  0.55  8.07  0.0  0.0       1

# %%
# (2) 데이터 info (결측치 파악), 데이터 크기

print('dataframe size : ', df.shape)
df.info()
# Out:
# dataframe size :  (214, 11)
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 214 entries, 0 to 213
# Data columns (total 11 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   id      214 non-null    int64
#  1   RI      214 non-null    float64
#  2   Na      214 non-null    float64
#  3   Mg      214 non-null    float64
#  4   Al      214 non-null    float64
#  5   Si      214 non-null    float64
#  6   K       214 non-null    float64
#  7   Ca      214 non-null    float64
#  8   Ba      214 non-null    float64
#  9   Fe      214 non-null    float64
#  10  target  214 non-null    int64
# dtypes: float64(9), int64(2)
# memory usage: 18.5 KB

# %%
# (3) data 기초통계량 확인

df.describe()
# Out:
#                id          RI          Na          Mg          Al          Si  \
# count  214.000000  214.000000  214.000000  214.000000  214.000000  214.000000
# mean   107.500000    1.518365   13.407850    2.684533    1.444907   72.650935
# std     61.920648    0.003037    0.816604    1.442408    0.499270    0.774546
# min      1.000000    1.511150   10.730000    0.000000    0.290000   69.810000
# 25%     54.250000    1.516522   12.907500    2.115000    1.190000   72.280000
# 50%    107.500000    1.517680   13.300000    3.480000    1.360000   72.790000
# 75%    160.750000    1.519157   13.825000    3.600000    1.630000   73.087500
# max    214.000000    1.533930   17.380000    4.490000    3.500000   75.410000
#
#                 K          Ca          Ba          Fe      target
# count  214.000000  214.000000  214.000000  214.000000  214.000000
# mean     0.497056    8.956963    0.175047    0.057009    2.780374
# std      0.652192    1.423153    0.497219    0.097439    2.103739
# ...

# %%
# (4) heatmap

# id 열은 제외
correlation_matrix = df[['RI', 'Na', 'Mg', 
                         'Al', 'Si', 'K', 
                         'Ca', 'Ba', 'Fe', 'target']].corr() 
plt.figure(figsize=(10, 8)) 
sns.heatmap(correlation_matrix, annot=True, cmap='RdBu', square=True,
            linewidths=1, linecolor='black', cbar_kws={"shrink": 0.8})

plt.title('Correlation Heatmap of Glass Dataset', fontsize=16)
plt.show()

# %% [markdown]
# target을 Mg로 설정한다고 가정했을 때, Mg와 correlation의 절댓값이 높은 feature는 **Al, Ba, Ca, Na, Si** 이다. 자세한 상황은 아래와 같다.
#
# - Mg는 Al과 **상당히** 높은 음의 상관관계 (-0.48)을 가진다.
# - 또한, Ba와고도 높은 음의 상관관계 (-0.49)를 가진다.
# - Ca와도 **상당한** 음의 상관관계(-0.44)를 가진다.
# - Na와 Si하고도 높지는 않지만 관계적으로는 음의 상관관계이다.
#
# 여기서 말하는 **상당하다**의 기준은, 다른 feature들 사이의 correlation 중에서 상대적으로 높다는 것을 의미한다. 사실은 0.4~0.5는 상관관계가 높다고 말할 수 없다고 본다. (상대적인 관점이라는 것을 강조한다.)
#
# 결국엔 **Al, Ba, Ca, Na, Si attributes를 feature**로, **Mg를 label(target)** 으로 삼아 regression을 진행한다. feature의 수가 너무 적어 학습이 제대로 되지 않을 수 있기 때문에 feature를 늘리는 방식을 고려해본다.

# %%
# (5) feature, input data split

glass_input = df[['Al', 'Ba', 'Ca', 'Na', 'Si']].to_numpy()
glass_target = df['Mg'].to_numpy()

glass_input.shape, glass_target.shape
# Out:
# ((214, 5), (214,))

# %%
# (6) train set, test set, validation set split, scaling (z-score normalization)

# X_train, y_train, X_test, y_test
X_train, X_test, y_train, y_test = train_test_split(glass_input, 
                                                   glass_target,
                                                   test_size=0.2)

# X_train, y_train, X_test, y_test
X_train, X_val, y_train, y_val = train_test_split(X_train, y_train,
                                                 test_size=0.2)

# scaling
ss_transformer = StandardScaler()
ss_transformer.fit(X_train)

X_train_scaled = ss_transformer.transform(X_train)
X_test_scaled = ss_transformer.transform(X_test)
X_val_scaled = ss_transformer.transform(X_val)

# %%
# (7) input data : PolynormialFeature 

from sklearn.preprocessing import PolynomialFeatures
poly = PolynomialFeatures(degree=2) # 2차까지
poly.fit(X_train)

X_train_poly = poly.transform (X_train)
X_test_poly = poly.transform (X_test)
X_val_poly = poly.transform (X_val )

print (f"shape | X_train_poly : {X_train_poly.shape}, X_test_poly : {X_test_poly.shape}, X_val_poly : {X_val_poly.shape}")
print (f"poly | {poly.get_feature_names_out()}")
# Out:
# shape | X_train_poly : (136, 21), X_test_poly : (43, 21), X_val_poly : (35, 21)
# poly | ['1' 'x0' 'x1' 'x2' 'x3' 'x4' 'x0^2' 'x0 x1' 'x0 x2' 'x0 x3' 'x0 x4'
#  'x1^2' 'x1 x2' 'x1 x3' 'x1 x4' 'x2^2' 'x2 x3' 'x2 x4' 'x3^2' 'x3 x4'
#  'x4^2']

# %%
# (8) scaling

ss_transformer = StandardScaler()
ss_transformer.fit(X_train_poly)

X_train_poly_scaled = ss_transformer.transform(X_train_poly)
X_test_poly_scaled = ss_transformer.transform(X_test_poly)
X_val_poly_scaled = ss_transformer.transform(X_val_poly)

# %% [markdown]
# 향후 계속 X_train_poly_scaled를 사용한다.

# %% [markdown]
# -------
#
# ### 2. SGDRegressor 통한 ML에서의 확률적 경사 하강법 적용
# deep learning을 하기 전, deep learning의 weight 및 bias 조정법인 **SGD (Stochastic Gradient Descent)** 를 scikit-learn으로 구현해본다. parameter는 random search를 통하여 최적화할 것이며, 자세한 조정범위는 아래에 서술한다.
# - loss function : 오차제곱법 사용 (squared_error)
# - max_iter : 3~100 (randint)

# %%
# random search를 통한 hyperparameter tuning

from sklearn.linear_model import SGDRegressor
from scipy.stats import randint, uniform
from sklearn.model_selection import RandomizedSearchCV

param = {
    'max_iter' : randint(3, 100)
}

sr = SGDRegressor(loss='squared_error')
rs = RandomizedSearchCV(sr, param, n_iter=150, n_jobs=-1)
rs.fit (X_train_poly_scaled, y_train)
# Out:
# /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/sklearn/linear_model/_stochastic_gradient.py:1561: ConvergenceWarning: Maximum number of iteration reached before convergence. Consider increasing max_iter to improve the fit.
#   warnings.warn(
# /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/sklearn/linear_model/_stochastic_gradient.py:1561: ConvergenceWarning: Maximum number of iteration reached before convergence. Consider increasing max_iter to improve the fit.
#   warnings.warn(
# /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/sklearn/linear_model/_stochastic_gradient.py:1561: ConvergenceWarning: Maximum number of iteration reached before convergence. Consider increasing max_iter to improve the fit.
#   warnings.warn(
# ...

# %%
# 하이퍼파라미터 조합별 성능 시각화

# 각 하이퍼파라미터 조합별 교차 검증 스코어 가져오기
results = rs.cv_results_
mean_scores = results['mean_test_score']
params = results['params']

# 시각화를 위한 데이터 준비
max_iter_values = [params[i]['max_iter'] for i in range(len(params))]

# 가로 방향으로 막대 그래프로 교차 검증 스코어 시각화
fig, ax = plt.subplots(figsize=(8, 30))
bars = ax.barh(range(len(mean_scores)), mean_scores, tick_label=[f"{compo}" for compo in max_iter_values])
ax.set_xlabel('Mean CV Score')
ax.set_title('Random Search Scores')

# X축의 범위를 자동으로 조정
plt.xlim((min(mean_scores) - 0.05, max(mean_scores) + 0.05))

plt.tight_layout()
plt.show()

# %% [markdown]
# 결정계수가 모두 꽤 괜찮다. **딥러닝이 기대되는 순간**이다.

# %%
# best score, best model, train score, test score

sr = rs.best_estimator_
print ("best score : ", rs.best_score_)
print ("best estimator (model) : ", sr)

sr_score = [sr.score(X_train_poly_scaled, y_train), sr.score(X_test_poly_scaled, y_test)]
print (f"train score, test score : {sr_score}")
# Out:
# best score :  0.8310876915880536
# best estimator (model) :  SGDRegressor(max_iter=33)
# train score, test score : [0.9068490054114366, 0.7969797016440344]

# %% [markdown]
# -------
#
# ### 3.  ANN (fully connected)
# - hidden layer를 구성하지 않고, 입력층과 출력층만 존재하는 인공신경망을 struction할 것이다.
# - 기존 train set에서 validation set을 하나 더 구성하였고, 추후 evaluation에 사용할 예정이다.
# - 출력층의 activation을 사용하지 않는다. (regression이기 때문에)

# %%
# modelling

model = keras.Sequential([
    keras.layers.Flatten(input_shape=(21, )), 
    keras.layers.Dense(1)
])

model.summary()
keras.utils.plot_model(model, show_shapes=True)
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# ...
#  flatten (Flatten)           (None, 21)                0
#
#  dense (Dense)               (None, 1)                 22
#
# ...
# Total params: 22 (88.00 Byte)
# Trainable params: 22 (88.00 Byte)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %%
# compile
# reference : https://dacon.io/forum/405791

model.compile(optimizer='adam', loss='mse', metrics=['mae'])

# %% [markdown]
# 만약 여기서 metrics로 'mape'를 설정하였다면 정말 큰 숫자가 나올 것이다. 경험담이다. 나왔다. mape는 0~100%의 범위를 가지는 비율로써, 0에 가까울 수록 오차가 없어 모델의 성능이 좋은 건데, mape를 사용하는 순간 비정상적으로 큰 비율이 출력된다. 원인은 다음과 같다.
#
# - 모델이 너무 간단해서 그럴 수 있다고 생각한다.
# - 애초에 flatten 층과 함께 parameter의 갯수가 현저히 적어서 이런 문제가 발생하는 것 같다.
# - target이 0과 가깝게 scaling해놨기 때문에 그럴 것.

# %%
# fit

history = model.fit(X_train_poly_scaled, y_train, epochs=100, 
                   validation_data=(X_val_poly_scaled, y_val))

print (history.history)
# Out:
# Epoch 1/100
# 5/5 [==============================] - 1s 35ms/step - loss: 15.0851 - mae: 3.6959 - val_loss: 18.6832 - val_mae: 4.1184
# Epoch 2/100
# 5/5 [==============================] - 0s 7ms/step - loss: 14.7486 - mae: 3.6576 - val_loss: 18.2673 - val_mae: 4.0760
# Epoch 3/100
# 5/5 [==============================] - 0s 7ms/step - loss: 14.4150 - mae: 3.6176 - val_loss: 17.8711 - val_mae: 4.0379
# Epoch 4/100
# 5/5 [==============================] - 0s 8ms/step - loss: 14.0909 - mae: 3.5794 - val_loss: 17.4786 - val_mae: 4.0004
# Epoch 5/100
# 5/5 [==============================] - 0s 8ms/step - loss: 13.7776 - mae: 3.5391 - val_loss: 17.1014 - val_mae: 3.9636
# Epoch 6/100
# 5/5 [==============================] - 0s 8ms/step - loss: 13.4697 - mae: 3.5013 - val_loss: 16.7292 - val_mae: 3.9269
# Epoch 7/100
# 5/5 [==============================] - 0s 9ms/step - loss: 13.1779 - mae: 3.4641 - val_loss: 16.3620 - val_mae: 3.8901
# Epoch 8/100
# ...

# %%
# loss 시각화

plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.xlabel('number of epoch')
plt.ylabel('loss')
plt.legend (['train loss', 'validation loss'])
plt.show()

# %% [markdown]
# 위 mape 성능과 위 figure을 확인해보았을 때 앞으로 할 수 있는건 다음과 같다.
#
# - loss는 매우 선형적으로 줄어드니, **model을 조금 더 복잡**하게 만들어서 성능을 더 잘 나올 수 있도록 restruction하자.
#     - DNN에서 parameter 수를 최소 10000개로 늘리려고 한다.
#     - 각 activation은 relu 사용

# %%
# evaluate

model.evaluate(X_val_poly_scaled, y_val)
# Out:
# 2/2 [==============================] - 0s 3ms/step - loss: 5.2108 - mae: 2.2507
# [5.210771083831787, 2.250746488571167]

# %% [markdown]
# -------
#
# ### 4. DNN
# - hidden layer을 충분히 구성하여 신경망을 struction할 것임
#     - parameter는 최소한 15000개 이상으로 증폭, 각 node의 activation은 relu 사용
#     - epoch는 100으로 고정
# - 아래와 같이 experiment할 예정이다.
#     - optimizer는 **적응형 학습율 optimizer인 adam을 사용한다.**
#     - validation loss 감소를 위하여 **dropout 층을 추가 후, callback으로 early stopping을 도입**한다.
#         - patiences는 5로 한다.

# %%
# modelling DNN

model = keras.Sequential([
    keras.layers.Flatten(input_shape=(21, )), 
    keras.layers.Dense(256, activation='relu'), 
    keras.layers.Dense(128, activation='relu'),
    keras.layers.Dropout(0.2),
    keras.layers.Dense(64, activation='relu'),
    keras.layers.Dense(32, activation='relu'),
    keras.layers.Dropout(0.2),
    keras.layers.Dense(16, activation='relu'),
    keras.layers.Dense(1)
])

model.summary()
keras.utils.plot_model(model, show_shapes=True)
# Out:
# Model: "sequential_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# ...
#  flatten_1 (Flatten)         (None, 21)                0
#
#  dense_1 (Dense)             (None, 256)               5632
#
#  dense_2 (Dense)             (None, 128)               32896
#
#  dropout (Dropout)           (None, 128)               0
#
#  dense_3 (Dense)             (None, 64)                8256
#
#  dense_4 (Dense)             (None, 32)                2080
#
#  dropout_1 (Dropout)         (None, 32)                0
#
#  dense_5 (Dense)             (None, 16)                528
#
#  dense_6 (Dense)             (None, 1)                 17
#
# ...
# Total params: 49409 (193.00 KB)
# Trainable params: 49409 (193.00 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %%
# compile

adam = keras.optimizers.Adam()
model.compile(optimizer=adam, 
              loss='mse', metrics=['mae'])

# %%
# callback 설정 및 fit

early_stopping_cb = keras.callbacks.EarlyStopping(patience=5, 
                                                 restore_best_weights=True)

history = model.fit(X_train_poly_scaled, y_train, epochs=100, 
                    validation_data=(X_val_poly_scaled, y_val), batch_size=10, 
                    callbacks=early_stopping_cb, verbose=True)
# Out:
# Epoch 1/100
# 14/14 [==============================] - 1s 12ms/step - loss: 7.2345 - mae: 2.3871 - val_loss: 5.8707 - val_mae: 2.3701
# Epoch 2/100
# 14/14 [==============================] - 0s 4ms/step - loss: 2.6504 - mae: 1.3991 - val_loss: 0.7489 - val_mae: 0.6855
# Epoch 3/100
# 14/14 [==============================] - 0s 3ms/step - loss: 1.9067 - mae: 0.9602 - val_loss: 0.5688 - val_mae: 0.6177
# Epoch 4/100
# 14/14 [==============================] - 0s 4ms/step - loss: 0.9554 - mae: 0.7399 - val_loss: 0.2211 - val_mae: 0.3708
# Epoch 5/100
# 14/14 [==============================] - 0s 4ms/step - loss: 0.8283 - mae: 0.6742 - val_loss: 0.3318 - val_mae: 0.5010
# Epoch 6/100
# 14/14 [==============================] - 0s 4ms/step - loss: 0.9149 - mae: 0.7124 - val_loss: 0.2049 - val_mae: 0.3507
# Epoch 7/100
# 14/14 [==============================] - 0s 3ms/step - loss: 0.6530 - mae: 0.6138 - val_loss: 0.3459 - val_mae: 0.4654
# Epoch 8/100
# ...

# %%
# loss 시각화

plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.xlabel('number of epoch')
plt.ylabel('loss')
plt.legend (['train loss', 'validation loss'])
plt.show()

# %%
# evaluate

model.evaluate(X_val_poly_scaled, y_val)
# Out:
# 2/2 [==============================] - 0s 3ms/step - loss: 0.0804 - mae: 0.2099
# [0.08042024075984955, 0.20988056063652039]

# %% [markdown]
# 방금 전보다 매우 낮은 loss를 출력하고 있는 것을 확인 가능하다. 성공이다.

# %% [markdown]
# -------
#
# ### 5.  CNN (2D)
# - convolution을 통하여 중요한 feature만 도드라지게 하여 학습을 진행한다.
# - 일단은, CNN을 여기에 적용하기엔 부적합할 수 있다. 하지만 진행해보자면...
#     - 3차원 tensor로 전환하여 Conv2D layer로 convolution을 시행할 수 있을 것 같다. 아래와 같이 전환한다.
#         - 배치 크기 : row의 갯수
#         - 세로 : 1 (관계형 데이터 csv이기 때문에 한 row를 기준으로)
#         - 가로 : feature의 갯수 (col의 갯수)
#         - 채널 : 1 (데이터를 단일 채널이라고 가정)
#     - 전환 후 CNN 2d를 적용하여 main feature extraction 후 pooling을 진행한다.
#     - Conv, pooling을 2번 반복 후 dense layer를 두어 regression한다.
#         - 중간에 dropout 층을 배치하여 overfitting을 막고 학습에 신중하도록 한다.
# - overfitting을 막기 위하여, DNN에서 했던 것과 같이 early stopping 콜백을 설치하려고 했으나, 충분한 학습을 한 후 loss 추이를 확인하기 위하여 콜백을 두지 않겠다.

# %%
# X_train_poly_scaled, X_test_poly_scaled, X_val_poly_scaled 데이터를 3차원 tensor로 전환한다.

X_train_cnn = X_train_poly_scaled.reshape((X_train_poly_scaled.shape[0], 1, X_train_poly_scaled.shape[1], 1))
X_test_cnn = X_test_poly_scaled.reshape((X_test_poly_scaled.shape[0], 1, X_test_poly_scaled.shape[1], 1))
X_val_cnn = X_val_poly_scaled.reshape((X_val_poly_scaled.shape[0], 1, X_val_poly_scaled.shape[1], 1))

# %%
# shape 확인

X_train_cnn.shape, X_test_cnn.shape, X_val_cnn.shape
# Out:
# ((136, 1, 21, 1), (43, 1, 21, 1), (35, 1, 21, 1))

# %%
# modelling (functional API 방식)

input_layer = keras.Input(shape=(1, 21, 1))
conv_1 = keras.layers.Conv2D(128, kernel_size=(1, 3), activation='relu', padding='same')(input_layer)
pooling_1 = keras.layers.MaxPooling2D((1, 2))(conv_1)
conv_2 = keras.layers.Conv2D(64, kernel_size=(1, 3), activation='relu', padding='same')(pooling_1)
pooling_2 = keras.layers.MaxPooling2D((1, 2))(conv_2)
flatten = keras.layers.Flatten()(pooling_2)
dense_1 = keras.layers.Dense(64, activation='relu') (flatten)
dropout_1 = keras.layers.Dropout(0.2) (dense_1)
dense_2 = keras.layers.Dense(32, activation='relu') (dropout_1)
dropout_2 = keras.layers.Dropout(0.2) (dense_2)
dense_3 = keras.layers.Dense(16, activation='relu') (dropout_2)
output_layer = keras.layers.Dense(1, activation='linear') (dense_3)

# model = keras.Model(
#     input_layer,
#     conv_1,
#     pooling_1,
#     conv_2,
#     pooling_2,
#     flatten,
#     dense_1,
#     dropout_1,
#     dense_2,
#     dropout_2,
#     dense_3,
#     output_layer
# )

model = keras.Model(inputs=input_layer, outputs=output_layer)

model.summary()
keras.utils.plot_model(model, show_shapes=True, show_layer_activations=True)
# Out:
# Model: "model_3"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# ...
#  input_6 (InputLayer)        [(None, 1, 21, 1)]        0
#
#  conv2d_9 (Conv2D)           (None, 1, 21, 128)        512
#
#  max_pooling2d_9 (MaxPoolin  (None, 1, 10, 128)        0
#  g2D)
#
#  conv2d_10 (Conv2D)          (None, 1, 10, 64)         24640
#
#  max_pooling2d_10 (MaxPooli  (None, 1, 5, 64)          0
#  ng2D)
#
#  flatten_6 (Flatten)         (None, 320)               0
#
#  dense_23 (Dense)            (None, 64)                20544
#
#  dropout_10 (Dropout)        (None, 64)                0
#
#  dense_24 (Dense)            (None, 32)                2080
#
#  dropout_11 (Dropout)        (None, 32)                0
#
#  dense_25 (Dense)            (None, 16)                528
#
#  dense_26 (Dense)            (None, 1)                 17
#
# ...
# Total params: 48321 (188.75 KB)
# Trainable params: 48321 (188.75 KB)
# ...

# %%
# compile

adam = keras.optimizers.Adam(learning_rate=0.001)
model.compile (optimizer=adam, loss='mse', metrics=['mae'])

# %%
# fit (충분한 학습을 하기 위하여 조기 종료 콜백을 넣지 않아보겠다)

# early_stopping_cb = keras.callbacks.EarlyStopping(patience=10, 
#                                                 restore_best_weights=True)

history = model.fit(X_train_cnn, y_train, epochs=100, 
                    validation_data=(X_val_cnn, y_val), batch_size=10, 
                    # callbacks=early_stopping_cb, 
                    verbose=True)
# Out:
# Epoch 1/100
# 14/14 [==============================] - 1s 19ms/step - loss: 8.2638 - mae: 2.5437 - val_loss: 8.4004 - val_mae: 2.8079
# Epoch 2/100
# 14/14 [==============================] - 0s 8ms/step - loss: 4.5352 - mae: 1.9071 - val_loss: 4.4709 - val_mae: 1.2632
# Epoch 3/100
# 14/14 [==============================] - 0s 8ms/step - loss: 2.3357 - mae: 1.0578 - val_loss: 1.3297 - val_mae: 1.0177
# Epoch 4/100
# 14/14 [==============================] - 0s 7ms/step - loss: 1.2998 - mae: 0.9131 - val_loss: 0.4611 - val_mae: 0.4365
# Epoch 5/100
# 14/14 [==============================] - 0s 8ms/step - loss: 1.3700 - mae: 0.8587 - val_loss: 0.9568 - val_mae: 0.9147
# Epoch 6/100
# 14/14 [==============================] - 0s 8ms/step - loss: 1.0098 - mae: 0.7868 - val_loss: 0.2966 - val_mae: 0.4118
# Epoch 7/100
# 14/14 [==============================] - 0s 8ms/step - loss: 1.0212 - mae: 0.7239 - val_loss: 0.2390 - val_mae: 0.4050
# Epoch 8/100
# ...

# %%
# loss 시각화

plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.xlabel('number of epoch')
plt.ylabel('loss')
plt.legend (['train loss', 'validation loss'])
plt.show()
