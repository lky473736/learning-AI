# %% [markdown]
# # learning-AI101 : raisin classification (DL)
# ### 건포도 데이터를 Dense layer struction을 통한 DNN 방식 및 CNN을 적용하여 classification
#
# <br>
#
# - **임규연 (lky473736)**
# - 2024.07.30. ~ 2024.08.01.에 DL 작성
# - **dataset** : https://archive.ics.uci.edu/dataset/850/raisin
# - **data abstract** : Images of Kecimen and Besni raisin varieties grown in Turkey were obtained with CVS. A total of 900 raisin grains were used, including 450 pieces from both varieties. These images were subjected to various stages of pre-processing and 7 morphological features were extracted. These features have been classified using three different artificial intelligence techniques.
#
# ------

# %% [markdown]
# - **CAUTION** : 데이터 EDA는 raisin classification (ML)에서 진행하여, 본 문서에서는 진행하지 않습니다.

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from tensorflow import keras
# Out:
# 2024-08-01 03:59:06.225112: I tensorflow/core/platform/cpu_feature_guard.cc:182] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.

# %%
# 데이터 불러오기

df = pd.read_excel('./data/Raisin_Dataset/Raisin_Dataset.xlsx')
df.info()
print (df.columns)
df.head()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 900 entries, 0 to 899
# Data columns (total 8 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Area             900 non-null    int64
#  1   MajorAxisLength  900 non-null    float64
#  2   MinorAxisLength  900 non-null    float64
#  3   Eccentricity     900 non-null    float64
#  4   ConvexArea       900 non-null    int64
#  5   Extent           900 non-null    float64
#  6   Perimeter        900 non-null    float64
#  7   Class            900 non-null    object
# dtypes: float64(5), int64(2), object(1)
# memory usage: 56.4+ KB
# Index(['Area', 'MajorAxisLength', 'MinorAxisLength', 'Eccentricity',
#        'ConvexArea', 'Extent', 'Perimeter', 'Class'],
#       dtype='object')
#     Area  MajorAxisLength  MinorAxisLength  Eccentricity  ConvexArea  \
# 0  87524       442.246011       253.291155      0.819738       90546
# 1  75166       406.690687       243.032436      0.801805       78789
# 2  90856       442.267048       266.328318      0.798354       93717
# 3  45928       286.540559       208.760042      0.684989       47336
# 4  79408       352.190770       290.827533      0.564011       81463
#
#      Extent  Perimeter    Class
# 0  0.758651   1184.040  Kecimen
# 1  0.684130   1121.786  Kecimen
# 2  0.637613   1208.575  Kecimen
# 3  0.699599    844.162  Kecimen
# 4  0.792772   1073.251  Kecimen

# %% [markdown]
# -----
#
# ## <span id='dl'><mark>DL</mark></span>
#
# deep learning으로 raisin을 classification한다. 목차는 아래와 같다.
#
# - **1. SGDClassifier를 통한 ML에서의 확률적 경사 하강법 적용**
# - **2. ANN (fully connected)**
# - **3. DNN**
# - **4. CNN**

# %% [markdown]
# -------
#
# ### 1. SGDClassifier를 통한 ML에서의 확률적 경사 하강법 적용
# deep learning을 하기 전, deep learning의 weight 및 bias 조정법인 **SGD (Stochastic Gradient Descent)** 를 scikit-learn으로 구현 후 classification score를 확인해본다. parameter는 random search를 통하여 최적화할 것이며, 자세한 조정범위는 아래에 서술한다.
# - loss function : log_loss (logistic regression (sigmoid))
# - max_iter : 10~30 (randint)

# %%
# data split 및 normalization

from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler

raisin_input = df[df.columns[:-1]]
raisin_target = df[df.columns[-1]]

X_train, X_test, y_train, y_test = train_test_split(raisin_input, raisin_target, 
                                                   stratify=raisin_target, test_size=0.2)

ss = StandardScaler()
X_train_scaled = ss.fit_transform(X_train)
X_test_scaled = ss.transform(X_test)

# %%
# random search를 통한 hyperparameter tuning

from sklearn.linear_model import SGDClassifier
from scipy.stats import randint, uniform
from sklearn.model_selection import RandomizedSearchCV

param = {
    'max_iter' : randint(10, 30)
}

sc = SGDClassifier(loss='log_loss')
rs = RandomizedSearchCV(sc, param, n_iter=20, n_jobs=-1)
rs.fit (X_train_scaled, y_train)
# Out:
# /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/sklearn/linear_model/_stochastic_gradient.py:713: ConvergenceWarning: Maximum number of iteration reached before convergence. Consider increasing max_iter to improve the fit.
#   warnings.warn(
# /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/sklearn/linear_model/_stochastic_gradient.py:713: ConvergenceWarning: Maximum number of iteration reached before convergence. Consider increasing max_iter to improve the fit.
#   warnings.warn(
# /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/sklearn/linear_model/_stochastic_gradient.py:713: ConvergenceWarning: Maximum number of iteration reached before convergence. Consider increasing max_iter to improve the fit.
#   warnings.warn(
# /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/sklearn/linear_model/_stochastic_gradient.py:713: ConvergenceWarning: Maximum number of iteration reached before convergence. Consider increasing max_iter to improve the fit.
#   warnings.warn(
# /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/sklearn/linear_model/_stochastic_gradient.py:713: ConvergenceWarning: Maximum number of iteration reached before convergence. Consider increasing max_iter to improve the fit.
#   warnings.warn(
# /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/sklearn/linear_model/_stochastic_gradient.py:713: ConvergenceWarning: Maximum number of iteration reached before convergence. Consider increasing max_iter to improve the fit.
#   warnings.warn(
# /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/sklearn/linear_model/_stochastic_gradient.py:713: ConvergenceWarning: Maximum number of iteration reached before convergence. Consider increasing max_iter to improve the fit.
#   warnings.warn(
# /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/sklearn/linear_model/_stochastic_gradient.py:713: ConvergenceWarning: Maximum number of iteration reached before convergence. Consider increasing max_iter to improve the fit.
#   warnings.warn(
# /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/sklearn/linear_model/_stochastic_gradient.py:713: ConvergenceWarning: Maximum number of iteration reached before convergence. Consider increasing max_iter to improve the fit.
#   warnings.warn(
# /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/sklearn/linear_model/_stochastic_gradient.py:713: ConvergenceWarning: Maximum number of iteration reached before convergence. Consider increasing max_iter to improve the fit.
#   warnings.warn(
# /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/sklearn/linear_model/_stochastic_gradient.py:713: ConvergenceWarning: Maximum number of iteration reached before convergence. Consider increasing max_iter to improve the fit.
#   warnings.warn(
# /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/sklearn/linear_model/_stochastic_gradient.py:713: ConvergenceWarning: Maximum number of iteration reached before convergence. Consider increasing max_iter to improve the fit.
#   warnings.warn(
# /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/sklearn/linear_model/_stochastic_gradient.py:713: ConvergenceWarning: Maximum number of iteration reached before convergence. Consider increasing max_iter to improve the fit.
#   warnings.warn(
# /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/sklearn/linear_model/_stochastic_gradient.py:713: ConvergenceWarning: Maximum number of iteration reached before convergence. Consider increasing max_iter to improve the fit.
#   warnings.warn(
# /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/sklearn/linear_model/_stochastic_gradient.py:713: ConvergenceWarning: Maximum number of iteration reached before convergence. Consider increasing max_iter to improve the fit.
#   warnings.warn(
# /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/sklearn/linear_model/_stochastic_gradient.py:713: ConvergenceWarning: Maximum number of iteration reached before convergence. Consider increasing max_iter to improve the fit.
#   warnings.warn(
# /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/sklearn/linear_model/_stochastic_gradient.py:713: ConvergenceWarning: Maximum number of iteration reached before convergence. Consider increasing max_iter to improve the fit.
#   warnings.warn(
# /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/sklearn/linear_model/_stochastic_gradient.py:713: ConvergenceWarning: Maximum number of iteration reached before convergence. Consider increasing max_iter to improve the fit.
#   warnings.warn(
# /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/sklearn/linear_model/_stochastic_gradient.py:713: ConvergenceWarning: Maximum number of iteration reached before convergence. Consider increasing max_iter to improve the fit.
#   warnings.warn(
# /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/sklearn/linear_model/_stochastic_gradient.py:713: ConvergenceWarning: Maximum number of iteration reached before convergence. Consider increasing max_iter to improve the fit.
#   warnings.warn(
# /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/sklearn/linear_model/_stochastic_gradient.py:713: ConvergenceWarning: Maximum number of iteration reached before convergence. Consider increasing max_iter to improve the fit.
#   warnings.warn(
# /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/sklearn/linear_model/_stochastic_gradient.py:713: ConvergenceWarning: Maximum number of iteration reached before convergence. Consider increasing max_iter to improve the fit.
#   warnings.warn(
# /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/sklearn/linear_model/_stochastic_gradient.py:713: ConvergenceWarning: Maximum number of iteration reached before convergence. Consider increasing max_iter to improve the fit.
#   warnings.warn(
# /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/sklearn/linear_model/_stochastic_gradient.py:713: ConvergenceWarning: Maximum number of iteration reached before convergence. Consider increasing max_iter to improve the fit.
#   warnings.warn(
# /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/sklearn/linear_model/_stochastic_gradient.py:713: ConvergenceWarning: Maximum number of iteration reached before convergence. Consider increasing max_iter to improve the fit.
#   warnings.warn(
# /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/sklearn/linear_model/_stochastic_gradient.py:713: ConvergenceWarning: Maximum number of iteration reached before convergence. Consider increasing max_iter to improve the fit.
#   warnings.warn(
# /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/sklearn/linear_model/_stochastic_gradient.py:713: ConvergenceWarning: Maximum number of iteration reached before convergence. Consider increasing max_iter to improve the fit.
#   warnings.warn(
# /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/sklearn/linear_model/_stochastic_gradient.py:713: ConvergenceWarning: Maximum number of iteration reached before convergence. Consider increasing max_iter to improve the fit.
#   warnings.warn(
# /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/sklearn/linear_model/_stochastic_gradient.py:713: ConvergenceWarning: Maximum number of iteration reached before convergence. Consider increasing max_iter to improve the fit.
#   warnings.warn(
# /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/sklearn/linear_model/_stochastic_gradient.py:713: ConvergenceWarning: Maximum number of iteration reached before convergence. Consider increasing max_iter to improve the fit.
#   warnings.warn(
# /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/sklearn/linear_model/_stochastic_gradient.py:713: ConvergenceWarning: Maximum number of iteration reached before convergence. Consider increasing max_iter to improve the fit.
#   warnings.warn(
# /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/sklearn/linear_model/_stochastic_gradient.py:713: ConvergenceWarning: Maximum number of iteration reached before convergence. Consider increasing max_iter to improve the fit.
#   warnings.warn(
# /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/sklearn/linear_model/_stochastic_gradient.py:713: ConvergenceWarning: Maximum number of iteration reached before convergence. Consider increasing max_iter to improve the fit.
#   warnings.warn(
# /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/sklearn/linear_model/_stochastic_gradient.py:713: ConvergenceWarning: Maximum number of iteration reached before convergence. Consider increasing max_iter to improve the fit.
#   warnings.warn(
# /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/sklearn/linear_model/_stochastic_gradient.py:713: ConvergenceWarning: Maximum number of iteration reached before convergence. Consider increasing max_iter to improve the fit.
#   warnings.warn(
# /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/sklearn/linear_model/_stochastic_gradient.py:713: ConvergenceWarning: Maximum number of iteration reached before convergence. Consider increasing max_iter to improve the fit.
#   warnings.warn(
# /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/sklearn/linear_model/_stochastic_gradient.py:713: ConvergenceWarning: Maximum number of iteration reached before convergence. Consider increasing max_iter to improve the fit.
#   warnings.warn(
# /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/sklearn/linear_model/_stochastic_gradient.py:713: ConvergenceWarning: Maximum number of iteration reached before convergence. Consider increasing max_iter to improve the fit.
#   warnings.warn(
# /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/sklearn/linear_model/_stochastic_gradient.py:713: ConvergenceWarning: Maximum number of iteration reached before convergence. Consider increasing max_iter to improve the fit.
#   warnings.warn(
# /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/sklearn/linear_model/_stochastic_gradient.py:713: ConvergenceWarning: Maximum number of iteration reached before convergence. Consider increasing max_iter to improve the fit.
#   warnings.warn(
# /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/sklearn/linear_model/_stochastic_gradient.py:713: ConvergenceWarning: Maximum number of iteration reached before convergence. Consider increasing max_iter to improve the fit.
#   warnings.warn(
# /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/sklearn/linear_model/_stochastic_gradient.py:713: ConvergenceWarning: Maximum number of iteration reached before convergence. Consider increasing max_iter to improve the fit.
#   warnings.warn(
# /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/sklearn/linear_model/_stochastic_gradient.py:713: ConvergenceWarning: Maximum number of iteration reached before convergence. Consider increasing max_iter to improve the fit.
#   warnings.warn(
# /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/sklearn/linear_model/_stochastic_gradient.py:713: ConvergenceWarning: Maximum number of iteration reached before convergence. Consider increasing max_iter to improve the fit.
#   warnings.warn(
# /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/sklearn/linear_model/_stochastic_gradient.py:713: ConvergenceWarning: Maximum number of iteration reached before convergence. Consider increasing max_iter to improve the fit.
#   warnings.warn(
# /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/sklearn/linear_model/_stochastic_gradient.py:713: ConvergenceWarning: Maximum number of iteration reached before convergence. Consider increasing max_iter to improve the fit.
#   warnings.warn(
# /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/sklearn/linear_model/_stochastic_gradient.py:713: ConvergenceWarning: Maximum number of iteration reached before convergence. Consider increasing max_iter to improve the fit.
#   warnings.warn(
# /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/sklearn/linear_model/_stochastic_gradient.py:713: ConvergenceWarning: Maximum number of iteration reached before convergence. Consider increasing max_iter to improve the fit.
#   warnings.warn(
# /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/sklearn/linear_model/_stochastic_gradient.py:713: ConvergenceWarning: Maximum number of iteration reached before convergence. Consider increasing max_iter to improve the fit.
#   warnings.warn(
# /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/sklearn/linear_model/_stochastic_gradient.py:713: ConvergenceWarning: Maximum number of iteration reached before convergence. Consider increasing max_iter to improve the fit.
#   warnings.warn(
# /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/sklearn/linear_model/_stochastic_gradient.py:713: ConvergenceWarning: Maximum number of iteration reached before convergence. Consider increasing max_iter to improve the fit.
#   warnings.warn(
# /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/sklearn/linear_model/_stochastic_gradient.py:713: ConvergenceWarning: Maximum number of iteration reached before convergence. Consider increasing max_iter to improve the fit.
#   warnings.warn(
# /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/sklearn/linear_model/_stochastic_gradient.py:713: ConvergenceWarning: Maximum number of iteration reached before convergence. Consider increasing max_iter to improve the fit.
#   warnings.warn(
# /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/sklearn/linear_model/_stochastic_gradient.py:713: ConvergenceWarning: Maximum number of iteration reached before convergence. Consider increasing max_iter to improve the fit.
#   warnings.warn(
# /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/sklearn/linear_model/_stochastic_gradient.py:713: ConvergenceWarning: Maximum number of iteration reached before convergence. Consider increasing max_iter to improve the fit.
#   warnings.warn(
# /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/sklearn/linear_model/_stochastic_gradient.py:713: ConvergenceWarning: Maximum number of iteration reached before convergence. Consider increasing max_iter to improve the fit.
#   warnings.warn(
# /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/sklearn/linear_model/_stochastic_gradient.py:713: ConvergenceWarning: Maximum number of iteration reached before convergence. Consider increasing max_iter to improve the fit.
#   warnings.warn(
# /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/sklearn/linear_model/_stochastic_gradient.py:713: ConvergenceWarning: Maximum number of iteration reached before convergence. Consider increasing max_iter to improve the fit.
#   warnings.warn(
# /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/sklearn/linear_model/_stochastic_gradient.py:713: ConvergenceWarning: Maximum number of iteration reached before convergence. Consider increasing max_iter to improve the fit.
#   warnings.warn(
# /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/sklearn/linear_model/_stochastic_gradient.py:713: ConvergenceWarning: Maximum number of iteration reached before convergence. Consider increasing max_iter to improve the fit.
#   warnings.warn(
# /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/sklearn/linear_model/_stochastic_gradient.py:713: ConvergenceWarning: Maximum number of iteration reached before convergence. Consider increasing max_iter to improve the fit.
#   warnings.warn(
# /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/sklearn/linear_model/_stochastic_gradient.py:713: ConvergenceWarning: Maximum number of iteration reached before convergence. Consider increasing max_iter to improve the fit.
#   warnings.warn(
# /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/sklearn/linear_model/_stochastic_gradient.py:713: ConvergenceWarning: Maximum number of iteration reached before convergence. Consider increasing max_iter to improve the fit.
#   warnings.warn(
# /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/sklearn/linear_model/_stochastic_gradient.py:713: ConvergenceWarning: Maximum number of iteration reached before convergence. Consider increasing max_iter to improve the fit.
#   warnings.warn(
# /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/sklearn/linear_model/_stochastic_gradient.py:713: ConvergenceWarning: Maximum number of iteration reached before convergence. Consider increasing max_iter to improve the fit.
#   warnings.warn(
# /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/sklearn/linear_model/_stochastic_gradient.py:713: ConvergenceWarning: Maximum number of iteration reached before convergence. Consider increasing max_iter to improve the fit.
#   warnings.warn(
# /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/sklearn/linear_model/_stochastic_gradient.py:713: ConvergenceWarning: Maximum number of iteration reached before convergence. Consider increasing max_iter to improve the fit.
#   warnings.warn(
# /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/sklearn/linear_model/_stochastic_gradient.py:713: ConvergenceWarning: Maximum number of iteration reached before convergence. Consider increasing max_iter to improve the fit.
#   warnings.warn(
# /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/sklearn/linear_model/_stochastic_gradient.py:713: ConvergenceWarning: Maximum number of iteration reached before convergence. Consider increasing max_iter to improve the fit.
#   warnings.warn(
# /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/sklearn/linear_model/_stochastic_gradient.py:713: ConvergenceWarning: Maximum number of iteration reached before convergence. Consider increasing max_iter to improve the fit.
#   warnings.warn(
# /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/sklearn/linear_model/_stochastic_gradient.py:713: ConvergenceWarning: Maximum number of iteration reached before convergence. Consider increasing max_iter to improve the fit.
#   warnings.warn(
# /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/sklearn/linear_model/_stochastic_gradient.py:713: ConvergenceWarning: Maximum number of iteration reached before convergence. Consider increasing max_iter to improve the fit.
#   warnings.warn(
# /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/sklearn/linear_model/_stochastic_gradient.py:713: ConvergenceWarning: Maximum number of iteration reached before convergence. Consider increasing max_iter to improve the fit.
#   warnings.warn(
# /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/sklearn/linear_model/_stochastic_gradient.py:713: ConvergenceWarning: Maximum number of iteration reached before convergence. Consider increasing max_iter to improve the fit.
#   warnings.warn(
# /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/sklearn/linear_model/_stochastic_gradient.py:713: ConvergenceWarning: Maximum number of iteration reached before convergence. Consider increasing max_iter to improve the fit.
#   warnings.warn(
# /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/sklearn/linear_model/_stochastic_gradient.py:713: ConvergenceWarning: Maximum number of iteration reached before convergence. Consider increasing max_iter to improve the fit.
#   warnings.warn(
# /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/sklearn/linear_model/_stochastic_gradient.py:713: ConvergenceWarning: Maximum number of iteration reached before convergence. Consider increasing max_iter to improve the fit.
#   warnings.warn(
# /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/sklearn/linear_model/_stochastic_gradient.py:713: ConvergenceWarning: Maximum number of iteration reached before convergence. Consider increasing max_iter to improve the fit.
#   warnings.warn(
# /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/sklearn/linear_model/_stochastic_gradient.py:713: ConvergenceWarning: Maximum number of iteration reached before convergence. Consider increasing max_iter to improve the fit.
#   warnings.warn(
# /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/sklearn/linear_model/_stochastic_gradient.py:713: ConvergenceWarning: Maximum number of iteration reached before convergence. Consider increasing max_iter to improve the fit.
#   warnings.warn(
# /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/sklearn/linear_model/_stochastic_gradient.py:713: ConvergenceWarning: Maximum number of iteration reached before convergence. Consider increasing max_iter to improve the fit.
#   warnings.warn(
# /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/sklearn/linear_model/_stochastic_gradient.py:713: ConvergenceWarning: Maximum number of iteration reached before convergence. Consider increasing max_iter to improve the fit.
#   warnings.warn(
# /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/sklearn/linear_model/_stochastic_gradient.py:713: ConvergenceWarning: Maximum number of iteration reached before convergence. Consider increasing max_iter to improve the fit.
#   warnings.warn(
# /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/sklearn/linear_model/_stochastic_gradient.py:713: ConvergenceWarning: Maximum number of iteration reached before convergence. Consider increasing max_iter to improve the fit.
#   warnings.warn(
# /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/sklearn/linear_model/_stochastic_gradient.py:713: ConvergenceWarning: Maximum number of iteration reached before convergence. Consider increasing max_iter to improve the fit.
#   warnings.warn(
# /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/sklearn/linear_model/_stochastic_gradient.py:713: ConvergenceWarning: Maximum number of iteration reached before convergence. Consider increasing max_iter to improve the fit.
#   warnings.warn(
# /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/sklearn/linear_model/_stochastic_gradient.py:713: ConvergenceWarning: Maximum number of iteration reached before convergence. Consider increasing max_iter to improve the fit.
#   warnings.warn(
# /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/sklearn/linear_model/_stochastic_gradient.py:713: ConvergenceWarning: Maximum number of iteration reached before convergence. Consider increasing max_iter to improve the fit.
#   warnings.warn(
# /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/sklearn/linear_model/_stochastic_gradient.py:713: ConvergenceWarning: Maximum number of iteration reached before convergence. Consider increasing max_iter to improve the fit.
#   warnings.warn(
# /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/sklearn/linear_model/_stochastic_gradient.py:713: ConvergenceWarning: Maximum number of iteration reached before convergence. Consider increasing max_iter to improve the fit.
#   warnings.warn(
# /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/sklearn/linear_model/_stochastic_gradient.py:713: ConvergenceWarning: Maximum number of iteration reached before convergence. Consider increasing max_iter to improve the fit.
#   warnings.warn(
# /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/sklearn/linear_model/_stochastic_gradient.py:713: ConvergenceWarning: Maximum number of iteration reached before convergence. Consider increasing max_iter to improve the fit.
#   warnings.warn(
# /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/sklearn/linear_model/_stochastic_gradient.py:713: ConvergenceWarning: Maximum number of iteration reached before convergence. Consider increasing max_iter to improve the fit.
#   warnings.warn(
# /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/sklearn/linear_model/_stochastic_gradient.py:713: ConvergenceWarning: Maximum number of iteration reached before convergence. Consider increasing max_iter to improve the fit.
#   warnings.warn(
# /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/sklearn/linear_model/_stochastic_gradient.py:713: ConvergenceWarning: Maximum number of iteration reached before convergence. Consider increasing max_iter to improve the fit.
#   warnings.warn(
# /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/sklearn/linear_model/_stochastic_gradient.py:713: ConvergenceWarning: Maximum number of iteration reached before convergence. Consider increasing max_iter to improve the fit.
#   warnings.warn(
# /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/sklearn/linear_model/_stochastic_gradient.py:713: ConvergenceWarning: Maximum number of iteration reached before convergence. Consider increasing max_iter to improve the fit.
#   warnings.warn(
# /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/sklearn/linear_model/_stochastic_gradient.py:713: ConvergenceWarning: Maximum number of iteration reached before convergence. Consider increasing max_iter to improve the fit.
#   warnings.warn(
# /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/sklearn/linear_model/_stochastic_gradient.py:713: ConvergenceWarning: Maximum number of iteration reached before convergence. Consider increasing max_iter to improve the fit.
#   warnings.warn(
# /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/sklearn/linear_model/_stochastic_gradient.py:713: ConvergenceWarning: Maximum number of iteration reached before convergence. Consider increasing max_iter to improve the fit.
#   warnings.warn(
# RandomizedSearchCV(estimator=SGDClassifier(loss='log_loss'), n_iter=20,
#                    n_jobs=-1,
#                    param_distributions={'max_iter': <scipy.stats._distn_infrastructure.rv_discrete_frozen object at 0x141291190>})

# %%
# 하이퍼파라미터 조합별 성능 시각화

# 각 하이퍼파라미터 조합별 교차 검증 스코어 가져오기
results = rs.cv_results_
mean_scores = results['mean_test_score']
params = results['params']

# 시각화를 위한 데이터 준비
max_iter_values = [params[i]['max_iter'] for i in range(len(params))]

# 가로 방향으로 막대 그래프로 교차 검증 스코어 시각화
fig, ax = plt.subplots(figsize=(8, 10))
bars = ax.barh(range(len(mean_scores)), mean_scores, tick_label=[f"{compo}" for compo in max_iter_values])
ax.set_xlabel('Mean CV Accuracy')
ax.set_title('Random Search Scores')
plt.xlim((0, 1))
plt.tight_layout()
plt.show()

# %%
# best score, best model, train score, test score

sc = rs.best_estimator_
print ("best score : ", rs.best_score_)
print ("best estimator (model) : ", sc)

sc_score = [sc.score(X_train_scaled, y_train), sc.score(X_test_scaled, y_test)]
print (f"train score, test score : {sc_score}")
# Out:
# best score :  0.8680555555555556
# best estimator (model) :  SGDClassifier(loss='log_loss', max_iter=16)
# train score, test score : [0.825, 0.8]

# %% [markdown]
# 현재 본 dataset의 feature은 7개이므로, 아래와 같은 linear combination formula를 작성할 수 있다.
#
# $z = w_1 \times f_1 + w_2 \times f_2 +  w_3 \times f_3 +  w_4 \times f_4 +  w_5 \times f_5 +  w_6 \times f_6 +  w_7 \times f_7 + bias$
#
# **결과적으로 7개의 model paramter가 loss function의 global minima에 도달할 때까지 learning rate에 의해 조절되어 가면서, 최적의 weight와 bias를 찾게 되는 것**이다. 이를 조금 더 자세히 구현하고 layer 각각을 디자인하기 위해 Dense를 struction한다.

# %% [markdown]
# -------
#
# ### 2. ANN (fully connected)
# - hidden layer를 구성하지 않고, 입력층과 출력층만 존재하는 인공신경망을 struction할 것이다.
# - 우선, 기존 train set에서 validation set을 하나 더 구성하여 추후 evaluation에 사용할 예정이다.
# - 또한 one-hot encoding하여 target값을 0과 1로 구성하고 loss function은 categorical_crossentropy를 사용한다.
#     - one-hot encoding하는 방식 중 scikit-learn 내장 메소드인 OneHotEncoder를 사용한다.

# %% [markdown]
# #### 2-1) validation set 구성 및 one-hot encoding

# %%
# train set에서 validation set을 하나 더 구성

X_train_scaled, X_val_scaled, y_train, y_val = train_test_split(X_train_scaled, y_train,
                                                               test_size=0.2, 
                                                               stratify=y_train)

print (X_train_scaled.shape, X_val_scaled.shape)
# Out:
# (576, 7) (144, 7)

# %%
# one-hot encoding

from sklearn.preprocessing import OneHotEncoder

y_train = y_train.values.reshape(-1, 1)
y_test = y_test.values.reshape(-1, 1)
y_val = y_val.values.reshape(-1, 1)

encoder = OneHotEncoder(sparse=False)
y_train = encoder.fit_transform(y_train)
y_test = encoder.transform(y_test)
y_val = encoder.transform(y_val)

# kecimen, Besni 이렇게 두 target이니, 제대로 one-hot encoding된 것을 확인 가능
# Out:
# /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/sklearn/preprocessing/_encoders.py:975: FutureWarning: `sparse` was renamed to `sparse_output` in version 1.2 and will be removed in 1.4. `sparse_output` is ignored unless you leave `sparse` to its default value.
#   warnings.warn(

# %% [markdown]
# #### 2-2) modelling, compile, fit

# %%
# modelling

print ("records shape : ", df.iloc[0].shape)

model = keras.Sequential([
    keras.layers.Flatten(input_shape=(7, )), 
    keras.layers.Dense(2, activation='sigmoid')
])

model.summary()
keras.utils.plot_model(model, show_shapes=True)
# Out:
# records shape :  (8,)
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  flatten (Flatten)           (None, 7)                 0
#
#  dense (Dense)               (None, 2)                 16
#
# =================================================================
# Total params: 16 (64.00 Byte)
# Trainable params: 16 (64.00 Byte)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %%
# compile

model.compile(optimizer='adam', loss='binary_crossentropy', metrics='accuracy')

# %%
# fit

history = model.fit(X_train_scaled, y_train, epochs=50, batch_size=20, 
                   validation_data=(X_val_scaled, y_val))

print (history.history)
# Out:
# Epoch 1/50
# 29/29 [==============================] - 0s 6ms/step - loss: 0.9136 - accuracy: 0.2205 - val_loss: 0.9021 - val_accuracy: 0.2569
# Epoch 2/50
# 29/29 [==============================] - 0s 2ms/step - loss: 0.
0.40288108587265015, 0.39917972683906555, 0.3952159583568573, 0.3919932544231415, 0.38900598883628845, 0.38615238666534424, 0.3834213316440582, 0.38096296787261963, 0.3785564601421356, 0.3762483596801758, 0.37397488951683044, 0.37213853001594543, 0.3702438473701477, 0.36850112676620483, 0.36680519580841064, 0.3651580512523651, 0.363702654838562, 0.36230653524398804, 0.36091408133506775, 0.35952359437942505, 0.3583717942237854, 0.35721784830093384, 0.3559514582157135, 0.3550093472003937, 0.35401323437690735], 'val_accuracy': [0.2569444477558136, 0.3055555522441864, 0.3680555522441864, 0.5347222089767456, 0.6736111044883728, 0.6944444179534912, 0.7291666865348816, 0.7569444179534912, 0.7638888955116272, 0.7847222089767456, 0.7916666865348816, 0.7916666865348816, 0.7916666865348816, 0.7986111044883728, 0.7986111044883728, 0.7986111044883728, 0.8194444179534912, 0.8263888955116272, 0.8402777910232544, 0.8402777910232544, 0.8402777910232544, 0.8402777910232544, 0.8333333134651184, 0.8263888955116272, 0.8333333134651184, 0.8333333134651184, 0.8402777910232544, 0.8333333134651184, 0.8402777910232544, 0.8402777910232544, 0.8472222089767456, 0.8541666865348816, 0.8541666865348816, 0.8541666865348816, 0.8472222089767456, 0.8541666865348816, 0.8541666865348816, 0.8611111044883728, 0.8611111044883728, 0.8611111044883728, 0.8680555820465088, 0.8680555820465088, 0.8680555820465088, 0.8680555820465088, 0.8680555820465088, 0.8680555820465088, 0.8680555820465088, 0.8680555820465088, 0.8680555820465088, 0.8680555820465088]}

# %% [markdown]
# #### 2-3) loss 시각화 및 evaluate

# %%
# loss 시각화

plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.xlabel('number of epoch')
plt.ylabel('loss')
plt.legend (['train loss', 'validation loss'])
plt.show()

# %% [markdown]
# 위 그래프를 통해 알 수 있는 사실은 아래와 같다.
#
# - **loss 감소 패턴의 동일성**
#   - train loss과 validation loss 모두 에포크가 진행됨에 따라 감소하고 있음
#   - loss가 줄어든다 -> accuracy가 상승한다.
#
# - **overfitting 여부**
#   - 두 손실 곡선이 비슷한 형태로 감소하고 있고, 검증 손실이 훈련 손실보다 크게 차이나지 않기 때문에, overfitting이 심하게 난다고 볼 수 없음
#   - 만약 에포크가 더 진행되면 overfitting 발생할 가능성도 있음
#
# - **모델 복잡도**
#   - **ANN 모델의 파라미터가 16개밖에 되지 않기 때문에 매우 간단**한 모델
#   - 간단한 모델이기 때문에, 학습이 잘 이루어지고 validation data set에 대한 일반화 성능도 준수한 것

# %%
# evaluate

model.evaluate(X_val_scaled, y_val)
# Out:
# 5/5 [==============================] - 0s 1ms/step - loss: 0.3540 - accuracy: 0.8681
# [0.35401326417922974, 0.8680555820465088]

# %% [markdown]
# -------
#
# ### 3. DNN
# - hidden layer을 충분히 구성하여 신경망을 struction할 것임
#     - parameter는 최소한 15000개 이상으로 증폭, 각 node의 activation은 relu 사용
#     - epoch는 30으로 고정
# - 아래와 같이 experiment할 예정이다.
#     - **(1) hidden layer을 추가하여 DNN 구성**
#         - (1) 기본 경사 하강법
#             - (1-1-1) optimizer : SGD
#             - (1-1-2) optimizer : momentum optimization
#             - (1-1-3) optimizer : nesterov momentum optimization
#             - (1-1-4) 시각화 및 비교
#         - (2) 적응적 학습율
#             - (1-2-1) optimizer : RMSprop (기본값)
#             - (1-2-2) optimizer : Adagrad
#             - (1-2-3) optimizer : Adam
#             - (1-2-4) 시각화 및 비교
#     - **(2) validation loss 감소를 위한 시도**
#         - (1) dropout
#         - (2) callback : early stopping

# %% [markdown]
# #### 3-1) hidden layer를 추가하여 DNN 구성

# %%
# modelling DNN

print ("records shape : ", df.iloc[0].shape)

model = keras.Sequential([
    keras.layers.Flatten(input_shape=(7, )), 
    keras.layers.Dense(256, activation='relu'), 
    keras.layers.Dense(64, activation='relu'),
    keras.layers.Dense(32, activation='relu'),
    keras.layers.Dense(16, activation='relu'),
    keras.layers.Dense(2, activation='sigmoid')
])

model.summary()
keras.utils.plot_model(model, show_shapes=True)
# Out:
# records shape :  (8,)
# Model: "sequential_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  flatten_1 (Flatten)         (None, 7)                 0
#
#  dense_1 (Dense)             (None, 256)               2048
#
#  dense_2 (Dense)             (None, 64)                16448
#
#  dense_3 (Dense)             (None, 32)                2080
#
#  dense_4 (Dense)             (None, 16)                528
#
#  dense_5 (Dense)             (None, 2)                 34
#
# =================================================================
# Total params: 21138 (82.57 KB)
# Trainable params: 21138 (82.57 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %% [markdown]
# ##### 3-1-1) 기본 경사 하강법
# ##### (1-1-1) optimizer : SGD

# %%
# compile, fit

sgd = keras.optimizers.SGD()
model.compile(optimizer=sgd, loss='binary_crossentropy', metrics='accuracy')
history = model.fit(X_train_scaled, y_train, epochs=30, 
                    validation_data=(X_val_scaled, y_val), batch_size=18)

print (history)
# Out:
# Epoch 1/30
# 32/32 [==============================] - 1s 5ms/step - loss: 0.7010 - accuracy: 0.4566 - val_loss: 0.6922 - val_accuracy: 0.5417
# Epoch 2/30
# 32/32 [==============================] - 0s 2ms/step - loss: 0.6820 - accuracy: 0.7066 - val_loss: 0.6700 - val_accuracy: 0.8333
# Epoch 3/30
# 32/32 [==============================] - 0s 2ms/step - loss: 0.6624 - accuracy: 0.8472 - val_loss: 0.6489 - val_accuracy: 0.8681
# Epoch 4/30
# 32/32 [==============================] - 0s 2ms/step - loss: 0.6433 - accuracy: 0.8559 - val_loss: 0.6287 - val_accuracy: 0.8611
# Epoch 5/30
# 32/32 [==============================] - 0s 2ms/step - loss: 0.6239 - accuracy: 0.8628 - val_loss: 0.6076 - val_accuracy: 0.8611
# Epoch 6/30
# 32/32 [==============================] - 0s 2ms/step - loss: 0.6027 - accuracy: 0.8681 - val_loss: 0.5842 - val_accuracy: 0.8611
# Epoch 7/30
# 32/32 [==============================] - 0s 3ms/step - loss: 0.5787 - accuracy: 0.8646 - val_loss: 0.5574 - val_accuracy: 0.8611
# Epoch 8/30
# 32/32 [==============================] - 0s 2ms/step - loss: 0.5519 - accuracy: 0.8681 - val_loss: 0.5280 - val_accuracy: 0.8542
# Epoch 9/30
# 32/32 [==============================] - 0s 2ms/step - loss: 0.5234 - accuracy: 0.8733 - val_loss: 0.4975 - val_accuracy: 0.8611
# Epoch 10/30
# 32/32 [==============================] - 0s 2ms/step - loss: 0.4941 - accuracy: 0.8733 - val_loss: 0.4672 - val_accuracy: 0.8681
# Epoch 11/30
# 32/32 [==============================] - 0s 2ms/step - loss: 0.4652 - accuracy: 0.8767 - val_loss: 0.4385 - val_accuracy: 0.8681
# Epoch 12/30
# 32/32 [==============================] - 0s 2ms/step - loss: 0.4386 - accuracy: 0.8785 - val_loss: 0.4128 - val_accuracy: 0.8681
# Epoch 13/30
# 32/32 [==============================] - 0s 2ms/step - loss: 0.4152 - accuracy: 0.8785 - val_loss: 0.3910 - val_accuracy: 0.8750
# Epoch 14/30
# 32/32 [==============================] - 0s 2ms/step - loss: 0.3952 - accuracy: 0.8802 - val_loss: 0.3734 - val_accuracy: 0.8681
# Epoch 15/30
# 32/32 [==============================] - 0s 2ms/step - loss: 0.3795 - accuracy: 0.8819 - val_loss: 0.3600 - val_accuracy: 0.8681
# Epoch 16/30
# 32/32 [==============================] - 0s 2ms/step - loss: 0.3671 - accuracy: 0.8837 - val_loss: 0.3500 - val_accuracy: 0.8750
# Epoch 17/30
# 32/32 [==============================] - 0s 2ms/step - loss: 0.3577 - accuracy: 0.8872 - val_loss: 0.3427 - val_accuracy: 0.8819
# Epoch 18/30
# 32/32 [==============================] - 0s 2ms/step - loss: 0.3504 - accuracy: 0.8819 - val_loss: 0.3371 - val_accuracy: 0.8819
# Epoch 19/30
# 32/32 [==============================] - 0s 2ms/step - loss: 0.3450 - accuracy: 0.8854 - val_loss: 0.3336 - val_accuracy: 0.8750
# Epoch 20/30
# 32/32 [==============================] - 0s 2ms/step - loss: 0.3412 - accuracy: 0.8819 - val_loss: 0.3310 - val_accuracy: 0.8750
# Epoch 21/30
# 32/32 [==============================] - 0s 2ms/step - loss: 0.3380 - accuracy: 0.8802 - val_loss: 0.3292 - val_accuracy: 0.8750
# Epoch 22/30
# 32/32 [==============================] - 0s 2ms/step - loss: 0.3356 - accuracy: 0.8802 - val_loss: 0.3280 - val_accuracy: 0.8750
# Epoch 23/30
# 32/32 [==============================] - 0s 2ms/step - loss: 0.3336 - accuracy: 0.8819 - val_loss: 0.3272 - val_accuracy: 0.8750
# Epoch 24/30
# 32/32 [==============================] - 0s 2ms/step - loss: 0.3324 - accuracy: 0.8785 - val_loss: 0.3267 - val_accuracy: 0.8750
# Epoch 25/30
# 32/32 [==============================] - 0s 2ms/step - loss: 0.3310 - accuracy: 0.8785 - val_loss: 0.3264 - val_accuracy: 0.8750
# Epoch 26/30
# 32/32 [==============================] - 0s 2ms/step - loss: 0.3295 - accuracy: 0.8785 - val_loss: 0.3263 - val_accuracy: 0.8750
# Epoch 27/30
# 32/32 [==============================] - 0s 2ms/step - loss: 0.3284 - accuracy: 0.8819 - val_loss: 0.3263 - val_accuracy: 0.8750
# Epoch 28/30
# 32/32 [==============================] - 0s 2ms/step - loss: 0.3276 - accuracy: 0.8819 - val_loss: 0.3262 - val_accuracy: 0.8681
# Epoch 29/30
# 32/32 [==============================] - 0s 2ms/step - loss: 0.3268 - accuracy: 0.8819 - val_loss: 0.3263 - val_accuracy: 0.8681
# Epoch 30/30
# 32/32 [==============================] - 0s 2ms/step - loss: 0.3258 - accuracy: 0.8819 - val_loss: 0.3264 - val_accuracy: 0.8681
# <keras.src.callbacks.History object at 0x141bdb590>

# %%
# evaluate

sgd_score = model.evaluate(X_val_scaled, y_val)
print (sgd_score)##### (1-1-2) optimizer : momentum optimization
# Out:
# 5/5 [==============================] - 0s 2ms/step - loss: 0.3264 - accuracy: 0.8681
# [0.32641634345054626, 0.8680555820465088]

# %% [markdown]
# ##### (1-1-2) optimizer : momentum optimization

# %%
# compile, fit

sgd = keras.optimizers.SGD(momentum=0.9)
model.compile(optimizer=sgd, loss='binary_crossentropy', metrics='accuracy')
history = model.fit(X_train_scaled, y_train, epochs=30, 
                    validation_data=(X_val_scaled, y_val), batch_size=18)

print (history)
# Out:
# Epoch 1/30
# 32/32 [==============================] - 1s 5ms/step - loss: 0.3334 - accuracy: 0.8819 - val_loss: 0.3298 - val_accuracy: 0.8611
# Epoch 2/30
# 32/32 [==============================] - 0s 2ms/step - loss: 0.3223 - accuracy: 0.8785 - val_loss: 0.3281 - val_accuracy: 0.8611
# Epoch 3/30
# 32/32 [==============================] - 0s 2ms/step - loss: 0.3177 - accuracy: 0.
30
# 32/32 [==============================] - 0s 2ms/step - loss: 0.2503 - accuracy: 0.8906 - val_loss: 0.3276 - val_accuracy: 0.8681
# Epoch 17/30
# 32/32 [==============================] - 0s 2ms/step - loss: 0.2451 - accuracy: 0.9045 - val_loss: 0.3278 - val_accuracy: 0.8681
# Epoch 18/30
# 32/32 [==============================] - 0s 2ms/step - loss: 0.2513 - accuracy: 0.8958 - val_loss: 0.3220 - val_accuracy: 0.8681
# Epoch 19/30
# 32/32 [==============================] - 0s 2ms/step - loss: 0.2516 - accuracy: 0.8993 - val_loss: 0.3413 - val_accuracy: 0.8611
# Epoch 20/30
# 32/32 [==============================] - 0s 2ms/step - loss: 0.2542 - accuracy: 0.8958 - val_loss: 0.3445 - val_accuracy: 0.8611
# Epoch 21/30
# 32/32 [==============================] - 0s 2ms/step - loss: 0.2466 - accuracy: 0.8958 - val_loss: 0.3309 - val_accuracy: 0.8750
# Epoch 22/30
# 32/32 [==============================] - 0s 2ms/step - loss: 0.2438 - accuracy: 0.9080 - val_loss: 0.3522 - val_accuracy: 0.8542
# Epoch 23/30
# 32/32 [==============================] - 0s 2ms/step - loss: 0.2645 - accuracy: 0.8941 - val_loss: 0.3618 - val_accuracy: 0.8542
# Epoch 24/30
# 32/32 [==============================] - 0s 2ms/step - loss: 0.2535 - accuracy: 0.8958 - val_loss: 0.3590 - val_accuracy: 0.8681
# Epoch 25/30
# 32/32 [==============================] - 0s 2ms/step - loss: 0.2488 - accuracy: 0.8976 - val_loss: 0.3349 - val_accuracy: 0.8681
# Epoch 26/30
# 32/32 [==============================] - 0s 2ms/step - loss: 0.2409 - accuracy: 0.9045 - val_loss: 0.3223 - val_accuracy: 0.8681
# Epoch 27/30
# 32/32 [==============================] - 0s 2ms/step - loss: 0.2362 - accuracy: 0.9167 - val_loss: 0.3409 - val_accuracy: 0.8542
# Epoch 28/30
# 32/32 [==============================] - 0s 2ms/step - loss: 0.2454 - accuracy: 0.9132 - val_loss: 0.3477 - val_accuracy: 0.8542
# Epoch 29/30
# 32/32 [==============================] - 0s 2ms/step - loss: 0.2420 - accuracy: 0.9149 - val_loss: 0.3294 - val_accuracy: 0.8611
# Epoch 30/30
# 32/32 [==============================] - 0s 2ms/step - loss: 0.2640 - accuracy: 0.9010 - val_loss: 0.3471 - val_accuracy: 0.8750
# <keras.src.callbacks.History object at 0x142890610>

# %%
# evaluate

nesterov_score = model.evaluate(X_val_scaled, y_val)
print (nesterov_score)
# Out:
# 5/5 [==============================] - 0s 1ms/step - loss: 0.3471 - accuracy: 0.8750
# [0.3471144437789917, 0.875]

# %% [markdown]
# ##### (1-1-4) 시각화 및 비교

# %%
labels = [
    'SGD loss',
    'momentum optimization loss',
    'nesterov momentum optimization loss',
    'SGD acc',
    'momentum optimization acc',
    'nesterov momentum optimization acc',
]

scores = [compo[0] for compo in [sgd_score, momentum_score, nesterov_score]] + [compo[1] for compo in [sgd_score, momentum_score, nesterov_score]]
print (scores)

plt.barh(labels, scores, color=['red' for i in range(3)] + ['blue' for i in range (3)])

plt.xlabel('percentage')
plt.ylabel('label')
plt.title('acc and loss each optimizers')

plt.show()
# Out:
# [0.32641634345054626, 0.3688969016075134, 0.3471144437789917, 0.8680555820465088, 0.8472222089767456, 0.875]

# %% [markdown]
# ##### 3-1-2) 적응적 학습율
# - 전에 보았던 learning rate는 전부 기본값 0.01로 고정된 채 SGD를 내부적으로 진행한 것
# - 모델이 global minima에 가까이 갈 수록 learning rate를 낮추는 optimizer를 사용하면 전보다 더 나은 성능을 보일 수 있을 것이라고 생각한다
# <br>
#
# ##### (1-2-1) optimizer : RMSprop

# %%
# compile, fit

rmsprop = keras.optimizers.RMSprop()
model.compile(optimizer=rmsprop, loss='binary_crossentropy', metrics='accuracy')
history = model.fit(X_train_scaled, y_train, epochs=30, 
                    validation_data=(X_val_scaled, y_val), batch_size=18)

print (history)
# Out:
# Epoch 1/30
# 32/32 [==============================] - 1s 6ms/step - loss: 0.2618 - accuracy: 0.9045 - val_loss: 0.3213 - val_accuracy: 0.8542
# Epoch 2/30
# 32/32 [==============================] - 0s 2ms/step - loss: 0.2409 - accuracy: 0.9080 - val_loss: 0.3649 - val_accuracy: 0.8611
# Epoch 3/30
# 32/32 [==============================] - 0s 2ms/step - loss: 0.2466 - accuracy: 0.9010 - val_loss: 0.3129 - val_accuracy: 0.8750
# Epoch 4/30
# 32/32 [==============================] - 0s 2ms/step - loss: 0.2443 - accuracy: 0.9115 - val_loss: 0.3438 - val_accuracy: 0.8542
# Epoch 5/30
# 32/32 [==============================] - 0s 2ms/step - loss: 0.2434 - accuracy: 0.9045 - val_loss: 0.3478 - val_accuracy: 0.8611
# Epoch 6/30
# 32/32 [==============================] - 0s 2ms/step - loss: 0.2506 - accuracy: 0.8993 - val_loss: 0.3336 - val_accuracy: 0.8542
# Epoch 7/30
# 32/32 [==============================] - 0s 2ms/step - loss: 0.2458 - accuracy: 0.9080 - val_loss: 0.3645 - val_accuracy: 0.8542
# Epoch 8/30
# 32/32 [==============================] - 0s 2ms/step - loss: 0.2505 - accuracy: 0.9045 - val_loss: 0.3293 - val_accuracy: 0.8750
# Epoch 9/30
# 32/32 [==============================] - 0s 2ms/step - loss: 0.2419 - accuracy: 0.9080 - val_loss: 0.3217 - val_accuracy: 0.8750
# Epoch 10/30
# 32/32 [==============================] - 0s 2ms/step - loss: 0.2458 - accuracy: 0.8976 - val_loss: 0.3230 - val_accuracy: 0.8681
# Epoch 11/30
# 32/32 [==============================] - 0s 2ms/step - loss: 0.2462 - accuracy: 0.9062 - val_loss: 0.3372 - val_accuracy: 0.8611
# Epoch 12/30
# 32/32 [==============================] - 0s 2ms/step - loss: 0.2357 - accuracy: 0.9115 - val_loss: 0.3531 - val_accuracy: 0.8611
# Epoch 13/30
# 32/32 [==============================] - 0s 2ms/step - loss: 0.2439 - accuracy: 0.9045 - val_loss: 0.3510 - val_accuracy: 0.8542
# Epoch 14/30
# 32/32 [==============================] - 0s 2ms/step - loss: 0.2339 - accuracy: 0.
# Epoch 27/30
# 32/32 [==============================] - 0s 2ms/step - loss: 0.1989 - accuracy: 0.9358 - val_loss: 0.3353 - val_accuracy: 0.8750
# Epoch 28/30
# 32/32 [==============================] - 0s 2ms/step - loss: 0.1988 - accuracy: 0.9375 - val_loss: 0.3353 - val_accuracy: 0.8750
# Epoch 29/30
# 32/32 [==============================] - 0s 2ms/step - loss: 0.1988 - accuracy: 0.9358 - val_loss: 0.3352 - val_accuracy: 0.8750
# Epoch 30/30
# 32/32 [==============================] - 0s 2ms/step - loss: 0.1986 - accuracy: 0.9340 - val_loss: 0.3352 - val_accuracy: 0.8750
# <keras.src.callbacks.History object at 0x14299ed50>

# %%
# evaluate

adagrad_score = model.evaluate(X_val_scaled, y_val)
print (adagrad_score)
# Out:
# 5/5 [==============================] - 0s 1ms/step - loss: 0.3352 - accuracy: 0.8750
# [0.3351978063583374, 0.875]

# %% [markdown]
# ##### (1-2-3) optimizer : Adam

# %%
# compile, fit

adam = keras.optimizers.Adam()
model.compile(optimizer=adam, loss='binary_crossentropy', metrics='accuracy')
history = model.fit(X_train_scaled, y_train, epochs=30, 
                    validation_data=(X_val_scaled, y_val), batch_size=18)

print (history)
# Out:
# Epoch 1/30
# 32/32 [==============================] - 1s 5ms/step - loss: 0.2295 - accuracy: 0.9201 - val_loss: 0.3583 - val_accuracy: 0.8681
# Epoch 2/30
# 32/32 [==============================] - 0s 2ms/step - loss: 0.2292 - accuracy: 0.9149 - val_loss: 0.3406 - val_accuracy: 0.8819
# Epoch 3/30
# 32/32 [==============================] - 0s 2ms/step - loss: 0.2270 - accuracy: 0.9132 - val_loss: 0.3640 - val_accuracy: 0.8681
# Epoch 4/30
# 32/32 [==============================] - 0s 2ms/step - loss: 0.2487 - accuracy: 0.8993 - val_loss: 0.3468 - val_accuracy: 0.8819
# Epoch 5/30
# 32/32 [==============================] - 0s 2ms/step - loss: 0.2359 - accuracy: 0.9201 - val_loss: 0.3325 - val_accuracy: 0.8611
# Epoch 6/30
# 32/32 [==============================] - 0s 2ms/step - loss: 0.2175 - accuracy: 0.9184 - val_loss: 0.3255 - val_accuracy: 0.8750
# Epoch 7/30
# 32/32 [==============================] - 0s 2ms/step - loss: 0.2127 - accuracy: 0.9201 - val_loss: 0.3258 - val_accuracy: 0.8750
# Epoch 8/30
# 32/32 [==============================] - 0s 2ms/step - loss: 0.2213 - accuracy: 0.9132 - val_loss: 0.3412 - val_accuracy: 0.8472
# Epoch 9/30
# 32/32 [==============================] - 0s 2ms/step - loss: 0.2163 - accuracy: 0.9184 - val_loss: 0.3294 - val_accuracy: 0.8750
# Epoch 10/30
# 32/32 [==============================] - 0s 2ms/step - loss: 0.2118 - accuracy: 0.9201 - val_loss: 0.3258 - val_accuracy: 0.8750
# Epoch 11/30
# 32/32 [==============================] - 0s 2ms/step - loss: 0.2114 - accuracy: 0.9236 - val_loss: 0.3306 - val_accuracy: 0.8681
# Epoch 12/30
# 32/32 [==============================] - 0s 2ms/step - loss: 0.2044 - accuracy: 0.9236 - val_loss: 0.3422 - val_accuracy: 0.8819
# Epoch 13/30
# 32/32 [==============================] - 0s 2ms/step - loss: 0.2066 - accuracy: 0.9236 - val_loss: 0.3347 - val_accuracy: 0.8750
# Epoch 14/30
# 32/32 [==============================] - 0s 2ms/step - loss: 0.2062 - accuracy: 0.9271 - val_loss: 0.3176 - val_accuracy: 0.8819
# Epoch 15/30
# 32/32 [==============================] - 0s 2ms/step - loss: 0.2137 - accuracy: 0.9184 - val_loss: 0.3385 - val_accuracy: 0.8750
# Epoch 16/30
# 32/32 [==============================] - 0s 2ms/step - loss: 0.2116 - accuracy: 0.9236 - val_loss: 0.3744 - val_accuracy: 0.8611
# Epoch 17/30
# 32/32 [==============================] - 0s 2ms/step - loss: 0.2150 - accuracy: 0.9167 - val_loss: 0.3301 - val_accuracy: 0.8819
# Epoch 18/30
# 32/32 [==============================] - 0s 3ms/step - loss: 0.2084 - accuracy: 0.9253 - val_loss: 0.3572 - val_accuracy: 0.8681
# Epoch 19/30
# 32/32 [==============================] - 0s 2ms/step - loss: 0.2127 - accuracy: 0.9201 - val_loss: 0.3506 - val_accuracy: 0.8750
# Epoch 20/30
# 32/32 [==============================] - 0s 2ms/step - loss: 0.2021 - accuracy: 0.9219 - val_loss: 0.3391 - val_accuracy: 0.8750
# Epoch 21/30
# 32/32 [==============================] - 0s 2ms/step - loss: 0.2025 - accuracy: 0.9253 - val_loss: 0.3446 - val_accuracy: 0.8750
# Epoch 22/30
# 32/32 [==============================] - 0s 2ms/step - loss: 0.1976 - accuracy: 0.9323 - val_loss: 0.3437 - val_accuracy: 0.8750
# Epoch 23/30
# 32/32 [==============================] - 0s 2ms/step - loss: 0.1955 - accuracy: 0.9236 - val_loss: 0.3451 - val_accuracy: 0.8750
# Epoch 24/30
# 32/32 [==============================] - 0s 2ms/step - loss: 0.1908 - accuracy: 0.9288 - val_loss: 0.3510 - val_accuracy: 0.8681
# Epoch 25/30
# 32/32 [==============================] - 0s 2ms/step - loss: 0.1893 - accuracy: 0.9323 - val_loss: 0.3542 - val_accuracy: 0.8819
# Epoch 26/30
# 32/32 [==============================] - 0s 2ms/step - loss: 0.1941 - accuracy: 0.9219 - val_loss: 0.3401 - val_accuracy: 0.8750
# Epoch 27/30
# 32/32 [==============================] - 0s 2ms/step - loss: 0.2011 - accuracy: 0.9219 - val_loss: 0.3607 - val_accuracy: 0.8681
# Epoch 28/30
# 32/32 [==============================] - 0s 2ms/step - loss: 0.1907 - accuracy: 0.9358 - val_loss: 0.3648 - val_accuracy: 0.8681
# Epoch 29/30
# 32/32 [==============================] - 0s 2ms/step - loss: 0.1848 - accuracy: 0.9358 - val_loss: 0.3675 - val_accuracy: 0.9028
# Epoch 30/30
# 32/32 [==============================] - 0s 2ms/step - loss: 0.1957 - accuracy: 0.9288 - val_loss: 0.3635 - val_accuracy: 0.8611
# <keras.src.callbacks.History object at 0x14269ca50>

# %%
# evaluate

adam_score = model.evaluate(X_val_scaled, y_val)
print (adam_score )
# Out:
# 5/5 [==============================] - 0s 1ms/step - loss: 0.3635 - accuracy: 0.8611
# [0.36354339122772217, 0.8611111044883728]

# %% [markdown]
# ##### (2-1-4) 시각화 및 비교

# %%
# visualization

labels = [
    'RMSprop loss',
    'Adagrad loss',
    'Adam loss',
    'RMSprop acc',
    'Adagrad acc',
    'Adam acc',
]

scores = [compo[0] for compo in [rmsprop_score, adagrad_score, adam_score]] + [compo[1] for compo in [rmsprop_score, adagrad_score, adam_score]]
print (scores)

plt.barh(labels, scores, color=['red' for i in range(3)] + ['blue' for i in range (3)])

plt.xlabel('percentage')
plt.ylabel('label')
plt.title('acc and loss each optimizers')

plt.show()
# Out:
# [0.35607850551605225, 0.3351978063583374, 0.36354339122772217, 0.8541666865348816, 0.875, 0.8611111044883728]

# %% [markdown]
# 위 figure을 보고 다음과 같은 사실을 유추 가능하다.
# - **Adagrad의 acc가 가장 높으며, loss도 가장 낮다**
# - Adam의 loss가 가장 높으며, Adagrad의 loss가 가장 낮다.
#
# 동일선상에서 비교하였을 때, 현재 dataset에서의 optimizer는 **adagrad가 적합**하다고 볼 수 있다. 따라서 추후 validation loss 감소를 위한 시도 때에서의 model optimizer는 adagrad를 사용할 것이다.

# %% [markdown]
# #### 3-2) validation loss 감소를 위한 시도
#
# ```sh
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  flatten_6 (Flatten)         (None, 7)                 0
#
#  dense_10 (Dense)            (None, 256)               2048
#
#  dense_11 (Dense)            (None, 64)                16448
#
#  dense_12 (Dense)            (None, 32)                2080
#
#  dense_13 (Dense)            (None, 16)                528
#
#  dense_14 (Dense)            (None, 2)                 34
#
# =================================================================
# ```
# - validation loss 감소를 위하여 아래와 같은 방법을 시도해 볼 것이다.
#     - **dropout**
#         - 위 figure를 보았을 때, dense_11에서 param이 가장 많이 밀집된 것을 확인 가능하다. 따라서 여기서 30%의 dropout을 하여 특정 노드의 의존성을 해제하겠다.
#     - **early stopping**
#         - 5번 연속 검증 점수가 향상되지 않을 시 훈련을 중지할 것이다.

# %%
# optimizer인 adagrad를 이용한 compile, fit 및 loss 시각화
# 여기에선 epoch를 100으로 늘려 fit한다.

adagrad = keras.optimizers.Adagrad()
model.compile(optimizer=adagrad, loss='binary_crossentropy', metrics='accuracy')
history = model.fit(X_train_scaled, y_train, epochs=100, 
                    validation_data=(X_val_scaled, y_val), batch_size=18, verbose=0)

plt.title('adagrad loss plot')
plt.plot (history.history['loss'])
plt.plot (history.history['val_loss'])
plt.xlabel ('number of epoch')
plt.ylabel ('loss')
plt.legend(['train loss', 'validation loss'])

plt.show()

# %% [markdown]
# **일단 되게 난감한 상황인게, validation loss가 epoch가 늘어남에 따라서 계속적으로 우상향하고 있다.** 이는 즉 학습을 거듭할 수록 overfitting되어가고 있다는 의미인데, 이를 해결하기 위하여 dropout해보자.

# %% [markdown]
# ##### 3-2-1) dropout

# %%
# modelling DNN + dropout

print ("records shape : ", df.iloc[0].shape)

model = keras.Sequential([
    keras.layers.Flatten(input_shape=(7, )), 
    keras.layers.Dense(256, activation='relu'), 
    keras.layers.Dense(64, activation='relu'),
    keras.layers.Dropout(0.3),  # dropout 층 추가
    keras.layers.Dense(32, activation='relu'),
    keras.layers.Dense(16, activation='relu'),
    keras.layers.Dense(2, activation='sigmoid')
])

model.summary()
keras.utils.plot_model(model, show_shapes=True)
# Out:
# records shape :  (8,)
# Model: "sequential_2"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  flatten_2 (Flatten)         (None, 7)                 0
#
#  dense_6 (Dense)             (None, 256)               2048
#
#  dense_7 (Dense)             (None, 64)                16448
#
#  dropout (Dropout)           (None, 64)                0
#
#  dense_8 (Dense)             (None, 32)                2080
#
#  dense_9 (Dense)             (None, 16)                528
#
#  dense_10 (Dense)            (None, 2)                 34
#
# =================================================================
# Total params: 21138 (82.57 KB)
# Trainable params: 21138 (82.57 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %%
# 재학습 및 재시각화

adagrad = keras.optimizers.Adagrad()
model.compile(optimizer=adagrad, loss='binary_crossentropy', metrics='accuracy')
history = model.fit(X_train_scaled, y_train, epochs=100, 
                    validation_data=(X_val_scaled, y_val), batch_size=18, verbose=0)

plt.title('(dropout) adagrad loss plot')
plt.plot (history.history['loss'])
plt.plot (history.history['val_loss'])
plt.xlabel ('number of epoch')
plt.ylabel ('loss')
plt.legend(['train loss', 'validation loss'])

plt.show()

# %% [markdown]
# **overfitting을 막았다.** validation loss는 완벽한 우하향 곡선을 띄고 있는데, 계속적으로 감소하고 있으며 음의 무한대로 발산하고 있다.

# %%
# confusion matrix 및 report

from sklearn.metrics import classification_report, confusion_matrix

y_pred = np.argmax(model.predict(X_test_scaled), axis=1)
y_test_labels = np.argmax(y_test, axis=1) if y_test.ndim > 1 else y_test

print (classification_report(y_test_labels, y_pred))
print (confusion_matrix(y_test_labels, y_pred))
# Out:
# 6/6 [==============================] - 0s 1ms/step
#               precision    recall  f1-score   support
#
#            0       0.87      0.80      0.83        90
#            1       0.81      0.88      0.84        90
#
#     accuracy                           0.84       180
#    macro avg       0.84      0.84      0.84       180
# weighted avg       0.84      0.84      0.84       180
#
# [[72 18]
#  [11 79]]

# %% [markdown]
# ##### 3-2-2) early stopping

# %%
# ModelCheckpoint와 EarlyStopping 메소드를 차례대로 사용하여 구현

model.compile(loss='binary_crossentropy', metrics='accuracy')

checkpoint_cb = keras.callbacks.ModelCheckpoint('./model/classification_raisin_model_best.h5', save_best_only=True)
early_stopping_cb = keras.callbacks.EarlyStopping(patience=5, 
                                                 restore_best_weights=True)

history = model.fit(X_train_scaled, y_train, epochs=100, 
                    validation_data=(X_val_scaled, y_val),
                   callbacks=[checkpoint_cb, early_stopping_cb], verbose=0)

print ("best epochs : ", early_stopping_cb.stopped_epoch)
# Out:
# /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/keras/src/engine/training.py:3103: UserWarning: You are saving your model as an HDF5 file via `model.save()`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')`.
#   saving_api.save_model(
# best epochs :  5

# %%
# 시각화

plt.title('(early stopping) adagrad loss plot')
plt.plot (history.history['loss'])
plt.plot (history.history['val_loss'])
plt.xlabel ('number of epoch')
plt.ylabel ('loss')
plt.legend(['train loss', 'validation loss'])

plt.show()

# %% [markdown]
# -------
#
# ### 4. CNN
# - convolution을 이용하여 유용한 feature을 드러내게 한 후, 그에 따른 유의미한 학습을 진행한다.
# - 아래와 같이 진행한다.
#     - **(1) reshape and data preparing, label encoding**
#     - **(2) modelling**
#     - **(3) compile, fit**
#     - **(4) evaluation**

# %% [markdown]
# #### 4-1) reshape and data preparing, label encoding
# - 현재 raisin dataset은 7개의 특성, 1개의 label(target)을 지닌다. CNN으로 하기에 적합하다고 보기 어렵다.
#     - 따라서 X_image라고 하는 변수를 만들어, (1, 7, 1) 크기로 redesign한 후에 CNN을 진행한다.
#     - train set, validation set, test set을 준비한다.
#     - label encoding을 통하여 y의 값을 encoding한다.

# %%
# input, target을 scaling 및 reshape

ss = StandardScaler()
raisin_input = ss.fit_transform(raisin_input)
X_images = raisin_input.reshape(-1, 7, 1, 1)  # (samples, height, width, channels)

# %%
# label encoding

from sklearn.preprocessing import LabelEncoder

le = LabelEncoder()
raisin_target = le.fit_transform(raisin_target)

# %%
# dataset 분리

X_train, X_test, y_train, y_test = train_test_split(X_images, raisin_target, 
                                                    test_size=0.2, stratify=raisin_target)

# %%
# validation set 분리

X_train, X_val, y_train, y_val = train_test_split(X_train, y_train, 
                                                    test_size=0.2)

# %% [markdown]
# #### 4-2) modelling
# - 아래와 같이 modelling한다.
#     - **convolution layers (feature extractor)**
#         - (1) Conv2D로 convolution한 feature map을 생성
#             - filter : 32개
#             - kernel_size : (3, 1)
#             - activation : relu
#             - padding : same
#                 - 입력과 feature map (출력)의 크기를 동일히 하기 위함
#         - (2) MaxPooling2D로 각 pooling area마다 중요한 instance get
#             - pooling area size : (2, 1)
#         - (3) 다시 Conv2D로 convolution
#             - filter : 64개
#             - 나머지는 (1)과 동일
#         - (4) MaxPooling2D ((2)와 동일)
#         - **보류 : Negative dimension size caused by subtracting 2 from 1 오류로 인한 보류**
#             - (5) 다시 Conv2D로 convolution
#                 - filter : 128개
#                 - 나머지는 (1)과 동일
#             - (6) MaxPooling2D ((2)와 동일)
#     - **dense layers (classification)**
#         - Flatten
#         - (1) dense
#             - 128개의 뉴런, activation : relu
#         - (2) dropout
#             - 40% dropout
#         - (3) dense
#             - 64개의 뉴런, activation : relu
#         - (4) dropout
#             - 40% dropout
#         - (5) dense
#             - 32개의 뉴런, activation : relu
#         - (6) dense (output layer)
#             - 1개 (이진 분류), activation : sigmoid

# %%
# modelling

model = keras.Sequential([
    keras.layers.Conv2D(32, (3, 1), activation='relu', padding='same', input_shape=(7, 1, 1)),
    keras.layers.MaxPooling2D((2, 1)),
    keras.layers.Conv2D(64, (3, 1), activation='relu', padding='same'),
    keras.layers.MaxPooling2D((2, 1)),
#     keras.layers.Conv2D(128, (3, 1), activation='relu', padding='same'),
#     keras.layers.MaxPooling2D((2, 1)),
    keras.layers.Flatten(),
    keras.layers.Dense(128, activation='relu'),
    keras.layers.Dropout(0.4),
    keras.layers.Dense(64, activation='relu'),
    keras.layers.Dropout(0.4),
    keras.layers.Dense(32, activation='relu'),
    keras.layers.Dense(1, activation='sigmoid')  # 이진 분류
])

model.summary()
keras.utils.plot_model(model, show_shapes=True,
                      show_layer_names=True, show_layer_activations=True)
# Out:
# Model: "sequential_6"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d_8 (Conv2D)           (None, 7, 1, 32)          128
#
#  max_pooling2d_8 (MaxPoolin  (None, 3, 1, 32)          0
#  g2D)
#
#  conv2d_9 (Conv2D)           (None, 3, 1, 64)          6208
#
#  max_pooling2d_9 (MaxPoolin  (None, 1, 1, 64)          0
#  g2D)
#
#  flatten_6 (Flatten)         (None, 64)                0
#
#  dense_20 (Dense)            (None, 128)               8320
#
#  dropout_7 (Dropout)         (None, 128)               0
#
#  dense_21 (Dense)            (None, 64)                8256
#
#  dropout_8 (Dropout)         (None, 64)                0
#
#  dense_22 (Dense)            (None, 32)                2080
#
#  dense_23 (Dense)            (None, 1)                 33
#
# =================================================================
# Total params: 25025 (97.75 KB)
# Trainable params: 25025 (97.75 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %% [markdown]
# #### 4-3) compile, fit
# - compile은 다음과 같이 진행한다.
#     - optimizer는 적응형 학습율 optimizer인 adagrad을 사용한다.
# - overfitting을 방지하고자 early stopping callback을 추가할 것이다.
#     - patience를 3으로 한다.
#     - epochs는 200으로 한정한다.

# %%
# compile and fit

model.compile (optimizer='adagrad', loss='binary_crossentropy',
              metrics='accuracy')
early_stopping_cb = keras.callbacks.EarlyStopping(patience=3,
                                                 restore_best_weights=True)

history = model.fit (X_train, y_train, epochs=200,
                    validation_data=(X_val, y_val),
                    callbacks=[early_stopping_cb], verbose=2)
# Out:
# Epoch 1/200
# 18/18 - 1s - loss: 0.6972 - accuracy: 0.4306 - val_loss: 0.6941 - val_accuracy: 0.5347 - 599ms/epoch - 33ms/step
# Epoch 2/200
# 18/18 - 0s - loss: 0.6939 - accuracy: 0.4653 - val_loss: 0.6917 - val_accuracy: 0.5347 - 51ms/epoch - 3ms/step
# Epoch 3/200
# 18/18 - 0s - loss: 0.6921 - accuracy: 0.4774 - val_loss: 0.6894 - val_accuracy: 0.5347 - 49ms/epoch - 3ms/step
# Epoch 4/200
# 18/18 - 0s - loss: 0.6899 - accuracy: 0.4635 - val_loss: 0.6870 - val_accuracy: 0.5347 - 49ms/epoch - 3ms/step
# Epoch 5/200
# 18/18 - 0s - loss: 0.6860 - accuracy: 0.5139 - val_loss: 0.6847 - val_accuracy: 0.5347 - 49ms/epoch - 3ms/step
# Epoch 6/200
# 18/18 - 0s - loss: 0.6842 - accuracy: 0.4722 - val_loss: 0.6827 - val_accuracy: 0.5417 - 51ms/epoch - 3ms/step
# Epoch 7/200
# 18/18 - 0s - loss: 0.6837 - accuracy: 0.5174 - val_loss: 0.6807 - val_accuracy: 0.5417 - 48ms/epoch - 3ms/step
# Epoch 8/200
# 18/18 - 0s - loss: 0.6833 - accuracy: 0.4931 - val_loss: 0.6788 - val_accuracy: 0.5347 - 48ms/epoch - 3ms/step
- val_accuracy: 0.8125 - 51ms/epoch - 3ms/step
# Epoch 195/200
# 18/18 - 0s - loss: 0.3582 - accuracy: 0.8628 - val_loss: 0.3735 - val_accuracy: 0.8125 - 51ms/epoch - 3ms/step
# Epoch 196/200
# 18/18 - 0s - loss: 0.3713 - accuracy: 0.8628 - val_loss: 0.3733 - val_accuracy: 0.8125 - 48ms/epoch - 3ms/step
# Epoch 197/200
# 18/18 - 0s - loss: 0.3657 - accuracy: 0.8663 - val_loss: 0.3731 - val_accuracy: 0.8125 - 48ms/epoch - 3ms/step
# Epoch 198/200
# 18/18 - 0s - loss: 0.3740 - accuracy: 0.8594 - val_loss: 0.3728 - val_accuracy: 0.8125 - 50ms/epoch - 3ms/step
# Epoch 199/200
# 18/18 - 0s - loss: 0.3653 - accuracy: 0.8542 - val_loss: 0.3726 - val_accuracy: 0.8125 - 46ms/epoch - 3ms/step
# Epoch 200/200
# 18/18 - 0s - loss: 0.3636 - accuracy: 0.8524 - val_loss: 0.3724 - val_accuracy: 0.8125 - 53ms/epoch - 3ms/step

# %% [markdown]
# #### 4-4) evaluation
# - validation loss와 train loss를 시각화
# - validation evalutaion, test evaluation
# - report 및 confusion matrix 시각화

# %%
# validation loss와 train loss의 시각화

plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.legend(['train loss', 'validation loss'])
plt.show()

# %%
# validation evalutaion과 test evaluation

print(X_val.shape, X_test.shape)

score_val = model.evaluate(X_val, y_val)
score_test = model.evaluate(X_test, y_test)

print (f"validation evaluation : {score_val}")
print (f"test evaluation : {score_test}")
# Out:
# (144, 7, 1, 1) (180, 7, 1, 1)
# 5/5 [==============================] - 0s 2ms/step - loss: 0.3724 - accuracy: 0.8125
# 6/6 [==============================] - 0s 2ms/step - loss: 0.3981 - accuracy: 0.8444
# validation evaluation : [0.37242138385772705, 0.8125]
# test evaluation : [0.39812931418418884, 0.8444444537162781]

# %%
# confusion matrix 및 report
# validation dataset과 test dataset을 따로 report 및 matrix drawing

y_val_pred_probs = model.predict(X_val)
y_test_pred_probs = model.predict(X_test)
y_val_pred = (y_val_pred_probs > 0.5).astype(int)
y_test_pred = (y_test_pred_probs > 0.5).astype(int)

print ()

cm_val = confusion_matrix(y_val, y_val_pred)
print ("- validation data confusion matrix -\n")
print (cm_val)

print ('\n --------------- \n')

cm_test = confusion_matrix(y_test, y_test_pred)
print ("- test data confusion matrix -\n")
print (cm_test)

print ('\n --------------- \n')

cr_val = classification_report(y_val, y_val_pred, target_names=['besni', 'kecimen'])
print ("- validation data report of classification -\n")
print (cr_val)

print ('\n --------------- \n')

cr_test = classification_report(y_test, y_test_pred, target_names=['besni', 'kecimen'])
print ("- test data report of classification -\n")
print (cr_test)
# Out:
# 5/5 [==============================] - 0s 1ms/step
# 6/6 [==============================] - 0s 1ms/step
#
# - validation data confusion matrix -
#
# [[61 16]
#  [11 56]]
#
#  ---------------
#
# - test data confusion matrix -
#
# [[72 18]
#  [10 80]]
#
#  ---------------
#
# - validation data report of classification -
#
#               precision    recall  f1-score   support
#
#        besni       0.85      0.79      0.82        77
#      kecimen       0.78      0.84      0.81        67
#
#     accuracy                           0.81       144
#    macro avg       0.81      0.81      0.81       144
# weighted avg       0.81      0.81      0.81       144
#
#
#  ---------------
#
# - test data report of classification -
#
#               precision    recall  f1-score   support
#
#        besni       0.88      0.80      0.84        90
#      kecimen       0.82      0.89      0.85        90
#
#     accuracy                           0.84       180
#    macro avg       0.85      0.84      0.84       180
# weighted avg       0.85      0.84      0.84       180
