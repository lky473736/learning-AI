# %% [markdown]
# ## learning-AI101 : topic1_5
#
# 근데 hidden layer가 있나없나 결과가 비슷함 (형태가 유지됨 - 선형성)
# -> 따라서 **activation function 도입** (형태가 유지가 안됨 - 비선형성)
# activation function은 비선형적이게 바꾸는 수식일 뿐임
# ![image.png](attachment:19567ea2-3d34-478e-b0a4-3aaa4ce689e1.png)
# **activation function 종류 (이차전지와 인공지능)**
# - sigmoid (기울기 소실 발생 - overfitting)
# - ReLU (힌튼, 기울기 소실 x)
#
# 솔직히 선형적이고 단순한 예측은 activation function이 필요가 없음 (선형회귀)
# 하지만 비선형적이고 복잡한 예측은 반드시 activation function이 필수불가결 (딥러닝은 다 있음)

# %%
# 단순 선형회귀 예제
# Y = aX + b
