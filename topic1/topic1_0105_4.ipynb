# %% [markdown]
# ## learning-AI101 : topic1_4
# 그래서 결국 hidden layer 많으면 더 정교해짐
#
# weighted_sum == 가중치랑 전의 노드값들의 시그마
# > $h = \displaystyle\sum_{i=1}^{k}{(a_i * w_i)}$
# **loss function 이용해서 오차를 최소화하는 weight를 인공지능이 찾을거임**

# %% [markdown]
# **loss function(손실함수) - 함수의 정확도를 평가하는 기준**
# 기본 전제는 데이터. 실제 데이터가 있어야 인공지능이 실제 데이터의 방향대로 weight를 조절할 것임
# - 평균 **제곱** 오차
# - 오차 **제곱**법
# - 제곱하는 이유 : 오차가 음수가 될 수 있음 + overfitting 방지
#
# ![스크린샷 2024-01-05 오후 1.58.04.png](attachment:3dc249c6-2ff4-46f8-9a8a-b895a74aa3cb.png)
#
# - 위는 평균 제곱 오차 수식. hat variable이 보통은 예측한 값.
# - 예측한 값과 실제 데이터와의 차이를 제곱하여 다 더한걸 1/n
